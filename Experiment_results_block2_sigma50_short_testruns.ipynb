# %% [markdown]
# #  Hydra Multi-Asset Monte Carlo Experiment with varying trade sizes

# %% [markdown]
# # Testcase Definition
#
# #### Simulation Settings
# - There are 100 timesteps for each simulation run
# - Each testcase has 10 MC runs with different randomized variables
# - Block 2 randomizes trade sizes
#
#
#
# #### Agent Activities - Action Sequence
#
# There are two agents acting during the simulation. The trading agent performs "R-for-R" trades of varying direction and size over most simulation timesteps. The liquidity agent provides liquidity to the pool at timestep 10 and removes the liquidity from the pool at timestep 90.
#
# ##### Trading agent
#
# - One Agent performs random "R-for-R" trades during the simulation.
# - The direction of the trade is a random coin flip for each timestep.
# - The size of the trade is drawn from $\mathcal{N}(\mu, \sigma)$ for each timestep.
# - The agent does not act at timestep 10 nor timestep 90.
#
# ##### Liquidity agent
#
# - One Agent provides liquidity in Risk asset "i" to the pool
# - He provides the liquidity at timestep 10
# - He removes the liquidity at timestep 90
# - He does not act at other timesteps
#
# #### Block 2:
# | #   | Run | a |  $\mu_i$  | $\sigma_i$ |  $\mu_j$  | $\sigma_j$ | $\mu$   | $\sigma$ | Total runs |
# | --- |:---:|:-------:|:---------:|:----------:|:---------:|:----------:| ------- | -------- | ---------- |
# | 1   | 01 - 10    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$       |
# | 2   | 11 - 20    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 3   | 21 - 30    |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 4  |  31 - 40   |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 5  | 41 - 50    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 6  | 51 - 60    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
#
# All tests in block 2 are performed as $10$ Monte-Carlo runs for the given parameters which results in $60$ runs in total.

# %% [markdown]
# ## Run Model

# %%
from model.config_wrapper import ConfigWrapper

from model import run_wrapper
from cadCAD import configs

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# df = run.run()
# rdf = run.postprocessing(df)
# rdf = df # debugging substeps
# pd.set_option("mode.chained_assignment", None)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py

# %%
(data, tensor_field, sessions) = run_wrapper.run(drop_midsteps=True)

experiments = data
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 2
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 15, 2, 24)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 1, 1]
# SubsetIDs: [0, 0, 1, 1]
# Ns       : [0, 1, 0, 1]
# ExpIDs   : [0, 0, 0, 0]
# Execution Mode: parallelized
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1974, 'ri_sold': 987, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of   R added to pool of  i  =  1050
#  R removed from pool of  j  =  16380.430836353917
# i{'q_sold': 2130, 'ri_sold': 4260, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of   =  987
#  R removed from pool of  j  =  15412.112282068469
#  {'q_sold': 2306, 'ri_sold': 4612, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j  =  4260
#  R removed from pool of  i  =  276.27648867690004
# {'q_sold': 1954, 'ri_sold': 3908, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  j  =  3908
#  R removed from pool of   R added to pool of i  =  251.44930871995166
#  j  =  4612
#  R removed from pool of  i  =  298.4414207537193
# {'q_sold': 1954, 'ri_sold': 3908, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# {'q_sold': 2316, 'ri_sold': 1158, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  j  =  3908
#  R removed from pool of  i  =  250.8084233700065
# {'q_sold': 2154, 'ri_sold': 4308, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  1158
#  R removed from pool of  j  =  17755.910291042645
# {'q_sold': 1908, 'ri_sold': 3816, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4308
#  R removed from pool of  i  =  274.29953857162036
#  R added to pool of  j  =  3816
#  R removed from pool of  {'q_sold': 2110, 'ri_sold': 1055, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of i i  =  1055
#  R removed from pool of  j  =  16376.491080523934
#  {'q_sold': 1908, 'ri_sold': 3816, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} =  252.268131034798
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  954
#  R removed from pool of  j  =  14282.334835263202
#  {'q_sold': 2050, 'ri_sold': 4100, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j  =  3816
#  R removed from pool of  i  =  248.8341646041954
# {'q_sold': 1618, 'ri_sold': 3236, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  j  =  4100
#  R removed from pool of  i  =  276.6241061765468
# {'q_sold': 1656, 'ri_sold': 3312, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  R added to pool of   j  =  3312
#  R removed from pool of  i  =  221.8232136084698
# {'q_sold': 1888, 'ri_sold': 3776, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j
#  R to R swap called
#   R added to pool of  j  =  3776
#  R removed from pool of  i  =  251.1374716318678
#  = {'q_sold': 1798, 'ri_sold': 899, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'} 3236
#
#  R removed from pool of  i  =  209.5711915899301
# {'q_sold': 2064, 'ri_sold': 4128, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}{'q_sold': 1820, 'ri_sold': 910, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#
#  R to R swap called
#  R to R swap called
#  R added to pool of  R added to pool of   i  =  910
#  R removed from pool of  j  =  13550.89993313537
# {'q_sold': 1718, 'ri_sold': 3436, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j
#  R to R swap called
#   R added to pool of  =  4128
#  R removed from pool of  i  =  265.4394488526741
# {'q_sold': 2294, 'ri_sold': 1147, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
# j  =  3436
#  R removed from pool of  i  =  233.05384487775154
# {'q_sold': 1956, 'ri_sold': 978, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  978
#  R removed from pool of  j  =  14263.712211642182
#  i  =  1147
#  R removed from pool of  j  =  17604.663051052252
# {'q_sold': 2014, 'ri_sold': 1007, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'}{'q_sold': 1716, 'ri_sold': 858, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#
#  R to R swap called
#  R added to pool of  {'q_sold': 1892, 'ri_sold': 3784, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}i
#   =  858 R to R swap called
#  R added to pool of
# j R removed from pool of  j  =   12185.200918163988
# {'q_sold': 2024, 'ri_sold': 4048, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} =
#  R to R swap called
#  R added to pool of  j  =  4048
#  3784
#  R removed from pool of  i  =  249.877077907091
#  R removed from pool of {'q_sold': 1770, 'ri_sold': 3540, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} i
#  R to R swap called
#   =  287.3881009644829
# {'q_sold': 2076, 'ri_sold': 4152, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R added to pool of  j  =  3540
#  R removed from pool of  i  =  232.09891529707238
# {'q_sold': 1880, 'ri_sold': 3760, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#  R to R swap called
#  R added to pool of
#  j  =  3760
#  R removed from pool of  i  =  244.77940467279404
# {'q_sold': 1942, 'ri_sold': 3884, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  4152
#  R removed from pool of  i  =  292.32717993087135
# {'q_sold': 1880, 'ri_sold': 3760, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} j  =  3884
#  R removed from pool of
#  R to R swap called
#  R added to pool of  j  =  3760
#  R removed from pool of  i  =  262.6185741957743
#  i  =  250.98681597877294
# {'q_sold': 2372, 'ri_sold': 4744, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  R to R swap called
#  j  =  4744
#  R removed from pool of  i  =  328.5234109873418
# {'q_sold': 1790, 'ri_sold': 3580, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  999
#  R removed from pool of  j  =  15288.625925970846
# {'q_sold': 2166, 'ri_sold': 1083, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of  j  =  3580
#  R removed from pool of  i  =  245.85677952645347
#
# {'q_sold': 1756, 'ri_sold': 3512, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  3512
#  R removed from pool of  i  =  239.48661292972974
#  {'q_sold': 2042, 'ri_sold': 4084, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}i  =  1083
#  R removed from pool of  j  =  16072.022520390572
#
# {'q_sold': 1610, 'ri_sold': 3220, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R to R swap called
#  R added to pool of  j  =  4084
#  R removed from pool of  i  =  276.39832999627106
#  R added to pool of {'q_sold': 1736, 'ri_sold': 868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  3220
#  R removed from pool of  i  =  219.74878314742818
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R added to pool of  i  =  1020
#  R removed from pool of  j  =  14773.810499069747
#  R to R swap called
#  R added to pool of  i  =  868
#  R removed from pool of  j  =  12715.357723145979
# {'q_sold': 2148, 'ri_sold': 4296, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# {'q_sold': 2036, 'ri_sold': 4072, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  4296
#  R removed from pool of  i  =  299.72555034188554
#  {'q_sold': 1978, 'ri_sold': 989, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}j  =  4072
#  R removed from pool of  i  =  280.36961121624336
#
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R to R swap called
#  R added to pool of  i  =  970
#  R removed from pool of  j  =  13948.375594681711
#  R added to pool of {'q_sold': 1706, 'ri_sold': 3412, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} i  =  989
#  R removed from pool of  j  =  14035.897103475756
#
# {'q_sold': 1858, 'ri_sold': 929, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R to R swap called  R added to pool of
#  j  =  3412
#  R removed from pool of  i  =  239.803053969983
# {'q_sold': 1908, 'ri_sold': 3816, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of  i  =  929
#  R removed from pool of  j  =  12827.672224752023
#
# {'q_sold': 2212, 'ri_sold': 1106, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R to R swap called
#  R added to pool of  j  =  3816
#  R removed from pool of  i  =  266.246110284701
# {'q_sold': 2070, 'ri_sold': 1035, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1106
#  R removed from pool of  j  =  14839.457740931539
# {'q_sold': 1648, 'ri_sold': 3296, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#   R added to pool of i  =  1035
#  R removed from pool of  j  =  14671.512511015637
# {'q_sold': 2066, 'ri_sold': 1033, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of j i   =  3296
#  R removed from pool of  i  =  248.6317832726054
# {'q_sold': 1924, 'ri_sold': 962, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} =
#  R to R swap called
#  R added to pool of   i  =  962
#  R removed from pool of  j  =  12627.31259549607
# {'q_sold': 1866, 'ri_sold': 3732, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}1033
#  R to R swap called
#
#  R added to pool of  R removed from pool of  j  =  14216.967759382562
# {'q_sold': 2124, 'ri_sold': 1062, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
# j R added to pool of   =  3732
#  R removed from pool of  i  =  287.0023133554496
# {'q_sold': 2208, 'ri_sold': 4416, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of i j  =  4416
#  R removed from pool of  i  =  336.6813809177838
# {'q_sold': 2188, 'ri_sold': 4376, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  =  1062
#  R removed from pool of  j  =  14190.873963731225
# {'q_sold': 1834, 'ri_sold': 3668, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R added to pool of  R to R swap called
#  j  R added to pool of  =  j  =  3668
#  R removed from pool of  i  =  277.539062659489
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} 4376
#  R removed from pool of
#  R to R swap called
# i  =  330.5491212680936
# {'q_sold': 2068, 'ri_sold': 1034, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  i  =  970
#  R to R swap called
#  R removed from pool of  j  =  12697.37831055699
# {'q_sold': 2196, 'ri_sold': 4392, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  R added to pool of   j  =  4392
#  R removed from pool of  i  =  338.48029477894306
# {'q_sold': 1906, 'ri_sold': 953, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}i
#  R to R swap called
#  R added to pool of   i  =  953
#  R removed from pool of  j  =  12261.891756466706
# {'q_sold': 1964, 'ri_sold': 982, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} =
#  R to R swap called
#  R added to pool of   i  =  982
#  R removed from pool of  j 1034
#  R removed from pool of  =  12304.94835032802
#  {'q_sold': 1780, 'ri_sold': 3560, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j  =  13555.99765794049
# {'q_sold': 1762, 'ri_sold': 881, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#
#  R to R swap called
#  R to R swap called
#  R added to pool of  R added to pool of   j  =  3560
#  R removed from pool of  i  =  286.81115515949205
# {'q_sold': 2164, 'ri_sold': 4328, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}i
#  R to R swap called
#  R added to pool of   j  =  4328
#  R removed from pool of  i  =  345.70483164070174
# {'q_sold': 2272, 'ri_sold': 4544, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} =
#  R to R swap called
#  881
#  R removed from pool of  j  =  11248.785447123228
# {'q_sold': 1986, 'ri_sold': 993, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of  j  =  4544
#  R removed from pool of  i  =  359.4875561541412
#
#  R to R swap called
#  R added to pool of {'q_sold': 2202, 'ri_sold': 1101, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} i  =  993
#  R removed from pool of  j  =  12359.029620028217
#
#  R to R swap called
# {'q_sold': 2074, 'ri_sold': 4148, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  R added to pool of   j  =  4148i  =  1101
#  R removed from pool of  j  =  13777.674448347301
#
# {'q_sold': 1872, 'ri_sold': 936, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R removed from pool of  i  =  336.26352635142393
#
# {'q_sold': 2074, 'ri_sold': 1037, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R to R swap called
#  R added to pool of  i  =  1037
#  R removed from pool of  j  =  12672.292179759941
#  R added to pool of  i  =  936
#  R removed from pool of  j  =  11394.843843449722
# {'q_sold': 2308, 'ri_sold': 1154, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
# {'q_sold': 1994, 'ri_sold': 3988, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  1154
#  R removed from pool of  j  =  13695.439977050293
# {'q_sold': 2314, 'ri_sold': 1157, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  R to R swap called
#  j  =  3988
#  R removed from pool of  i  =  330.2645685393363
# {'q_sold': 1478, 'ri_sold': 2956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  1157
#  R removed from pool of  j  =  13319.13343380799
# {'q_sold': 2166, 'ri_sold': 1083, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  j  =  2956
#  R removed from pool of  i  =  242.927717495244
# {'q_sold': 2018, 'ri_sold': 1009, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1083
#  R removed from pool of  j  =  12109.277071841643
#  R added to pool of  i  =  1009
#  R removed from pool of  j  =  12152.94943574979
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1942, 'ri_sold': 971, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  i  =  971
#  R removed from pool of  j  =  10574.262112049852
# {'q_sold': 1604, 'ri_sold': 3208, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  1010
#  R removed from pool of  j  =  11843.188390859985
#  {'q_sold': 1958, 'ri_sold': 979, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}j  =  3208
#  R removed from pool of  i  =  297.13005005801097
# {'q_sold': 2072, 'ri_sold': 4144, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R added to pool of  i  =  979
#  R removed from pool of  j  =  11183.93856679101
#  R to R swap called {'q_sold': 2296, 'ri_sold': 1148, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#
#  R to R swap called
#  R added to pool of  j  =  4144
#  R removed from pool of  i  =  380.52359759411775
# {'q_sold': 1898, 'ri_sold': 949, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1148
#  R removed from pool of  j  =  12758.095234021195
# {'q_sold': 1840, 'ri_sold': 920, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  949
#  R removed from pool of  j  =  10260.556020524702
# {'q_sold': 1900, 'ri_sold': 950, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  920
#  R removed from pool of  j  =  9956.86542554712
# {'q_sold': 2184, 'ri_sold': 4368, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  950
#  R removed from pool of  j  =  10027.479080571444
#  R added to pool of  j  =  4368
#  R removed from pool of  i  =  406.2517882466782
# {'q_sold': 2066, 'ri_sold': 1033, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
# {'q_sold': 1896, 'ri_sold': 3792, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  i  =  1033
#  R removed from pool of  j  =  10636.349335152307
# {'q_sold': 2104, 'ri_sold': 4208, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3792
#  R removed from pool of  i  =  349.307706290856
#  R added to pool of {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4208
#  R removed from pool of  i  =  411.85985997482203
#
# {'q_sold': 2194, 'ri_sold': 1097, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R added to pool of  R to R swap called
#  i  =  1010
#  R removed from pool of  j  =  10872.92118189123
# {'q_sold': 1860, 'ri_sold': 3720, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  1097
#  R removed from pool of  j  =  11113.894514547777
#  j  =  3720
#  R removed from pool of  i  =  348.4773579160683
# {'q_sold': 1922, 'ri_sold': 961, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1936, 'ri_sold': 3872, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  i  =  961
#  R removed from pool of  j  =  10179.955150913098
# {'q_sold': 1708, 'ri_sold': 854, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  R to R swap called
#  R added to pool of   i  =  854
#  R removed from pool of  j  = j  =  3872
#  R removed from pool of  i  =  385.5691509237513
# {'q_sold': 2060, 'ri_sold': 4120, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of 8842.828204759047 j  =  4120
#  R removed from pool of  i  =  406.27739540231414
#
# {'q_sold': 2002, 'ri_sold': 4004, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}{'q_sold': 2054, 'ri_sold': 1027, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R to R swap called
#  R added to pool of  R added to pool of   i  =  1027
#  R removed from pool of  j  =  10335.534406815772
# j  =  4004{'q_sold': 1954, 'ri_sold': 3908, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R removed from pool of  i  =  388.94387509161606
#
#  R to R swap called
#  R added to pool of {'q_sold': 1718, 'ri_sold': 859, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  3908
#  R removed from pool of  i  =  391.38178970036097
# {'q_sold': 1916, 'ri_sold': 958, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#
#  R to R swap called
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  859
#  R removed from pool of  j  =  8791.696523841354
#  i  =  958
#  R removed from pool of  j  =  9499.830097467988
# {'q_sold': 1840, 'ri_sold': 920, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1932, 'ri_sold': 3864, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of
#  i  =  920
#  R removed from pool of  j  =  8916.797774712322
#  R to R swap called
# {'q_sold': 1968, 'ri_sold': 984, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  j  =  3864
#  R removed from pool of  i  =  379.79288359126076
#  R to R swap called
#  R added to pool of {'q_sold': 2082, 'ri_sold': 4164, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} i  =  984
#  R removed from pool of  j  =  9320.863565045525
#
# {'q_sold': 2378, 'ri_sold': 1189, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#  R to R swap called
#
#  R added to pool of  i  =  1189
#  R removed from pool of  j  =  10975.011671195272
# {'q_sold': 2036, 'ri_sold': 4072, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  j  =  4164
#  R removed from pool of  i  =  405.3126627821475
# {'q_sold': 2052, 'ri_sold': 4104, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  4104
#  R removed from pool of  i  =  395.5059969408903
#  j  =  4072
#  R removed from pool of  i  =  445.0635358041618{'q_sold': 1986, 'ri_sold': 3972, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of
#  j  =  3972
#  R removed from pool of  i  =  379.0919257327914
# {'q_sold': 1618, 'ri_sold': 809, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1996, 'ri_sold': 998, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R added to pool of  R to R swap called
#  R added to pool of   i  =  998
#  R removed from pool of  j  =  9071.913089572452
# i  =  809
#  R removed from pool of  j  =  8431.064632096444
# {'q_sold': 2014, 'ri_sold': 4028, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}{'q_sold': 2494, 'ri_sold': 1247, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#
#  R added to pool of  R to R swap called
#   R added to pool of j  =  4028
#  R removed from pool of  i  =  446.0140986845363
# {'q_sold': 1962, 'ri_sold': 981, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of i i  =  981
#  R removed from pool of  j  =  8804.396127548185
# {'q_sold': 2062, 'ri_sold': 4124, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called  =  1247
#  R removed from pool of  j  =  12667.92877900519
#
# {'q_sold': 1994, 'ri_sold': 997, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  R to R swap called
#  j  =  4124
#  R removed from pool of  i  =  462.3064211255405
# {'q_sold': 1768, 'ri_sold': 3536, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  R added to pool of  j  =  3536
#  R removed from pool of  i  =  392.45040465146303
#  i  =  997
#  R removed from pool of  j  =  9852.466266304487
# {'q_sold': 2230, 'ri_sold': 4460, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# {'q_sold': 2152, 'ri_sold': 4304, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R added to pool of  j  =  4460
#  R removed from pool of  i  =  489.8981241788715
# {'q_sold': 2160, 'ri_sold': 4320, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R to R swap called
#  R added to pool of  j  =  4304
#  R removed from pool of  i  =  438.52413021447137
# {'q_sold': 1820, 'ri_sold': 3640, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  j  =  4320 R added to pool of
#  R removed from pool of  i  =  469.17967516509816
#  j  =  3640
#  R removed from pool of  i  =  367.2418448838871
# {'q_sold': 2282, 'ri_sold': 4564, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# {'q_sold': 1720, 'ri_sold': 860, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  860
#  R removed from pool of  j R added to pool of  j  =  4564
#  R removed from pool of  i  =  490.07080023316666
# {'q_sold': 2118, 'ri_sold': 1059, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#   =  8473.10868212406
# {'q_sold': 2440, 'ri_sold': 4880, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  i  =  1059
#  R removed from pool of  j  =  9796.290658065933
#  j  =  {'q_sold': 1802, 'ri_sold': 3604, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# 4880
#  R removed from pool of  i  =  R added to pool of  j  =  3604 497.5100763300434
#
# {'q_sold': 1888, 'ri_sold': 944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R removed from pool of  i  =  392.697664313484
# {'q_sold': 2020, 'ri_sold': 4040, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#
#  R to R swap called
#  R to R swap called
#  R added to pool of  i  =  944
#  R removed from pool of  j  =  9209.623275624122
#  R added to pool of {'q_sold': 1900, 'ri_sold': 950, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4040
#  R removed from pool of  i  =  435.9064618877601
# {'q_sold': 1690, 'ri_sold': 3380, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R added to pool of  j  =  3380
#  R removed from pool of  i  =  R to R swap called
#  R added to pool of  361.25364429177716
# {'q_sold': 2014, 'ri_sold': 4028, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} i  =  950
#  R removed from pool of  j  =  9058.463217631332
# {'q_sold': 1788, 'ri_sold': 3576, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R added to pool of  R to R swap called
#  j  =  3576
#  R removed from pool of  i  =  377.6257281934377
# {'q_sold': 2096, 'ri_sold': 4192, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of  j  =  4028
#  R removed from pool of  i  =  426.47954994416796
#
# {'q_sold': 1818, 'ri_sold': 3636, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R to R swap called
#  R added to pool of  j  =  3636
#  R removed from pool of  i  =  381.2635027207434
#  R added to pool of {'q_sold': 2310, 'ri_sold': 1155, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4192
#  R removed from pool of  i  =  438.35759582626633
#
#  R to R swap called
# {'q_sold': 1844, 'ri_sold': 3688, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  i  =  1155
#  R removed from pool of  j  =  10913.583556766156
# {'q_sold': 1936, 'ri_sold': 3872, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  j  =  3688
#  R removed from pool of  i  =  381.85779827437364
# {'q_sold': 2164, 'ri_sold': 4328, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  3872
#  R removed from pool of  i  =  413.44254485238343
# {'q_sold': 1754, 'ri_sold': 877, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4328
#  R removed from pool of  i  =  443.662479440216
#
# {'q_sold': 2046, 'ri_sold': 4092, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R added to pool of  R to R swap called
#  R added to pool of   j  =  4092
#  R removed from pool of  i  =  415.10790289985016
# {'q_sold': 2262, 'ri_sold': 4524, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}i
#  R to R swap called
#   R added to pool of  =  877
#  R removed from pool of  j  =  8168.291704989155
# {'q_sold': 1680, 'ri_sold': 840, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4524
#  R removed from pool of  i  =  454.0774759121705
#
#  R to R swap called
#  R added to pool of {'q_sold': 2038, 'ri_sold': 1019, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
# i R added to pool of   =  840
#  R removed from pool of  j  =  7666.226105083013
# {'q_sold': 2052, 'ri_sold': 4104, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# i  =  1019
#  R removed from pool of  j  =  10082.686330884695
#  R added to pool of {'q_sold': 2158, 'ri_sold': 1079, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} j  =  4104
#  R removed from pool of  i  =  451.7491933738347
#
#  R to R swap called
# {'q_sold': 1754, 'ri_sold': 3508, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  3508
#  R removed from pool of  i  =  382.3672789938282
# {'q_sold': 1736, 'ri_sold': 868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of i i  =  868
#  R removed from pool of  j  =  7918.068383534788
# {'q_sold': 2106, 'ri_sold': 1053, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of   i  =  1053
#  R removed from pool of  j  =  9391.89073202468
#  =  {'q_sold': 2060, 'ri_sold': 4120, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}1079
#  R removed from pool of  j  =  10407.629075493896
#
# {'q_sold': 2052, 'ri_sold': 1026, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#  R added to pool of
#  R to R swap called
#  R added to pool of  ij  =  1026
#  R removed from pool of  j  =  9649.221406063065
# ...
#  R to R swap called
#
#  R added to pool of  R to R swap called  j  =  3916
#  R removed from pool of  i  =  373.40989076625556
# {'q_sold': 2064, 'ri_sold': 4128, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#
#  R to R swap called
#  R added to pool of  R added to pool of  j  j  =  4128
#  R removed from pool of  i  =  =   3716
#  R removed from pool of  i  =  452.16473994846456
# {'q_sold': 2296, 'ri_sold': 4592, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# 389.19734426843934 R added to pool of
#  {'q_sold': 2172, 'ri_sold': 1086, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}j  =  4592
#  R removed from pool of  i  =  551.503241620725
#
# {'q_sold': 1970, 'ri_sold': 985, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R added to pool of  R to R swap called
#  i  =  1086
#  R removed from pool of  j  =  11400.785717214225
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  R added to pool of   i  =  985
#  R removed from pool of  j  =  8155.44211499847
# i{'q_sold': 1800, 'ri_sold': 3600, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}  =  999
#  R removed from pool of  j  =  10171.334838328883
#
#  R to R swap called
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of  j  =  3600
#  R removed from pool of  i  =  437.91887447284535
# {'q_sold': 1944, 'ri_sold': 3888, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#
#  R added to pool of  R to R swap called
#  R added to pool of   ji   =  3888 =
#  R removed from pool of  i   = 999
#  R removed from pool of  j  =  9882.04289524327
# {'q_sold': 2066, 'ri_sold': 4132, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# 467.4129744260572 R added to pool of
#  {'q_sold': 1836, 'ri_sold': 918, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}j
#   R to R swap called  =
#  4132
#  R added to pool of  R removed from pool of   ii  =   =  421.19726801407523
#  {'q_sold': 2104, 'ri_sold': 4208, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}918
#  R removed from pool of  j  =  7591.534292154363
# {'q_sold': 2308, 'ri_sold': 4616, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of
#   R to R swap called j
#   =  4616
#  R added to pool of  j  =  4208
#  R removed from pool of  i  =  423.788129159715
# {'q_sold': 1980, 'ri_sold': 990, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R removed from pool of
#  R to R swap called
#  R added to pool of  i  =  560.7961213656235
# {'q_sold': 2082, 'ri_sold': 4164, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# i  =  990
#  R removed from pool of  j R added to pool of   j  =  4164
#  R removed from pool of  i  =  498.9477136514615
# {'q_sold': 2140, 'ri_sold': 4280, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  =   R to R swap called
# 9751.180855654413
#  R added to pool of  j  =  4280
#  R removed from pool of  i  =  506.1272010898683
# {'q_sold': 2046, 'ri_sold': 4092, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
# {'q_sold': 1920, 'ri_sold': 3840, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#  R to R swap called
#  R added to pool of
#  j  =  R added to pool of  3840 j  =  4092
#  R removed from pool of  i  =  477.6453494480811
#
# {'q_sold': 2004, 'ri_sold': 4008, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R removed from pool of  i  =  393.2102358657867
#
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R to R swap called
#
#  R added to pool of  R to R swap called
#  R added to pool of j i  =  1010
#  R removed from pool of  j  =  9777.867648140178
# {'q_sold': 1846, 'ri_sold': 3692, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  =  j  =  3692
#  R removed from pool of  i  =  384.7646909772884
# {'q_sold': 2006, 'ri_sold': 4012, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
# 4008
#  R removed from pool of  i  =  462.0270149856806
#  R added to pool of  j  =  4012
#  R removed from pool of  i  =  413.4210245301947
# {'q_sold': 2292, 'ri_sold': 1146, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 2100, 'ri_sold': 4200, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of
#  i  =  1146
#  R removed from pool of   R to R swap called j
#   R added to pool of  =   j11007.245709695853
#  {'q_sold': 2192, 'ri_sold': 4384, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} =  4200
#  R removed from pool of  i  =  478.0998621052131
#
#  R to R swap called
#  R added to pool of {'q_sold': 2432, 'ri_sold': 1216, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
# j R to R swap called
#  =  R added to pool of   i  =  1216
#  R removed from pool of  4384
#  R removed from pool of  i  =  460.87848256365396
# {'q_sold': 1848, 'ri_sold': 3696, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}j
#  R to R swap called   =  10577.733354651718
#
# {'q_sold': 2176, 'ri_sold': 4352, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j  =  4352
#  R removed from pool of  i  =  505.09378408198245
# {'q_sold': 2038, 'ri_sold': 1019, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1019
#  R removed from pool of  j  =  8720.526036826079
# 49988.93057023108j
# {'q_sold': 2438, 'ri_sold': 1219, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 49988.93057023108}
# Ri_plus =  1013377.4901604957
# {'q_sold': 1840, 'ri_sold': 3680, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  =  3696
#  R removed from pool of  i  =  383.9590298032854
# 49902.21438502438 R added to pool of
#  j  =  3680
#  R removed from pool of  i  =  433.36154034617357
# {'q_sold': 1882, 'ri_sold': 941, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1834, 'ri_sold': 917, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 49902.21438502438}
#  R to R swap called
#  R added to pool of
#  iRi_plus =    = 1009047.6827975422
#  941
#  R removed from pool of {'q_sold': 1576, 'ri_sold': 3152, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#   R to R swap called j  =  7937.513933142647
# {'q_sold': 1896, 'ri_sold': 3792, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of
#  j  =  3792
#  R removed from pool of  i  =  452.46307165105827
# {'q_sold': 1850, 'ri_sold': 3700, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  R added to pool of  j   =  3700
#  R removed from pool of  i  =  436.3368736162083
# {'q_sold': 2032, 'ri_sold': 1016, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}j
#  R to R swap called
#  R added to pool of   i  =  1016
#  R removed from pool of  j  =  8549.945514939958
# {'q_sold': 2070, 'ri_sold': 1035, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} =
#  R to R swap called
#  R added to pool of  3152
#  R removed from pool of  i  =  324.1741827757796
# {'q_sold': 2376, 'ri_sold': 4752, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  i  =  1035
#  R removed from pool of  j  =  8479.089081697632
# {'q_sold': 2192, 'ri_sold': 4384, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
# j R to R swap called
#   R added to pool of  =   4752
#  R removed from pool of  i  =  j 483.1194096643012 =  4384
#  R removed from pool of  i  =  538.6088921338087
#
# {'q_sold': 1886, 'ri_sold': 943, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}{'q_sold': 1822, 'ri_sold': 911, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of
#  i  =  911
#  R removed from pool of  j  =  8906.230895603308
# {'q_sold': 2100, 'ri_sold': 4200, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R to R swap called
#
#  R added to pool of  R to R swap called
# i  =  943
#  R removed from pool of  j  =  7635.689649582142
# {'q_sold': 1736, 'ri_sold': 868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'} R added to pool of
#  j  =  4200
#  R removed from pool of  i  R to R swap called  =  432.5658040003618
# {'q_sold': 2368, 'ri_sold': 4736, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#
#  R to R swap called
#  R added to pool of  R added to pool of   i  =  j 868
#  =  R removed from pool of  4736
#  R removed from pool of  i  =  481.43969441310037
# {'q_sold': 2236, 'ri_sold': 1118, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1118
# j  =  6866.862375645316
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R removed from pool of  j  =  10898.843648846028
# {'q_sold': 1658, 'ri_sold': 3316, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'} R added to pool of
#  R to R swap called
#  R added to pool of   j  =  3316
#  R removed from pool of  i  =  343.9409976460738
# {'q_sold': 2272, 'ri_sold': 4544, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}i
#  R to R swap called
#  R added to pool of   j  =  4544
#  R removed from pool of  i  =  465.909218137851
#  =  954
#  R removed from pool of  j  =  7374.94506237458
# {'q_sold': 1978, 'ri_sold': 3956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3956
#  R removed from pool of  i  =  400.6189540621126
# {'q_sold': 2248, 'ri_sold': 1124, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1124
#  R removed from pool of  j  =  10985.37516407203
# Total execution time: 3.00s

# %% [markdown]
# # Results dataframe analysis

# %% [markdown]
# ### Excerpt from the results (head & tail)

# %%
experiments.head()
# Out:
#    index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 0      0  2000000  1000000   10000  2000000  1000000   10000  1000000
# 1      3  2000000  1000000   10000  2000000  1000000   10000  1000000
# 2      6  2000000  1000000   10000  2000000  1000000   10000  1000000
# 3      9  2000000  1000000   10000  2000000  1000000   10000  1000000
# 4     12  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#     UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 0  1000000  1000000000000  ...  1000000000000                    i
# 1  1000000  1000000000000  ...  1000000000000                    i
# 2  1000000  1000000000000  ...  1000000000000                    j
# 3  1000000  1000000000000  ...  1000000000000                    j
# 4  1000000  1000000000000  ...  1000000000000                    i
#
#    trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 0               1000            test_q_for_r                N/A           0
# 1               1050            test_r_for_r                  j           0
# 2               1065            test_r_for_r                  i           0
# 3                977            test_r_for_r                  i           0
# 4               1158            test_r_for_r                  j           0
#
#    subset  run  substep timestep
# 0       0    1        0        0
# 1       0    1        3        1
# 2       0    1        3        2
# 3       0    1        3        3
# 4       0    1        3        4
#
# [5 rows x 30 columns]

# %%
experiments.tail()
# Out:
#      index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 399   1191  2000000  1000000   10000  2000000  1000000   10000  1000000
# 400   1194  2000000  1000000   10000  2000000  1000000   10000  1000000
# 401   1197  2000000  1000000   10000  2000000  1000000   10000  1000000
# 402   1200  2000000  1000000   10000  2000000  1000000   10000  1000000
# 403   1203  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#       UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 399  1000000  1000000000000  ...  1000000000000                    i
# 400  1000000  1000000000000  ...  1000000000000                    j
# 401  1000000  1000000000000  ...  1000000000000                    i
# 402  1000000  1000000000000  ...  1000000000000                    i
# 403  1000000  1000000000000  ...  1000000000000                    i
#
#      trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 399               1035            test_r_for_r                  j           1
# 400               1096            test_r_for_r                  i           1
# 401                943            test_r_for_r                  j           1
# 402                868            test_r_for_r                  j           1
# 403                954            test_r_for_r                  j           1
#
#      subset  run  substep timestep
# 399       1    2        3       96
# 400       1    2        3       97
# 401       1    2        3       98
# 402       1    2        3       99
# 403       1    2        3      100
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Individual MonteCarlo results
#
# - Choose the subset from $\{0,1,2\}$ ... for different values for `a`
# - Choose the simulation from $\{0,\dots,9\}$ ... for the distinct simulation run

# %%
experiment1 = experiments[experiments.subset == 2]
experiment1 = experiment1[experiment1.run == 8]
experiment2 = experiment1.sort_values(by=['timestep'], ascending=True)
experiment2
# Out:
# Empty DataFrame
# Columns: [index, UNI_Qi, UNI_Ri, UNI_Si, UNI_Qj, UNI_Rj, UNI_Sj, UNI_ij, UNI_ji, UNI_Sij, uni_agents, UNI_P_RQi, UNI_P_RQj, UNI_P_ij, pool, Q, H, Sq, Y, hydra_agents, C, asset_random_choice, trade_random_size, trade_random_direction, purchased_asset_id, simulation, subset, run, substep, timestep]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ### Starting balances

# %%
experiments.UNI_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Ri = experiments[experiments.timestep == 0]
starting_Ri = starting_Ri['UNI_Ri']
starting_Ri.reset_index(drop=True)
starting_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = starting_Ri.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_i")
plt.show()

# %%
experiments.UNI_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Rj = experiments[experiments.timestep == 0]
starting_Rj = starting_Rj['UNI_Rj']
starting_Rj.reset_index(drop=True)
starting_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
a = starting_Rj.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_j")
plt.show()

# %% [markdown]
# ### Trade Sizes

# %%
experiments.trade_random_size.unique()
# Out:
# array([1000, 1050, 1065,  977, 1158,  954, 1025,  828,  944,  899,  910,
#         859,  978,  858, 1012, 1038,  940, 1186,  895,  878, 1021,  868,
#        1018,  970,  853, 1035, 1033, 1062,  917, 1098,  953,  982,  890,
#        1082, 1136, 1101,  936,  997,  739, 1009, 1010,  979, 1148,  920,
#        1092,  948,  930,  961,  854, 1001,  966, 1041, 1026,  993,  809,
#        1247, 1076,  860, 1220,  950,  894, 1048,  922, 1023, 1131, 1019,
#        1079, 1024,  929, 1066,  903,  918, 1097,  976,  925,  919, 1083,
#        1002, 1063,  915,  956,  876, 1039, 1016, 1006,  886,  987, 1153,
#        1077, 1055, 1032, 1147, 1007,  946,  885,  971,  999,  805, 1020,
#        1074,  989, 1106,  824,  962,  933, 1104, 1094, 1034,  881, 1037,
#        1154, 1157,  802, 1036,  949, 1052,  968, 1030, 1027,  958,  984,
#        1189,  998,  981, 1031,  884, 1115, 1080, 1141, 1059,  901,  845,
#         909, 1155,  877,  840, 1053,  932, 1187, 1116, 1042, 1190,  912,
#        1028, 1146,  974, 1273,  893, 1049, 1072,  916,  849, 1086, 1022,
#         863, 1386, 1114,  969,  952,  814, 1069,  839,  927, 1005, 1215,
#        1064,  934, 1051, 1087,  874, 1045,  908,  898,  857, 1145,  902,
#        1047, 1159, 1214, 1029,  980,  942, 1085, 1090, 1075, 1128,  941,
#        1110, 1003, 1060, 1210,  879,  911, 1008,  856,  990,  960,  923,
#        1096,  924,  788, 1188, 1184, 1118,  829, 1124, 1057, 1109,  907,
#        1058, 1232, 1068,  935,  798,  921,  880,  967, 1177, 1213, 1127,
#        1078,  995,  676,  975, 1164, 1014, 1117, 1067,  985,  938,  951,
#         931,  900,  986,  972, 1070, 1216, 1088, 1219,  943], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = experiments.trade_random_size.unique()
_ = plt.hist(a, bins=30)  # arguments are passed to np.histogram
plt.title("Histogram for trade sizes")
plt.show()

# %%
def get_M(k, v):
    if k == 'sim_config':
        k, v = 'M', v['M']
    return k, v

config_ids = [
    dict(
        get_M(k, v) for k, v in config.__dict__.items() if k in ['simulation_id', 'run_id', 'sim_config', 'subset_id']
    ) for config in configs
]

# %% [markdown]
# # Liquidity dynamics

# %% [markdown]
# ## Hydra -- base

# %% [markdown]
# ### Fan Plots

# %%
param_fan_plot3(experiments, config_ids, 'a','Q')

# %%
param_fan_plot3(experiments, config_ids, 'a','H')

# %%
param_fan_plot3(experiments, config_ids, 'a','Sq')

# %%
param_fan_plot3(experiments, config_ids, 'a','Y')

# %% [markdown]
# ## Hydra -- pool

# %% [markdown]
# ### Risk asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','C')

# %% [markdown]
# ### Risk asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','C')

# %% [markdown]
# # Prices

# %% [markdown]
# ## Asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','P')

# %% [markdown]
# ## Asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','P')
