# %% [markdown]
# #  Hydra Multi-Asset Monte Carlo Experiment with varying trade sizes

# %% [markdown]
# # Testcase Definition
#
# #### Simulation Settings
# - There are 100 timesteps for each simulation run
# - Each testcase has 10 MC runs with different randomized variables
# - Block 2 randomizes trade sizes
#
#
#
# #### Agent Activities - Action Sequence
#
# There are two agents acting during the simulation. The trading agent performs "R-for-R" trades of varying direction and size over most simulation timesteps. The liquidity agent provides liquidity to the pool at timestep 10 and removes the liquidity from the pool at timestep 90.
#
# ##### Trading agent
#
# - One Agent performs random "R-for-R" trades during the simulation.
# - The direction of the trade is a random coin flip for each timestep.
# - The size of the trade is drawn from $\mathcal{N}(\mu, \sigma)$ for each timestep.
# - The agent does not act at timestep 10 nor timestep 90.
#
# ##### Liquidity agent
#
# - One Agent provides liquidity in Risk asset "i" to the pool
# - He provides the liquidity at timestep 10
# - He removes the liquidity at timestep 90
# - He does not act at other timesteps
#
# #### Block 2:
# | #   | Run | a |  $\mu_i$  | $\sigma_i$ |  $\mu_j$  | $\sigma_j$ | $\mu$   | $\sigma$ | Total runs |
# | --- |:---:|:-------:|:---------:|:----------:|:---------:|:----------:| ------- | -------- | ---------- |
# | 1   | 01 - 10    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$       |
# | 2   | 11 - 20    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 3   | 21 - 30    |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 4  |  31 - 40   |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 5  | 41 - 50    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 6  | 51 - 60    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
#
# All tests in block 2 are performed as $10$ Monte-Carlo runs for the given parameters which results in $60$ runs in total.

# %% [markdown]
# ## Run Model

# %%
from model.config_wrapper import ConfigWrapper

from model import run_wrapper
from cadCAD import configs

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# df = run.run()
# rdf = run.postprocessing(df)
# rdf = df # debugging substeps
# pd.set_option("mode.chained_assignment", None)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py

# %%
(data, tensor_field, sessions) = run_wrapper.run(drop_midsteps=True)

experiments = data
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 15, 3, 24)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0]
# SubsetIDs: [0, 1, 2]
# Ns       : [0, 1, 2]
# ExpIDs   : [0, 0, 0]
# Execution Mode: parallelized
# {'q_sold': 2498, 'ri_sold': 1249, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1249
#  R removed from pool of  j  =  4943.14135172253
# {'q_sold': 1862, 'ri_sold': 3724, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3724
#  R removed from pool of  i  =  942.3211207670392
# {'q_sold': 2648, 'ri_sold': 1324, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1324
#  R removed from pool of  j  =  5222.99407985562
# {'q_sold': 3524, 'ri_sold': 7048, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7048
#  R removed from pool of  i  =  1782.7556610940956
# {'q_sold': 1766, 'ri_sold': 883, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  883
#  R removed from pool of  j  =  3505.692192252376
# {'q_sold': 1766, 'ri_sold': 3532, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3532
#  R removed from pool of  i  =  889.5985089257592
# {'q_sold': 3580, 'ri_sold': 7160, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7160
#  R removed from pool of  i  =  1780.6694380386034
# {'q_sold': 2768, 'ri_sold': 1384, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1384
#  R removed from pool of  j  =  5575.480101840687
# {'q_sold': 1532, 'ri_sold': 3064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3064
#  R removed from pool of  i  =  762.8318314308999
# {'q_sold': 2544, 'ri_sold': 1272, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'}
# {'q_sold': 1538, 'ri_sold': 769, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  769
#  R removed from pool of  j  =  3088.7920998225454
# {'q_sold': 1536, 'ri_sold': 768, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  768
#  R removed from pool of  j  =  3062.576521699433
# {'q_sold': 2242, 'ri_sold': 1121, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1121
#  R removed from pool of  j  =  4430.909845791408
# {'q_sold': 88, 'ri_sold': 44, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  44
#  R removed from pool of  j  =  172.97246643994004
# {'q_sold': 276, 'ri_sold': 138, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  138
#  R removed from pool of  j  =  542.0449363953667
# {'q_sold': 1438, 'ri_sold': 719, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  719
#  R removed from pool of  j  =  2812.90329130413
# {'q_sold': 988, 'ri_sold': 1976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1976
#  R removed from pool of  i  =  505.5828074084129
# {'q_sold': 2316, 'ri_sold': 4632, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4632
#  R removed from pool of  i  =  1175.905799495522
# {'q_sold': 1092, 'ri_sold': 546, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  546
#  R removed from pool of  j  =  2157.062155554653
# {'q_sold': 588, 'ri_sold': 1176, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1176
#  R removed from pool of  i  =  298.0166718130931
# {'q_sold': 3466, 'ri_sold': 6932, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6932
#  R removed from pool of  i  =  1739.9814127760474
# {'q_sold': 1776, 'ri_sold': 888, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  888
#  R removed from pool of  j  =  3551.8787304523867
# {'q_sold': 2068, 'ri_sold': 4136, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4136
#  R removed from pool of  i  =  1033.3279145192355
# {'q_sold': 576, 'ri_sold': 1152, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1152
#  R removed from pool of  i  =  286.0327784740366
# {'q_sold': 1456, 'ri_sold': 2912, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2912
#  R removed from pool of  i  =  719.6026871486101
# {'q_sold': 2112, 'ri_sold': 4224, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4224
#  R removed from pool of  i  =  1035.1814347753534
# {'q_sold': 850, 'ri_sold': 1700, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1700
#  R removed from pool of  i  =  413.7651828962844
# {'q_sold': 2376, 'ri_sold': 4752, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4752
#  R removed from pool of  i  =  1148.0080525418743
# {'q_sold': 1400, 'ri_sold': 2800, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2800
#  R removed from pool of  i  =  670.5767191760242
# {'q_sold': 1710, 'ri_sold': 3420, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3420
#  R removed from pool of  i  =  813.2421059801709
# {'q_sold': 1400, 'ri_sold': 2800, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2800
#  R removed from pool of  i  =  661.0972441389458
# {'q_sold': 3854, 'ri_sold': 7708, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7708
#  R removed from pool of  i  =  1798.3268329645507
# {'q_sold': 1988, 'ri_sold': 3976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3976
#  R removed from pool of  i  =  915.453346307273
# {'q_sold': 944, 'ri_sold': 1888, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1888
#  R removed from pool of  i  =  431.84563818364404
# {'q_sold': 2824, 'ri_sold': 1412, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1412
#  R removed from pool of  j  =  6143.666595511953
# {'q_sold': 780, 'ri_sold': 390, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  390
#  R removed from pool of  j  =  1682.0227744234726
# {'q_sold': 2210, 'ri_sold': 4420, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4420
#  R removed from pool of  i  =  1021.6806418604683
# {'q_sold': 42, 'ri_sold': 84, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  84
#  R removed from pool of  i  =  19.31818049098365
# {'q_sold': 672, 'ri_sold': 1344, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1344
#  R removed from pool of  i  =  308.59516411821824
# {'q_sold': 2198, 'ri_sold': 1099, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1099
#  R removed from pool of  j  =  4767.952730307006
# {'q_sold': 2740, 'ri_sold': 1370, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1370
#  R removed from pool of  j  =  5872.630011951784
# {'q_sold': 2172, 'ri_sold': 4344, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4344
#  R removed from pool of  i  =  1015.1452629073756
# {'q_sold': 1886, 'ri_sold': 3772, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3772
#  R removed from pool of  i  =  873.4157657832839
# {'q_sold': 1700, 'ri_sold': 3400, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3400
#  R removed from pool of  i  =  780.9425576347858
# {'q_sold': 522, 'ri_sold': 261, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  261
#  R removed from pool of  j  =  1139.2126076727873
# {'q_sold': 1282, 'ri_sold': 2564, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2564
#  R removed from pool of  i  =  586.4892704453086
# {'q_sold': 1540, 'ri_sold': 3080, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3080
#  R removed from pool of  i  =  700.0806110248668
# {'q_sold': 3058, 'ri_sold': 6116, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6116
#  R removed from pool of  i  =  1375.989045121707
# {'q_sold': 2344, 'ri_sold': 4688, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4688
#  R removed from pool of  i  =  1042.1508131484734
# {'q_sold': 238, 'ri_sold': 119, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  119
#  R removed from pool of  j  =  537.770301243756
# {'q_sold': 2326, 'ri_sold': 4652, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4652
#  R removed from pool of  i  =  1024.7659266074188
# {'q_sold': 1616, 'ri_sold': 3232, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3232
#  R removed from pool of  i  =  705.82395303878
# {'q_sold': 1324, 'ri_sold': 2648, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2648
#  R removed from pool of  i  =  574.5798244641628
# {'q_sold': 2612, 'ri_sold': 5224, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5224
#  R removed from pool of  i  =  1123.8659865924856
# {'q_sold': 3032, 'ri_sold': 6064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6064
#  R removed from pool of  i  =  1288.7267446451588
# {'q_sold': 2932, 'ri_sold': 1466, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1466
#  R removed from pool of  j  =  6891.956638929434
# {'q_sold': 1162, 'ri_sold': 2324, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2324
#  R removed from pool of  i  =  496.78479073301423
# {'q_sold': 1692, 'ri_sold': 3384, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3384
#  R removed from pool of  i  =  718.9230413991027
# {'q_sold': 2332, 'ri_sold': 1166, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1166
#  R removed from pool of  j  =  5475.98896063026
# {'q_sold': 2976, 'ri_sold': 5952, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5952
#  R removed from pool of  i  =  1266.7069705225294
# {'q_sold': 1522, 'ri_sold': 761, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  761
#  R removed from pool of  j  =  3584.9619175179396
# {'q_sold': 1816, 'ri_sold': 3632, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3632
#  R removed from pool of  i  =  770.9459753873525
# {'q_sold': 894, 'ri_sold': 1788, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1788
#  R removed from pool of  i  =  377.3181842860067
# {'q_sold': 804, 'ri_sold': 1608, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1608
#  R removed from pool of  i  =  338.09653853892814
# {'q_sold': 2814, 'ri_sold': 1407, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1407
#  R removed from pool of  j  =  6655.436842401279
# {'q_sold': 3358, 'ri_sold': 1679, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1679
#  R removed from pool of  j  =  7818.680560015608
# {'q_sold': 1928, 'ri_sold': 3856, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3856
#  R removed from pool of  i  =  831.6084196603624
# {'q_sold': 3004, 'ri_sold': 6008, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6008
#  R removed from pool of  i  =  1281.9344642226351
# {'q_sold': 2362, 'ri_sold': 1181, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1181
#  R removed from pool of  j  =  5537.779518709751
# {'q_sold': 1356, 'ri_sold': 2712, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2712
#  R removed from pool of  i  =  580.1358104590327
# {'q_sold': 2362, 'ri_sold': 4724, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4724
#  R removed from pool of  i  =  1002.4430488174548
# {'q_sold': 3540, 'ri_sold': 7080, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7080
#  R removed from pool of  i  =  1483.4496712385444
# {'q_sold': 1966, 'ri_sold': 983, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  983
#  R removed from pool of  j  =  4703.522302528145
# {'q_sold': 3566, 'ri_sold': 7132, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7132
#  R removed from pool of  i  =  1486.677757042693
# {'q_sold': -618, 'ri_sold': -309, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  -309
#  R removed from pool of  j  =  -1496.083849835908
# {'q_sold': 2822, 'ri_sold': 5644, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5644
#  R removed from pool of  i  =  1156.9110203745076
# {'q_sold': 2088, 'ri_sold': 1044, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1044
#  R removed from pool of  j  =  5096.129284389783
# {'q_sold': 1702, 'ri_sold': 3404, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3404
#  R removed from pool of  i  =  698.5973085017176
# {'q_sold': 2092, 'ri_sold': 1046, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1046
#  R removed from pool of  j  =  5087.643589272164
# {'q_sold': 14, 'ri_sold': 28, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  28
#  R removed from pool of  i  =  5.78769717074465
# {'q_sold': 1782, 'ri_sold': 3564, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3564
#  R removed from pool of  i  =  733.8849702854641
# {'q_sold': 2358, 'ri_sold': 1179, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1179
#  R removed from pool of  j  =  5712.537598673487
# {'q_sold': 3478, 'ri_sold': 1739, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1739
#  R removed from pool of  j  =  8300.640330755617
# {'q_sold': 1482, 'ri_sold': 2964, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2964
#  R removed from pool of  i  =  624.5205741917016
# {'q_sold': 1192, 'ri_sold': 2384, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2384
#  R removed from pool of  i  =  499.4372983366484
# {'q_sold': 1500, 'ri_sold': 3000, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3000
#  R removed from pool of  i  =  624.8756817203248
# {'q_sold': 2916, 'ri_sold': 5832, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5832
#  R removed from pool of  i  =  1203.3819176177494
# {'q_sold': 2330, 'ri_sold': 4660, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4660
#  R removed from pool of  i  =  950.9067290468374
# {'q_sold': 1472, 'ri_sold': 2944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2944
#  R removed from pool of  i  =  595.9409657929791
# 50065.995822158664
# {'q_sold': 2514, 'ri_sold': 1257, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 50065.995822158664}
# Ri_plus =  968276.0161558609
# {'q_sold': 2098, 'ri_sold': 4196, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4196
#  R removed from pool of  i  =  842.9966490752995
# {'q_sold': 2970, 'ri_sold': 1485, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1485
#  R removed from pool of  j  =  7366.699619094143
# {'q_sold': 1298, 'ri_sold': 2596, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2596
#  R removed from pool of  i  =  525.9588022369426
# {'q_sold': 1674, 'ri_sold': 837, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  837
#  R removed from pool of  j  =  4124.499420945067
# {'q_sold': 1608, 'ri_sold': 804, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  804
#  R removed from pool of  j  =  3928.0171410392504
# {'q_sold': 538, 'ri_sold': 1076, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1076
#  R removed from pool of  i  =  220.91119911440182
# {'q_sold': 2298, 'ri_sold': 1149, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1149
#  R removed from pool of  j  =  5569.543400126509
# {'q_sold': 2262, 'ri_sold': 1131, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1131
#  R removed from pool of  j  =  5417.850519106025
# {'q_sold': 2006, 'ri_sold': 1003, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1003
#  R removed from pool of  j  =  4752.091729989508
# {'q_sold': 1766, 'ri_sold': 3532, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3532
#  R removed from pool of  i  =  746.4675963150803
# {'q_sold': 586, 'ri_sold': 1172, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1172
#  R removed from pool of  i  =  293.96202588942833
# {'q_sold': 1580, 'ri_sold': 3160, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3160
#  R removed from pool of  i  =  788.3210405415157
# {'q_sold': 1658, 'ri_sold': 3316, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3316
#  R removed from pool of  i  =  820.5988268777728
# {'q_sold': 1198, 'ri_sold': 2396, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2396
#  R removed from pool of  i  =  588.7447195135755
# {'q_sold': 1840, 'ri_sold': 920, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  920
#  R removed from pool of  j  =  3737.874986491981
# {'q_sold': 2406, 'ri_sold': 1203, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1203
#  R removed from pool of  j  =  4835.896466928185
# {'q_sold': 3888, 'ri_sold': 1944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1944
#  R removed from pool of  j  =  7693.072013758239
# {'q_sold': 2176, 'ri_sold': 1088, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1088
#  R removed from pool of  j  =  4241.41338549077
# {'q_sold': 2258, 'ri_sold': 4516, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4516
#  R removed from pool of  i  =  1158.0355055065593
# {'q_sold': 1926, 'ri_sold': 963, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'}
# {'q_sold': 82, 'ri_sold': 41, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  41
#  R removed from pool of  j  =  160.77115187537856
# {'q_sold': 1974, 'ri_sold': 987, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  987
#  R removed from pool of  j  =  3850.8874689600198
# {'q_sold': 2062, 'ri_sold': 4124, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4124
#  R removed from pool of  i  =  1056.6396296827588
# {'q_sold': 4464, 'ri_sold': 8928, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  8928
#  R removed from pool of  i  =  2250.6481163811404
# {'q_sold': 1808, 'ri_sold': 3616, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3616
#  R removed from pool of  i  =  897.4992906239349
# {'q_sold': 2302, 'ri_sold': 1151, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1151
#  R removed from pool of  j  =  4631.5335206282325
# {'q_sold': 1966, 'ri_sold': 983, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  983
#  R removed from pool of  j  =  3913.970731515088
# {'q_sold': 832, 'ri_sold': 1664, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1664
#  R removed from pool of  i  =  419.0817847494036
# {'q_sold': 3144, 'ri_sold': 1572, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1572
#  R removed from pool of  j  =  6206.5426434119
# {'q_sold': 2752, 'ri_sold': 1376, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1376
#  R removed from pool of  j  =  5354.844731649384
# {'q_sold': 2792, 'ri_sold': 5584, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5584
#  R removed from pool of  i  =  1434.4739418886602
# {'q_sold': 1092, 'ri_sold': 2184, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2184
#  R removed from pool of  i  =  555.6201755502261
# {'q_sold': 3404, 'ri_sold': 6808, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6808
#  R removed from pool of  i  =  1712.7555786063895
# {'q_sold': 600, 'ri_sold': 300, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  300
#  R removed from pool of  j  =  1200.7914978482295
# {'q_sold': 2588, 'ri_sold': 1294, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1294
#  R removed from pool of  j  =  5138.864742968115
# {'q_sold': 4192, 'ri_sold': 2096, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  2096
#  R removed from pool of  j  =  8186.66923636687
# {'q_sold': 1010, 'ri_sold': 505, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  505
#  R removed from pool of  j  =  1947.576185752987
# {'q_sold': 1434, 'ri_sold': 717, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  717
#  R removed from pool of  j  =  2748.842495635152
# {'q_sold': 2100, 'ri_sold': 4200, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4200
#  R removed from pool of  i  =  1093.5153268948197
# {'q_sold': 1498, 'ri_sold': 2996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2996
#  R removed from pool of  i  =  773.0046458751895
# {'q_sold': 450, 'ri_sold': 900, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  900
#  R removed from pool of  i  =  231.0782244980801
# {'q_sold': 2070, 'ri_sold': 4140, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4140
#  R removed from pool of  i  =  1056.2864311989397
# {'q_sold': 938, 'ri_sold': 1876, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1876
#  R removed from pool of  i  =  475.06717647193
# {'q_sold': 2474, 'ri_sold': 4948, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4948
#  R removed from pool of  i  =  1242.4411049652845
# {'q_sold': 1082, 'ri_sold': 541, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  541
#  R removed from pool of  j  =  2161.982746525202
# {'q_sold': 3550, 'ri_sold': 7100, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7100
#  R removed from pool of  i  =  1765.8855996666243
# {'q_sold': 1218, 'ri_sold': 2436, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2436
#  R removed from pool of  i  =  598.8009990241844
# {'q_sold': 1678, 'ri_sold': 3356, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3356
#  R removed from pool of  i  =  819.1246213256381
# {'q_sold': 2814, 'ri_sold': 1407, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1407
#  R removed from pool of  j  =  5747.683277689968
# {'q_sold': 770, 'ri_sold': 385, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  385
#  R removed from pool of  j  =  1558.7413491117768
# {'q_sold': 2228, 'ri_sold': 1114, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1114
#  R removed from pool of  j  =  4476.810646338039
# {'q_sold': 3308, 'ri_sold': 1654, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1654
#  R removed from pool of  j  =  6556.694822927238
# {'q_sold': 394, 'ri_sold': 197, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  197
#  R removed from pool of  j  =  773.8563114812132
# {'q_sold': 2186, 'ri_sold': 1093, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1093
#  R removed from pool of  j  =  4266.543769885786
# {'q_sold': 2260, 'ri_sold': 4520, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4520
#  R removed from pool of  i  =  1157.5640497358982
# {'q_sold': 2782, 'ri_sold': 1391, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1391
#  R removed from pool of  j  =  5425.339242838789
# {'q_sold': 764, 'ri_sold': 382, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  382
#  R removed from pool of  j  =  1477.0892809394281
# {'q_sold': 680, 'ri_sold': 1360, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1360
#  R removed from pool of  i  =  351.7704938664101
# {'q_sold': 2522, 'ri_sold': 5044, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5044
#  R removed from pool of  i  =  1294.2237265247386
# {'q_sold': 2298, 'ri_sold': 4596, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4596
#  R removed from pool of  i  =  1165.1610035710037
# {'q_sold': 2252, 'ri_sold': 4504, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4504
#  R removed from pool of  i  =  1129.0107481379528
# ...
#  R to R swap called
#  R added to pool of  j  =  4812
#  R removed from pool of  i  =  1174.1522320234217
# {'q_sold': 740, 'ri_sold': 370, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  370
#  R removed from pool of  j  =  1522.7811196600087
# {'q_sold': 2918, 'ri_sold': 5836, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5836
#  R removed from pool of  i  =  1410.2298533022404
# {'q_sold': 4124, 'ri_sold': 2062, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  2062
#  R removed from pool of  j  =  8504.06244849891
# {'q_sold': 3034, 'ri_sold': 6068, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6068
#  R removed from pool of  i  =  1475.8961348986486
# {'q_sold': 482, 'ri_sold': 241, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  241
#  R removed from pool of  j  =  997.3088576253504
# {'q_sold': 1516, 'ri_sold': 3032, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3032
#  R removed from pool of  i  =  730.7861471702345
# {'q_sold': 3268, 'ri_sold': 1634, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1634
#  R removed from pool of  j  =  6747.212560381857
# {'q_sold': 1294, 'ri_sold': 2588, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2588
#  R removed from pool of  i  =  630.0820760176284
# {'q_sold': 2444, 'ri_sold': 1222, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1222
#  R removed from pool of  j  =  5003.680078529636
# {'q_sold': 2776, 'ri_sold': 1388, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1388
#  R removed from pool of  j  =  5606.252279849607
# {'q_sold': 1074, 'ri_sold': 537, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  537
#  R removed from pool of  j  =  2147.339889170369
# {'q_sold': 1942, 'ri_sold': 971, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  971
#  R removed from pool of  j  =  3852.602341015241
# {'q_sold': -1240, 'ri_sold': -2480, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  -2480
#  R removed from pool of  i  =  -630.2411360552069
# {'q_sold': 976, 'ri_sold': 1952, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1952
#  R removed from pool of  i  =  496.4031870160252
# {'q_sold': 1748, 'ri_sold': 3496, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3496
#  R removed from pool of  i  =  882.7463246949483
# {'q_sold': 754, 'ri_sold': 377, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  377
#  R removed from pool of  j  =  1496.9609843932558
# {'q_sold': 3634, 'ri_sold': 1817, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1817
#  R removed from pool of  j  =  7133.7572683861945
# {'q_sold': 570, 'ri_sold': 285, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  285
#  R removed from pool of  j  =  1106.921494341339
# {'q_sold': 1560, 'ri_sold': 780, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  780
#  R removed from pool of  j  =  3013.04562465474
# {'q_sold': 2132, 'ri_sold': 1066, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1066
#  R removed from pool of  j  =  4079.346800038009
# {'q_sold': 3442, 'ri_sold': 6884, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  6884
#  R removed from pool of  i  =  1792.251999597298
# {'q_sold': 566, 'ri_sold': 1132, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1132
#  R removed from pool of  i  =  291.6073913106229
# {'q_sold': 3164, 'ri_sold': 1582, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1582
#  R removed from pool of  j  =  6100.993274726672
# {'q_sold': 2012, 'ri_sold': 4024, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4024
#  R removed from pool of  i  =  1046.291529881768
# {'q_sold': 1020, 'ri_sold': 2040, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2040
#  R removed from pool of  i  =  526.1926012029871
# {'q_sold': 2464, 'ri_sold': 4928, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4928
#  R removed from pool of  i  =  1259.5321062104777
# {'q_sold': 2200, 'ri_sold': 4400, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4400
#  R removed from pool of  i  =  1110.9389130333439
# {'q_sold': 1400, 'ri_sold': 2800, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2800
#  R removed from pool of  i  =  700.3639773244504
# {'q_sold': 2070, 'ri_sold': 1035, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1035
#  R removed from pool of  j  =  4130.685793826939
# {'q_sold': 1616, 'ri_sold': 808, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  808
#  R removed from pool of  j  =  3194.115379321971
# {'q_sold': 2114, 'ri_sold': 4228, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4228
#  R removed from pool of  i  =  1068.0979609244969
# {'q_sold': 2664, 'ri_sold': 1332, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1332
#  R removed from pool of  j  =  5265.482961672242
# {'q_sold': 3588, 'ri_sold': 7176, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  7176
#  R removed from pool of  i  =  1810.798398370389
# {'q_sold': 764, 'ri_sold': 382, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  382
#  R removed from pool of  j  =  1525.0335447207326
# {'q_sold': 4134, 'ri_sold': 8268, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  8268
#  R removed from pool of  i  =  2053.0480827232823
# {'q_sold': 48, 'ri_sold': 96, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  96
#  R removed from pool of  i  =  23.581412013503723
# {'q_sold': 1850, 'ri_sold': 3700, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3700
#  R removed from pool of  i  =  904.4472669996321
# {'q_sold': 2590, 'ri_sold': 5180, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5180
#  R removed from pool of  i  =  1251.915427699103
# {'q_sold': 2282, 'ri_sold': 1141, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1141
#  R removed from pool of  j  =  4723.829023029888
# 49998.9911830038
# {'q_sold': 1378, 'ri_sold': 689, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 49998.9911830038}
# Ri_plus =  982238.1291414407
# {'q_sold': 1792, 'ri_sold': 3584, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3584
#  R removed from pool of  i  =  866.9042812746484
# {'q_sold': 1508, 'ri_sold': 754, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  754
#  R removed from pool of  j  =  3119.0987078243634
# {'q_sold': 1412, 'ri_sold': 706, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  706
#  R removed from pool of  j  =  2897.924598289188
# {'q_sold': 2850, 'ri_sold': 1425, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1425
#  R removed from pool of  j  =  5783.618723432068
# {'q_sold': 2358, 'ri_sold': 1179, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1179
#  R removed from pool of  j  =  4720.028165059397
# {'q_sold': 1308, 'ri_sold': 2616, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  2616
#  R removed from pool of  i  =  655.2423533330439
# {'q_sold': 2900, 'ri_sold': 1450, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1450
#  R removed from pool of  j  =  5765.0498984101
# {'q_sold': 2308, 'ri_sold': 1154, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1154
#  R removed from pool of  j  =  4526.359593419358
# {'q_sold': 2814, 'ri_sold': 5628, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5628
#  R removed from pool of  i  =  1432.7820934368065
# {'q_sold': 2630, 'ri_sold': 5260, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  5260
#  R removed from pool of  i  =  1320.0206826209323
# Total execution time: 0.93s

# %% [markdown]
# # Results dataframe analysis

# %% [markdown]
# ### Excerpt from the results (head & tail)

# %%
experiments.head()
# Out:
#    index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 0      0  2000000  1000000   10000  2000000  1000000   10000  1000000
# 1      3  2000000  1000000   10000  2000000  1000000   10000  1000000
# 2      6  2000000  1000000   10000  2000000  1000000   10000  1000000
# 3      9  2000000  1000000   10000  2000000  1000000   10000  1000000
# 4     12  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#     UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 0  1000000  1000000000000  ...  1000000000000                    i
# 1  1000000  1000000000000  ...  1000000000000                    i
# 2  1000000  1000000000000  ...  1000000000000                    j
# 3  1000000  1000000000000  ...  1000000000000                    i
# 4  1000000  1000000000000  ...  1000000000000                    j
#
#    trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 0               1000            test_q_for_r                N/A           0
# 1               1249            test_r_for_r                  j           0
# 2                931            test_r_for_r                  i           0
# 3               1324            test_r_for_r                  j           0
# 4               1762            test_r_for_r                  i           0
#
#    subset  run  substep timestep
# 0       0    1        0        0
# 1       0    1        3        1
# 2       0    1        3        2
# 3       0    1        3        3
# 4       0    1        3        4
#
# [5 rows x 30 columns]

# %%
experiments.tail()
# Out:
#      index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 298    890  2000000  1000000   10000  2000000  1000000   10000  1000000
# 299    893  2000000  1000000   10000  2000000  1000000   10000  1000000
# 300    896  2000000  1000000   10000  2000000  1000000   10000  1000000
# 301    899  2000000  1000000   10000  2000000  1000000   10000  1000000
# 302    902  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#       UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 298  1000000  1000000000000  ...  1000000000000                    j
# 299  1000000  1000000000000  ...  1000000000000                    i
# 300  1000000  1000000000000  ...  1000000000000                    i
# 301  1000000  1000000000000  ...  1000000000000                    j
# 302  1000000  1000000000000  ...  1000000000000                    j
#
#      trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 298                654            test_r_for_r                  i           0
# 299               1450            test_r_for_r                  j           0
# 300               1154            test_r_for_r                  j           0
# 301               1407            test_r_for_r                  i           0
# 302               1315            test_r_for_r                  i           0
#
#      subset  run  substep timestep
# 298       2    2        3       96
# 299       2    2        3       97
# 300       2    2        3       98
# 301       2    2        3       99
# 302       2    2        3      100
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Individual MonteCarlo results
#
# - Choose the subset from $\{0,1,2\}$ ... for different values for `a`
# - Choose the simulation from $\{0,\dots,9\}$ ... for the distinct simulation run

# %%
experiment1 = experiments[experiments.subset == 2]
experiment1 = experiment1[experiment1.run == 8]
experiment2 = experiment1.sort_values(by=['timestep'], ascending=True)
experiment2
# Out:
# Empty DataFrame
# Columns: [index, UNI_Qi, UNI_Ri, UNI_Si, UNI_Qj, UNI_Rj, UNI_Sj, UNI_ij, UNI_ji, UNI_Sij, uni_agents, UNI_P_RQi, UNI_P_RQj, UNI_P_ij, pool, Q, H, Sq, Y, hydra_agents, C, asset_random_choice, trade_random_size, trade_random_direction, purchased_asset_id, simulation, subset, run, substep, timestep]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ### Starting balances

# %%
experiments.UNI_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Ri = experiments[experiments.timestep == 0]
starting_Ri = starting_Ri['UNI_Ri']
starting_Ri.reset_index(drop=True)
starting_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = starting_Ri.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_i")
plt.show()

# %%
experiments.UNI_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Rj = experiments[experiments.timestep == 0]
starting_Rj = starting_Rj['UNI_Rj']
starting_Rj.reset_index(drop=True)
starting_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
a = starting_Rj.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_j")
plt.show()

# %% [markdown]
# ### Trade Sizes

# %%
experiments.trade_random_size.unique()
# Out:
# array([1000, 1249,  931, 1324, 1762,  883, 1790, 1384,  766, 1272,  769,
#         768, 1121,   44,  138,  719,  494, 1158,  546,  294, 1733,  888,
#        1034,  288,  728, 1056,  425, 1188,  700,  855, 1927,  994,  472,
#        1412,  390, 1105,   21,  336, 1099, 1370, 1086,  943,  850,  261,
#         641,  770, 1529, 1172,  119, 1163,  808,  662, 1306, 1516, 1466,
#         581,  846, 1166, 1488,  761,  908,  447,  402, 1407, 1679,  964,
#        1502, 1181,  678, 1770,  983, 1783, -309, 1411, 1044,  851, 1046,
#           7,  891, 1179, 1739,  741,  596,  750, 1458, 1165,  736, 1257,
#        1049, 1485,  649,  837,  804,  269, 1149, 1131, 1003,  293,  790,
#         829,  599,  920, 1203, 1944, 1088, 1129,  963,   41,  987, 1031,
#        2232,  904, 1151,  416, 1572, 1376, 1396, 1702,  300, 1294, 2096,
#         505,  717, 1050,  749,  225, 1035,  469, 1237,  541, 1775,  609,
#         839,  385, 1114, 1654,  197, 1093, 1130, 1391,  382,  340, 1261,
#        1126, 1174,  660, 1117, 1147,  643, 1933,  405, 1329,  513, 1394,
#        1580,  590, 1482, 1207, 1949,  878,  624,  556,  593,  962, 1171,
#        1139, 1414, 1007, 1727,  868, 2361, 1313,  572,  465, 1242,  889,
#        1358,  577,  243,  777, 1429, 1108,  378, 1087, 1193,  559, 1077,
#        1030,  429, 1281, 1542, 1527,  312,  532, 1258, 2927, 1286, 1568,
#        1478, 1326,  843, 1380,  614,  882,  758, 1041, 2158,   67, 1344,
#         194,  765, 1545, 1033,  462, 1340,  635, 1109, 1023,  675, 2072,
#        1317,  -12, 1094,  670, 1427,  604, 1253, 1433,  400,  833,  763,
#         674, 1883,  370, 1459, 2062, 1517,  241, 1634,  647, 1222, 1388,
#         537,  971, -620,  488,  874,  377, 1817,  285,  780, 1066, 1721,
#         283, 1582, 1006,  510, 1232, 1100, 1057, 1332, 1794, 2067,   24,
#         925, 1295, 1141,  689,  896,  754,  706, 1425,  654, 1450, 1154,
#        1315], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = experiments.trade_random_size.unique()
_ = plt.hist(a, bins=30)  # arguments are passed to np.histogram
plt.title("Histogram for trade sizes")
plt.show()

# %%
def get_M(k, v):
    if k == 'sim_config':
        k, v = 'M', v['M']
    return k, v

config_ids = [
    dict(
        get_M(k, v) for k, v in config.__dict__.items() if k in ['simulation_id', 'run_id', 'sim_config', 'subset_id']
    ) for config in configs
]

# %% [markdown]
# # Liquidity dynamics

# %% [markdown]
# ## Hydra -- base

# %% [markdown]
# ### Fan Plots

# %%
param_fan_plot3(experiments, config_ids, 'a','Q')

# %%
param_fan_plot3(experiments, config_ids, 'a','H')

# %%
param_fan_plot3(experiments, config_ids, 'a','Sq')

# %%
param_fan_plot3(experiments, config_ids, 'a','Y')

# %% [markdown]
# ## Hydra -- pool

# %% [markdown]
# ### Risk asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','C')

# %% [markdown]
# ### Risk asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','C')

# %% [markdown]
# # Prices

# %% [markdown]
# ## Asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','P')

# %% [markdown]
# ## Asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','P')
