# %% [markdown]
# #  Hydra Multi-Asset Monte Carlo Experiment with varying trade sizes

# %% [markdown]
# # Testcase Definition
#
# #### Simulation Settings
# - There are 100 timesteps for each simulation run
# - Each testcase has 10 MC runs with different randomized variables
# - Block 2 randomizes trade sizes
#
#
#
# #### Agent Activities - Action Sequence
#
# There are two agents acting during the simulation. The trading agent performs "R-for-R" trades of varying direction and size over most simulation timesteps. The liquidity agent provides liquidity to the pool at timestep 10 and removes the liquidity from the pool at timestep 90.
#
# ##### Trading agent
#
# - One Agent performs random "R-for-R" trades during the simulation.
# - The direction of the trade is a random coin flip for each timestep.
# - The size of the trade is drawn from $\mathcal{N}(\mu, \sigma)$ for each timestep.
# - The agent does not act at timestep 10 nor timestep 90.
#
# ##### Liquidity agent
#
# - One Agent provides liquidity in Risk asset "i" to the pool
# - He provides the liquidity at timestep 10
# - He removes the liquidity at timestep 90
# - He does not act at other timesteps
#
# #### Block 2:
# | #   | Run | a |  $\mu_i$  | $\sigma_i$ |  $\mu_j$  | $\sigma_j$ | $\mu$   | $\sigma$ | Total runs |
# | --- |:---:|:-------:|:---------:|:----------:|:---------:|:----------:| ------- | -------- | ---------- |
# | 1   | 01 - 10    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$       |
# | 2   | 11 - 20    |   0.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 3   | 21 - 30    |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 4  |  31 - 40   |    1    | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
# | 5  | 41 - 50    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $50$     | $10$        |
# | 6  | 51 - 60    |   1.5   | $1.000.000$ |    $0$     | $1.000.000$ |    $0$     | $1.000$ | $500$    | $10$        |
#
# All tests in block 2 are performed as $10$ Monte-Carlo runs for the given parameters which results in $60$ runs in total.

# %% [markdown]
# ## Run Model

# %%
from model.config_wrapper import ConfigWrapper

from model import run_wrapper
from cadCAD import configs

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# df = run.run()
# rdf = run.postprocessing(df)
# rdf = df # debugging substeps
# pd.set_option("mode.chained_assignment", None)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py

# %%
(data, tensor_field, sessions) = run_wrapper.run(drop_midsteps=True)

experiments = data
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 15, 3, 24)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0]
# SubsetIDs: [0, 1, 2]
# Ns       : [0, 1, 2]
# ExpIDs   : [0, 0, 0]
# Execution Mode: parallelized
# {'q_sold': 2050, 'ri_sold': 1025, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1025
#  R removed from pool of  j  =  4060.9008353062673
# {'q_sold': 1988, 'ri_sold': 3976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3976
#  R removed from pool of  i  =  1003.671722017345
# {'q_sold': 2066, 'ri_sold': 4132, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4132
#  R removed from pool of  i  =  1033.0469980242196
# {'q_sold': 2154, 'ri_sold': 4308, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4308
#  R removed from pool of  i  =  1066.3518881613854
# {'q_sold': 1978, 'ri_sold': 989, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  989
#  R removed from pool of  j  =  3996.9725867720554
# {'q_sold': 1978, 'ri_sold': 3956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3956
#  R removed from pool of  i  =  978.9090478048893
# {'q_sold': 2158, 'ri_sold': 4316, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4316
#  R removed from pool of  i  =  1057.6484466841212
# {'q_sold': 2078, 'ri_sold': 1039, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1039
#  R removed from pool of  j  =  4240.278073598864
# {'q_sold': 1954, 'ri_sold': 3908, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3908
#  R removed from pool of  i  =  957.9541382774478
# {'q_sold': 2056, 'ri_sold': 1028, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'}
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  977
#  R removed from pool of  j  =  3985.5118506187573
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  977
#  R removed from pool of  j  =  3948.8285544057144
# {'q_sold': 2026, 'ri_sold': 4052, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4052
#  R removed from pool of  i  =  1002.4056442843284
# {'q_sold': 1810, 'ri_sold': 3620, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3620
#  R removed from pool of  i  =  887.5625929448288
# {'q_sold': 1828, 'ri_sold': 3656, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3656
#  R removed from pool of  i  =  888.8539678972447
# {'q_sold': 1944, 'ri_sold': 3888, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3888
#  R removed from pool of  i  =  937.0575568566564
# {'q_sold': 1900, 'ri_sold': 950, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  950
#  R removed from pool of  j  =  3941.4568478496512
# {'q_sold': 2032, 'ri_sold': 4064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4064
#  R removed from pool of  i  =  979.398276799242
# {'q_sold': 1910, 'ri_sold': 3820, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3820
#  R removed from pool of  i  =  912.287986247451
# {'q_sold': 1860, 'ri_sold': 930, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  930
#  R removed from pool of  j  =  3893.8345166654326
# {'q_sold': 2148, 'ri_sold': 1074, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1074
#  R removed from pool of  j  =  4453.783676593448
# {'q_sold': 1978, 'ri_sold': 989, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  989
#  R removed from pool of  j  =  4061.137008377118
# {'q_sold': 2008, 'ri_sold': 4016, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4016
#  R removed from pool of  i  =  978.0589120826917
# {'q_sold': 1858, 'ri_sold': 3716, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3716
#  R removed from pool of  i  =  896.942640676978
# {'q_sold': 1946, 'ri_sold': 973, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  973
#  R removed from pool of  j  =  4029.641385188559
# {'q_sold': 2012, 'ri_sold': 4024, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4024
#  R removed from pool of  i  =  971.6441357928561
# {'q_sold': 1886, 'ri_sold': 3772, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3772
#  R removed from pool of  i  =  902.6592537621036
# {'q_sold': 2038, 'ri_sold': 1019, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1019
#  R removed from pool of  j  =  4255.789805949898
# {'q_sold': 1940, 'ri_sold': 3880, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3880
#  R removed from pool of  i  =  929.4216296636732
# {'q_sold': 1972, 'ri_sold': 3944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3944
#  R removed from pool of  i  =  936.3178393749986
# {'q_sold': 1940, 'ri_sold': 3880, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3880
#  R removed from pool of  i  =  912.9379660444101
# {'q_sold': 2186, 'ri_sold': 4372, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4372
#  R removed from pool of  i  =  1019.1091241772519
# {'q_sold': 2000, 'ri_sold': 1000, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1000
#  R removed from pool of  j  =  4290.418904706719
# {'q_sold': 1896, 'ri_sold': 948, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  948
#  R removed from pool of  j  =  4029.0772098917514
# {'q_sold': 2084, 'ri_sold': 1042, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1042
#  R removed from pool of  j  =  4386.256887062336
# {'q_sold': 1878, 'ri_sold': 939, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  939
#  R removed from pool of  j  =  3915.237188452971
# {'q_sold': 2022, 'ri_sold': 1011, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1011
#  R removed from pool of  j  =  4176.320426063961
# {'q_sold': 1806, 'ri_sold': 903, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  903
#  R removed from pool of  j  =  3696.3423860619077
# {'q_sold': 1868, 'ri_sold': 3736, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3736
#  R removed from pool of  i  =  912.6462643124396
# {'q_sold': 2020, 'ri_sold': 4040, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4040
#  R removed from pool of  i  =  978.0637042052113
# {'q_sold': 2074, 'ri_sold': 1037, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1037
#  R removed from pool of  j  =  4282.241397968493
# {'q_sold': 2018, 'ri_sold': 1009, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1009
#  R removed from pool of  j  =  4126.236392001389
# {'q_sold': 1990, 'ri_sold': 995, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  995
#  R removed from pool of  j  =  4030.5348962700227
# {'q_sold': 1970, 'ri_sold': 985, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  985
#  R removed from pool of  j  =  3952.9417799219955
# {'q_sold': 1854, 'ri_sold': 3708, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3708
#  R removed from pool of  i  =  924.2298521390185
# {'q_sold': 1930, 'ri_sold': 965, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  965
#  R removed from pool of  j  =  3870.8284975653514
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  977
#  R removed from pool of  j  =  3883.4018006441183
# {'q_sold': 2106, 'ri_sold': 1053, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1053
#  R removed from pool of  j  =  4145.975915410323
# {'q_sold': 2036, 'ri_sold': 4072, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4072
#  R removed from pool of  i  =  1034.3018829708453
# {'q_sold': 1824, 'ri_sold': 912, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  912
#  R removed from pool of  j  =  3592.546459425357
# {'q_sold': 2034, 'ri_sold': 4068, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4068
#  R removed from pool of  i  =  1032.1184509324376
# {'q_sold': 1962, 'ri_sold': 981, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  981
#  R removed from pool of  j  =  3867.4412983180955
# {'q_sold': 1934, 'ri_sold': 3868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3868
#  R removed from pool of  i  =  981.1410709172487
# {'q_sold': 2062, 'ri_sold': 4124, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4124
#  R removed from pool of  i  =  1036.2552733207121
# {'q_sold': 2104, 'ri_sold': 4208, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4208
#  R removed from pool of  i  =  1047.0647933710134
# {'q_sold': 2094, 'ri_sold': 1047, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1047
#  R removed from pool of  j  =  4207.740885544685
# {'q_sold': 1918, 'ri_sold': 3836, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3836
#  R removed from pool of  i  =  954.915668996051
# {'q_sold': 1970, 'ri_sold': 985, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  985
#  R removed from pool of  j  =  3956.292950589792
# {'q_sold': 2034, 'ri_sold': 4068, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4068
#  R removed from pool of  i  =  1012.6794839458307
# {'q_sold': 2098, 'ri_sold': 1049, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1049
#  R removed from pool of  j  =  4213.183204878471
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  977
#  R removed from pool of  j  =  3886.8408339980524
# {'q_sold': 1982, 'ri_sold': 991, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  991
#  R removed from pool of  j  =  3906.429838049924
# {'q_sold': 1890, 'ri_sold': 3780, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3780
#  R removed from pool of  i  =  959.0698903750163
# {'q_sold': 1882, 'ri_sold': 941, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  941
#  R removed from pool of  j  =  3709.0927415570477
# {'q_sold': 2082, 'ri_sold': 1041, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1041
#  R removed from pool of  j  =  4065.5843449019594
# {'q_sold': 2136, 'ri_sold': 4272, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4272
#  R removed from pool of  i  =  1093.585330978036
# {'q_sold': 1994, 'ri_sold': 3988, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3988
#  R removed from pool of  i  =  1010.9320354938973
# {'q_sold': 2102, 'ri_sold': 4204, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4204
#  R removed from pool of  i  =  1055.4354760898277
# {'q_sold': 2038, 'ri_sold': 4076, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4076
#  R removed from pool of  i  =  1013.400181063218
# {'q_sold': 1936, 'ri_sold': 968, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  968
#  R removed from pool of  j  =  3894.226637249696
# {'q_sold': 2038, 'ri_sold': 4076, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4076
#  R removed from pool of  i  =  1012.9688435961725
# {'q_sold': 2154, 'ri_sold': 4308, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4308
#  R removed from pool of  i  =  1060.1938023618422
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  999
#  R removed from pool of  j  =  4060.5179534541676
# {'q_sold': 2158, 'ri_sold': 4316, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4316
#  R removed from pool of  i  =  1061.5405173441395
# {'q_sold': 1740, 'ri_sold': 3480, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3480
#  R removed from pool of  i  =  848.2022485545604
# {'q_sold': 2084, 'ri_sold': 1042, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1042
#  R removed from pool of  j  =  4271.183512067073
# {'q_sold': 2010, 'ri_sold': 4020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4020
#  R removed from pool of  i  =  981.0062140957452
# {'q_sold': 1972, 'ri_sold': 986, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  986
#  R removed from pool of  j  =  4040.3680191464955
# {'q_sold': 2010, 'ri_sold': 1005, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1005
#  R removed from pool of  j  =  4079.5247289154213
# {'q_sold': 1802, 'ri_sold': 901, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  901
#  R removed from pool of  j  =  3624.5973360085627
# {'q_sold': 1980, 'ri_sold': 3960, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3960
#  R removed from pool of  i  =  983.9885194870876
# {'q_sold': 2036, 'ri_sold': 4072, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4072
#  R removed from pool of  i  =  1002.3711352018872
# {'q_sold': 2148, 'ri_sold': 1074, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1074
#  R removed from pool of  j  =  4361.507519700332
# {'q_sold': 1950, 'ri_sold': 3900, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3900
#  R removed from pool of  i  =  960.8714716655668
# {'q_sold': 1920, 'ri_sold': 960, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  960
#  R removed from pool of  j  =  3896.478887039353
# {'q_sold': 1950, 'ri_sold': 975, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  975
#  R removed from pool of  j  =  3921.376816534088
# {'q_sold': 2092, 'ri_sold': 4184, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4184
#  R removed from pool of  i  =  1039.9787489988375
# {'q_sold': 2034, 'ri_sold': 4068, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4068
#  R removed from pool of  i  =  1001.4456652045483
# {'q_sold': 1948, 'ri_sold': 3896, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3896
#  R removed from pool of  i  =  950.2650420083664
# 50152.69400149372
# {'q_sold': 2052, 'ri_sold': 1026, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 50152.69400149372}
# Ri_plus =  984700.61476331
# {'q_sold': 2010, 'ri_sold': 1005, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1005
#  R removed from pool of  j  =  4119.151166551164
# {'q_sold': 2098, 'ri_sold': 4196, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4196
#  R removed from pool of  i  =  1023.657869358547
# {'q_sold': 1930, 'ri_sold': 3860, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3860
#  R removed from pool of  i  =  932.867123273667
# {'q_sold': 1968, 'ri_sold': 3936, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3936
#  R removed from pool of  i  =  942.6530674035894
# {'q_sold': 1962, 'ri_sold': 3924, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3924
#  R removed from pool of  i  =  931.2713380339555
# {'q_sold': 1854, 'ri_sold': 3708, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3708
#  R removed from pool of  i  =  872.3070876853308
# {'q_sold': 2030, 'ri_sold': 1015, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1015
#  R removed from pool of  j  =  4311.559759910917
# {'q_sold': 2028, 'ri_sold': 1014, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1014
#  R removed from pool of  j  =  4264.949454007205
# {'q_sold': 2002, 'ri_sold': 1001, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1001
#  R removed from pool of  j  =  4169.340463293716
# {'q_sold': 1978, 'ri_sold': 3956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3956
#  R removed from pool of  i  =  950.0147308807354
# {'q_sold': 1860, 'ri_sold': 930, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  930
#  R removed from pool of  j  =  3685.3247997576836
# {'q_sold': 1958, 'ri_sold': 979, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  979
#  R removed from pool of  j  =  3842.9556767072063
# {'q_sold': 1966, 'ri_sold': 3932, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3932
#  R removed from pool of  i  =  1001.5721012046561
# {'q_sold': 1920, 'ri_sold': 3840, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3840
#  R removed from pool of  i  =  968.628812670242
# {'q_sold': 1984, 'ri_sold': 3968, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3968
#  R removed from pool of  i  =  991.1894636901561
# {'q_sold': 2042, 'ri_sold': 1021, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1021
#  R removed from pool of  j  =  4086.7326369211078
# {'q_sold': 2190, 'ri_sold': 4380, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4380
#  R removed from pool of  i  =  1093.868544475874
# {'q_sold': 2018, 'ri_sold': 4036, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4036
#  R removed from pool of  i  =  997.4558363397373
# {'q_sold': 2026, 'ri_sold': 1013, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1013
#  R removed from pool of  j  =  4098.577135343454
# {'q_sold': 1994, 'ri_sold': 997, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A'}
# {'q_sold': 1810, 'ri_sold': 905, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  905
#  R removed from pool of  j  =  3626.749660295667
# {'q_sold': 1998, 'ri_sold': 3996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3996
#  R removed from pool of  i  =  996.6872210870497
# {'q_sold': 2008, 'ri_sold': 1004, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1004
#  R removed from pool of  j  =  4025.173615477979
# {'q_sold': 2248, 'ri_sold': 4496, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4496
#  R removed from pool of  i  =  1120.78828883986
# {'q_sold': 1982, 'ri_sold': 3964, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3964
#  R removed from pool of  i  =  977.9260712941177
# {'q_sold': 2032, 'ri_sold': 4064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4064
#  R removed from pool of  i  =  992.7839607788483
# {'q_sold': 1998, 'ri_sold': 3996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3996
#  R removed from pool of  i  =  966.6271495225374
# {'q_sold': 1884, 'ri_sold': 3768, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3768
#  R removed from pool of  i  =  902.9279959341511
# {'q_sold': 2116, 'ri_sold': 4232, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4232
#  R removed from pool of  i  =  1004.3687111324398
# {'q_sold': 2076, 'ri_sold': 1038, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1038
#  R removed from pool of  j  =  4372.963963884162
# {'q_sold': 2080, 'ri_sold': 4160, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4160
#  R removed from pool of  i  =  987.7019872516394
# {'q_sold': 1910, 'ri_sold': 955, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  955
#  R removed from pool of  j  =  4022.931804964319
# {'q_sold': 2142, 'ri_sold': 1071, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1071
#  R removed from pool of  j  =  4465.55523620348
# {'q_sold': 1860, 'ri_sold': 930, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  930
#  R removed from pool of  j  =  3838.7645346770296
# {'q_sold': 2060, 'ri_sold': 1030, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1030
#  R removed from pool of  j  =  4209.984967369586
# {'q_sold': 2220, 'ri_sold': 4440, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4440
#  R removed from pool of  i  =  1085.969943725504
# {'q_sold': 1902, 'ri_sold': 951, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  951
#  R removed from pool of  j  =  3890.7923548761755
# {'q_sold': 1944, 'ri_sold': 3888, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3888
#  R removed from pool of  i  =  950.3207198932068
# {'q_sold': 2010, 'ri_sold': 4020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4020
#  R removed from pool of  i  =  973.1545659285039
# {'q_sold': 1950, 'ri_sold': 975, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  975
#  R removed from pool of  j  =  4027.5860334414756
# {'q_sold': 1846, 'ri_sold': 923, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  923
#  R removed from pool of  j  =  3776.6692110311706
# {'q_sold': 2008, 'ri_sold': 4016, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4016
#  R removed from pool of  i  =  981.2049107734347
# {'q_sold': 1894, 'ri_sold': 3788, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3788
#  R removed from pool of  i  =  916.7336015248438
# {'q_sold': 2048, 'ri_sold': 1024, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1024
#  R removed from pool of  j  =  4228.956591180293
# {'q_sold': 1910, 'ri_sold': 955, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  955
#  R removed from pool of  j  =  3905.0641394661507
# {'q_sold': 2156, 'ri_sold': 1078, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1078
#  R removed from pool of  j  =  4363.557687013061
# {'q_sold': 1922, 'ri_sold': 3844, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3844
#  R removed from pool of  i  =  950.2504365972709
# {'q_sold': 1968, 'ri_sold': 3936, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3936
#  R removed from pool of  i  =  963.7533299664501
# {'q_sold': 2082, 'ri_sold': 1041, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1041
#  R removed from pool of  j  =  4249.841415652772
# {'q_sold': 1878, 'ri_sold': 939, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  939
#  R removed from pool of  j  =  3795.784154882771
# {'q_sold': 2024, 'ri_sold': 4048, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4048
#  R removed from pool of  i  =  1001.0832875652704
# {'q_sold': 2132, 'ri_sold': 4264, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4264
#  R removed from pool of  i  =  1043.8056471151067
# {'q_sold': 1840, 'ri_sold': 3680, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3680
#  R removed from pool of  i  =  892.152246879763
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1010
#  R removed from pool of  j  =  4163.646449117805
# {'q_sold': 2026, 'ri_sold': 1013, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1013
#  R removed from pool of  j  =  4133.921622918686
# {'q_sold': 2080, 'ri_sold': 1040, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1040
#  R removed from pool of  j  =  4200.916115180124
# {'q_sold': 1878, 'ri_sold': 3756, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3756
#  R removed from pool of  i  =  930.3622667182935
# {'q_sold': 1868, 'ri_sold': 3736, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3736
#  R removed from pool of  i  =  916.9346562043065
# {'q_sold': 2054, 'ri_sold': 1027, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1027
#  R removed from pool of  j  =  4182.162986465148
# {'q_sold': 2030, 'ri_sold': 4060, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4060
#  R removed from pool of  i  =  997.1497177298879
# {'q_sold': 2026, 'ri_sold': 4052, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4052
#  R removed from pool of  i  =  985.3654248644598
# ...
#  R to R swap called
#  R added to pool of  i  =  1021
#  R removed from pool of  j  =  4412.414212166914
# {'q_sold': 1874, 'ri_sold': 3748, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3748
#  R removed from pool of  i  =  867.9786453444976
# {'q_sold': 2092, 'ri_sold': 1046, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1046
#  R removed from pool of  j  =  4512.381186601007
# {'q_sold': 2214, 'ri_sold': 4428, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4428
#  R removed from pool of  i  =  1026.547988978331
# {'q_sold': 2104, 'ri_sold': 1052, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1052
#  R removed from pool of  j  =  4537.165162120014
# {'q_sold': 1850, 'ri_sold': 925, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  925
#  R removed from pool of  j  =  3947.1832452757517
# {'q_sold': 1952, 'ri_sold': 976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  976
#  R removed from pool of  j  =  4122.632742874208
# {'q_sold': 2128, 'ri_sold': 1064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1064
#  R removed from pool of  j  =  4445.783933092491
# {'q_sold': 1930, 'ri_sold': 3860, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3860
#  R removed from pool of  i  =  924.4920223410008
# {'q_sold': 2046, 'ri_sold': 1023, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1023
#  R removed from pool of  j  =  4269.0698500406
# {'q_sold': 2078, 'ri_sold': 4156, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4156
#  R removed from pool of  i  =  996.0478569259867
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  954
#  R removed from pool of  j  =  3981.4418615991017
# {'q_sold': 1996, 'ri_sold': 998, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  998
#  R removed from pool of  j  =  4122.256411488168
# {'q_sold': 1676, 'ri_sold': 3352, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3352
#  R removed from pool of  i  =  812.3182904790156
# {'q_sold': 1898, 'ri_sold': 3796, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3796
#  R removed from pool of  i  =  911.5653219812084
# {'q_sold': 1976, 'ri_sold': 3952, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3952
#  R removed from pool of  i  =  939.7335985279642
# {'q_sold': 1876, 'ri_sold': 3752, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3752
#  R removed from pool of  i  =  883.5290035284124
# {'q_sold': 2164, 'ri_sold': 1082, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1082
#  R removed from pool of  j  =  4589.9610694489675
# {'q_sold': 1858, 'ri_sold': 929, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  929
#  R removed from pool of  j  =  3898.8318505531643
# {'q_sold': 1956, 'ri_sold': 3912, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3912
#  R removed from pool of  i  =  932.1221299080644
# {'q_sold': 2014, 'ri_sold': 4028, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4028
#  R removed from pool of  i  =  950.1681317674229
# {'q_sold': 2146, 'ri_sold': 4292, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4292
#  R removed from pool of  i  =  1001.8941438868642
# {'q_sold': 1858, 'ri_sold': 929, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  929
#  R removed from pool of  j  =  3981.28686453111
# {'q_sold': 2118, 'ri_sold': 1059, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1059
#  R removed from pool of  j  =  4490.260468937107
# {'q_sold': 2002, 'ri_sold': 4004, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4004
#  R removed from pool of  i  =  944.8967551505193
# {'q_sold': 1902, 'ri_sold': 951, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  951
#  R removed from pool of  j  =  4029.7312621367164
# {'q_sold': 2048, 'ri_sold': 1024, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1024
#  R removed from pool of  j  =  4293.582816087175
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1010
#  R removed from pool of  j  =  4189.422310866066
# {'q_sold': 1940, 'ri_sold': 3880, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3880
#  R removed from pool of  i  =  935.7718077714089
# {'q_sold': 2008, 'ri_sold': 4016, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4016
#  R removed from pool of  i  =  958.8873263496207
# {'q_sold': 1962, 'ri_sold': 981, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  981
#  R removed from pool of  j  =  4108.130209935829
# {'q_sold': 2012, 'ri_sold': 1006, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1006
#  R removed from pool of  j  =  4168.667468223139
# {'q_sold': 2068, 'ri_sold': 1034, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1034
#  R removed from pool of  j  =  4238.844956058427
# {'q_sold': 2160, 'ri_sold': 1080, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1080
#  R removed from pool of  j  =  4378.60976172064
# {'q_sold': 1878, 'ri_sold': 939, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  939
#  R removed from pool of  j  =  3767.075371934101
# {'q_sold': 2214, 'ri_sold': 4428, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4428
#  R removed from pool of  i  =  1102.802700651344
# {'q_sold': 1806, 'ri_sold': 903, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  903
#  R removed from pool of  j  =  3629.5099199945107
# {'q_sold': 1986, 'ri_sold': 993, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  993
#  R removed from pool of  j  =  3952.154895900516
# {'q_sold': 2060, 'ri_sold': 1030, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1030
#  R removed from pool of  j  =  4056.798713480821
# {'q_sold': 2030, 'ri_sold': 1015, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1015
#  R removed from pool of  j  =  3955.9319378276123
# 50142.80245087331
# {'q_sold': 1938, 'ri_sold': 969, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'N/A', 'UNI_burn': 50142.80245087331}
# Ri_plus =  987080.2545935102
# {'q_sold': 1980, 'ri_sold': 990, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  990
#  R removed from pool of  j  =  3818.968979154597
# {'q_sold': 1952, 'ri_sold': 3904, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3904
#  R removed from pool of  i  =  1011.9282638662262
# {'q_sold': 1942, 'ri_sold': 3884, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  3884
#  R removed from pool of  i  =  996.3632959123934
# {'q_sold': 2086, 'ri_sold': 4172, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4172
#  R removed from pool of  i  =  1058.88957708003
# {'q_sold': 2036, 'ri_sold': 1018, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1018
#  R removed from pool of  j  =  4011.7472148985835
# {'q_sold': 1932, 'ri_sold': 966, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  966
#  R removed from pool of  j  =  3767.8232672611484
# {'q_sold': 2090, 'ri_sold': 1045, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1045
#  R removed from pool of  j  =  4033.863944140612
# {'q_sold': 2032, 'ri_sold': 4064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4064
#  R removed from pool of  i  =  1052.7647454295075
# {'q_sold': 2082, 'ri_sold': 4164, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4164
#  R removed from pool of  i  =  1066.9274075812427
# {'q_sold': 2064, 'ri_sold': 4128, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  4128
#  R removed from pool of  i  =  1046.1611935651163
# Total execution time: 0.94s

# %% [markdown]
# # Results dataframe analysis

# %% [markdown]
# ### Excerpt from the results (head & tail)

# %%
experiments.head()
# Out:
#    index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 0      0  2000000  1000000   10000  2000000  1000000   10000  1000000
# 1      3  2000000  1000000   10000  2000000  1000000   10000  1000000
# 2      6  2000000  1000000   10000  2000000  1000000   10000  1000000
# 3      9  2000000  1000000   10000  2000000  1000000   10000  1000000
# 4     12  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#     UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 0  1000000  1000000000000  ...  1000000000000                    i
# 1  1000000  1000000000000  ...  1000000000000                    i
# 2  1000000  1000000000000  ...  1000000000000                    j
# 3  1000000  1000000000000  ...  1000000000000                    j
# 4  1000000  1000000000000  ...  1000000000000                    j
#
#    trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 0               1000            test_q_for_r                N/A           0
# 1               1025            test_r_for_r                  j           0
# 2                994            test_r_for_r                  i           0
# 3               1033            test_r_for_r                  i           0
# 4               1077            test_r_for_r                  i           0
#
#    subset  run  substep timestep
# 0       0    1        0        0
# 1       0    1        3        1
# 2       0    1        3        2
# 3       0    1        3        3
# 4       0    1        3        4
#
# [5 rows x 30 columns]

# %%
experiments.tail()
# Out:
#      index   UNI_Qi   UNI_Ri  UNI_Si   UNI_Qj   UNI_Rj  UNI_Sj   UNI_ij  \
# 298    890  2000000  1000000   10000  2000000  1000000   10000  1000000
# 299    893  2000000  1000000   10000  2000000  1000000   10000  1000000
# 300    896  2000000  1000000   10000  2000000  1000000   10000  1000000
# 301    899  2000000  1000000   10000  2000000  1000000   10000  1000000
# 302    902  2000000  1000000   10000  2000000  1000000   10000  1000000
#
#       UNI_ji        UNI_Sij  ...              C  asset_random_choice  \
# 298  1000000  1000000000000  ...  1000000000000                    i
# 299  1000000  1000000000000  ...  1000000000000                    i
# 300  1000000  1000000000000  ...  1000000000000                    j
# 301  1000000  1000000000000  ...  1000000000000                    j
# 302  1000000  1000000000000  ...  1000000000000                    j
#
#      trade_random_size  trade_random_direction purchased_asset_id  simulation  \
# 298                966            test_r_for_r                  j           0
# 299               1045            test_r_for_r                  j           0
# 300               1016            test_r_for_r                  i           0
# 301               1041            test_r_for_r                  i           0
# 302               1032            test_r_for_r                  i           0
#
#      subset  run  substep timestep
# 298       2    2        3       96
# 299       2    2        3       97
# 300       2    2        3       98
# 301       2    2        3       99
# 302       2    2        3      100
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Individual MonteCarlo results
#
# - Choose the subset from $\{0,1,2\}$ ... for different values for `a`
# - Choose the simulation from $\{0,\dots,9\}$ ... for the distinct simulation run

# %%
experiment1 = experiments[experiments.subset == 2]
experiment1 = experiment1[experiment1.run == 8]
experiment2 = experiment1.sort_values(by=['timestep'], ascending=True)
experiment2
# Out:
# Empty DataFrame
# Columns: [index, UNI_Qi, UNI_Ri, UNI_Si, UNI_Qj, UNI_Rj, UNI_Sj, UNI_ij, UNI_ji, UNI_Sij, uni_agents, UNI_P_RQi, UNI_P_RQj, UNI_P_ij, pool, Q, H, Sq, Y, hydra_agents, C, asset_random_choice, trade_random_size, trade_random_direction, purchased_asset_id, simulation, subset, run, substep, timestep]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ### Starting balances

# %%
experiments.UNI_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Ri = experiments[experiments.timestep == 0]
starting_Ri = starting_Ri['UNI_Ri']
starting_Ri.reset_index(drop=True)
starting_Ri.unique()
# Out:
# array([1000000], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = starting_Ri.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_i")
plt.show()

# %%
experiments.UNI_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
starting_Rj = experiments[experiments.timestep == 0]
starting_Rj = starting_Rj['UNI_Rj']
starting_Rj.reset_index(drop=True)
starting_Rj.unique()
# Out:
# array([1000000], dtype=int64)

# %%
a = starting_Rj.unique()
_ = plt.hist(a, bins=10)  # arguments are passed to np.histogram
plt.title("Histogram for starting R_j")
plt.show()

# %% [markdown]
# ### Trade Sizes

# %%
experiments.trade_random_size.unique()
# Out:
# array([1000, 1025,  994, 1033, 1077,  989, 1079, 1039,  977, 1028, 1013,
#         905,  914,  972,  950, 1016,  955,  930, 1074, 1004,  929,  973,
#        1006,  943, 1019,  970,  986, 1093,  948, 1042,  939, 1011,  903,
#         934, 1010, 1037, 1009,  995,  985,  927,  965, 1053, 1018,  912,
#        1017,  981,  967, 1031, 1052, 1047,  959, 1049,  991,  945,  941,
#        1041, 1068,  997, 1051,  968,  999,  870, 1005,  901,  990,  975,
#         960, 1046,  974, 1026,  984, 1015, 1014, 1001,  979,  983,  992,
#        1021, 1095, 1124,  942, 1058, 1038, 1040, 1071, 1030, 1110,  951,
#         923,  947, 1024, 1078,  961, 1012, 1066,  920, 1027,  966, 1094,
#         952,  988,  963,  956, 1073,  987, 1137, 1032,  958, 1036,  925,
#         978, 1043,  938, 1020, 1008, 1003, 1029, 1055,  932,  954, 1193,
#        1057, 1048,  962,  976, 1116,  907, 1035, 1034,  964, 1108,  899,
#        1044,  940, 1089,  937, 1107, 1064, 1023,  998,  838,  949, 1082,
#        1007, 1059, 1080,  993,  969,  971, 1045], dtype=int64)

# %%
import matplotlib.pyplot as plt
a = experiments.trade_random_size.unique()
_ = plt.hist(a, bins=30)  # arguments are passed to np.histogram
plt.title("Histogram for trade sizes")
plt.show()

# %%
def get_M(k, v):
    if k == 'sim_config':
        k, v = 'M', v['M']
    return k, v

config_ids = [
    dict(
        get_M(k, v) for k, v in config.__dict__.items() if k in ['simulation_id', 'run_id', 'sim_config', 'subset_id']
    ) for config in configs
]

# %% [markdown]
# # Liquidity dynamics

# %% [markdown]
# ## Hydra -- base

# %% [markdown]
# ### Fan Plots

# %%
param_fan_plot3(experiments, config_ids, 'a','Q')

# %%
param_fan_plot3(experiments, config_ids, 'a','H')

# %%
param_fan_plot3(experiments, config_ids, 'a','Sq')

# %%
param_fan_plot3(experiments, config_ids, 'a','Y')

# %% [markdown]
# ## Hydra -- pool

# %% [markdown]
# ### Risk asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','C')

# %% [markdown]
# ### Risk asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j', 'R', 'S')

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','C')

# %% [markdown]
# # Prices

# %% [markdown]
# ## Asset i

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','i','P')

# %% [markdown]
# ## Asset j

# %%
param_pool_simulation_plot(experiments, config_ids, 'a','j','P')
