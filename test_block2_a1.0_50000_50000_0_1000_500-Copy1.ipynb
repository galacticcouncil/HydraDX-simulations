# %% [markdown]
# # Documentation for Hydra Multi-Asset Verification Test
#
# ## Model Description
#
# The methodology for the tests is to create two universes - one for Hydra and one for Uniswap - to subsequently be able to represent sequences of actions on each side. As the Hydra system is unique in its design and has no counterpart yet for approprate comparisons the role of the benchmark will be fulfilled by assembling several Uniswaps together in a way that everything that can be done in Hydra can be accordingly reproduced. This allows next to compare the implications on both systems and ultimately assess the quantitative and qualitative differences of results and impacts on the Hydra system and its agents.
#
# This approach necessitates the definition and specification of two models:
#    - 1 Hydra Omnipool model with one instance that is defined in line with the [Hydra Mathematical Specification](https://hackmd.io/M7OeWimITKGVxBDHGQa6gQ?view)
#    - 1 Uniswap model with several instances that each are responsible for a particular mechanism
#         - which of 1 instance is used for liquidity provision in asset $R_i$: this is modeled as a Uniswap of $R_i$ and $Q$
#         - which of 1 instance is used for liquidity provision in asset $R_j$: this is modeled as a Uniswap of $R_j$ and $Q$
#         - which of 1 instance is used for swaps between assets $R_i$ and $R_j$: this is modeled as a Uniswap of $R_i$ and $R_j$
#
# ![](https://i.imgur.com/yb6Zh3T.png)
#
# ## Test cases
#
# A variety of testcases can be explored with this model resulting from a combination of the following parameters
#
#    - Event: Add Liquidity, Remove Liquidity, Swap Asset, Swap Asset for Base
#    - Asset: $R_i$, $R_j$, $R_k$, $Q$
#    - Multiple Action Type: Alternating, $i$ only, $j$ only
#    - Composite Action Type: Alternating, Trade Bias
#    - Enable Symmetric Liquidity: True, False
#
# In addition to these settings also a fee structure can be imposed:
#
#    - Fixed Fee
#
# ## Test agents
#
# The model specifies a number of eight agents that each have their local balances, can interact with the system and are modeled to be responsible for **one action only**. This allows to track for each testcase how the balances will develop and to show independently which events will trigger changes to local and global states. Most importantly directly and indirectly affected variables can be easily identified.
#
# Two dataframes of agents are initialized identically for both the Uniswap and the Hydra world and then work their way through on each side according to the testcase. Afterwards the effects on both sides can be compared.
#
# ![](https://i.imgur.com/r9IAJMr.png)
#
#
#
# ## Composite Action Tests
#
# Besides being able to test all mechanisms individually also compositions of actions can be performed. This means selecting and combining two from the above testcases and letting the respective agents take the actions repeadetly. A composition action test therefore is defined as two actions which each can be a combination of *event* and *asset* selected from the list of testcases above, for example:
# - Add liquidity in $R_i$ and Add liquidity in $R_j$
# - Add liquidity in $R_i$ and Swap $R_i$ for $Q$
# - Remove liquidity in $R_j$ and Swap $R_i$ for $Q$
# - ...
#
# In total there would be 28 composit pairs which can be derived from this decision tree:
# selecting any one of the four primitive mechanisms of: **trade in/out** or **add/remove liquidity** of some given asset and then the subsequent action could be the three remaining mechanisms of the same asset or doing anyone of the four mechanisms in another asset.
#
# These basic combinations can be explored before further proceeding with
# - trade sizes,
# - trade frequencies,
# - randomization,...

# %% [markdown]
# # Testcase in this notebook
#
#
# This notebook documents the results of the following experiment:
# - **Action 1**: One agent adds liquidity in XX
# - **Action 2**: Another agent trades XX for XX.
#
# which is a reslt of the following settings:
#
# - exo_trade = ['test_q_for_r'] # agent 0
# - exo_liq = ['test_add'] # agent 3
# - exo_asset = ['alternating']
# - exo_composite = ['alternating']

# %% [markdown]
# ## Introduction to Uniswap
# >Uniswap is an automated market maker for exchanging ERC20 tokens. Anyone can become a liquidity provider, and invest in the liquidity pool of an ERC20 token. This allows other users to trade that token for other tokens at an exchange rate based on their relative availibility. When a token trade is executed, a small fee is paid to the liquidity providers that enabled the transaction.
# https://uniswap.io/
#
# There are basically eight ways (_mechanisms_) in which an agent can interact with an instance of Uniswap (https://github.com/Uniswap/uniswap-v1/blob/master/contracts/uniswap_exchange.vy):
# 1. `addLiquidity`: deposit ETH and tokens in the liquidity pool; mint UNI tokens - "shares" of that Uniswap instance - in exchange;
# 1. `removeLiquidity`: burn UNI tokens; withdraw a proportional amount of ETH and tokens in exchange;
# 1. `ethToTokenInput`: user specifies an exact amount of ETH they send; receives corresponding amount of tokens
# 1. `ethToTokenOutput`: user sends some ETH and specifies an exact amount of tokens they want to buy; Uniswap refunds ETH sent in excess
# 1. `tokenToEthInput`: user specifies an exact amount of tokens they send; receives corresponding amount of ETH
# 1. `tokenToEthOutput`: user specifies an exact amount of ETH they want to buy; Uniswap takes the corresponding amount of tokens from the user account
# 1. `tokenToTokenInput`: user specifies an exact amount of "token A" they send; receives corresponding amount of "token B" (effectively a `tokenToEthInput` in instance A combined with a `ethToTokenInput` in instance B)
# 1. `tokenToTokenOutput`: user specifies an exact amount of "token B˜ they want to buy; Uniswap takes the corresponding amount of "token A" from the user account (effectively a `ethToTokenOutput` in instance B combined with a `tokenToEthOutput` in instance A)
#
# ## Limitations and simplifications of this model
# * When triggering mechanisms, Uniswap users may include conditions they would like to apply to the transaction. For example, they could define a minimum amount of UNI tokens they wish to receive as a result of adding liquidity to the pool; or the maximum number of tokens they are willing to pay for the amount of ETH requested in a `tokenToEthOutput` operation; or a deadline after which the transaction should not be processed. **This simplified model does not account for this kind conditioning.**
#
# * The `ethToTokenOutput`, `tokenToEthOutput` mechanisms are not implemented. **All swaps are treated as of the "input defined" type.**
#
# * The `tokenToToken` mechanism are not implemented, as they are merely a `tokenToEth` in the context of a single Uniswap instance.
#
# * **User _behavior_ has not been modeled**. User _actions_ are derived from the history of events of the Uniswap instance being analyzed.

# %% [markdown]
# ## Introduction to Hydra
# >Hydra is an automated market maker that generalizes the concept of Uniswap and Balancer to a) an arbitrary number of dimensions and b) a variant weight distaribution of assets in the pool that changes in accordance with action sequences in the pool. Anyone can become a liquidity provider, and invest in the 'Omnipool'. This allows other users to trade that token for other tokens at an exchange rate based on their relative availibility. When a token trade is executed, a small fee is paid to the liquidity providers that enabled the transaction.
# https://hydradx.io/
#
# There is a predefined set of (_mechanisms_) in which an agent can interact with an the Hydra Protocol :
# 1. `addLiquidity`: deposit a risk asset in the omnipool; mint HDX tokens - "shares" of this risk asset - in exchange;
# 1. `removeLiquidity`: burn HDX tokens; withdraw a proportional amount of the risk asset in exchange;
# 1. `tokenToTokenInput`: user specifies an exact amount of "token A" they send; receives corresponding amount of "token B"
# 1. `tokenToTokenOutput`: user specifies an exact amount of "token B˜ they want to buy; Hydra takes the corresponding amount of "token A" from the user account

# %% [markdown]
# ## Model File structure
#
# The folder **model** contains:
#
#  - a file config.py:
#
#     This file configures the simulation experiments by setting the number of monte carlo runs, the number of timesteps for the simulation and the simulation parameters. It also aggregates the partial states and the initial state variables.
#
#     The purpose of this file is to *configure and initialize* the experiment.
#
#
#  - a file partial_state_update_block.py
#
#     This file defines each partial state update block individually. This feature allows cadCAD to divide each simulation timestep into several 'blocks' where different state variables are mutated conditioned upon the policy input.
#
#     In the current setting
#     - the first block maps the user action to the appropriate mechanism in the uniswap world
#     - the second block maps the user action to the appropriate mechanism in the hydra world
#     - the third block resolves the quantities of HDX and weights in the hydra world
#     - the forth block calculates the metrics: the swap prices in the uniswap world and the pool prices in the hydra world
#
#     This file corresponds to the system specification diagram, where each column is one partial state update block
#
#     The purpose of this file is to *define* the sequence and details of state updates for each simulation timestep. The relevant mechanisms are imported from the files in the **parts** folder
#
#
#  - a file plot_utils.py
#
#     This file defines all plot functions that can be called in the jupyter notebook to visualize the results. In general there are three types of plots:
#     - plots related to the uniswap world (do not contain the word 'hydra')
#     - plots related to the hydra world (contain the word 'hydra')
#     - general plots applicable to both worlds (f.e Impermanent Loss)
#
#     It also can be distinguished between plots related to global system variables and local agent variables:
#     - global variables (do not contain the word 'agent')
#     - local variables (contain the word 'agent')
#
#     The purpose of this file is to *define* the way how particular properties can be plotted over time.
#
#
#  - a file run.py
#
#     This file *defines* the run and postprocessing methods and is used to execute the simulation run:
#     - run() is used to execute the simulation and create a dataframe
#     - postprocessing is used to extract relevant metrics from the simulation output in the dataframe
#
#      The purpose of this file is to *execute* the simulation and *create* metrics.
#
#
#  - a file state_variables.py
#
#     This file *sets* the number of agents and *defines* the local (agent-level) state variables, *sets* the number of assets and *defines* the global (system-state) variables of the system, *computes* the prices of the assets and *defines* the initial state object
#     - the agent states describe their holdings of assets that agents have contributed to the pool or still hold outside as well as their quantities of shares they received for their contribution
#     - the global states describe the quantities of assets in the system
#     - price variables are computed from the states both in the uniswap and hydra world
#     - the initial state object consists of
#         - two agent dataframes, one for each world respectively
#         - two sets of global variables, one for each world respectively
#         - prices for each world (? is pool = prices ?)
#
#     The purpose of this file is to *define* the global and local states of the system.
#
#
#  - a file sys_params.py
#
#     This file *contains* the system parameters and allows to select items from a list for them. Following parameters can be defined:
#     - trade action type
#     - liquidity action type
#     - multiple asset action type
#     - composite action type
#     - liquidity add type (symmetry)
#
#     In addition the following is set
#     - initial values for assets
#     - hard coded fee value
#     - choice of the system parameters from the list above
#
#
#  - a folder **parts** which itself contains general files relevant for both instances, files related specifically to Uniswap and files related specifically to Hydra
#       - [action.py](model/parts/action.py)
#        This is an action dictionary which drives the model. As there are no behavioral assumptions in the model yet, currently actions are prescribed actions in testing mode derived from events. However, action schema respects https://www.kaggle.com/markusbkoch/uniswap-ethdai-exchange as much as possible, allowing for future analysis against uniswap transaction datasets.
#         This file contains a function called 'actionDecoder' which takes its inputs from the file sys_params.py and maps those encoded events to agent actions. At first an arbitrary action dictionary is defined which then is adapted according to the choices of system parameters. In particular relevant are the parameter definitions of the asset, the composite and whether there is a trade or liquidity event defined.
#
#     - [uniswap.py](model/parts/uniswap.py)
#      Reads in action output and directs the action to the appropriate Uniswap mechanism for each corresponding Uniswap instance. Currently there are two instances in place, namely the R_i<>Q pair and the R_j<>Q pair. Both instances have their respective requisite state variables: UNI_Qx, UNI_Rx, and UNI_Sx.
#
#     - [utils.py](model/parts/utils.py)
#     Computes the state update for each Uniswap state variable and outputs the updated global state variables.
#
#      - [agent_utils.py](model/parts/agent_utils.py)
#      Computes the corresponding agent local state for each Uniswap agent resolving their action and outputs the updates local state variables.
#
#       -  [hydra.py](model/prts/hydra.py)
#      Reads in action output and directs the action to the appropriate Hydra mechanism for each state variable: Q, Sq, and pool.
#
#       - [hydra_utils.py](model/parts/hydra_utils.py)
#      Computes the state update for each Hydra state variable
#
#     -  [asset_utils.py](model/parts/asset_utils.py)
#      Computes the state update for each Reserve Asset in a Hydra Omnipool
#
#     -  [hydra_agent_utils_class.py](model/parts/hydra_agent_utils_class.py)
#      Computes the corresponding agent local state for each Hydra agent resolving their action and outputs the updates local state variables.
#
#      #### The interrelations between the files are shown here:
#
#     ![](https://i.imgur.com/mNhfQE4.png)

# %% [markdown]
# ## Run Model
#
# The following command lines import all packages, experiments and run the model
#
# This is the execution of cadcad. This writes the config object, does the execution and returns the rdf - which is a data object that shows the rows and columns of results in a dataframe
#
# Here is one additional option as well. The postprocessing causes the index of the results to be every forth because of the cadcad architecture where the partial state updates are the substeps. With this option selected we see only the end of each timestep - the last substep. Therefore only final results are shown. To get a line for each substep the postprocessing needs to be deactivated.

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# rdf = df # debugging substeps
# Out:
# running file: run.py
# running file: config.py
# running file: state_variables.py
# running file: sys_params.py
# {'fee_numerator': [1000], 'fee_denominator': [1000], 'exo_trade': ['pass'], 'exo_liq': ['pass'], 'ENABLE_SYMMETRIC_LIQ': [False], 'exo_asset': ['alternating'], 'exo_composite': ['alternating'], 'Ki': [10000000], 'ACTION_LIST': [['test_add', 'test_r_for_q', 'test_q_for_r', 'test_r_for_r', 'test_remove']], 'CHANGE_LOG': ['4-01-21'], 'a': [0.5, 1.0, 1.5], 'ENABLE_BALANCER_PRICING': [True], 'exo_trade_size': ['vary_size'], 'mu': [1000], 'sigma': [500], 'exo_random_sequence': ['on'], 'firstrun': [1], 'liquidity_Ri': [1344372], 'liquidity_Rj': [409518]}
# end of file: sys_params.py
# running file: asset_utils.py
# end of file: asset_utils.py
# {'fee_numerator': [1000], 'fee_denominator': [1000], 'exo_trade': ['pass'], 'exo_liq': ['pass'], 'ENABLE_SYMMETRIC_LIQ': [False], 'exo_asset': ['alternating'], 'exo_composite': ['alternating'], 'Ki': [10000000], 'ACTION_LIST': [['test_add', 'test_r_for_q', 'test_q_for_r', 'test_r_for_r', 'test_remove']], 'CHANGE_LOG': ['4-01-21'], 'a': [0.5, 1.0, 1.5], 'ENABLE_BALANCER_PRICING': [True], 'exo_trade_size': ['vary_size'], 'mu': [1000], 'sigma': [500], 'exo_random_sequence': ['on'], 'firstrun': [1], 'liquidity_Ri': [1344372], 'liquidity_Rj': [409518]}
# {'fee_numerator': [1000], 'fee_denominator': [1000], 'exo_trade': ['pass'], 'exo_liq': ['pass'], 'ENABLE_SYMMETRIC_LIQ': [False], 'exo_asset': ['alternating'], 'exo_composite': ['alternating'], 'Ki': [10000000], 'ACTION_LIST': [['test_add', 'test_r_for_q', 'test_q_for_r', 'test_r_for_r', 'test_remove']], 'CHANGE_LOG': ['4-01-21'], 'a': [0.5, 1.0, 1.5], 'ENABLE_BALANCER_PRICING': [True], 'exo_trade_size': ['vary_size'], 'mu': [1000], 'sigma': [500], 'exo_random_sequence': ['on'], 'firstrun': [1], 'liquidity_Ri': [1344372], 'liquidity_Rj': [409518]}
# end of file: state_variables.py
# running file: partial_state_update_block.py
# running file: action_list.py
# end of file: action_list.py
# end of file: partial_state_update_block.py
# {'fee_numerator': [1000], 'fee_denominator': [1000], 'exo_trade': ['pass'], 'exo_liq': ['pass'], 'ENABLE_SYMMETRIC_LIQ': [False], 'exo_asset': ['alternating'], 'exo_composite': ['alternating'], 'Ki': [10000000], 'ACTION_LIST': [['test_add', 'test_r_for_q', 'test_q_for_r', 'test_r_for_r', 'test_remove']], 'CHANGE_LOG': ['4-01-21'], 'a': [0.5, 1.0, 1.5], 'ENABLE_BALANCER_PRICING': [True], 'exo_trade_size': ['vary_size'], 'mu': [1000], 'sigma': [500], 'exo_random_sequence': ['on'], 'firstrun': [1], 'liquidity_Ri': [1344372], 'liquidity_Rj': [409518]}
# end of file: config.py
# end of file: run.py
# running file: plot_utils.py
# end of file: plot_utils.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 3, 22)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0]
# SubsetIDs: [0, 1, 2]
# Ns       : [0, 1, 2]
# ExpIDs   : [0, 0, 0]
# Execution Mode: parallelized
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  i
# q_sold  1400
# ri_sold  1400
# timestep  2
# asset_id  i
# q_sold  1400
# ri_sold  1400
# here
# not here
# timestep  2
# asset_id  j
# q_sold  872
# ri_sold  872
# timestep  3
# asset_id  j
# q_sold  872
# ri_sold  872
# here
# not here
# timestep  3
# asset_id  j
# q_sold  266
# ri_sold  266
# timestep  4
# asset_id  j
# q_sold  266
# ri_sold  266
# here
# not here
# timestep  4
# asset_id  i
# q_sold  845
# ri_sold  845
# timestep  5
# asset_id  i
# q_sold  845
# ri_sold  845
# here
# not here
# timestep  5
# asset_id  i
# q_sold  1244
# ri_sold  1244
# timestep  6
# asset_id  i
# q_sold  1244
# ri_sold  1244
# here
# not here
# timestep  6
# asset_id  j
# q_sold  490
# ri_sold  490
# timestep  7
# asset_id  j
# q_sold  490
# ri_sold  490
# here
# not here
# timestep  7
# asset_id  j
# q_sold  208
# ri_sold  208
# timestep  8
# asset_id  j
# q_sold  208
# ri_sold  208
# here
# not here
# timestep  8
# asset_id  i
# q_sold  1347
# ri_sold  1347
# timestep  9
# asset_id  i
# q_sold  1347
# ri_sold  1347
# here
# not here
# timestep  9
# asset_id  i
# q_sold  551
# ri_sold  551
# timestep  10
# asset_id  i
# q_sold  551
# ri_sold  551
# addliq - Sq delta Sq 7071.067811865475
# addliq - Sq delta S 7071.067811865476
# delta S 7071.067811865475
# delta W 7071.067811865476
# here
# not here
# timestep  10
# asset_id  i
# q_sold  2047
# ri_sold  2047
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  140000  170000  160000    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  i
# q_sold  2047
# ri_sold  2047
# here
# not here
# timestep  11
# asset_id  i
# q_sold  440
# ri_sold  440
# timestep  12
# asset_id  i
# q_sold  440
# ri_sold  440
# here
# not here
# timestep  12
# asset_id  j
# q_sold  1301
# ri_sold  1301
# timestep  13
# asset_id  j
# q_sold  1301
# ri_sold  1301
# here
# not here
# timestep  13
# asset_id  j
# q_sold  1703
# ri_sold  1703
# timestep  14
# asset_id  j
# q_sold  1703
# ri_sold  1703
# here
# not here
# timestep  14
# asset_id  j
# q_sold  1920
# ri_sold  1920
# timestep  15
# asset_id  j
# q_sold  1920
# ri_sold  1920
# here
# not here
# timestep  15
# asset_id  i
# q_sold  1053
# ri_sold  1053
# timestep  16
# asset_id  i
# q_sold  1053
# ri_sold  1053
# here
# not here
# timestep  16
# asset_id  i
# q_sold  294
# ri_sold  294
# timestep  17
# asset_id  i
# q_sold  294
# ri_sold  294
# here
# not here
# timestep  17
# asset_id  i
# q_sold  769
# ri_sold  769
# timestep  18
# asset_id  i
# q_sold  769
# ri_sold  769
# here
# not here
# timestep  18
# asset_id  i
# q_sold  1346
# ri_sold  1346
# timestep  19
# asset_id  i
# q_sold  1346
# ri_sold  1346
# here
# not here
# timestep  19
# asset_id  j
# q_sold  1637
# ri_sold  1637
# timestep  20
# asset_id  j
# q_sold  1637
# ri_sold  1637
# here
# not here
# timestep  20
# asset_id  j
# q_sold  816
# ri_sold  816
# timestep  21
# asset_id  j
# q_sold  816
# ri_sold  816
# here
# not here
# timestep  21
# asset_id  j
# q_sold  969
# ri_sold  969
# timestep  22
# asset_id  j
# q_sold  969
# ri_sold  969
# here
# not here
# timestep  22
# asset_id  i
# q_sold  1717
# ri_sold  1717
# timestep  23
# asset_id  i
# q_sold  1717
# ri_sold  1717
# here
# not here
# timestep  23
# asset_id  i
# q_sold  -347
# ri_sold  -347
# timestep  24
# asset_id  i
# q_sold  -347
# ri_sold  -347
# here
# not here
# timestep  24
# asset_id  i
# q_sold  1141
# ri_sold  1141
# timestep  25
# asset_id  i
# q_sold  1141
# ri_sold  1141
# here
# not here
# timestep  25
# asset_id  j
# q_sold  998
# ri_sold  998
# timestep  26
# asset_id  j
# q_sold  998
# ri_sold  998
# here
# not here
# timestep  26
# asset_id  i
# q_sold  1759
# ri_sold  1759
# timestep  27
# asset_id  i
# q_sold  1759
# ri_sold  1759
# here
# not here
# timestep  27
# asset_id  j
# q_sold  1430
# ri_sold  1430
# timestep  28
# asset_id  j
# q_sold  1430
# ri_sold  1430
# here
# not here
# timestep  28
# asset_id  i
# q_sold  1267
# ri_sold  1267
# timestep  29
# asset_id  i
# q_sold  1267
# ri_sold  1267
# here
# not here
# timestep  29
# asset_id  j
# q_sold  679
# ri_sold  679
# timestep  30
# asset_id  j
# q_sold  679
# ri_sold  679
# here
# not here
# timestep  30
# asset_id  j
# q_sold  982
# ri_sold  982
# timestep  31
# asset_id  j
# q_sold  982
# ri_sold  982
# here
# not here
# timestep  31
# asset_id  i
# q_sold  1260
# ri_sold  1260
# timestep  32
# asset_id  i
# q_sold  1260
# ri_sold  1260
# here
# not here
# timestep  32
# asset_id  j
# q_sold  1130
# ri_sold  1130
# timestep  33
# asset_id  j
# q_sold  1130
# ri_sold  1130
# here
# not here
# timestep  33
# asset_id  j
# q_sold  365
# ri_sold  365
# timestep  34
# asset_id  j
# q_sold  365
# ri_sold  365
# here
# not here
# timestep  34
# asset_id  j
# q_sold  999
# ri_sold  999
# timestep  35
# asset_id  j
# q_sold  999
# ri_sold  999
# here
# not here
# timestep  35
# asset_id  i
# q_sold  1473
# ri_sold  1473
# timestep  36
# asset_id  i
# q_sold  1473
# ri_sold  1473
# here
# not here
# timestep  36
# asset_id  i
# q_sold  307
# ri_sold  307
# timestep  37
# asset_id  i
# q_sold  307
# ri_sold  307
# here
# not here
# timestep  37
# asset_id  i
# q_sold  -196
# ri_sold  -196
# timestep  38
# asset_id  i
# q_sold  -196
# ri_sold  -196
# here
# not here
# timestep  38
# asset_id  j
# q_sold  1270
# ri_sold  1270
# timestep  39
# asset_id  j
# q_sold  1270
# ri_sold  1270
# here
# not here
# timestep  39
# asset_id  j
# q_sold  1073
# ri_sold  1073
# timestep  40
# asset_id  j
# q_sold  1073
# ri_sold  1073
# here
# not here
# timestep  40
# asset_id  i
# q_sold  819
# ri_sold  819
# timestep  41
# asset_id  i
# q_sold  819
# ri_sold  819
# here
# not here
# timestep  41
# asset_id  j
# q_sold  1050
# ri_sold  1050
# timestep  42
# asset_id  j
# q_sold  1050
# ri_sold  1050
# here
# not here
# timestep  42
# asset_id  j
# q_sold  362
# ri_sold  362
# timestep  43
# asset_id  j
# q_sold  362
# ri_sold  362
# here
# not here
# timestep  43
# asset_id  j
# q_sold  803
# ri_sold  803
# timestep  44
# asset_id  j
# q_sold  803
# ri_sold  803
# here
# not here
# timestep  44
# asset_id  j
# q_sold  490
# ri_sold  490
# timestep  45
# asset_id  j
# q_sold  490
# ri_sold  490
# here
# not here
# timestep  45
# asset_id  i
# q_sold  851
# ri_sold  851
# timestep  46
# asset_id  i
# q_sold  851
# ri_sold  851
# here
# not here
# timestep  46
# asset_id  i
# q_sold  652
# ri_sold  652
# timestep  47
# asset_id  i
# q_sold  652
# ri_sold  652
# here
# not here
# timestep  47
# asset_id  j
# q_sold  335
# ri_sold  335
# timestep  48
# asset_id  j
# q_sold  335
# ri_sold  335
# here
# not here
# timestep  48
# asset_id  j
# q_sold  196
# ri_sold  196
# timestep  49
# asset_id  j
# q_sold  196
# ri_sold  196
# here
# not here
# timestep  49
# asset_id  j
# q_sold  1064
# ri_sold  1064
# timestep  50
# asset_id  j
# q_sold  1064
# ri_sold  1064
# here
# not here
# timestep  50
# asset_id  j
# q_sold  423
# ri_sold  423
# timestep  51
# asset_id  j
# q_sold  423
# ri_sold  423
# here
# not here
# timestep  51
# asset_id  j
# q_sold  1394
# ri_sold  1394
# timestep  52
# asset_id  j
# q_sold  1394
# ri_sold  1394
# here
# not here
# timestep  52
# asset_id  i
# q_sold  1484
# ri_sold  1484
# timestep  53
# asset_id  i
# q_sold  1484
# ri_sold  1484
# here
# not here
# timestep  53
# asset_id  i
# q_sold  223
# ri_sold  223
# timestep  54
# asset_id  i
# q_sold  223
# ri_sold  223
# here
# not here
# timestep  54
# asset_id  i
# q_sold  837
# ri_sold  837
# timestep  55
# asset_id  i
# q_sold  837
# ri_sold  837
# here
# not here
# timestep  55
# asset_id  j
# q_sold  1355
# ri_sold  1355
# timestep  56
# asset_id  j
# q_sold  1355
# ri_sold  1355
# here
# not here
# timestep  56
# asset_id  i
# q_sold  460
# ri_sold  460
# timestep  57
# asset_id  i
# q_sold  460
# ri_sold  460
# here
# not here
# timestep  57
# asset_id  j
# q_sold  1389
# ri_sold  1389
# timestep  58
# asset_id  j
# q_sold  1389
# ri_sold  1389
# here
# not here
# timestep  58
# asset_id  i
# q_sold  965
# ri_sold  965
# timestep  59
# asset_id  i
# q_sold  965
# ri_sold  965
# here
# not here
# timestep  59
# asset_id  i
# q_sold  547
# ri_sold  547
# timestep  60
# asset_id  i
# q_sold  547
# ri_sold  547
# here
# not here
# timestep  60
# asset_id  j
# q_sold  1913
# ri_sold  1913
# timestep  61
# asset_id  j
# q_sold  1913
# ri_sold  1913
# here
# not here
# timestep  61
# asset_id  j
# q_sold  667
# ri_sold  667
# timestep  62
# asset_id  j
# q_sold  667
# ri_sold  667
# here
# not here
# timestep  62
# asset_id  j
# q_sold  1590
# ri_sold  1590
# timestep  63
# asset_id  j
# q_sold  1590
# ri_sold  1590
# here
# not here
# timestep  63
# asset_id  j
# q_sold  1084
# ri_sold  1084
# timestep  64
# asset_id  j
# q_sold  1084
# ri_sold  1084
# here
# not here
# timestep  64
# asset_id  i
# q_sold  599
# ri_sold  599
# timestep  65
# asset_id  i
# q_sold  599
# ri_sold  599
# here
# not here
# timestep  65
# asset_id  j
# q_sold  1436
# ri_sold  1436
# timestep  66
# asset_id  j
# q_sold  1436
# ri_sold  1436
# here
# not here
# timestep  66
# asset_id  j
# q_sold  2405
# ri_sold  2405
# timestep  67
# asset_id  j
# q_sold  2405
# ri_sold  2405
# here
# not here
# timestep  67
# asset_id  j
# q_sold  574
# ri_sold  574
# timestep  68
# asset_id  j
# q_sold  574
# ri_sold  574
# here
# not here
# timestep  68
# asset_id  j
# q_sold  283
# ri_sold  283
# timestep  69
# asset_id  j
# q_sold  283
# ri_sold  283
# here
# not here
# timestep  69
# asset_id  j
# q_sold  -95
# ri_sold  -95
# timestep  70
# asset_id  j
# q_sold  -95
# ri_sold  -95
# here
# not here
# timestep  70
# asset_id  i
# q_sold  471
# ri_sold  471
# timestep  71
# asset_id  i
# q_sold  471
# ri_sold  471
# here
# not here
# timestep  71
# asset_id  j
# q_sold  1598
# ri_sold  1598
# timestep  72
# asset_id  j
# q_sold  1598
# ri_sold  1598
# here
# not here
# timestep  72
# asset_id  i
# q_sold  1600
# ri_sold  1600
# timestep  73
# asset_id  i
# q_sold  1600
# ri_sold  1600
# here
# not here
# timestep  73
# asset_id  i
# q_sold  950
# ri_sold  950
# timestep  74
# asset_id  i
# q_sold  950
# ri_sold  950
# here
# not here
# timestep  74
# asset_id  i
# q_sold  904
# ri_sold  904
# timestep  75
# asset_id  i
# q_sold  904
# ri_sold  904
# here
# not here
# timestep  75
# asset_id  j
# q_sold  1331
# ri_sold  1331
# timestep  76
# asset_id  j
# q_sold  1331
# ri_sold  1331
# here
# not here
# timestep  76
# asset_id  j
# q_sold  1221
# ri_sold  1221
# timestep  77
# asset_id  j
# q_sold  1221
# ri_sold  1221
# here
# not here
# timestep  77
# asset_id  i
# q_sold  494
# ri_sold  494
# timestep  78
# asset_id  i
# q_sold  494
# ri_sold  494
# here
# not here
# timestep  78
# asset_id  i
# q_sold  1350
# ri_sold  1350
# timestep  79
# asset_id  i
# q_sold  1350
# ri_sold  1350
# here
# not here
# timestep  79
# asset_id  i
# q_sold  802
# ri_sold  802
# timestep  80
# asset_id  i
# q_sold  802
# ri_sold  802
# here
# not here
# timestep  80
# asset_id  i
# q_sold  1142
# ri_sold  1142
# timestep  81
# asset_id  i
# q_sold  1142
# ri_sold  1142
# here
# not here
# timestep  81
# asset_id  j
# q_sold  1581
# ri_sold  1581
# timestep  82
# asset_id  j
# q_sold  1581
# ri_sold  1581
# here
# not here
# timestep  82
# asset_id  i
# q_sold  1959
# ri_sold  1959
# timestep  83
# asset_id  i
# q_sold  1959
# ri_sold  1959
# here
# not here
# timestep  83
# asset_id  j
# q_sold  880
# ri_sold  880
# timestep  84
# asset_id  j
# q_sold  880
# ri_sold  880
# here
# not here
# timestep  84
# asset_id  i
# q_sold  -55
# ri_sold  -55
# timestep  85
# asset_id  i
# q_sold  -55
# ri_sold  -55
# here
# not here
# timestep  85
# asset_id  j
# q_sold  475
# ri_sold  475
# timestep  86
# asset_id  j
# q_sold  475
# ri_sold  475
# here
# not here
# timestep  86
# asset_id  j
# q_sold  1272
# ri_sold  1272
# timestep  87
# asset_id  j
# q_sold  1272
# ri_sold  1272
# here
# not here
# timestep  87
# asset_id  j
# q_sold  345
# ri_sold  345
# timestep  88
# asset_id  j
# q_sold  345
# ri_sold  345
# here
# not here
# timestep  88
# asset_id  i
# q_sold  1561
# ri_sold  1561
# timestep  89
# asset_id  i
# q_sold  1561
# ri_sold  1561
# here
# not here
# timestep  89
# asset_id  j
# q_sold  489
# ri_sold  489
# timestep  90
# asset_id  j
# q_sold  489
# ri_sold  489
# 160000
# Timestep-------------=  90
# delta_S remove 10000
# delta_W remove 10000.000000000002
# here
# not here
# timestep  90
# asset_id  j
# q_sold  400
# ri_sold  400
# 160000
# timestep  91
# asset_id  j
# q_sold  400
# ri_sold  400
# here
# not here
# timestep  91
# asset_id  i
# q_sold  1022
# ri_sold  1022
# timestep  92
# asset_id  i
# q_sold  1022
# ri_sold  1022
# here
# not here
# timestep  92
# asset_id  i
# q_sold  876
# ri_sold  876
# timestep  93
# asset_id  i
# q_sold  876
# ri_sold  876
# here
# not here
# timestep  93
# asset_id  i
# q_sold  1421
# ri_sold  1421
# timestep  94
# asset_id  i
# q_sold  1421
# ri_sold  1421
# here
# not here
# timestep  94
# asset_id  j
# q_sold  1499
# ri_sold  1499
# timestep  95
# asset_id  j
# q_sold  1499
# ri_sold  1499
# here
# not here
# timestep  95
# asset_id  j
# q_sold  1085
# ri_sold  1085
# timestep  96
# asset_id  j
# q_sold  1085
# ri_sold  1085
# here
# not here
# timestep  96
# asset_id  i
# q_sold  1181
# ri_sold  1181
# timestep  97
# asset_id  i
# q_sold  1181
# ri_sold  1181
# here
# not here
# timestep  97
# asset_id  j
# q_sold  1609
# ri_sold  1609
# timestep  98
# asset_id  j
# q_sold  1609
# ri_sold  1609
# here
# not here
# timestep  98
# asset_id  i
# q_sold  988
# ri_sold  988
# timestep  99
# asset_id  i
# q_sold  988
# ri_sold  988
# here
# not here
# timestep  99
# asset_id  j
# q_sold  1099
# ri_sold  1099
# timestep  100
# asset_id  j
# q_sold  1099
# ri_sold  1099
# here
# not here
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  j
# q_sold  1573
# ri_sold  1573
# timestep  2
# asset_id  j
# q_sold  1573
# ri_sold  1573
# here
# not here
# timestep  2
# asset_id  j
# q_sold  1354
# ri_sold  1354
# timestep  3
# asset_id  j
# q_sold  1354
# ri_sold  1354
# here
# not here
# timestep  3
# asset_id  i
# q_sold  1314
# ri_sold  1314
# timestep  4
# asset_id  i
# q_sold  1314
# ri_sold  1314
# here
# not here
# timestep  4
# asset_id  j
# q_sold  686
# ri_sold  686
# timestep  5
# asset_id  j
# q_sold  686
# ri_sold  686
# here
# not here
# timestep  5
# asset_id  i
# q_sold  2302
# ri_sold  2302
# timestep  6
# asset_id  i
# q_sold  2302
# ri_sold  2302
# here
# not here
# timestep  6
# asset_id  i
# q_sold  883
# ri_sold  883
# timestep  7
# asset_id  i
# q_sold  883
# ri_sold  883
# here
# not here
# timestep  7
# asset_id  i
# q_sold  810
# ri_sold  810
# timestep  8
# asset_id  i
# q_sold  810
# ri_sold  810
# here
# not here
# timestep  8
# asset_id  i
# q_sold  1052
# ri_sold  1052
# timestep  9
# asset_id  i
# q_sold  1052
# ri_sold  1052
# here
# not here
# timestep  9
# asset_id  i
# q_sold  682
# ri_sold  682
# timestep  10
# asset_id  i
# q_sold  682
# ri_sold  682
# addliq - Sq delta Sq 10000.0
# addliq - Sq delta S 10000.0
# delta S 10000.0
# delta W 10000.0
# here
# not here
# timestep  10
# asset_id  i
# q_sold  1084
# ri_sold  1084
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  140000  170000  160000    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  i
# q_sold  1084
# ri_sold  1084
# here
# not here
# timestep  11
# asset_id  i
# q_sold  -35
# ri_sold  -35
# timestep  12
# asset_id  i
# q_sold  -35
# ri_sold  -35
# here
# not here
# timestep  12
# asset_id  i
# q_sold  1125
# ri_sold  1125
# timestep  13
# asset_id  i
# q_sold  1125
# ri_sold  1125
# here
# not here
# timestep  13
# asset_id  i
# q_sold  1577
# ri_sold  1577
# timestep  14
# asset_id  i
# q_sold  1577
# ri_sold  1577
# here
# not here
# timestep  14
# asset_id  j
# q_sold  764
# ri_sold  764
# timestep  15
# asset_id  j
# q_sold  764
# ri_sold  764
# here
# not here
# timestep  15
# asset_id  j
# q_sold  1044
# ri_sold  1044
# timestep  16
# asset_id  j
# q_sold  1044
# ri_sold  1044
# here
# not here
# timestep  16
# asset_id  j
# q_sold  1104
# ri_sold  1104
# timestep  17
# asset_id  j
# q_sold  1104
# ri_sold  1104
# here
# not here
# timestep  17
# asset_id  i
# q_sold  67
# ri_sold  67
# timestep  18
# asset_id  i
# q_sold  67
# ri_sold  67
# here
# not here
# timestep  18
# asset_id  i
# q_sold  1000
# ri_sold  1000
# timestep  19
# asset_id  i
# q_sold  1000
# ri_sold  1000
# here
# not here
# timestep  19
# asset_id  i
# q_sold  1526
# ri_sold  1526
# timestep  20
# asset_id  i
# q_sold  1526
# ri_sold  1526
# here
# not here
# timestep  20
# asset_id  j
# q_sold  1088
# ri_sold  1088
# timestep  21
# asset_id  j
# q_sold  1088
# ri_sold  1088
# here
# not here
# timestep  21
# asset_id  j
# q_sold  1221
# ri_sold  1221
# timestep  22
# asset_id  j
# q_sold  1221
# ri_sold  1221
# here
# not here
# timestep  22
# asset_id  j
# q_sold  1074
# ri_sold  1074
# timestep  23
# asset_id  j
# q_sold  1074
# ri_sold  1074
# here
# not here
# timestep  23
# asset_id  j
# q_sold  1736
# ri_sold  1736
# timestep  24
# asset_id  j
# q_sold  1736
# ri_sold  1736
# here
# not here
# timestep  24
# asset_id  i
# q_sold  1554
# ri_sold  1554
# timestep  25
# asset_id  i
# q_sold  1554
# ri_sold  1554
# here
# not here
# timestep  25
# asset_id  j
# q_sold  904
# ri_sold  904
# timestep  26
# asset_id  j
# q_sold  904
# ri_sold  904
# here
# not here
# timestep  26
# asset_id  j
# q_sold  1183
# ri_sold  1183
# timestep  27
# asset_id  j
# q_sold  1183
# ri_sold  1183
# here
# not here
# timestep  27
# asset_id  j
# q_sold  1935
# ri_sold  1935
# timestep  28
# asset_id  j
# q_sold  1935
# ri_sold  1935
# here
# not here
# timestep  28
# asset_id  i
# q_sold  1240
# ri_sold  1240
# timestep  29
# asset_id  i
# q_sold  1240
# ri_sold  1240
# here
# not here
# timestep  29
# asset_id  j
# q_sold  1095
# ri_sold  1095
# timestep  30
# asset_id  j
# q_sold  1095
# ri_sold  1095
# here
# not here
# timestep  30
# asset_id  j
# q_sold  452
# ri_sold  452
# timestep  31
# asset_id  j
# q_sold  452
# ri_sold  452
# here
# not here
# timestep  31
# asset_id  i
# q_sold  1426
# ri_sold  1426
# timestep  32
# asset_id  i
# q_sold  1426
# ri_sold  1426
# here
# not here
# timestep  32
# asset_id  j
# q_sold  714
# ri_sold  714
# timestep  33
# asset_id  j
# q_sold  714
# ri_sold  714
# here
# not here
# timestep  33
# asset_id  j
# q_sold  244
# ri_sold  244
# timestep  34
# asset_id  j
# q_sold  244
# ri_sold  244
# here
# not here
# timestep  34
# asset_id  i
# q_sold  702
# ri_sold  702
# timestep  35
# asset_id  i
# q_sold  702
# ri_sold  702
# here
# not here
# timestep  35
# asset_id  j
# q_sold  1212
# ri_sold  1212
# timestep  36
# asset_id  j
# q_sold  1212
# ri_sold  1212
# here
# not here
# timestep  36
# asset_id  j
# q_sold  1313
# ri_sold  1313
# timestep  37
# asset_id  j
# q_sold  1313
# ri_sold  1313
# here
# not here
# timestep  37
# asset_id  j
# q_sold  1648
# ri_sold  1648
# timestep  38
# asset_id  j
# q_sold  1648
# ri_sold  1648
# here
# not here
# timestep  38
# asset_id  j
# q_sold  908
# ri_sold  908
# timestep  39
# asset_id  j
# q_sold  908
# ri_sold  908
# here
# not here
# timestep  39
# asset_id  j
# q_sold  1153
# ri_sold  1153
# timestep  40
# asset_id  j
# q_sold  1153
# ri_sold  1153
# here
# not here
# timestep  40
# asset_id  i
# q_sold  594
# ri_sold  594
# timestep  41
# asset_id  i
# q_sold  594
# ri_sold  594
# here
# not here
# timestep  41
# asset_id  j
# q_sold  790
# ri_sold  790
# timestep  42
# asset_id  j
# q_sold  790
# ri_sold  790
# here
# not here
# timestep  42
# asset_id  j
# q_sold  694
# ri_sold  694
# timestep  43
# asset_id  j
# q_sold  694
# ri_sold  694
# here
# not here
# timestep  43
# asset_id  j
# q_sold  1150
# ri_sold  1150
# timestep  44
# asset_id  j
# q_sold  1150
# ri_sold  1150
# here
# not here
# timestep  44
# asset_id  j
# q_sold  99
# ri_sold  99
# timestep  45
# asset_id  j
# q_sold  99
# ri_sold  99
# here
# not here
# timestep  45
# asset_id  j
# q_sold  438
# ri_sold  438
# timestep  46
# asset_id  j
# q_sold  438
# ri_sold  438
# here
# not here
# timestep  46
# asset_id  j
# q_sold  842
# ri_sold  842
# timestep  47
# asset_id  j
# q_sold  842
# ri_sold  842
# here
# not here
# timestep  47
# asset_id  j
# q_sold  617
# ri_sold  617
# timestep  48
# asset_id  j
# q_sold  617
# ri_sold  617
# here
# not here
# timestep  48
# asset_id  j
# q_sold  980
# ri_sold  980
# timestep  49
# asset_id  j
# q_sold  980
# ri_sold  980
# here
# not here
# timestep  49
# asset_id  i
# q_sold  1803
# ri_sold  1803
# timestep  50
# asset_id  i
# q_sold  1803
# ri_sold  1803
# here
# not here
# timestep  50
# asset_id  j
# q_sold  883
# ri_sold  883
# timestep  51
# asset_id  j
# q_sold  883
# ri_sold  883
# here
# not here
# timestep  51
# asset_id  i
# q_sold  593
# ri_sold  593
# timestep  52
# asset_id  i
# q_sold  593
# ri_sold  593
# here
# not here
# timestep  52
# asset_id  j
# q_sold  870
# ri_sold  870
# timestep  53
# asset_id  j
# q_sold  870
# ri_sold  870
# here
# not here
# timestep  53
# asset_id  i
# q_sold  1115
# ri_sold  1115
# timestep  54
# asset_id  i
# q_sold  1115
# ri_sold  1115
# here
# not here
# timestep  54
# asset_id  j
# q_sold  1354
# ri_sold  1354
# timestep  55
# asset_id  j
# q_sold  1354
# ri_sold  1354
# here
# not here
# timestep  55
# asset_id  j
# q_sold  830
# ri_sold  830
# timestep  56
# asset_id  j
# q_sold  830
# ri_sold  830
# here
# not here
# timestep  56
# asset_id  j
# q_sold  253
# ri_sold  253
# timestep  57
# asset_id  j
# q_sold  253
# ri_sold  253
# here
# not here
# timestep  57
# asset_id  i
# q_sold  1281
# ri_sold  1281
# timestep  58
# asset_id  i
# q_sold  1281
# ri_sold  1281
# here
# not here
# timestep  58
# asset_id  i
# q_sold  1590
# ri_sold  1590
# timestep  59
# asset_id  i
# q_sold  1590
# ri_sold  1590
# here
# not here
# timestep  59
# asset_id  i
# q_sold  229
# ri_sold  229
# timestep  60
# asset_id  i
# q_sold  229
# ri_sold  229
# here
# not here
# timestep  60
# asset_id  j
# q_sold  687
# ri_sold  687
# timestep  61
# asset_id  j
# q_sold  687
# ri_sold  687
# here
# not here
# timestep  61
# asset_id  j
# q_sold  816
# ri_sold  816
# timestep  62
# asset_id  j
# q_sold  816
# ri_sold  816
# here
# not here
# timestep  62
# asset_id  j
# q_sold  804
# ri_sold  804
# timestep  63
# asset_id  j
# q_sold  804
# ri_sold  804
# here
# not here
# timestep  63
# asset_id  i
# q_sold  1321
# ri_sold  1321
# timestep  64
# asset_id  i
# q_sold  1321
# ri_sold  1321
# here
# not here
# timestep  64
# asset_id  j
# q_sold  814
# ri_sold  814
# timestep  65
# asset_id  j
# q_sold  814
# ri_sold  814
# here
# not here
# timestep  65
# asset_id  j
# q_sold  368
# ri_sold  368
# timestep  66
# asset_id  j
# q_sold  368
# ri_sold  368
# here
# not here
# timestep  66
# asset_id  i
# q_sold  725
# ri_sold  725
# timestep  67
# asset_id  i
# q_sold  725
# ri_sold  725
# here
# not here
# timestep  67
# asset_id  i
# q_sold  1710
# ri_sold  1710
# timestep  68
# asset_id  i
# q_sold  1710
# ri_sold  1710
# here
# not here
# timestep  68
# asset_id  i
# q_sold  706
# ri_sold  706
# timestep  69
# asset_id  i
# q_sold  706
# ri_sold  706
# here
# not here
# timestep  69
# asset_id  i
# q_sold  77
# ri_sold  77
# timestep  70
# asset_id  i
# q_sold  77
# ri_sold  77
# here
# not here
# timestep  70
# asset_id  i
# q_sold  1877
# ri_sold  1877
# timestep  71
# asset_id  i
# q_sold  1877
# ri_sold  1877
# here
# not here
# timestep  71
# asset_id  i
# q_sold  973
# ri_sold  973
# timestep  72
# asset_id  i
# q_sold  973
# ri_sold  973
# here
# not here
# timestep  72
# asset_id  j
# q_sold  1872
# ri_sold  1872
# timestep  73
# asset_id  j
# q_sold  1872
# ri_sold  1872
# here
# not here
# timestep  73
# asset_id  i
# q_sold  710
# ri_sold  710
# timestep  74
# asset_id  i
# q_sold  710
# ri_sold  710
# here
# not here
# timestep  74
# asset_id  i
# q_sold  1119
# ri_sold  1119
# timestep  75
# asset_id  i
# q_sold  1119
# ri_sold  1119
# here
# not here
# timestep  75
# asset_id  i
# q_sold  1406
# ri_sold  1406
# timestep  76
# asset_id  i
# q_sold  1406
# ri_sold  1406
# here
# not here
# timestep  76
# asset_id  j
# q_sold  745
# ri_sold  745
# timestep  77
# asset_id  j
# q_sold  745
# ri_sold  745
# here
# not here
# timestep  77
# asset_id  i
# q_sold  1317
# ri_sold  1317
# timestep  78
# asset_id  i
# q_sold  1317
# ri_sold  1317
# here
# not here
# timestep  78
# asset_id  j
# q_sold  -499
# ri_sold  -499
# timestep  79
# asset_id  j
# q_sold  -499
# ri_sold  -499
# here
# not here
# timestep  79
# asset_id  j
# q_sold  1148
# ri_sold  1148
# timestep  80
# asset_id  j
# q_sold  1148
# ri_sold  1148
# here
# not here
# timestep  80
# asset_id  i
# q_sold  1723
# ri_sold  1723
# timestep  81
# asset_id  i
# q_sold  1723
# ri_sold  1723
# here
# not here
# timestep  81
# asset_id  i
# q_sold  1363
# ri_sold  1363
# timestep  82
# asset_id  i
# q_sold  1363
# ri_sold  1363
# here
# not here
# timestep  82
# asset_id  j
# q_sold  109
# ri_sold  109
# timestep  83
# asset_id  j
# q_sold  109
# ri_sold  109
# here
# not here
# timestep  83
# asset_id  i
# q_sold  1512
# ri_sold  1512
# timestep  84
# asset_id  i
# q_sold  1512
# ri_sold  1512
# here
# not here
# timestep  84
# asset_id  j
# q_sold  959
# ri_sold  959
# timestep  85
# asset_id  j
# q_sold  959
# ri_sold  959
# here
# not here
# timestep  85
# asset_id  j
# q_sold  -237
# ri_sold  -237
# timestep  86
# asset_id  j
# q_sold  -237
# ri_sold  -237
# here
# not here
# timestep  86
# asset_id  i
# q_sold  1188
# ri_sold  1188
# timestep  87
# asset_id  i
# q_sold  1188
# ri_sold  1188
# here
# not here
# timestep  87
# asset_id  j
# q_sold  1330
# ri_sold  1330
# timestep  88
# asset_id  j
# q_sold  1330
# ri_sold  1330
# here
# not here
# timestep  88
# asset_id  i
# q_sold  1142
# ri_sold  1142
# timestep  89
# asset_id  i
# q_sold  1142
# ri_sold  1142
# here
# not here
# timestep  89
# asset_id  j
# q_sold  1347
# ri_sold  1347
# timestep  90
# asset_id  j
# q_sold  1347
# ri_sold  1347
# 160000
# Timestep-------------=  90
# delta_S remove 10000
# delta_W remove 10000.0
# here
# not here
# timestep  90
# asset_id  i
# q_sold  1547
# ri_sold  1547
# 160000
# timestep  91
# asset_id  i
# q_sold  1547
# ri_sold  1547
# here
# not here
# timestep  91
# asset_id  i
# q_sold  1224
# ri_sold  1224
# timestep  92
# asset_id  i
# q_sold  1224
# ri_sold  1224
# here
# not here
# timestep  92
# asset_id  j
# q_sold  248
# ri_sold  248
# timestep  93
# asset_id  j
# q_sold  248
# ri_sold  248
# here
# not here
# timestep  93
# asset_id  j
# q_sold  748
# ri_sold  748
# timestep  94
# asset_id  j
# q_sold  748
# ri_sold  748
# here
# not here
# timestep  94
# asset_id  j
# q_sold  444
# ri_sold  444
# timestep  95
# asset_id  j
# q_sold  444
# ri_sold  444
# here
# not here
# timestep  95
# asset_id  j
# q_sold  257
# ri_sold  257
# timestep  96
# asset_id  j
# q_sold  257
# ri_sold  257
# here
# not here
# timestep  96
# asset_id  i
# q_sold  792
# ri_sold  792
# timestep  97
# asset_id  i
# q_sold  792
# ri_sold  792
# here
# not here
# timestep  97
# asset_id  i
# q_sold  1270
# ri_sold  1270
# timestep  98
# asset_id  i
# q_sold  1270
# ri_sold  1270
# here
# not here
# timestep  98
# asset_id  j
# q_sold  853
# ri_sold  853
# timestep  99
# asset_id  j
# q_sold  853
# ri_sold  853
# here
# not here
# timestep  99
# asset_id  j
# q_sold  167
# ri_sold  167
# timestep  100
# asset_id  j
# q_sold  167
# ri_sold  167
# here
# not here
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  i
# q_sold  891
# ri_sold  891
# timestep  2
# asset_id  i
# q_sold  891
# ri_sold  891
# here
# not here
# timestep  2
# asset_id  i
# q_sold  1525
# ri_sold  1525
# timestep  3
# asset_id  i
# q_sold  1525
# ri_sold  1525
# here
# not here
# timestep  3
# asset_id  i
# q_sold  277
# ri_sold  277
# timestep  4
# asset_id  i
# q_sold  277
# ri_sold  277
# here
# not here
# timestep  4
# asset_id  i
# q_sold  531
# ri_sold  531
# timestep  5
# asset_id  i
# q_sold  531
# ri_sold  531
# here
# not here
# timestep  5
# asset_id  i
# q_sold  1618
# ri_sold  1618
# timestep  6
# asset_id  i
# q_sold  1618
# ri_sold  1618
# here
# not here
# timestep  6
# asset_id  j
# q_sold  1346
# ri_sold  1346
# timestep  7
# asset_id  j
# q_sold  1346
# ri_sold  1346
# here
# not here
# timestep  7
# asset_id  i
# q_sold  356
# ri_sold  356
# timestep  8
# asset_id  i
# q_sold  356
# ri_sold  356
# here
# not here
# timestep  8
# asset_id  i
# q_sold  -183
# ri_sold  -183
# timestep  9
# asset_id  i
# q_sold  -183
# ri_sold  -183
# here
# not here
# timestep  9
# asset_id  i
# q_sold  668
# ri_sold  668
# timestep  10
# asset_id  i
# q_sold  668
# ri_sold  668
# addliq - Sq delta Sq 14142.13562373095
# addliq - Sq delta S 14142.135623730952
# delta S 14142.13562373095
# delta W 14142.135623730952
# here
# not here
# timestep  10
# asset_id  i
# q_sold  1864
# ri_sold  1864
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  140000  170000  160000    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  i
# q_sold  1864
# ri_sold  1864
# here
# not here
# timestep  11
# asset_id  i
# q_sold  1766
# ri_sold  1766
# timestep  12
# asset_id  i
# q_sold  1766
# ri_sold  1766
# here
# not here
# timestep  12
# asset_id  i
# q_sold  205
# ri_sold  205
# timestep  13
# asset_id  i
# q_sold  205
# ri_sold  205
# here
# not here
# timestep  13
# asset_id  i
# q_sold  618
# ri_sold  618
# timestep  14
# asset_id  i
# q_sold  618
# ri_sold  618
# here
# not here
# timestep  14
# asset_id  j
# q_sold  803
# ri_sold  803
# timestep  15
# asset_id  j
# q_sold  803
# ri_sold  803
# here
# not here
# timestep  15
# asset_id  i
# q_sold  1150
# ri_sold  1150
# timestep  16
# asset_id  i
# q_sold  1150
# ri_sold  1150
# here
# not here
# timestep  16
# asset_id  i
# q_sold  616
# ri_sold  616
# timestep  17
# asset_id  i
# q_sold  616
# ri_sold  616
# here
# not here
# timestep  17
# asset_id  i
# q_sold  1306
# ri_sold  1306
# timestep  18
# asset_id  i
# q_sold  1306
# ri_sold  1306
# here
# not here
# timestep  18
# asset_id  j
# q_sold  856
# ri_sold  856
# timestep  19
# asset_id  j
# q_sold  856
# ri_sold  856
# here
# not here
# timestep  19
# asset_id  i
# q_sold  1326
# ri_sold  1326
# timestep  20
# asset_id  i
# q_sold  1326
# ri_sold  1326
# here
# not here
# timestep  20
# asset_id  i
# q_sold  1834
# ri_sold  1834
# timestep  21
# asset_id  i
# q_sold  1834
# ri_sold  1834
# here
# not here
# timestep  21
# asset_id  j
# q_sold  496
# ri_sold  496
# timestep  22
# asset_id  j
# q_sold  496
# ri_sold  496
# here
# not here
# timestep  22
# asset_id  j
# q_sold  1117
# ri_sold  1117
# timestep  23
# asset_id  j
# q_sold  1117
# ri_sold  1117
# here
# not here
# timestep  23
# asset_id  j
# q_sold  587
# ri_sold  587
# timestep  24
# asset_id  j
# q_sold  587
# ri_sold  587
# here
# not here
# timestep  24
# asset_id  i
# q_sold  157
# ri_sold  157
# timestep  25
# asset_id  i
# q_sold  157
# ri_sold  157
# here
# not here
# timestep  25
# asset_id  i
# q_sold  453
# ri_sold  453
# timestep  26
# asset_id  i
# q_sold  453
# ri_sold  453
# here
# not here
# timestep  26
# asset_id  j
# q_sold  1247
# ri_sold  1247
# timestep  27
# asset_id  j
# q_sold  1247
# ri_sold  1247
# here
# not here
# timestep  27
# asset_id  j
# q_sold  1678
# ri_sold  1678
# timestep  28
# asset_id  j
# q_sold  1678
# ri_sold  1678
# here
# not here
# timestep  28
# asset_id  i
# q_sold  769
# ri_sold  769
# timestep  29
# asset_id  i
# q_sold  769
# ri_sold  769
# here
# not here
# timestep  29
# asset_id  i
# q_sold  -52
# ri_sold  -52
# timestep  30
# asset_id  i
# q_sold  -52
# ri_sold  -52
# here
# not here
# timestep  30
# asset_id  i
# q_sold  1341
# ri_sold  1341
# timestep  31
# asset_id  i
# q_sold  1341
# ri_sold  1341
# here
# not here
# timestep  31
# asset_id  j
# q_sold  1188
# ri_sold  1188
# timestep  32
# asset_id  j
# q_sold  1188
# ri_sold  1188
# here
# not here
# timestep  32
# asset_id  i
# q_sold  984
# ri_sold  984
# timestep  33
# asset_id  i
# q_sold  984
# ri_sold  984
# here
# not here
# timestep  33
# asset_id  j
# q_sold  1698
# ri_sold  1698
# timestep  34
# asset_id  j
# q_sold  1698
# ri_sold  1698
# here
# not here
# timestep  34
# asset_id  j
# q_sold  781
# ri_sold  781
# timestep  35
# asset_id  j
# q_sold  781
# ri_sold  781
# here
# not here
# timestep  35
# asset_id  j
# q_sold  1579
# ri_sold  1579
# timestep  36
# asset_id  j
# q_sold  1579
# ri_sold  1579
# here
# not here
# timestep  36
# asset_id  i
# q_sold  1197
# ri_sold  1197
# timestep  37
# asset_id  i
# q_sold  1197
# ri_sold  1197
# here
# not here
# timestep  37
# asset_id  j
# q_sold  1576
# ri_sold  1576
# timestep  38
# asset_id  j
# q_sold  1576
# ri_sold  1576
# here
# not here
# timestep  38
# asset_id  i
# q_sold  1824
# ri_sold  1824
# timestep  39
# asset_id  i
# q_sold  1824
# ri_sold  1824
# here
# not here
# timestep  39
# asset_id  j
# q_sold  626
# ri_sold  626
# timestep  40
# asset_id  j
# q_sold  626
# ri_sold  626
# here
# not here
# timestep  40
# asset_id  j
# q_sold  564
# ri_sold  564
# timestep  41
# asset_id  j
# q_sold  564
# ri_sold  564
# here
# not here
# timestep  41
# asset_id  j
# q_sold  1045
# ri_sold  1045
# timestep  42
# asset_id  j
# q_sold  1045
# ri_sold  1045
# here
# not here
# timestep  42
# asset_id  j
# q_sold  786
# ri_sold  786
# timestep  43
# asset_id  j
# q_sold  786
# ri_sold  786
# here
# not here
# timestep  43
# asset_id  i
# q_sold  1757
# ri_sold  1757
# timestep  44
# asset_id  i
# q_sold  1757
# ri_sold  1757
# here
# not here
# timestep  44
# asset_id  i
# q_sold  1000
# ri_sold  1000
# timestep  45
# asset_id  i
# q_sold  1000
# ri_sold  1000
# here
# not here
# timestep  45
# asset_id  i
# q_sold  1553
# ri_sold  1553
# timestep  46
# asset_id  i
# q_sold  1553
# ri_sold  1553
# here
# not here
# timestep  46
# asset_id  i
# q_sold  1832
# ri_sold  1832
# timestep  47
# asset_id  i
# q_sold  1832
# ri_sold  1832
# here
# not here
# timestep  47
# asset_id  j
# q_sold  864
# ri_sold  864
# timestep  48
# asset_id  j
# q_sold  864
# ri_sold  864
# here
# not here
# timestep  48
# asset_id  i
# q_sold  1027
# ri_sold  1027
# timestep  49
# asset_id  i
# q_sold  1027
# ri_sold  1027
# here
# not here
# timestep  49
# asset_id  j
# q_sold  1568
# ri_sold  1568
# timestep  50
# asset_id  j
# q_sold  1568
# ri_sold  1568
# here
# not here
# timestep  50
# asset_id  i
# q_sold  1220
# ri_sold  1220
# timestep  51
# asset_id  i
# q_sold  1220
# ri_sold  1220
# here
# not here
# timestep  51
# asset_id  i
# q_sold  1097
# ri_sold  1097
# timestep  52
# asset_id  i
# q_sold  1097
# ri_sold  1097
# here
# not here
# timestep  52
# asset_id  j
# q_sold  1153
# ri_sold  1153
# timestep  53
# asset_id  j
# q_sold  1153
# ri_sold  1153
# here
# not here
# timestep  53
# asset_id  j
# q_sold  858
# ri_sold  858
# timestep  54
# asset_id  j
# q_sold  858
# ri_sold  858
# here
# not here
# timestep  54
# asset_id  j
# q_sold  741
# ri_sold  741
# timestep  55
# asset_id  j
# q_sold  741
# ri_sold  741
# here
# not here
# timestep  55
# asset_id  j
# q_sold  2000
# ri_sold  2000
# timestep  56
# asset_id  j
# q_sold  2000
# ri_sold  2000
# here
# not here
# timestep  56
# asset_id  i
# q_sold  1186
# ri_sold  1186
# timestep  57
# asset_id  i
# q_sold  1186
# ri_sold  1186
# here
# not here
# timestep  57
# asset_id  i
# q_sold  1129
# ri_sold  1129
# timestep  58
# asset_id  i
# q_sold  1129
# ri_sold  1129
# here
# not here
# timestep  58
# asset_id  i
# q_sold  1460
# ri_sold  1460
# timestep  59
# asset_id  i
# q_sold  1460
# ri_sold  1460
# here
# not here
# timestep  59
# asset_id  j
# q_sold  1349
# ri_sold  1349
# timestep  60
# asset_id  j
# q_sold  1349
# ri_sold  1349
# here
# not here
# timestep  60
# asset_id  j
# q_sold  856
# ri_sold  856
# timestep  61
# asset_id  j
# q_sold  856
# ri_sold  856
# here
# not here
# timestep  61
# asset_id  j
# q_sold  1814
# ri_sold  1814
# timestep  62
# asset_id  j
# q_sold  1814
# ri_sold  1814
# here
# not here
# timestep  62
# asset_id  i
# q_sold  1825
# ri_sold  1825
# timestep  63
# asset_id  i
# q_sold  1825
# ri_sold  1825
# here
# not here
# timestep  63
# asset_id  i
# q_sold  770
# ri_sold  770
# timestep  64
# asset_id  i
# q_sold  770
# ri_sold  770
# here
# not here
# timestep  64
# asset_id  j
# q_sold  461
# ri_sold  461
# timestep  65
# asset_id  j
# q_sold  461
# ri_sold  461
# here
# not here
# timestep  65
# asset_id  j
# q_sold  1652
# ri_sold  1652
# timestep  66
# asset_id  j
# q_sold  1652
# ri_sold  1652
# here
# not here
# timestep  66
# asset_id  j
# q_sold  1078
# ri_sold  1078
# timestep  67
# asset_id  j
# q_sold  1078
# ri_sold  1078
# here
# not here
# timestep  67
# asset_id  i
# q_sold  1268
# ri_sold  1268
# timestep  68
# asset_id  i
# q_sold  1268
# ri_sold  1268
# here
# not here
# timestep  68
# asset_id  j
# q_sold  1028
# ri_sold  1028
# timestep  69
# asset_id  j
# q_sold  1028
# ri_sold  1028
# here
# not here
# timestep  69
# asset_id  i
# q_sold  1923
# ri_sold  1923
# timestep  70
# asset_id  i
# q_sold  1923
# ri_sold  1923
# here
# not here
# timestep  70
# asset_id  j
# q_sold  1690
# ri_sold  1690
# timestep  71
# asset_id  j
# q_sold  1690
# ri_sold  1690
# here
# not here
# timestep  71
# asset_id  i
# q_sold  1011
# ri_sold  1011
# timestep  72
# asset_id  i
# q_sold  1011
# ri_sold  1011
# here
# not here
# timestep  72
# asset_id  j
# q_sold  1195
# ri_sold  1195
# timestep  73
# asset_id  j
# q_sold  1195
# ri_sold  1195
# here
# not here
# timestep  73
# asset_id  j
# q_sold  355
# ri_sold  355
# timestep  74
# asset_id  j
# q_sold  355
# ri_sold  355
# here
# not here
# timestep  74
# asset_id  j
# q_sold  824
# ri_sold  824
# timestep  75
# asset_id  j
# q_sold  824
# ri_sold  824
# here
# not here
# timestep  75
# asset_id  j
# q_sold  848
# ri_sold  848
# timestep  76
# asset_id  j
# q_sold  848
# ri_sold  848
# here
# not here
# timestep  76
# asset_id  i
# q_sold  1049
# ri_sold  1049
# timestep  77
# asset_id  i
# q_sold  1049
# ri_sold  1049
# here
# not here
# timestep  77
# asset_id  j
# q_sold  988
# ri_sold  988
# timestep  78
# asset_id  j
# q_sold  988
# ri_sold  988
# here
# not here
# timestep  78
# asset_id  i
# q_sold  458
# ri_sold  458
# timestep  79
# asset_id  i
# q_sold  458
# ri_sold  458
# here
# not here
# timestep  79
# asset_id  j
# q_sold  1211
# ri_sold  1211
# timestep  80
# asset_id  j
# q_sold  1211
# ri_sold  1211
# here
# not here
# timestep  80
# asset_id  i
# q_sold  576
# ri_sold  576
# timestep  81
# asset_id  i
# q_sold  576
# ri_sold  576
# here
# not here
# timestep  81
# asset_id  j
# q_sold  761
# ri_sold  761
# timestep  82
# asset_id  j
# q_sold  761
# ri_sold  761
# here
# not here
# timestep  82
# asset_id  i
# q_sold  713
# ri_sold  713
# timestep  83
# asset_id  i
# q_sold  713
# ri_sold  713
# here
# not here
# timestep  83
# asset_id  i
# q_sold  1085
# ri_sold  1085
# timestep  84
# asset_id  i
# q_sold  1085
# ri_sold  1085
# here
# not here
# timestep  84
# asset_id  j
# q_sold  1229
# ri_sold  1229
# timestep  85
# asset_id  j
# q_sold  1229
# ri_sold  1229
# here
# not here
# timestep  85
# asset_id  i
# q_sold  1134
# ri_sold  1134
# timestep  86
# asset_id  i
# q_sold  1134
# ri_sold  1134
# here
# not here
# timestep  86
# asset_id  j
# q_sold  1710
# ri_sold  1710
# timestep  87
# asset_id  j
# q_sold  1710
# ri_sold  1710
# here
# not here
# timestep  87
# asset_id  i
# q_sold  1020
# ri_sold  1020
# timestep  88
# asset_id  i
# q_sold  1020
# ri_sold  1020
# here
# not here
# timestep  88
# asset_id  j
# q_sold  1154
# ri_sold  1154
# timestep  89
# asset_id  j
# q_sold  1154
# ri_sold  1154
# here
# not here
# timestep  89
# asset_id  i
# q_sold  1597
# ri_sold  1597
# timestep  90
# asset_id  i
# q_sold  1597
# ri_sold  1597
# 160000
# Timestep-------------=  90
# delta_S remove 10000
# delta_W remove 10000.0
# here
# not here
# timestep  90
# asset_id  i
# q_sold  1881
# ri_sold  1881
# 160000
# timestep  91
# asset_id  i
# q_sold  1881
# ri_sold  1881
# here
# not here
# timestep  91
# asset_id  j
# q_sold  1407
# ri_sold  1407
# timestep  92
# asset_id  j
# q_sold  1407
# ri_sold  1407
# here
# not here
# timestep  92
# asset_id  j
# q_sold  542
# ri_sold  542
# timestep  93
# asset_id  j
# q_sold  542
# ri_sold  542
# here
# not here
# timestep  93
# asset_id  j
# q_sold  333
# ri_sold  333
# timestep  94
# asset_id  j
# q_sold  333
# ri_sold  333
# here
# not here
# timestep  94
# asset_id  j
# q_sold  10
# ri_sold  10
# timestep  95
# asset_id  j
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  95
# asset_id  j
# q_sold  861
# ri_sold  861
# timestep  96
# asset_id  j
# q_sold  861
# ri_sold  861
# here
# not here
# timestep  96
# asset_id  i
# q_sold  1472
# ri_sold  1472
# timestep  97
# asset_id  i
# q_sold  1472
# ri_sold  1472
# here
# not here
# timestep  97
# asset_id  j
# q_sold  496
# ri_sold  496
# timestep  98
# asset_id  j
# q_sold  496
# ri_sold  496
# here
# not here
# timestep  98
# asset_id  j
# q_sold  641
# ri_sold  641
# timestep  99
# asset_id  j
# q_sold  641
# ri_sold  641
# here
# not here
# timestep  99
# asset_id  i
# q_sold  218
# ri_sold  218
# timestep  100
# asset_id  i
# q_sold  218
# ri_sold  218
# here
# not here
# Total execution time: 0.98s

# %% [markdown]
# ## Interpretation of Results

# %% [markdown]
# ### Creation of Results
#
# Before moving to the interpretation and analysis we first create and prepare the results: sometimes just to see whether the experiment is running corectly and sometimes to see into the results for analysis
#
# The following command lines creates views based on the simulation results.
#
# - the `model_history`, counting for the i-th base asset, the risk asset and the shares of the risk asset respectively.
# - the `uniswap_j`, counting for the j-th base asset, the risk asset and the shares of the risk asset respectively.,
# - the `uniswap_ij` counting for the i-j asset, the risk asset and the shares of the risk asset respectively, and
# - `hydra`, counting the base asset amount in the pool, the total base asset supply and the shares of the base asset respectively.

# %%
model_history = rdf[['UNI_Qi', 'UNI_Ri', 'UNI_Si']]
model_history.columns = ['model_UNI_Qi', 'model_UNI_Ri', 'model_UNI_Si']

uniswap_j = rdf[['UNI_Qj', 'UNI_Rj', 'UNI_Sj']]
uniswap_j.columns = ['UNI_Qj', 'UNI_Rj', 'UNI_Sj']

uniswap_ij = rdf[['UNI_ij', 'UNI_ji', 'UNI_Sij']]
uniswap_ij.columns = ['UNI_ij', 'UNI_ji', 'UNI_Sij']

hydra = rdf[['Q', 'H', 'Sq']]
hydra.columns = ['Hydra_Q', 'Hydra_H', 'Hydra_Sq']

# %% [markdown]
# ### Risk assets in the Omnipool - the `pool` variable
#
# The `pool` variable is the risk-asset side of the Omnipool in the Hydra world.
#
# For each asset in the Omnipool this variable tracks the following quantities:
#
# - $R$ (asset quantity),
# - $S$ (share quantity),
# - $W$ (weight quantity = share quantity),
# - $P$ (price) and
# - $dP$ (change in price).
#
# To locate specific values in the `pool` dataframe
# - `first_valid_index()`
# - `first_valid_index()*x`
# - `last_valid_index()`
#
# can be used for any integer value $x$.

# %%
print(rdf.pool[rdf.first_valid_index()])
# Out:
# <class 'model.parts.asset_utils.Asset'>: {'pool': {'i': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619, 'dP': 0}, 'j': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619}, 'k': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619}}}

# %%
rdf.pool[rdf.first_valid_index()].pool
# Out:
# {'i': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619, 'dP': 0},
#  'j': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619},
#  'k': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619}}

# %%
rdf.pool[rdf.first_valid_index()*10].pool
# Out:
# {'i': {'R': 100000,
#   'S': 17071.067811865476,
#   'W': 17071.067811865476,
#   'P': 0.24142135623730954,
#   'dP': 0},
#  'j': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619},
#  'k': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.282842712474619}}

# %%
rdf.pool[rdf.last_valid_index()].pool
# Out:
# {'i': {'R': 58578.643762690495,
#   'S': 14142.135623730952,
#   'W': 14142.135623730952,
#   'P': 0.6828427124746191,
#   'dP': 0},
#  'j': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.565685424949238},
#  'k': {'R': 50000, 'S': 10000, 'W': 10000, 'P': 0.565685424949238}}

# %% [markdown]
# ### Representing results in table form
#
# The simulation results and variable quantities can be shown in table form where
#
# - `head(n)`
# - `tail(n)`
#
# can be used to target the $n$ specific entries.
#
# ##### The columns show:
# ##### for the uniswap universe
# - `UNI_Qi`...the quantity of the i-th assets base
# - `UNI_Ri`...the quantity of the i-th assets risk
# - `UNI_Si`...the quantity of the i-th assets shares
# - `UNI_Qj`...the quantity of the j-th assets base
# - `UNI_Rj`...the quantity of the j-th assets risk
# - `UNI_Sj`...the quantity of the j-th assets shares
# - `uni_agents`...the definition of the actions of the uniswap agents
# - `UNI_P_RQi`...the price of the i-th risk asset in terms of Q
# - `UNI_P_RQj`...the price of the j-th risk asset in terms of Q
#
# ##### for the hydra universe
# - `pool`...the definition of the pool variable
# - `Q`...the quantity of the base asset in the hydra pool
# - `H`...the total quantity of the base asset in the hydra system
# - `Wq`...total quantity of weigths of the base asset
# - `Sq`...total quantity of shares of the base asset
# - `hydra_agents`...the definition of the actions of the hydra agents
#
# ##### simulation parameters
# - `simulation`...simulation number
# - `subset`...subset number
# - `run`...run number
# - `substep`...substep number
# - `timestep`...timestep of simulation
#
# Notice, that due to postprocessing of the simulation results this table always shows the forth substep of each timestep only.

# %%
rdf.head(5)
# Out:
#     UNI_Qi  UNI_Ri  UNI_Si  UNI_Qj  UNI_Rj  UNI_Sj  UNI_ij  UNI_ji  \
# 4    20000   50000   10000   20000   50000   10000   50000   50000
# 8    20000   50000   10000   20000   50000   10000   50000   50000
# 12   20000   50000   10000   20000   50000   10000   50000   50000
# 16   20000   50000   10000   20000   50000   10000   50000   50000
# 20   20000   50000   10000   20000   50000   10000   50000   50000
#
#        UNI_Sij                                         uni_agents  ...  \
# 4   2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 8   2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 12  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 16  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 20  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
#
#          Sq                                       hydra_agents  \
# 4  20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 8  20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 12 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 16 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 20 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
#
#                   C asset_random_choice  trade_random_size  simulation  \
# 4  1000000000000.00                   i               1400           0
# 8  1000000000000.00                   j                872           0
# 12 1000000000000.00                   j                266           0
# 16 1000000000000.00                   i                845           0
# 20 1000000000000.00                   i               1244           0
#
#     subset  run substep  timestep
# 4        0    1       4         1
# 8        0    1       4         2
# 12       0    1       4         3
# 16       0    1       4         4
# 20       0    1       4         5
#
# [5 rows x 27 columns]

# %%
rdf.tail()
# Out:
#       UNI_Qi  UNI_Ri  UNI_Si  UNI_Qj  UNI_Rj  UNI_Sj  UNI_ij  UNI_ji  \
# 1186   20000   50000   10000   20000   50000   10000   50000   50000
# 1190   20000   50000   10000   20000   50000   10000   50000   50000
# 1194   20000   50000   10000   20000   50000   10000   50000   50000
# 1198   20000   50000   10000   20000   50000   10000   50000   50000
# 1202   20000   50000   10000   20000   50000   10000   50000   50000
#
#          UNI_Sij                                         uni_agents  ...  \
# 1186  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1190  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1194  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1198  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1202  2500000000     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
#
#            Sq                                       hydra_agents  \
# 1186 24142.14     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1190 24142.14     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1194 24142.14     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1198 24142.14     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1202 24142.14     m  r_i_out  r_i_in       h     q_i     s_i ...
#
#                     C asset_random_choice  trade_random_size  simulation  \
# 1186 1414213562373.10                   i               1472           0
# 1190 1414213562373.10                   j                496           0
# 1194 1414213562373.10                   j                641           0
# 1198 1414213562373.10                   i                218           0
# 1202 1414213562373.10                   j                234           0
#
#       subset  run substep  timestep
# 1186       2    2       4        96
# 1190       2    2       4        97
# 1194       2    2       4        98
# 1198       2    2       4        99
# 1202       2    2       4       100
#
# [5 rows x 27 columns]

# %% [markdown]
# # The pools and global states

# %% [markdown]
# ## Global State variables for the Uniswap world
# ## i - Q instance
# ### Quantities of i-th risk asset, the Q asset and the i-asset shares
#
# The following command lines **create three plots** that show: (for the i-th asset)
# - on the left: the quantity of base asset `model_UNI_Qi`
# - center: the quantity of risk asset `model_UNI_Ri`
# - on the right: the quantity of shares `model_UNI_Si`
# over all simulation steps
#
# To show other assets the suffix of these commands can be replaced by f.e. `Qj` instead of `Qi`

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Qi'])
plt.title('UNISWAP Asset i Q-Base Token')

ax = plt.subplot(132)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Ri'])
plt.title('UNISWAP Asset i Reserve Risk')

ax = plt.subplot(133)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Si'])
plt.title('UNISWAP Asset i Shares')
plt.show()

# %% [markdown]
# ### Prices of the i-th asset
#
# The following command line creates a plot of the prices: (for the i-th asset)
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.
#
# For experiments where the price of the asset is affected - for example when it is traded - we expect this price either to rise or fall accordingly. For liquidity adds this price should remain unchanged.
#
# To show other assets the suffix of these commands can be replaced by f.e. `Qj` instead of `Qi`

# %%
price_plot(rdf,'UNISWAP Asset i Price', 'UNI_P_RQi', 'UNI_Ri', 'UNI_Qi')

# %% [markdown]
# ## j - Q instance
# ### Quantities of j-th risk asset, the Q asset and the j-asset shares
#
#
# The following command lines create three plots that show: (for the j-th asset)
# - on the left: the quantity of base asset `UNI_Qj`
# - center: the quantity of risk asset `UNI_Rj`
# - on the right: the quantity of shares `UNI_Sj`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Qj'])
plt.title('UNISWAP Asset j Q-Base Token')

ax = plt.subplot(132)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Rj'])
plt.title('UNISWAP Asset j Reserve Risk')

ax = plt.subplot(133)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Sj'])
plt.title('UNISWAP Asset j Shares')
plt.show()

# %% [markdown]
# ### Prices of the j-th asset
#
# The following command line creates a plot of the prices: (for the j-th asset)
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.
#
# For experiments where the price of the asset is affected - for example when it is traded - we expect this price either to rise or fall accordingly. For liquidity adds this price should remain unchanged.

# %%
price_plot(rdf,'UNISWAP Asset j Price', 'UNI_P_RQj', 'UNI_Rj', 'UNI_Qj')

# %% [markdown]
# ## i-j instance
# ### Quantities of i-th risk asset, the j-th risk asset and the i-j-asset shares
#
#
# The following command lines create three plots that show: (for the j-th asset)
# - on the left: the quantity of the i-th asset `UNI_ij`
# - center: the quantity of the j-th asset `UNI_ji`
# - on the right: the quantity of i-j-shares `UNI_Sij`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_ij'])
plt.title('UNISWAP IJ Instance Asset i Token')

ax = plt.subplot(132)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_ji'])
plt.title('UNISWAP IJ Instance Asset j Token')

ax = plt.subplot(133)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_Sij'])
plt.title('UNISWAP IJ Instance Shares')
plt.show()

# %% [markdown]
# ### Prices of the i-j asset swap
#
# The following command line creates a plot of the swap prices
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.

# %%
price_plot(rdf,'UNISWAP Instance ij Price', 'UNI_P_ij', 'UNI_ji','UNI_ij' )

# %% [markdown]
# ## Global State Variables for Hydra instance
#
# The Hydra system state can be described with the following global variables:
#
# | Symbol | Name | Definition  | Domain |  | Unit | |
# | --------|------- | -------- | -------- | -------- | -------- |-------|
# | $H$     | HDX Total Supply     | Supply is the total quantity of the native protocol token (HDX).|  ${\mathbb{R}_{++}}$| | HDX; an amount in real positive numbers
# | $Q$     | Base Pool Liquidity     | Base Pool Liquidity is the total quantity of the base asset (HDX) inside Pool.|  ${\mathbb{R}_{+}}$| | HDX; a positive real number if a pool has at least one risk asset
# | $\mathbf{\vec{R}}$ | Reserve Risk Assets     | An $n$-dimensional vector whose components are quantities of risk assets provided to the Liquidity Pool by liquidity providers.      |  $\mathbb{R}_{++}^{n}$ | | BTC, ETH, DOT,...; a vector of real positive numbers denoting quantities of each asset in the pool.
# | $\mathbf{\vec{S}}$     | Asset Shares     | Asset Shares are non-normalized values of each risk asset in the pool which are minted and distributed to the liquidity providers at time of inception of their asset into the Liquidity Pool. |  $\mathbb{R}_{++}^{n}$ | | a vector of real positive numbers
# | $S^Q$     | Base Pool Share     | The Pool value share of the base asset (HDX), i.e. claims on $Q$.|  $\mathbb{R}_{+}$ | | HDX; a real positive number if there exists at least one risk asset in the pool
# | $\mathbf{\vec{W}}$     | Asset Weights     | Asset Weights are non-normalized values of each risk asset in the pool used in the Uniswap/Balancer mechanisms. |  $\mathbb{R}_{++}^{n}$ | | a vector of real positive numbers
# | $W^Q$     | Base Pool Weight     | The non-normalized Pool value weight of the base asset (HDX).|  $\mathbb{R}_{+}$ | | a real positive number
# | $\mathbf{{P}}$     | Price    | The Price is a (n+1)x(n+1) Matrix listing all spot prices for all risk assets present in the Liquidity pool. Its components $p_{i,j}$ are the prices of the i-th asset denoted in the j-th asset.| $\mathbb{R}_{++}^{n\times n}$ | | f.e: ETH/HDX; depending on the component $p_{ij}$ of the matrix the unit is currency$_i$ / currency$_j$ where for the above example $i$ is ETH and $j$ is HDX. |
# | $\vec{p}^Q$     | Asset Base Price    | The Asset Base Price is a vector listing the spot prices of all risk assets in the pool in terms of the base asset HDX. | $\mathbb{R}^n_{++}$ | | A real number representing the rate of exchange between a risk asset and HDX, e.g. ETH/HDX. |
#
#
# Notice that $H$, $Q$ and $S^Q$ represent the Base side of the Omnipool and are tracked separately in the Hydra World whereas the other variables representing the Risk side of the Omnipool are encoded in $\mathbf{\vec{R}}$ , $\mathbf{\vec{S}}$  are tracked by the `pool` variable

# %% [markdown]
# ## Hydra World
# ### Base Asset side of the Omnipool
# ### Quantities of the base asset in the pool and in the system, and the base-shares
#
# The following command lines create three plots that show: (for the base asset)
# - on the left: the quantity of base asset in the pool `Hydra_Q`
# - center: the total quantity of base asset in the system `Hydra_H`
# - on the right: the quantity of base asset shares `Hydra_Sq`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
hydra.astype(float).plot(ax=ax, y=['Hydra_Q'])
plt.title('Hydra Q in OmniPool')

ax = plt.subplot(132) 
hydra.astype(float).plot(ax=ax, y=['Hydra_H'])
plt.title('Hydra H Total')

ax = plt.subplot(133)
hydra.astype(float).plot(ax=ax, y=['Hydra_Sq'])
plt.title('Hydra Sq Shares in OmniPool')
plt.show()

# %% [markdown]
# ## Hydra World
# ### Risk Asset side of the Omnipool
# ### Quantities of the i-th risk asset, i-Shares and the price for i
#
# The following command line creates three plots for the Hydra Omnipool (for the i-th asset on the risk side)
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset i Reserve and Shares', rdf.last_valid_index(),str('i'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 404
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-d5699a4afcdd> in <module>
# ----> 1 hydra_pool_plot(rdf,'Asset i Reserve and Shares', rdf.last_valid_index(),str('i'))
#
# ~\Documents\GitHub\hydra\hydra_multi_class\model\plot_utils.py in hydra_pool_plot(experiments, test_title, T, asset_id)
#      23     for i in range (df.substep.max(),T+df.substep.max(),df.substep.max()):
#      24         asset_R_list = []
# ---> 25         asset_R_list.append(df.pool[i].pool[asset_id]['R'])
#      26         asset_R.append(asset_R_list)
#      27
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     849
#     850         elif key_is_scalar:
# --> 851             return self._get_value(key)
#     852
#     853         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     957
#     958         # Similar to Index.get_value, but we do not fall back to positional
# --> 959         loc = self.index.get_loc(label)
#     960         return self.index._get_values_for_loc(self, loc, label)
#     961
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 404

# %% [markdown]
# ### Quantities of the j-th risk asset, j-Shares and the price for j
#
# The following command line creates three plots for the Hydra Omnipool
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset j Reserve and Shares', rdf.last_valid_index(),str('j'))

# %% [markdown]
# ### Quantities of the k-th risk asset, k-Shares and the price for k
#
# The following command line creates three plots for the Hydra Omnipool
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset k Reserve and Shares', rdf.last_valid_index(),str('k'))

# %% [markdown]
# ### Price comparison for assets on the risk side of the Omnipool
#
# The following command lines create a plots for the Hydra Omnipool prices:
# - Asset Base Prices
# - Share to Reserve Ratio Base Prices
# - Relative Asset Prices `i` to `j`
# - Relative Asset Prices `i` to `k`
# - Relative Asset Prices `j` to `k`

# %%
hydra_pool_price_plot(rdf,'Asset Base Price', rdf.last_valid_index(),['i', 'j','k'])

# %%
trade_liq_plot(rdf,'Share to Reserve Ratio Base Price', rdf.last_valid_index(),['i', 'j','k'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['i', 'j'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['i', 'k'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['j', 'k'])

# %% [markdown]
# # Agents and their Local State Variables
#
# The following section tracks the development for the agent states.
# As every agent is defined to be responsible for a different action and all agent states are shown this section can be used to assess
# - the intentional changes in the local states directly affected by the actions, and
# - the unintentional changes in local states of other agents who are indirectly affected
#
# All agents carry the following local states:
#
# | Symbol | Name | Definition  | Domain |   | Unit
# | -------- | -------- | -------- | -------- | -------- | --------|
# | $\mathbf{r}^j$     | Reserve Assets     | Reserve Assets are quantities of privately held risk assets by liquidity provider agent $j$ which are not (yet) related to the Liquidity Pool. |  $\mathbb{R}_{+}^{n}$| | BTC, ETH, DOT,...; an amount in real non-negative numbers denoted in the respective currency unit
# | $h^j$     | Base Asset     | Total Base Asset (HDX) amount of $H$ held by agent $j$. |  $\mathbb{R}_{+}$| | a real non-negative amount of HDX |
# | $\mathbf{s}^j$     | Risk Asset Shares     | Risk Asset Share as value of liquidity provider agent $j$'s contribution of risk asset(s) to the Liquidity Pool, minted and distributed (as a claim) to agent $j$ at the time of introduction into the Pool.| $\mathbb{R}_{+}^{n}$  | |a vector of amounts in real non-negative numbers
# | $s^{qj}$     | Base Asset Share     | Base Asset (HDX) share as value of liquidity provider agent $j$'s contribution of HDX to the Liquidity Pool,  minted and distributed to agent $j$ (as a claim) at the time of introduction into the Pool.| $\mathbb{R}_{+}$  | |a real non-negative number
#
# To locate specific values in the dataframe the commands
# - `first_valid_index()`
# - `first_valid_index()*x`
# - `last_valid_index()`
#
# can be used.

# %% [markdown]
# ## Hydra World
#
# Results for the copy of the agents going through the Hydra world are saved in `hydra_agents`

# %%
rdf['hydra_agents'][rdf.first_valid_index()]

# %%
rdf['hydra_agents'][rdf.first_valid_index()*10]

# %% [markdown]
# ## Uniswap world
#
# Results for the copy of the agents going through the Hydra world are saved in `uni_agents`

# %%
rdf['uni_agents'][rdf.first_valid_index()]

# %%
rdf['uni_agents'][rdf.first_valid_index()*7]

# %%
rdf['uni_agents'][rdf.first_valid_index()*12]

# %% [markdown]
# ## Agent Token Holdings - Uniswap World
#
#
# The following command line creates eight plots, one for each agent individually, showing his token holdings

# %%
agent_plot(rdf,'Uniswap Token Holding for Agent ', len(rdf['timestep'])) #,4,'j')

# %% [markdown]
# ## Agent Values - Uniswap World
#
# The following command line creates eight plots, one for each agents showing his values. These are the token holdings multiplied by price.

# %%
agent_value_plot(rdf,'Uniswap Value of S, R, and H in H equivalent', len(rdf['timestep'])) #,2, 'i')

# %% [markdown]
# ## Agent Token Holdings - Hydra World
#
# The following command line creates eight plots, one for each agents indivudially, showing his token holdings

# %%
hydra_agent_plot(rdf,'Hydra Token Holdings for Agent ', len(rdf['timestep']))

# %% [markdown]
# ## Agent Values - Hydra World
#
# The following command line creates eight plots, one for each agents showing his values. These are the token holdings multiplied by price.

# %%
hydra_agent_value_plot(rdf,'Hydra Omnipool Value of Si, Ri, and H in H equivalent', len(rdf['timestep'])) #,2, 'i')

# %% [markdown]
# ### Impermanent Loss (IL) calculation
#
# Impermanent loss is defined as
#
# $$
# IL = \frac{\delta Pool Value}{\delta Hold Value} - 1
# $$

# %%
IL_plot(rdf,'Impermanent Loss in Uniswap Instances Over Fixed Windows of ', 30)

# %%
import random
import math
liquidity_list = [10000, 25000, 50000, 75000, 100000, 250000, 500000, 750000, 1000000, 2000000]
sigma_ratio = [2]
liquidity_draw = []

len(liquidity_list)
liquidity_list[1]
for i in range(0, 5):
    liquidity_draw[i] = np.random.normal(liquidity_list[i], sigma_ratio)

# %%
import random
import math
liquidity_list = [10000, 25000, 50000, 75000, 100000, 250000, 500000, 750000, 1000000, 2000000]
sigma_ratio = [2]
liquidity_draw = []

liquidity_draw[0] = np.random.normal(liquidity_list[0], sigma_ratio)

# %%
liquidity_list = [10000, 25000, 50000, 75000, 100000, 250000, 500000, 750000, 1000000, 2000000]
sigma_ratio = 2
sigma_list = [x / sigma_ratio for x in liquidity_list]
liquidity_draw_ri = []
liquidity_draw_rj = []

for i in range(0, len(liquidity_list)):
    liquidity_draw_ri.append(max(0,math.ceil(np.random.normal(liquidity_list[i], sigma_list[i]))))
    liquidity_draw_rj.append(max(0,math.ceil(np.random.normal(liquidity_list[i], sigma_list[i]))))
    
liquidity_draw_ri, liquidity_draw_rj
