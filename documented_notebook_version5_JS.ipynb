# %% [markdown]
# # Documentation for Hydra Multi-Asset Verification Test
#
# ## Model Description
#
# The methodology for the tests is to create two universes - one for Hydra and one for Uniswap - to subsequently be able to represent sequences of actions on each side. As the Hydra system is unique in its design and has no counterpart yet for approprate comparisons the role of the benchmark will be fulfilled by assembling several Uniswaps together in a way that everything that can be done in Hydra can be accordingly reproduced. This allows next to compare the implications on both systems and ultimately assess the quantitative and qualitative differences of results and impacts on the Hydra system and its agents.
#
# This approach necessitates the definition and specification of two models:
#    - 1 Hydra Omnipool model with one instance that is defined in line with the [Hydra Mathematical Specification](https://hackmd.io/M7OeWimITKGVxBDHGQa6gQ?view)
#    - 1 Uniswap model with several instances that each are responsible for a particular mechanism
#         - which of 1 instance is used for liquidity provision in asset $R_i$: this is modeled as a Uniswap of $R_i$ and $Q$
#         - which of 1 instance is used for liquidity provision in asset $R_j$: this is modeled as a Uniswap of $R_j$ and $Q$
#         - which of 1 instance is used for swaps between assets $R_i$ and $R_j$: this is modeled as a Uniswap of $R_i$ and $R_j$
#
# ![](https://i.imgur.com/yb6Zh3T.png)
#
# ## Test cases
#
# A variety of testcases can be explored with this model resulting from a combination of the following parameters
#
#    - Event: Add Liquidity, Remove Liquidity, Swap Asset, Swap Asset for Base
#    - Asset: $R_i$, $R_j$, $R_k$, $Q$
#    - Multiple Action Type: Alternating, $i$ only, $j$ only
#    - Composite Action Type: Alternating, Trade Bias
#    - Enable Symmetric Liquidity: True, False
#
# In addition to these settings also a fee structure can be imposed:
#
#    - Fixed Fee
#
# ## Test agents
#
# The model specifies a number of eight agents that each have their local balances, can interact with the system and are modeled to be responsible for **one action only**. This allows to track for each testcase how the balances will develop and to show independently which events will trigger changes to local and global states. Most importantly directly and indirectly affected variables can be easily identified.
#
# Two dataframes of agents are initialized identically for both the Uniswap and the Hydra world and then work their way through on each side according to the testcase. Afterwards the effects on both sides can be compared.
#
# ![](https://i.imgur.com/r9IAJMr.png)
#
#
#
# ## Composite Action Tests
#
# Besides being able to test all mechanisms individually also compositions of actions can be performed. This means selecting and combining two from the above testcases and letting the respective agents take the actions repeadetly. A composition action test therefore is defined as two actions which each can be a combination of *event* and *asset* selected from the list of testcases above, for example:
# - Add liquidity in $R_i$ and Add liquidity in $R_j$
# - Add liquidity in $R_i$ and Swap $R_i$ for $Q$
# - Remove liquidity in $R_j$ and Swap $R_i$ for $Q$
# - ...
#
# In total there would be 28 composit pairs which can be derived from this decision tree:
# selecting any one of the four primitive mechanisms of: **trade in/out** or **add/remove liquidity** of some given asset and then the subsequent action could be the three remaining mechanisms of the same asset or doing anyone of the four mechanisms in another asset.
#
# These basic combinations can be explored before further proceeding with
# - trade sizes,
# - trade frequencies,
# - randomization,...

# %% [markdown]
# # Testcase in this notebook
#
#
# This notebook documents the results of the following experiment:
# - **Action 1**: One agent adds liquidity in XX
# - **Action 2**: Another agent trades XX for XX.
#
# which is a reslt of the following settings:
#
# - exo_trade = ['test_q_for_r'] # agent 0
# - exo_liq = ['test_add'] # agent 3
# - exo_asset = ['alternating']
# - exo_composite = ['alternating']

# %% [markdown]
# ## Introduction to Uniswap
# >Uniswap is an automated market maker for exchanging ERC20 tokens. Anyone can become a liquidity provider, and invest in the liquidity pool of an ERC20 token. This allows other users to trade that token for other tokens at an exchange rate based on their relative availibility. When a token trade is executed, a small fee is paid to the liquidity providers that enabled the transaction.
# https://uniswap.io/
#
# There are basically eight ways (_mechanisms_) in which an agent can interact with an instance of Uniswap (https://github.com/Uniswap/uniswap-v1/blob/master/contracts/uniswap_exchange.vy):
# 1. `addLiquidity`: deposit ETH and tokens in the liquidity pool; mint UNI tokens - "shares" of that Uniswap instance - in exchange;
# 1. `removeLiquidity`: burn UNI tokens; withdraw a proportional amount of ETH and tokens in exchange;
# 1. `ethToTokenInput`: user specifies an exact amount of ETH they send; receives corresponding amount of tokens
# 1. `ethToTokenOutput`: user sends some ETH and specifies an exact amount of tokens they want to buy; Uniswap refunds ETH sent in excess
# 1. `tokenToEthInput`: user specifies an exact amount of tokens they send; receives corresponding amount of ETH
# 1. `tokenToEthOutput`: user specifies an exact amount of ETH they want to buy; Uniswap takes the corresponding amount of tokens from the user account
# 1. `tokenToTokenInput`: user specifies an exact amount of "token A" they send; receives corresponding amount of "token B" (effectively a `tokenToEthInput` in instance A combined with a `ethToTokenInput` in instance B)
# 1. `tokenToTokenOutput`: user specifies an exact amount of "token B˜ they want to buy; Uniswap takes the corresponding amount of "token A" from the user account (effectively a `ethToTokenOutput` in instance B combined with a `tokenToEthOutput` in instance A)
#
# ## Limitations and simplifications of this model
# * When triggering mechanisms, Uniswap users may include conditions they would like to apply to the transaction. For example, they could define a minimum amount of UNI tokens they wish to receive as a result of adding liquidity to the pool; or the maximum number of tokens they are willing to pay for the amount of ETH requested in a `tokenToEthOutput` operation; or a deadline after which the transaction should not be processed. **This simplified model does not account for this kind conditioning.**
#
# * The `ethToTokenOutput`, `tokenToEthOutput` mechanisms are not implemented. **All swaps are treated as of the "input defined" type.**
#
# * The `tokenToToken` mechanism are not implemented, as they are merely a `tokenToEth` in the context of a single Uniswap instance.
#
# * **User _behavior_ has not been modeled**. User _actions_ are derived from the history of events of the Uniswap instance being analyzed.

# %% [markdown]
# ## Introduction to Hydra
# >Hydra is an automated market maker that generalizes the concept of Uniswap and Balancer to a) an arbitrary number of dimensions and b) a variant weight distaribution of assets in the pool that changes in accordance with action sequences in the pool. Anyone can become a liquidity provider, and invest in the 'Omnipool'. This allows other users to trade that token for other tokens at an exchange rate based on their relative availibility. When a token trade is executed, a small fee is paid to the liquidity providers that enabled the transaction.
# https://hydradx.io/
#
# There is a predefined set of (_mechanisms_) in which an agent can interact with an the Hydra Protocol :
# 1. `addLiquidity`: deposit a risk asset in the omnipool; mint HDX tokens - "shares" of this risk asset - in exchange;
# 1. `removeLiquidity`: burn HDX tokens; withdraw a proportional amount of the risk asset in exchange;
# 1. `tokenToTokenInput`: user specifies an exact amount of "token A" they send; receives corresponding amount of "token B"
# 1. `tokenToTokenOutput`: user specifies an exact amount of "token B˜ they want to buy; Hydra takes the corresponding amount of "token A" from the user account

# %% [markdown]
# ## Model File structure
#
# The folder **model** contains:
#
#  - a file config.py:
#
#     This file configures the simulation experiments by setting the number of monte carlo runs, the number of timesteps for the simulation and the simulation parameters. It also aggregates the partial states and the initial state variables.
#
#     The purpose of this file is to *configure and initialize* the experiment.
#
#
#  - a file partial_state_update_block.py
#
#     This file defines each partial state update block individually. This feature allows cadCAD to divide each simulation timestep into several 'blocks' where different state variables are mutated conditioned upon the policy input.
#
#     In the current setting
#     - the first block maps the user action to the appropriate mechanism in the uniswap world
#     - the second block maps the user action to the appropriate mechanism in the hydra world
#     - the third block resolves the quantities of HDX and weights in the hydra world
#     - the forth block calculates the metrics: the swap prices in the uniswap world and the pool prices in the hydra world
#
#     This file corresponds to the system specification diagram, where each column is one partial state update block
#
#     The purpose of this file is to *define* the sequence and details of state updates for each simulation timestep. The relevant mechanisms are imported from the files in the **parts** folder
#
#
#  - a file plot_utils.py
#
#     This file defines all plot functions that can be called in the jupyter notebook to visualize the results. In general there are three types of plots:
#     - plots related to the uniswap world (do not contain the word 'hydra')
#     - plots related to the hydra world (contain the word 'hydra')
#     - general plots applicable to both worlds (f.e Impermanent Loss)
#
#     It also can be distinguished between plots related to global system variables and local agent variables:
#     - global variables (do not contain the word 'agent')
#     - local variables (contain the word 'agent')
#
#     The purpose of this file is to *define* the way how particular properties can be plotted over time.
#
#
#  - a file run.py
#
#     This file *defines* the run and postprocessing methods and is used to execute the simulation run:
#     - run() is used to execute the simulation and create a dataframe
#     - postprocessing is used to extract relevant metrics from the simulation output in the dataframe
#
#      The purpose of this file is to *execute* the simulation and *create* metrics.
#
#
#  - a file state_variables.py
#
#     This file *sets* the number of agents and *defines* the local (agent-level) state variables, *sets* the number of assets and *defines* the global (system-state) variables of the system, *computes* the prices of the assets and *defines* the initial state object
#     - the agent states describe their holdings of assets that agents have contributed to the pool or still hold outside as well as their quantities of shares they received for their contribution
#     - the global states describe the quantities of assets in the system
#     - price variables are computed from the states both in the uniswap and hydra world
#     - the initial state object consists of
#         - two agent dataframes, one for each world respectively
#         - two sets of global variables, one for each world respectively
#         - prices for each world (? is pool = prices ?)
#
#     The purpose of this file is to *define* the global and local states of the system.
#
#
#  - a file sys_params.py
#
#     This file *contains* the system parameters and allows to select items from a list for them. Following parameters can be defined:
#     - trade action type
#     - liquidity action type
#     - multiple asset action type
#     - composite action type
#     - liquidity add type (symmetry)
#
#     In addition the following is set
#     - initial values for assets
#     - hard coded fee value
#     - choice of the system parameters from the list above
#
#
#  - a folder **parts** which itself contains general files relevant for both instances, files related specifically to Uniswap and files related specifically to Hydra
#       - [action.py](model/parts/action.py)
#        This is an action dictionary which drives the model. As there are no behavioral assumptions in the model yet, currently actions are prescribed actions in testing mode derived from events. However, action schema respects https://www.kaggle.com/markusbkoch/uniswap-ethdai-exchange as much as possible, allowing for future analysis against uniswap transaction datasets.
#         This file contains a function called 'actionDecoder' which takes its inputs from the file sys_params.py and maps those encoded events to agent actions. At first an arbitrary action dictionary is defined which then is adapted according to the choices of system parameters. In particular relevant are the parameter definitions of the asset, the composite and whether there is a trade or liquidity event defined.
#
#     - [uniswap.py](model/parts/uniswap.py)
#      Reads in action output and directs the action to the appropriate Uniswap mechanism for each corresponding Uniswap instance. Currently there are two instances in place, namely the R_i<>Q pair and the R_j<>Q pair. Both instances have their respective requisite state variables: UNI_Qx, UNI_Rx, and UNI_Sx.
#
#     - [utils.py](model/parts/utils.py)
#     Computes the state update for each Uniswap state variable and outputs the updated global state variables.
#
#      - [agent_utils.py](model/parts/agent_utils.py)
#      Computes the corresponding agent local state for each Uniswap agent resolving their action and outputs the updates local state variables.
#
#       -  [hydra.py](model/prts/hydra.py)
#      Reads in action output and directs the action to the appropriate Hydra mechanism for each state variable: Q, Sq, and pool.
#
#       - [hydra_utils.py](model/parts/hydra_utils.py)
#      Computes the state update for each Hydra state variable
#
#     -  [asset_utils.py](model/parts/asset_utils.py)
#      Computes the state update for each Reserve Asset in a Hydra Omnipool
#
#     -  [hydra_agent_utils_class.py](model/parts/hydra_agent_utils_class.py)
#      Computes the corresponding agent local state for each Hydra agent resolving their action and outputs the updates local state variables.
#
#      #### The interrelations between the files are shown here:
#
#     ![](https://i.imgur.com/mNhfQE4.png)

# %% [markdown]
# ## Run Model
#
# The following command lines import all packages, experiments and run the model
#
# This is the execution of cadcad. This writes the config object, does the execution and returns the rdf - which is a data object that shows the rows and columns of results in a dataframe
#
# Here is one additional option as well. The postprocessing causes the index of the results to be every forth because of the cadcad architecture where the partial state updates are the substeps. With this option selected we see only the end of each timestep - the last substep. Therefore only final results are shown. To get a line for each substep the postprocessing needs to be deactivated.

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# rdf = df # debugging substeps
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: partial_state_update_block.py
# running file: action_list.py
# end of file: action_list.py
# end of file: partial_state_update_block.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 16, 4, 22)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0, 0]
# SubsetIDs: [0, 1, 2, 3]
# Ns       : [0, 1, 2, 3]
# ExpIDs   : [0, 0, 0, 0]
# Execution Mode: parallelized
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  i
# q_sold  452
# ri_sold  452
# timestep  2
# asset_id  i
# q_sold  452
# ri_sold  452
# here
# not here
# timestep  2
# asset_id  i
# q_sold  726
# ri_sold  726
# timestep  3
# asset_id  i
# q_sold  726
# ri_sold  726
# here
# not here
# timestep  3
# asset_id  i
# q_sold  -182
# ri_sold  -182
# timestep  4
# asset_id  i
# q_sold  -182
# ri_sold  -182
# here
# not here
# timestep  4
# asset_id  i
# q_sold  1864
# ri_sold  1864
# timestep  5
# asset_id  i
# q_sold  1864
# ri_sold  1864
# here
# not here
# timestep  5
# asset_id  j
# q_sold  -244
# ri_sold  -244
# timestep  6
# asset_id  j
# q_sold  -244
# ri_sold  -244
# here
# not here
# timestep  6
# asset_id  j
# q_sold  389
# ri_sold  389
# timestep  7
# asset_id  j
# q_sold  389
# ri_sold  389
# here
# not here
# timestep  7
# asset_id  j
# q_sold  574
# ri_sold  574
# timestep  8
# asset_id  j
# q_sold  574
# ri_sold  574
# here
# not here
# timestep  8
# asset_id  i
# q_sold  1286
# ri_sold  1286
# timestep  9
# asset_id  i
# q_sold  1286
# ri_sold  1286
# here
# not here
# timestep  9
# asset_id  i
# q_sold  2046
# ri_sold  2046
# timestep  10
# asset_id  i
# q_sold  2046
# ri_sold  2046
# addliq - Sq delta Sq 691.0765690899374
# addliq - Sq delta S 691.0765690899374
# delta S 691.0765690899374
# delta W 691.0765690899374
# here
# not here
# timestep  10
# asset_id  j
# q_sold  680
# ri_sold  680
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  138045  171954  150977    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  j
# q_sold  680
# ri_sold  680
# here
# not here
# timestep  11
# asset_id  i
# q_sold  1262
# ri_sold  1262
# timestep  12
# asset_id  i
# q_sold  1262
# ri_sold  1262
# here
# not here
# timestep  12
# asset_id  i
# q_sold  1851
# ri_sold  1851
# timestep  13
# asset_id  i
# q_sold  1851
# ri_sold  1851
# here
# not here
# timestep  13
# asset_id  i
# q_sold  1091
# ri_sold  1091
# timestep  14
# asset_id  i
# q_sold  1091
# ri_sold  1091
# here
# not here
# timestep  14
# asset_id  i
# q_sold  1065
# ri_sold  1065
# timestep  15
# asset_id  i
# q_sold  1065
# ri_sold  1065
# here
# not here
# timestep  15
# asset_id  i
# q_sold  1462
# ri_sold  1462
# timestep  16
# asset_id  i
# q_sold  1462
# ri_sold  1462
# here
# not here
# timestep  16
# asset_id  i
# q_sold  451
# ri_sold  451
# timestep  17
# asset_id  i
# q_sold  451
# ri_sold  451
# here
# not here
# timestep  17
# asset_id  j
# q_sold  1302
# ri_sold  1302
# timestep  18
# asset_id  j
# q_sold  1302
# ri_sold  1302
# here
# not here
# timestep  18
# asset_id  j
# q_sold  485
# ri_sold  485
# timestep  19
# asset_id  j
# q_sold  485
# ri_sold  485
# here
# not here
# timestep  19
# asset_id  j
# q_sold  781
# ri_sold  781
# timestep  20
# asset_id  j
# q_sold  781
# ri_sold  781
# here
# not here
# timestep  20
# asset_id  i
# q_sold  965
# ri_sold  965
# timestep  21
# asset_id  i
# q_sold  965
# ri_sold  965
# here
# not here
# timestep  21
# asset_id  i
# q_sold  1352
# ri_sold  1352
# timestep  22
# asset_id  i
# q_sold  1352
# ri_sold  1352
# here
# not here
# timestep  22
# asset_id  i
# q_sold  1099
# ri_sold  1099
# timestep  23
# asset_id  i
# q_sold  1099
# ri_sold  1099
# here
# not here
# timestep  23
# asset_id  i
# q_sold  997
# ri_sold  997
# timestep  24
# asset_id  i
# q_sold  997
# ri_sold  997
# here
# not here
# timestep  24
# asset_id  j
# q_sold  1037
# ri_sold  1037
# timestep  25
# asset_id  j
# q_sold  1037
# ri_sold  1037
# here
# not here
# timestep  25
# asset_id  i
# q_sold  -213
# ri_sold  -213
# timestep  26
# asset_id  i
# q_sold  -213
# ri_sold  -213
# here
# not here
# timestep  26
# asset_id  i
# q_sold  1534
# ri_sold  1534
# timestep  27
# asset_id  i
# q_sold  1534
# ri_sold  1534
# here
# not here
# timestep  27
# asset_id  j
# q_sold  1980
# ri_sold  1980
# timestep  28
# asset_id  j
# q_sold  1980
# ri_sold  1980
# here
# not here
# timestep  28
# asset_id  i
# q_sold  1227
# ri_sold  1227
# timestep  29
# asset_id  i
# q_sold  1227
# ri_sold  1227
# here
# not here
# timestep  29
# asset_id  j
# q_sold  662
# ri_sold  662
# timestep  30
# asset_id  j
# q_sold  662
# ri_sold  662
# here
# not here
# timestep  30
# asset_id  j
# q_sold  1883
# ri_sold  1883
# timestep  31
# asset_id  j
# q_sold  1883
# ri_sold  1883
# here
# not here
# timestep  31
# asset_id  j
# q_sold  571
# ri_sold  571
# timestep  32
# asset_id  j
# q_sold  571
# ri_sold  571
# here
# not here
# timestep  32
# asset_id  i
# q_sold  1035
# ri_sold  1035
# timestep  33
# asset_id  i
# q_sold  1035
# ri_sold  1035
# here
# not here
# timestep  33
# asset_id  j
# q_sold  1670
# ri_sold  1670
# timestep  34
# asset_id  j
# q_sold  1670
# ri_sold  1670
# here
# not here
# timestep  34
# asset_id  i
# q_sold  1509
# ri_sold  1509
# timestep  35
# asset_id  i
# q_sold  1509
# ri_sold  1509
# here
# not here
# timestep  35
# asset_id  i
# q_sold  335
# ri_sold  335
# timestep  36
# asset_id  i
# q_sold  335
# ri_sold  335
# here
# not here
# timestep  36
# asset_id  j
# q_sold  1200
# ri_sold  1200
# timestep  37
# asset_id  j
# q_sold  1200
# ri_sold  1200
# here
# not here
# timestep  37
# asset_id  i
# q_sold  1050
# ri_sold  1050
# timestep  38
# asset_id  i
# q_sold  1050
# ri_sold  1050
# here
# not here
# timestep  38
# asset_id  j
# q_sold  890
# ri_sold  890
# timestep  39
# asset_id  j
# q_sold  890
# ri_sold  890
# here
# not here
# timestep  39
# asset_id  j
# q_sold  1343
# ri_sold  1343
# timestep  40
# asset_id  j
# q_sold  1343
# ri_sold  1343
# here
# not here
# timestep  40
# asset_id  j
# q_sold  726
# ri_sold  726
# timestep  41
# asset_id  j
# q_sold  726
# ri_sold  726
# here
# not here
# timestep  41
# asset_id  j
# q_sold  842
# ri_sold  842
# timestep  42
# asset_id  j
# q_sold  842
# ri_sold  842
# here
# not here
# timestep  42
# asset_id  i
# q_sold  630
# ri_sold  630
# timestep  43
# asset_id  i
# q_sold  630
# ri_sold  630
# here
# not here
# timestep  43
# asset_id  j
# q_sold  1518
# ri_sold  1518
# timestep  44
# asset_id  j
# q_sold  1518
# ri_sold  1518
# here
# not here
# timestep  44
# asset_id  j
# q_sold  933
# ri_sold  933
# timestep  45
# asset_id  j
# q_sold  933
# ri_sold  933
# here
# not here
# timestep  45
# asset_id  i
# q_sold  1203
# ri_sold  1203
# timestep  46
# asset_id  i
# q_sold  1203
# ri_sold  1203
# here
# not here
# timestep  46
# asset_id  j
# q_sold  1084
# ri_sold  1084
# timestep  47
# asset_id  j
# q_sold  1084
# ri_sold  1084
# here
# not here
# timestep  47
# asset_id  j
# q_sold  1407
# ri_sold  1407
# timestep  48
# asset_id  j
# q_sold  1407
# ri_sold  1407
# here
# not here
# timestep  48
# asset_id  j
# q_sold  1213
# ri_sold  1213
# timestep  49
# asset_id  j
# q_sold  1213
# ri_sold  1213
# here
# not here
# timestep  49
# asset_id  i
# q_sold  1219
# ri_sold  1219
# timestep  50
# asset_id  i
# q_sold  1219
# ri_sold  1219
# here
# not here
# timestep  50
# asset_id  j
# q_sold  1160
# ri_sold  1160
# timestep  51
# asset_id  j
# q_sold  1160
# ri_sold  1160
# here
# not here
# timestep  51
# asset_id  i
# q_sold  289
# ri_sold  289
# timestep  52
# asset_id  i
# q_sold  289
# ri_sold  289
# here
# not here
# timestep  52
# asset_id  j
# q_sold  -548
# ri_sold  -548
# timestep  53
# asset_id  j
# q_sold  -548
# ri_sold  -548
# here
# not here
# timestep  53
# asset_id  j
# q_sold  768
# ri_sold  768
# timestep  54
# asset_id  j
# q_sold  768
# ri_sold  768
# here
# not here
# timestep  54
# asset_id  i
# q_sold  886
# ri_sold  886
# timestep  55
# asset_id  i
# q_sold  886
# ri_sold  886
# here
# not here
# timestep  55
# asset_id  j
# q_sold  442
# ri_sold  442
# timestep  56
# asset_id  j
# q_sold  442
# ri_sold  442
# here
# not here
# timestep  56
# asset_id  i
# q_sold  1159
# ri_sold  1159
# timestep  57
# asset_id  i
# q_sold  1159
# ri_sold  1159
# here
# not here
# timestep  57
# asset_id  j
# q_sold  1975
# ri_sold  1975
# timestep  58
# asset_id  j
# q_sold  1975
# ri_sold  1975
# here
# not here
# timestep  58
# asset_id  j
# q_sold  762
# ri_sold  762
# timestep  59
# asset_id  j
# q_sold  762
# ri_sold  762
# here
# not here
# timestep  59
# asset_id  j
# q_sold  739
# ri_sold  739
# timestep  60
# asset_id  j
# q_sold  739
# ri_sold  739
# here
# not here
# timestep  60
# asset_id  j
# q_sold  716
# ri_sold  716
# timestep  61
# asset_id  j
# q_sold  716
# ri_sold  716
# here
# not here
# timestep  61
# asset_id  j
# q_sold  290
# ri_sold  290
# timestep  62
# asset_id  j
# q_sold  290
# ri_sold  290
# here
# not here
# timestep  62
# asset_id  j
# q_sold  916
# ri_sold  916
# timestep  63
# asset_id  j
# q_sold  916
# ri_sold  916
# here
# not here
# timestep  63
# asset_id  i
# q_sold  1412
# ri_sold  1412
# timestep  64
# asset_id  i
# q_sold  1412
# ri_sold  1412
# here
# not here
# timestep  64
# asset_id  j
# q_sold  2186
# ri_sold  2186
# timestep  65
# asset_id  j
# q_sold  2186
# ri_sold  2186
# here
# not here
# timestep  65
# asset_id  j
# q_sold  13
# ri_sold  13
# timestep  66
# asset_id  j
# q_sold  13
# ri_sold  13
# here
# not here
# timestep  66
# asset_id  i
# q_sold  1894
# ri_sold  1894
# timestep  67
# asset_id  i
# q_sold  1894
# ri_sold  1894
# here
# not here
# timestep  67
# asset_id  j
# q_sold  1753
# ri_sold  1753
# timestep  68
# asset_id  j
# q_sold  1753
# ri_sold  1753
# here
# not here
# timestep  68
# asset_id  i
# q_sold  1918
# ri_sold  1918
# timestep  69
# asset_id  i
# q_sold  1918
# ri_sold  1918
# here
# not here
# timestep  69
# asset_id  j
# q_sold  1793
# ri_sold  1793
# timestep  70
# asset_id  j
# q_sold  1793
# ri_sold  1793
# here
# not here
# timestep  70
# asset_id  i
# q_sold  321
# ri_sold  321
# timestep  71
# asset_id  i
# q_sold  321
# ri_sold  321
# here
# not here
# timestep  71
# asset_id  j
# q_sold  976
# ri_sold  976
# timestep  72
# asset_id  j
# q_sold  976
# ri_sold  976
# here
# not here
# timestep  72
# asset_id  i
# q_sold  1596
# ri_sold  1596
# timestep  73
# asset_id  i
# q_sold  1596
# ri_sold  1596
# here
# not here
# timestep  73
# asset_id  j
# q_sold  932
# ri_sold  932
# timestep  74
# asset_id  j
# q_sold  932
# ri_sold  932
# here
# not here
# timestep  74
# asset_id  i
# q_sold  2134
# ri_sold  2134
# timestep  75
# asset_id  i
# q_sold  2134
# ri_sold  2134
# here
# not here
# timestep  75
# asset_id  i
# q_sold  899
# ri_sold  899
# timestep  76
# asset_id  i
# q_sold  899
# ri_sold  899
# here
# not here
# timestep  76
# asset_id  j
# q_sold  362
# ri_sold  362
# timestep  77
# asset_id  j
# q_sold  362
# ri_sold  362
# here
# not here
# timestep  77
# asset_id  i
# q_sold  801
# ri_sold  801
# timestep  78
# asset_id  i
# q_sold  801
# ri_sold  801
# here
# not here
# timestep  78
# asset_id  j
# q_sold  585
# ri_sold  585
# timestep  79
# asset_id  j
# q_sold  585
# ri_sold  585
# here
# not here
# timestep  79
# asset_id  j
# q_sold  1186
# ri_sold  1186
# timestep  80
# asset_id  j
# q_sold  1186
# ri_sold  1186
# here
# not here
# timestep  80
# asset_id  j
# q_sold  59
# ri_sold  59
# timestep  81
# asset_id  j
# q_sold  59
# ri_sold  59
# here
# not here
# timestep  81
# asset_id  j
# q_sold  1289
# ri_sold  1289
# timestep  82
# asset_id  j
# q_sold  1289
# ri_sold  1289
# here
# not here
# timestep  82
# asset_id  j
# q_sold  959
# ri_sold  959
# timestep  83
# asset_id  j
# q_sold  959
# ri_sold  959
# here
# not here
# timestep  83
# asset_id  i
# q_sold  1490
# ri_sold  1490
# timestep  84
# asset_id  i
# q_sold  1490
# ri_sold  1490
# here
# not here
# timestep  84
# asset_id  j
# q_sold  369
# ri_sold  369
# timestep  85
# asset_id  j
# q_sold  369
# ri_sold  369
# here
# not here
# timestep  85
# asset_id  i
# q_sold  293
# ri_sold  293
# timestep  86
# asset_id  i
# q_sold  293
# ri_sold  293
# here
# not here
# timestep  86
# asset_id  i
# q_sold  1146
# ri_sold  1146
# timestep  87
# asset_id  i
# q_sold  1146
# ri_sold  1146
# here
# not here
# timestep  87
# asset_id  j
# q_sold  1505
# ri_sold  1505
# timestep  88
# asset_id  j
# q_sold  1505
# ri_sold  1505
# here
# not here
# timestep  88
# asset_id  j
# q_sold  1161
# ri_sold  1161
# timestep  89
# asset_id  j
# q_sold  1161
# ri_sold  1161
# here
# not here
# timestep  89
# asset_id  j
# q_sold  1451
# ri_sold  1451
# timestep  90
# asset_id  j
# q_sold  1451
# ri_sold  1451
# 150977
# Timestep-------------=  90
# delta_S remove 977
# delta_W remove 977.0
# here
# not here
# timestep  90
# asset_id  j
# q_sold  941
# ri_sold  941
# 150977
# timestep  91
# asset_id  j
# q_sold  941
# ri_sold  941
# here
# not here
# timestep  91
# asset_id  i
# q_sold  448
# ri_sold  448
# timestep  92
# asset_id  i
# q_sold  448
# ri_sold  448
# here
# not here
# timestep  92
# asset_id  j
# q_sold  645
# ri_sold  645
# timestep  93
# asset_id  j
# q_sold  645
# ri_sold  645
# here
# not here
# timestep  93
# asset_id  j
# q_sold  530
# ri_sold  530
# timestep  94
# asset_id  j
# q_sold  530
# ri_sold  530
# here
# not here
# timestep  94
# asset_id  j
# q_sold  1320
# ri_sold  1320
# timestep  95
# asset_id  j
# q_sold  1320
# ri_sold  1320
# here
# not here
# timestep  95
# asset_id  i
# q_sold  258
# ri_sold  258
# timestep  96
# asset_id  i
# q_sold  258
# ri_sold  258
# here
# not here
# timestep  96
# asset_id  j
# q_sold  1913
# ri_sold  1913
# timestep  97
# asset_id  j
# q_sold  1913
# ri_sold  1913
# here
# not here
# timestep  97
# asset_id  j
# q_sold  1314
# ri_sold  1314
# timestep  98
# asset_id  j
# q_sold  1314
# ri_sold  1314
# here
# not here
# timestep  98
# asset_id  j
# q_sold  865
# ri_sold  865
# timestep  99
# asset_id  j
# q_sold  865
# ri_sold  865
# here
# not here
# timestep  99
# asset_id  j
# q_sold  690
# ri_sold  690
# timestep  100
# asset_id  j
# q_sold  690
# ri_sold  690
# here
# not here
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  j
# q_sold  1344
# ri_sold  1344
# timestep  2
# asset_id  j
# q_sold  1344
# ri_sold  1344
# here
# not here
# timestep  2
# asset_id  i
# q_sold  1430
# ri_sold  1430
# timestep  3
# asset_id  i
# q_sold  1430
# ri_sold  1430
# here
# not here
# timestep  3
# asset_id  j
# q_sold  -272
# ri_sold  -272
# timestep  4
# asset_id  j
# q_sold  -272
# ri_sold  -272
# here
# not here
# timestep  4
# asset_id  j
# q_sold  509
# ri_sold  509
# timestep  5
# asset_id  j
# q_sold  509
# ri_sold  509
# here
# not here
# timestep  5
# asset_id  i
# q_sold  846
# ri_sold  846
# timestep  6
# asset_id  i
# q_sold  846
# ri_sold  846
# here
# not here
# timestep  6
# asset_id  i
# q_sold  521
# ri_sold  521
# timestep  7
# asset_id  i
# q_sold  521
# ri_sold  521
# here
# not here
# timestep  7
# asset_id  i
# q_sold  344
# ri_sold  344
# timestep  8
# asset_id  i
# q_sold  344
# ri_sold  344
# here
# not here
# timestep  8
# asset_id  i
# q_sold  1682
# ri_sold  1682
# timestep  9
# asset_id  i
# q_sold  1682
# ri_sold  1682
# here
# not here
# timestep  9
# asset_id  j
# q_sold  656
# ri_sold  656
# timestep  10
# asset_id  j
# q_sold  656
# ri_sold  656
# addliq - Sq delta Sq 977.3298566452567
# addliq - Sq delta S 977.3298566452567
# delta S 977.3298566452567
# delta W 977.3298566452567
# here
# not here
# timestep  10
# asset_id  i
# q_sold  1413
# ri_sold  1413
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  138045  171954  150977    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  i
# q_sold  1413
# ri_sold  1413
# here
# not here
# timestep  11
# asset_id  i
# q_sold  836
# ri_sold  836
# timestep  12
# asset_id  i
# q_sold  836
# ri_sold  836
# here
# not here
# timestep  12
# asset_id  j
# q_sold  486
# ri_sold  486
# timestep  13
# asset_id  j
# q_sold  486
# ri_sold  486
# here
# not here
# timestep  13
# asset_id  j
# q_sold  674
# ri_sold  674
# timestep  14
# asset_id  j
# q_sold  674
# ri_sold  674
# here
# not here
# timestep  14
# asset_id  i
# q_sold  829
# ri_sold  829
# timestep  15
# asset_id  i
# q_sold  829
# ri_sold  829
# here
# not here
# timestep  15
# asset_id  i
# q_sold  1692
# ri_sold  1692
# timestep  16
# asset_id  i
# q_sold  1692
# ri_sold  1692
# here
# not here
# timestep  16
# asset_id  i
# q_sold  1388
# ri_sold  1388
# timestep  17
# asset_id  i
# q_sold  1388
# ri_sold  1388
# here
# not here
# timestep  17
# asset_id  j
# q_sold  383
# ri_sold  383
# timestep  18
# asset_id  j
# q_sold  383
# ri_sold  383
# here
# not here
# timestep  18
# asset_id  j
# q_sold  1157
# ri_sold  1157
# timestep  19
# asset_id  j
# q_sold  1157
# ri_sold  1157
# here
# not here
# timestep  19
# asset_id  i
# q_sold  886
# ri_sold  886
# timestep  20
# asset_id  i
# q_sold  886
# ri_sold  886
# here
# not here
# timestep  20
# asset_id  j
# q_sold  763
# ri_sold  763
# timestep  21
# asset_id  j
# q_sold  763
# ri_sold  763
# here
# not here
# timestep  21
# asset_id  i
# q_sold  1277
# ri_sold  1277
# timestep  22
# asset_id  i
# q_sold  1277
# ri_sold  1277
# here
# not here
# timestep  22
# asset_id  j
# q_sold  599
# ri_sold  599
# timestep  23
# asset_id  j
# q_sold  599
# ri_sold  599
# here
# not here
# timestep  23
# asset_id  i
# q_sold  926
# ri_sold  926
# timestep  24
# asset_id  i
# q_sold  926
# ri_sold  926
# here
# not here
# timestep  24
# asset_id  i
# q_sold  1331
# ri_sold  1331
# timestep  25
# asset_id  i
# q_sold  1331
# ri_sold  1331
# here
# not here
# timestep  25
# asset_id  i
# q_sold  405
# ri_sold  405
# timestep  26
# asset_id  i
# q_sold  405
# ri_sold  405
# here
# not here
# timestep  26
# asset_id  i
# q_sold  1081
# ri_sold  1081
# timestep  27
# asset_id  i
# q_sold  1081
# ri_sold  1081
# here
# not here
# timestep  27
# asset_id  i
# q_sold  508
# ri_sold  508
# timestep  28
# asset_id  i
# q_sold  508
# ri_sold  508
# here
# not here
# timestep  28
# asset_id  j
# q_sold  1273
# ri_sold  1273
# timestep  29
# asset_id  j
# q_sold  1273
# ri_sold  1273
# here
# not here
# timestep  29
# asset_id  j
# q_sold  600
# ri_sold  600
# timestep  30
# asset_id  j
# q_sold  600
# ri_sold  600
# here
# not here
# timestep  30
# asset_id  i
# q_sold  1492
# ri_sold  1492
# timestep  31
# asset_id  i
# q_sold  1492
# ri_sold  1492
# here
# not here
# timestep  31
# asset_id  j
# q_sold  495
# ri_sold  495
# timestep  32
# asset_id  j
# q_sold  495
# ri_sold  495
# here
# not here
# timestep  32
# asset_id  i
# q_sold  1058
# ri_sold  1058
# timestep  33
# asset_id  i
# q_sold  1058
# ri_sold  1058
# here
# not here
# timestep  33
# asset_id  j
# q_sold  544
# ri_sold  544
# timestep  34
# asset_id  j
# q_sold  544
# ri_sold  544
# here
# not here
# timestep  34
# asset_id  j
# q_sold  1000
# ri_sold  1000
# timestep  35
# asset_id  j
# q_sold  1000
# ri_sold  1000
# here
# not here
# timestep  35
# asset_id  j
# q_sold  1255
# ri_sold  1255
# timestep  36
# asset_id  j
# q_sold  1255
# ri_sold  1255
# here
# not here
# timestep  36
# asset_id  i
# q_sold  791
# ri_sold  791
# timestep  37
# asset_id  i
# q_sold  791
# ri_sold  791
# here
# not here
# timestep  37
# asset_id  i
# q_sold  1026
# ri_sold  1026
# timestep  38
# asset_id  i
# q_sold  1026
# ri_sold  1026
# here
# not here
# timestep  38
# asset_id  i
# q_sold  958
# ri_sold  958
# timestep  39
# asset_id  i
# q_sold  958
# ri_sold  958
# here
# not here
# timestep  39
# asset_id  j
# q_sold  -6
# ri_sold  -6
# timestep  40
# asset_id  j
# q_sold  -6
# ri_sold  -6
# here
# not here
# timestep  40
# asset_id  j
# q_sold  879
# ri_sold  879
# timestep  41
# asset_id  j
# q_sold  879
# ri_sold  879
# here
# not here
# timestep  41
# asset_id  j
# q_sold  1075
# ri_sold  1075
# timestep  42
# asset_id  j
# q_sold  1075
# ri_sold  1075
# here
# not here
# timestep  42
# asset_id  i
# q_sold  1169
# ri_sold  1169
# timestep  43
# asset_id  i
# q_sold  1169
# ri_sold  1169
# here
# not here
# timestep  43
# asset_id  i
# q_sold  764
# ri_sold  764
# timestep  44
# asset_id  i
# q_sold  764
# ri_sold  764
# here
# not here
# timestep  44
# asset_id  i
# q_sold  759
# ri_sold  759
# timestep  45
# asset_id  i
# q_sold  759
# ri_sold  759
# here
# not here
# timestep  45
# asset_id  j
# q_sold  1302
# ri_sold  1302
# timestep  46
# asset_id  j
# q_sold  1302
# ri_sold  1302
# here
# not here
# timestep  46
# asset_id  i
# q_sold  300
# ri_sold  300
# timestep  47
# asset_id  i
# q_sold  300
# ri_sold  300
# here
# not here
# timestep  47
# asset_id  j
# q_sold  948
# ri_sold  948
# timestep  48
# asset_id  j
# q_sold  948
# ri_sold  948
# here
# not here
# timestep  48
# asset_id  i
# q_sold  1074
# ri_sold  1074
# timestep  49
# asset_id  i
# q_sold  1074
# ri_sold  1074
# here
# not here
# timestep  49
# asset_id  j
# q_sold  1161
# ri_sold  1161
# timestep  50
# asset_id  j
# q_sold  1161
# ri_sold  1161
# here
# not here
# timestep  50
# asset_id  j
# q_sold  549
# ri_sold  549
# timestep  51
# asset_id  j
# q_sold  549
# ri_sold  549
# here
# not here
# timestep  51
# asset_id  i
# q_sold  919
# ri_sold  919
# timestep  52
# asset_id  i
# q_sold  919
# ri_sold  919
# here
# not here
# timestep  52
# asset_id  j
# q_sold  1166
# ri_sold  1166
# timestep  53
# asset_id  j
# q_sold  1166
# ri_sold  1166
# here
# not here
# timestep  53
# asset_id  i
# q_sold  485
# ri_sold  485
# timestep  54
# asset_id  i
# q_sold  485
# ri_sold  485
# here
# not here
# timestep  54
# asset_id  i
# q_sold  1447
# ri_sold  1447
# timestep  55
# asset_id  i
# q_sold  1447
# ri_sold  1447
# here
# not here
# timestep  55
# asset_id  j
# q_sold  774
# ri_sold  774
# timestep  56
# asset_id  j
# q_sold  774
# ri_sold  774
# here
# not here
# timestep  56
# asset_id  i
# q_sold  709
# ri_sold  709
# timestep  57
# asset_id  i
# q_sold  709
# ri_sold  709
# here
# not here
# timestep  57
# asset_id  j
# q_sold  1611
# ri_sold  1611
# timestep  58
# asset_id  j
# q_sold  1611
# ri_sold  1611
# here
# not here
# timestep  58
# asset_id  i
# q_sold  1205
# ri_sold  1205
# timestep  59
# asset_id  i
# q_sold  1205
# ri_sold  1205
# here
# not here
# timestep  59
# asset_id  j
# q_sold  1888
# ri_sold  1888
# timestep  60
# asset_id  j
# q_sold  1888
# ri_sold  1888
# here
# not here
# timestep  60
# asset_id  i
# q_sold  174
# ri_sold  174
# timestep  61
# asset_id  i
# q_sold  174
# ri_sold  174
# here
# not here
# timestep  61
# asset_id  i
# q_sold  1368
# ri_sold  1368
# timestep  62
# asset_id  i
# q_sold  1368
# ri_sold  1368
# here
# not here
# timestep  62
# asset_id  j
# q_sold  363
# ri_sold  363
# timestep  63
# asset_id  j
# q_sold  363
# ri_sold  363
# here
# not here
# timestep  63
# asset_id  j
# q_sold  1105
# ri_sold  1105
# timestep  64
# asset_id  j
# q_sold  1105
# ri_sold  1105
# here
# not here
# timestep  64
# asset_id  j
# q_sold  691
# ri_sold  691
# timestep  65
# asset_id  j
# q_sold  691
# ri_sold  691
# here
# not here
# timestep  65
# asset_id  j
# q_sold  1725
# ri_sold  1725
# timestep  66
# asset_id  j
# q_sold  1725
# ri_sold  1725
# here
# not here
# timestep  66
# asset_id  i
# q_sold  1361
# ri_sold  1361
# timestep  67
# asset_id  i
# q_sold  1361
# ri_sold  1361
# here
# not here
# timestep  67
# asset_id  j
# q_sold  1314
# ri_sold  1314
# timestep  68
# asset_id  j
# q_sold  1314
# ri_sold  1314
# here
# not here
# timestep  68
# asset_id  i
# q_sold  551
# ri_sold  551
# timestep  69
# asset_id  i
# q_sold  551
# ri_sold  551
# here
# not here
# timestep  69
# asset_id  j
# q_sold  398
# ri_sold  398
# timestep  70
# asset_id  j
# q_sold  398
# ri_sold  398
# here
# not here
# timestep  70
# asset_id  j
# q_sold  953
# ri_sold  953
# timestep  71
# asset_id  j
# q_sold  953
# ri_sold  953
# here
# not here
# timestep  71
# asset_id  i
# q_sold  1027
# ri_sold  1027
# timestep  72
# asset_id  i
# q_sold  1027
# ri_sold  1027
# here
# not here
# timestep  72
# asset_id  i
# q_sold  538
# ri_sold  538
# timestep  73
# asset_id  i
# q_sold  538
# ri_sold  538
# here
# not here
# timestep  73
# asset_id  j
# q_sold  1352
# ri_sold  1352
# timestep  74
# asset_id  j
# q_sold  1352
# ri_sold  1352
# here
# not here
# timestep  74
# asset_id  i
# q_sold  1266
# ri_sold  1266
# timestep  75
# asset_id  i
# q_sold  1266
# ri_sold  1266
# here
# not here
# timestep  75
# asset_id  j
# q_sold  929
# ri_sold  929
# timestep  76
# asset_id  j
# q_sold  929
# ri_sold  929
# here
# not here
# timestep  76
# asset_id  j
# q_sold  729
# ri_sold  729
# timestep  77
# asset_id  j
# q_sold  729
# ri_sold  729
# here
# not here
# timestep  77
# asset_id  j
# q_sold  1037
# ri_sold  1037
# timestep  78
# asset_id  j
# q_sold  1037
# ri_sold  1037
# here
# not here
# timestep  78
# asset_id  j
# q_sold  1475
# ri_sold  1475
# timestep  79
# asset_id  j
# q_sold  1475
# ri_sold  1475
# here
# not here
# timestep  79
# asset_id  j
# q_sold  1326
# ri_sold  1326
# timestep  80
# asset_id  j
# q_sold  1326
# ri_sold  1326
# here
# not here
# timestep  80
# asset_id  j
# q_sold  467
# ri_sold  467
# timestep  81
# asset_id  j
# q_sold  467
# ri_sold  467
# here
# not here
# timestep  81
# asset_id  j
# q_sold  370
# ri_sold  370
# timestep  82
# asset_id  j
# q_sold  370
# ri_sold  370
# here
# not here
# timestep  82
# asset_id  j
# q_sold  1304
# ri_sold  1304
# timestep  83
# asset_id  j
# q_sold  1304
# ri_sold  1304
# here
# not here
# timestep  83
# asset_id  i
# q_sold  1238
# ri_sold  1238
# timestep  84
# asset_id  i
# q_sold  1238
# ri_sold  1238
# here
# not here
# timestep  84
# asset_id  j
# q_sold  1105
# ri_sold  1105
# timestep  85
# asset_id  j
# q_sold  1105
# ri_sold  1105
# here
# not here
# timestep  85
# asset_id  i
# q_sold  1605
# ri_sold  1605
# timestep  86
# asset_id  i
# q_sold  1605
# ri_sold  1605
# here
# not here
# timestep  86
# asset_id  i
# q_sold  1234
# ri_sold  1234
# timestep  87
# asset_id  i
# q_sold  1234
# ri_sold  1234
# here
# not here
# timestep  87
# asset_id  j
# q_sold  678
# ri_sold  678
# timestep  88
# asset_id  j
# q_sold  678
# ri_sold  678
# here
# not here
# timestep  88
# asset_id  j
# q_sold  1713
# ri_sold  1713
# timestep  89
# asset_id  j
# q_sold  1713
# ri_sold  1713
# here
# not here
# timestep  89
# asset_id  i
# q_sold  1362
# ri_sold  1362
# timestep  90
# asset_id  i
# q_sold  1362
# ri_sold  1362
# 150977
# Timestep-------------=  90
# delta_S remove 977
# delta_W remove 977.0
# here
# not here
# timestep  90
# asset_id  j
# q_sold  1063
# ri_sold  1063
# 150977
# timestep  91
# asset_id  j
# q_sold  1063
# ri_sold  1063
# here
# not here
# timestep  91
# asset_id  i
# q_sold  1938
# ri_sold  1938
# timestep  92
# asset_id  i
# q_sold  1938
# ri_sold  1938
# here
# not here
# timestep  92
# asset_id  i
# q_sold  1045
# ri_sold  1045
# timestep  93
# asset_id  i
# q_sold  1045
# ri_sold  1045
# here
# not here
# timestep  93
# asset_id  i
# q_sold  1318
# ri_sold  1318
# timestep  94
# asset_id  i
# q_sold  1318
# ri_sold  1318
# here
# not here
# timestep  94
# asset_id  i
# q_sold  622
# ri_sold  622
# timestep  95
# asset_id  i
# q_sold  622
# ri_sold  622
# here
# not here
# timestep  95
# asset_id  j
# q_sold  -240
# ri_sold  -240
# timestep  96
# asset_id  j
# q_sold  -240
# ri_sold  -240
# here
# not here
# timestep  96
# asset_id  i
# q_sold  409
# ri_sold  409
# timestep  97
# asset_id  i
# q_sold  409
# ri_sold  409
# here
# not here
# timestep  97
# asset_id  i
# q_sold  954
# ri_sold  954
# timestep  98
# asset_id  i
# q_sold  954
# ri_sold  954
# here
# not here
# timestep  98
# asset_id  j
# q_sold  1154
# ri_sold  1154
# timestep  99
# asset_id  j
# q_sold  1154
# ri_sold  1154
# here
# not here
# timestep  99
# asset_id  j
# q_sold  980
# ri_sold  980
# timestep  100
# asset_id  j
# q_sold  980
# ri_sold  980
# here
# not here
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  j
# q_sold  1257
# ri_sold  1257
# timestep  2
# asset_id  j
# q_sold  1257
# ri_sold  1257
# here
# not here
# timestep  2
# asset_id  i
# q_sold  1518
# ri_sold  1518
# timestep  3
# asset_id  i
# q_sold  1518
# ri_sold  1518
# here
# not here
# timestep  3
# asset_id  j
# q_sold  375
# ri_sold  375
# timestep  4
# asset_id  j
# q_sold  375
# ri_sold  375
# here
# not here
# timestep  4
# asset_id  j
# q_sold  724
# ri_sold  724
# timestep  5
# asset_id  j
# q_sold  724
# ri_sold  724
# here
# not here
# timestep  5
# asset_id  j
# q_sold  1713
# ri_sold  1713
# timestep  6
# asset_id  j
# q_sold  1713
# ri_sold  1713
# here
# not here
# timestep  6
# asset_id  i
# q_sold  1123
# ri_sold  1123
# timestep  7
# asset_id  i
# q_sold  1123
# ri_sold  1123
# here
# not here
# timestep  7
# asset_id  j
# q_sold  1607
# ri_sold  1607
# timestep  8
# asset_id  j
# q_sold  1607
# ri_sold  1607
# here
# not here
# timestep  8
# asset_id  i
# q_sold  1440
# ri_sold  1440
# timestep  9
# asset_id  i
# q_sold  1440
# ri_sold  1440
# here
# not here
# timestep  9
# asset_id  i
# q_sold  318
# ri_sold  318
# timestep  10
# asset_id  i
# q_sold  318
# ri_sold  318
# addliq - Sq delta Sq 691.0765690899374
# addliq - Sq delta S 691.0765690899374
# delta S 691.0765690899374
# delta W 691.0765690899374
# here
# not here
# timestep  10
# asset_id  j
# q_sold  1180
# ri_sold  1180
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  138045  171954  150977    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  j
# q_sold  1180
# ri_sold  1180
# here
# not here
# timestep  11
# asset_id  i
# q_sold  973
# ri_sold  973
# timestep  12
# asset_id  i
# q_sold  973
# ri_sold  973
# here
# not here
# timestep  12
# asset_id  i
# q_sold  1053
# ri_sold  1053
# timestep  13
# asset_id  i
# q_sold  1053
# ri_sold  1053
# here
# not here
# timestep  13
# asset_id  i
# q_sold  293
# ri_sold  293
# timestep  14
# asset_id  i
# q_sold  293
# ri_sold  293
# here
# not here
# timestep  14
# asset_id  i
# q_sold  -105
# ri_sold  -105
# timestep  15
# asset_id  i
# q_sold  -105
# ri_sold  -105
# here
# not here
# timestep  15
# asset_id  j
# q_sold  621
# ri_sold  621
# timestep  16
# asset_id  j
# q_sold  621
# ri_sold  621
# here
# not here
# timestep  16
# asset_id  i
# q_sold  1130
# ri_sold  1130
# timestep  17
# asset_id  i
# q_sold  1130
# ri_sold  1130
# here
# not here
# timestep  17
# asset_id  i
# q_sold  1308
# ri_sold  1308
# timestep  18
# asset_id  i
# q_sold  1308
# ri_sold  1308
# here
# not here
# timestep  18
# asset_id  j
# q_sold  1024
# ri_sold  1024
# timestep  19
# asset_id  j
# q_sold  1024
# ri_sold  1024
# here
# not here
# timestep  19
# asset_id  i
# q_sold  265
# ri_sold  265
# timestep  20
# asset_id  i
# q_sold  265
# ri_sold  265
# here
# not here
# timestep  20
# asset_id  i
# q_sold  1190
# ri_sold  1190
# timestep  21
# asset_id  i
# q_sold  1190
# ri_sold  1190
# here
# not here
# timestep  21
# asset_id  i
# q_sold  1715
# ri_sold  1715
# timestep  22
# asset_id  i
# q_sold  1715
# ri_sold  1715
# here
# not here
# timestep  22
# asset_id  j
# q_sold  579
# ri_sold  579
# timestep  23
# asset_id  j
# q_sold  579
# ri_sold  579
# here
# not here
# timestep  23
# asset_id  j
# q_sold  585
# ri_sold  585
# timestep  24
# asset_id  j
# q_sold  585
# ri_sold  585
# here
# not here
# timestep  24
# asset_id  i
# q_sold  410
# ri_sold  410
# timestep  25
# asset_id  i
# q_sold  410
# ri_sold  410
# here
# not here
# timestep  25
# asset_id  i
# q_sold  1203
# ri_sold  1203
# timestep  26
# asset_id  i
# q_sold  1203
# ri_sold  1203
# here
# not here
# timestep  26
# asset_id  i
# q_sold  898
# ri_sold  898
# timestep  27
# asset_id  i
# q_sold  898
# ri_sold  898
# here
# not here
# timestep  27
# asset_id  i
# q_sold  1464
# ri_sold  1464
# timestep  28
# asset_id  i
# q_sold  1464
# ri_sold  1464
# here
# not here
# timestep  28
# asset_id  j
# q_sold  718
# ri_sold  718
# timestep  29
# asset_id  j
# q_sold  718
# ri_sold  718
# here
# not here
# timestep  29
# asset_id  i
# q_sold  866
# ri_sold  866
# timestep  30
# asset_id  i
# q_sold  866
# ri_sold  866
# here
# not here
# timestep  30
# asset_id  j
# q_sold  1783
# ri_sold  1783
# timestep  31
# asset_id  j
# q_sold  1783
# ri_sold  1783
# here
# not here
# timestep  31
# asset_id  j
# q_sold  631
# ri_sold  631
# timestep  32
# asset_id  j
# q_sold  631
# ri_sold  631
# here
# not here
# timestep  32
# asset_id  j
# q_sold  1769
# ri_sold  1769
# timestep  33
# asset_id  j
# q_sold  1769
# ri_sold  1769
# here
# not here
# timestep  33
# asset_id  j
# q_sold  1254
# ri_sold  1254
# timestep  34
# asset_id  j
# q_sold  1254
# ri_sold  1254
# here
# not here
# timestep  34
# asset_id  j
# q_sold  969
# ri_sold  969
# timestep  35
# asset_id  j
# q_sold  969
# ri_sold  969
# here
# not here
# timestep  35
# asset_id  j
# q_sold  241
# ri_sold  241
# timestep  36
# asset_id  j
# q_sold  241
# ri_sold  241
# here
# not here
# timestep  36
# asset_id  i
# q_sold  1324
# ri_sold  1324
# timestep  37
# asset_id  i
# q_sold  1324
# ri_sold  1324
# here
# not here
# timestep  37
# asset_id  j
# q_sold  1713
# ri_sold  1713
# timestep  38
# asset_id  j
# q_sold  1713
# ri_sold  1713
# here
# not here
# timestep  38
# asset_id  i
# q_sold  1698
# ri_sold  1698
# timestep  39
# asset_id  i
# q_sold  1698
# ri_sold  1698
# here
# not here
# timestep  39
# asset_id  i
# q_sold  1251
# ri_sold  1251
# timestep  40
# asset_id  i
# q_sold  1251
# ri_sold  1251
# here
# not here
# timestep  40
# asset_id  i
# q_sold  -25
# ri_sold  -25
# timestep  41
# asset_id  i
# q_sold  -25
# ri_sold  -25
# here
# not here
# timestep  41
# asset_id  i
# q_sold  399
# ri_sold  399
# timestep  42
# asset_id  i
# q_sold  399
# ri_sold  399
# here
# not here
# timestep  42
# asset_id  i
# q_sold  1797
# ri_sold  1797
# timestep  43
# asset_id  i
# q_sold  1797
# ri_sold  1797
# here
# not here
# timestep  43
# asset_id  i
# q_sold  1633
# ri_sold  1633
# timestep  44
# asset_id  i
# q_sold  1633
# ri_sold  1633
# here
# not here
# timestep  44
# asset_id  i
# q_sold  789
# ri_sold  789
# timestep  45
# asset_id  i
# q_sold  789
# ri_sold  789
# here
# not here
# timestep  45
# asset_id  j
# q_sold  1139
# ri_sold  1139
# timestep  46
# asset_id  j
# q_sold  1139
# ri_sold  1139
# here
# not here
# timestep  46
# asset_id  i
# q_sold  246
# ri_sold  246
# timestep  47
# asset_id  i
# q_sold  246
# ri_sold  246
# here
# not here
# timestep  47
# asset_id  j
# q_sold  307
# ri_sold  307
# timestep  48
# asset_id  j
# q_sold  307
# ri_sold  307
# here
# not here
# timestep  48
# asset_id  j
# q_sold  1118
# ri_sold  1118
# timestep  49
# asset_id  j
# q_sold  1118
# ri_sold  1118
# here
# not here
# timestep  49
# asset_id  i
# q_sold  143
# ri_sold  143
# timestep  50
# asset_id  i
# q_sold  143
# ri_sold  143
# here
# not here
# timestep  50
# asset_id  i
# q_sold  74
# ri_sold  74
# timestep  51
# asset_id  i
# q_sold  74
# ri_sold  74
# here
# not here
# timestep  51
# asset_id  j
# q_sold  1302
# ri_sold  1302
# timestep  52
# asset_id  j
# q_sold  1302
# ri_sold  1302
# here
# not here
# timestep  52
# asset_id  j
# q_sold  2008
# ri_sold  2008
# timestep  53
# asset_id  j
# q_sold  2008
# ri_sold  2008
# here
# not here
# timestep  53
# asset_id  i
# q_sold  899
# ri_sold  899
# timestep  54
# asset_id  i
# q_sold  899
# ri_sold  899
# here
# not here
# timestep  54
# asset_id  i
# q_sold  1192
# ri_sold  1192
# timestep  55
# asset_id  i
# q_sold  1192
# ri_sold  1192
# here
# not here
# timestep  55
# asset_id  i
# q_sold  1011
# ri_sold  1011
# timestep  56
# asset_id  i
# q_sold  1011
# ri_sold  1011
# here
# not here
# timestep  56
# asset_id  j
# q_sold  233
# ri_sold  233
# timestep  57
# asset_id  j
# q_sold  233
# ri_sold  233
# here
# not here
# timestep  57
# asset_id  j
# q_sold  1665
# ri_sold  1665
# timestep  58
# asset_id  j
# q_sold  1665
# ri_sold  1665
# here
# not here
# timestep  58
# asset_id  j
# q_sold  514
# ri_sold  514
# timestep  59
# asset_id  j
# q_sold  514
# ri_sold  514
# here
# not here
# timestep  59
# asset_id  j
# q_sold  983
# ri_sold  983
# timestep  60
# asset_id  j
# q_sold  983
# ri_sold  983
# here
# not here
# timestep  60
# asset_id  i
# q_sold  848
# ri_sold  848
# timestep  61
# asset_id  i
# q_sold  848
# ri_sold  848
# here
# not here
# timestep  61
# asset_id  j
# q_sold  966
# ri_sold  966
# timestep  62
# asset_id  j
# q_sold  966
# ri_sold  966
# here
# not here
# timestep  62
# asset_id  i
# q_sold  1718
# ri_sold  1718
# timestep  63
# asset_id  i
# q_sold  1718
# ri_sold  1718
# here
# not here
# timestep  63
# asset_id  i
# q_sold  419
# ri_sold  419
# timestep  64
# asset_id  i
# q_sold  419
# ri_sold  419
# here
# not here
# timestep  64
# asset_id  i
# q_sold  1336
# ri_sold  1336
# timestep  65
# asset_id  i
# q_sold  1336
# ri_sold  1336
# here
# not here
# timestep  65
# asset_id  j
# q_sold  823
# ri_sold  823
# timestep  66
# asset_id  j
# q_sold  823
# ri_sold  823
# here
# not here
# timestep  66
# asset_id  i
# q_sold  1268
# ri_sold  1268
# timestep  67
# asset_id  i
# q_sold  1268
# ri_sold  1268
# here
# not here
# timestep  67
# asset_id  j
# q_sold  707
# ri_sold  707
# timestep  68
# asset_id  j
# q_sold  707
# ri_sold  707
# here
# not here
# timestep  68
# asset_id  j
# q_sold  1044
# ri_sold  1044
# timestep  69
# asset_id  j
# q_sold  1044
# ri_sold  1044
# here
# not here
# timestep  69
# asset_id  i
# q_sold  38
# ri_sold  38
# timestep  70
# asset_id  i
# q_sold  38
# ri_sold  38
# here
# not here
# timestep  70
# asset_id  i
# q_sold  1607
# ri_sold  1607
# timestep  71
# asset_id  i
# q_sold  1607
# ri_sold  1607
# here
# not here
# timestep  71
# asset_id  i
# q_sold  621
# ri_sold  621
# timestep  72
# asset_id  i
# q_sold  621
# ri_sold  621
# here
# not here
# timestep  72
# asset_id  j
# q_sold  1514
# ri_sold  1514
# timestep  73
# asset_id  j
# q_sold  1514
# ri_sold  1514
# here
# not here
# timestep  73
# asset_id  i
# q_sold  1442
# ri_sold  1442
# timestep  74
# asset_id  i
# q_sold  1442
# ri_sold  1442
# here
# not here
# timestep  74
# asset_id  i
# q_sold  541
# ri_sold  541
# timestep  75
# asset_id  i
# q_sold  541
# ri_sold  541
# here
# not here
# timestep  75
# asset_id  j
# q_sold  941
# ri_sold  941
# timestep  76
# asset_id  j
# q_sold  941
# ri_sold  941
# here
# not here
# timestep  76
# asset_id  i
# q_sold  1247
# ri_sold  1247
# timestep  77
# asset_id  i
# q_sold  1247
# ri_sold  1247
# here
# not here
# timestep  77
# asset_id  i
# q_sold  962
# ri_sold  962
# timestep  78
# asset_id  i
# q_sold  962
# ri_sold  962
# here
# not here
# timestep  78
# asset_id  i
# q_sold  452
# ri_sold  452
# timestep  79
# asset_id  i
# q_sold  452
# ri_sold  452
# here
# not here
# timestep  79
# asset_id  i
# q_sold  1469
# ri_sold  1469
# timestep  80
# asset_id  i
# q_sold  1469
# ri_sold  1469
# here
# not here
# timestep  80
# asset_id  i
# q_sold  1958
# ri_sold  1958
# timestep  81
# asset_id  i
# q_sold  1958
# ri_sold  1958
# here
# not here
# timestep  81
# asset_id  j
# q_sold  684
# ri_sold  684
# timestep  82
# asset_id  j
# q_sold  684
# ri_sold  684
# here
# not here
# timestep  82
# asset_id  j
# q_sold  1553
# ri_sold  1553
# timestep  83
# asset_id  j
# q_sold  1553
# ri_sold  1553
# here
# not here
# timestep  83
# asset_id  i
# q_sold  495
# ri_sold  495
# timestep  84
# asset_id  i
# q_sold  495
# ri_sold  495
# here
# not here
# timestep  84
# asset_id  j
# q_sold  610
# ri_sold  610
# timestep  85
# asset_id  j
# q_sold  610
# ri_sold  610
# here
# not here
# timestep  85
# asset_id  j
# q_sold  690
# ri_sold  690
# timestep  86
# asset_id  j
# q_sold  690
# ri_sold  690
# here
# not here
# timestep  86
# asset_id  j
# q_sold  764
# ri_sold  764
# timestep  87
# asset_id  j
# q_sold  764
# ri_sold  764
# here
# not here
# timestep  87
# asset_id  i
# q_sold  1033
# ri_sold  1033
# timestep  88
# asset_id  i
# q_sold  1033
# ri_sold  1033
# here
# not here
# timestep  88
# asset_id  j
# q_sold  1057
# ri_sold  1057
# timestep  89
# asset_id  j
# q_sold  1057
# ri_sold  1057
# here
# not here
# timestep  89
# asset_id  j
# q_sold  512
# ri_sold  512
# timestep  90
# asset_id  j
# q_sold  512
# ri_sold  512
# 150977
# Timestep-------------=  90
# delta_S remove 977
# delta_W remove 977.0
# here
# not here
# timestep  90
# asset_id  i
# q_sold  1131
# ri_sold  1131
# 150977
# timestep  91
# asset_id  i
# q_sold  1131
# ri_sold  1131
# here
# not here
# timestep  91
# asset_id  i
# q_sold  428
# ri_sold  428
# timestep  92
# asset_id  i
# q_sold  428
# ri_sold  428
# here
# not here
# timestep  92
# asset_id  i
# q_sold  636
# ri_sold  636
# timestep  93
# asset_id  i
# q_sold  636
# ri_sold  636
# here
# not here
# timestep  93
# asset_id  i
# q_sold  955
# ri_sold  955
# timestep  94
# asset_id  i
# q_sold  955
# ri_sold  955
# here
# not here
# timestep  94
# asset_id  j
# q_sold  890
# ri_sold  890
# timestep  95
# asset_id  j
# q_sold  890
# ri_sold  890
# here
# not here
# timestep  95
# asset_id  i
# q_sold  346
# ri_sold  346
# timestep  96
# asset_id  i
# q_sold  346
# ri_sold  346
# here
# not here
# timestep  96
# asset_id  i
# q_sold  930
# ri_sold  930
# timestep  97
# asset_id  i
# q_sold  930
# ri_sold  930
# here
# not here
# timestep  97
# asset_id  i
# q_sold  435
# ri_sold  435
# timestep  98
# asset_id  i
# q_sold  435
# ri_sold  435
# here
# not here
# timestep  98
# asset_id  i
# q_sold  343
# ri_sold  343
# timestep  99
# asset_id  i
# q_sold  343
# ri_sold  343
# here
# not here
# timestep  99
# asset_id  i
# q_sold  1371
# ri_sold  1371
# timestep  100
# asset_id  i
# q_sold  1371
# ri_sold  1371
# here
# not here
# timestep  0
# asset_id  i
# q_sold  10
# ri_sold  10
# timestep  1
# asset_id  i
# q_sold  10
# ri_sold  10
# here
# not here
# timestep  1
# asset_id  i
# q_sold  1260
# ri_sold  1260
# timestep  2
# asset_id  i
# q_sold  1260
# ri_sold  1260
# here
# not here
# timestep  2
# asset_id  i
# q_sold  797
# ri_sold  797
# timestep  3
# asset_id  i
# q_sold  797
# ri_sold  797
# here
# not here
# timestep  3
# asset_id  i
# q_sold  1141
# ri_sold  1141
# timestep  4
# asset_id  i
# q_sold  1141
# ri_sold  1141
# here
# not here
# timestep  4
# asset_id  j
# q_sold  658
# ri_sold  658
# timestep  5
# asset_id  j
# q_sold  658
# ri_sold  658
# here
# not here
# timestep  5
# asset_id  i
# q_sold  1338
# ri_sold  1338
# timestep  6
# asset_id  i
# q_sold  1338
# ri_sold  1338
# here
# not here
# timestep  6
# asset_id  j
# q_sold  546
# ri_sold  546
# timestep  7
# asset_id  j
# q_sold  546
# ri_sold  546
# here
# not here
# timestep  7
# asset_id  j
# q_sold  912
# ri_sold  912
# timestep  8
# asset_id  j
# q_sold  912
# ri_sold  912
# here
# not here
# timestep  8
# asset_id  i
# q_sold  491
# ri_sold  491
# timestep  9
# asset_id  i
# q_sold  491
# ri_sold  491
# here
# not here
# timestep  9
# asset_id  j
# q_sold  1128
# ri_sold  1128
# timestep  10
# asset_id  j
# q_sold  1128
# ri_sold  1128
# addliq - Sq delta Sq 977.3298566452567
# addliq - Sq delta S 977.3298566452567
# delta S 977.3298566452567
# delta W 977.3298566452567
# here
# not here
# timestep  10
# asset_id  i
# q_sold  1282
# ri_sold  1282
#    m  r_i_out  r_i_in       h     q_i     s_i  s_q  r_j_out  r_j_in     q_j  \
# 0  0   100000  110000  140000  170000  150000    0   120000  130000  180000
# 1  1   100000  110000  140000  170000  150000    0   120000  130000  180000
# 2  2    50000  160000  138045  171954  150977    0   120000  130000  180000
# 3  3   100000  110000  140000  170000  150000    0   120000  130000  180000
# 4  4   100000  110000  140000  170000  150000    0   120000  130000  180000
# 5  5   100000  110000  140000  170000  150000    0   120000  130000  180000
# 6  6   100000  110000  140000  170000  150000    0   120000  130000  180000
# 7  7   100000  110000  140000  170000  150000    0   120000  130000  180000
#
#       s_j
# 0  160000
# 1  160000
# 2  160000
# 3  160000
# 4  160000
# 5  160000
# 6  160000
# 7  160000
# timestep  11
# asset_id  i
# q_sold  1282
# ri_sold  1282
# here
# not here
# timestep  11
# asset_id  j
# q_sold  832
# ri_sold  832
# timestep  12
# asset_id  j
# q_sold  832
# ri_sold  832
# here
# not here
# timestep  12
# asset_id  j
# q_sold  532
# ri_sold  532
# timestep  13
# asset_id  j
# q_sold  532
# ri_sold  532
# here
# not here
# timestep  13
# asset_id  i
# q_sold  576
# ri_sold  576
# timestep  14
# asset_id  i
# q_sold  576
# ri_sold  576
# here
# not here
# timestep  14
# asset_id  j
# q_sold  924
# ri_sold  924
# timestep  15
# asset_id  j
# q_sold  924
# ri_sold  924
# here
# not here
# timestep  15
# asset_id  i
# q_sold  1592
# ri_sold  1592
# timestep  16
# asset_id  i
# q_sold  1592
# ri_sold  1592
# here
# not here
# timestep  16
# asset_id  j
# q_sold  1304
# ri_sold  1304
# timestep  17
# asset_id  j
# q_sold  1304
# ri_sold  1304
# here
# not here
# timestep  17
# asset_id  j
# q_sold  1139
# ri_sold  1139
# timestep  18
# asset_id  j
# q_sold  1139
# ri_sold  1139
# here
# not here
# timestep  18
# asset_id  j
# q_sold  1313
# ri_sold  1313
# timestep  19
# asset_id  j
# q_sold  1313
# ri_sold  1313
# here
# not here
# timestep  19
# asset_id  j
# q_sold  1480
# ri_sold  1480
# timestep  20
# asset_id  j
# q_sold  1480
# ri_sold  1480
# here
# not here
# timestep  20
# asset_id  i
# q_sold  1560
# ri_sold  1560
# timestep  21
# asset_id  i
# q_sold  1560
# ri_sold  1560
# here
# not here
# timestep  21
# asset_id  j
# q_sold  632
# ri_sold  632
# timestep  22
# asset_id  j
# q_sold  632
# ri_sold  632
# here
# not here
# timestep  22
# asset_id  j
# q_sold  1136
# ri_sold  1136
# timestep  23
# asset_id  j
# q_sold  1136
# ri_sold  1136
# here
# not here
# timestep  23
# asset_id  i
# q_sold  894
# ri_sold  894
# timestep  24
# asset_id  i
# q_sold  894
# ri_sold  894
# here
# not here
# timestep  24
# asset_id  j
# q_sold  818
# ri_sold  818
# timestep  25
# asset_id  j
# q_sold  818
# ri_sold  818
# here
# not here
# timestep  25
# asset_id  j
# q_sold  1050
# ri_sold  1050
# timestep  26
# asset_id  j
# q_sold  1050
# ri_sold  1050
# here
# not here
# timestep  26
# asset_id  i
# q_sold  1127
# ri_sold  1127
# timestep  27
# asset_id  i
# q_sold  1127
# ri_sold  1127
# here
# not here
# timestep  27
# asset_id  i
# q_sold  1482
# ri_sold  1482
# timestep  28
# asset_id  i
# q_sold  1482
# ri_sold  1482
# here
# not here
# timestep  28
# asset_id  j
# q_sold  374
# ri_sold  374
# timestep  29
# asset_id  j
# q_sold  374
# ri_sold  374
# here
# not here
# timestep  29
# asset_id  i
# q_sold  1154
# ri_sold  1154
# timestep  30
# asset_id  i
# q_sold  1154
# ri_sold  1154
# here
# not here
# timestep  30
# asset_id  j
# q_sold  758
# ri_sold  758
# timestep  31
# asset_id  j
# q_sold  758
# ri_sold  758
# here
# not here
# timestep  31
# asset_id  i
# q_sold  374
# ri_sold  374
# timestep  32
# asset_id  i
# q_sold  374
# ri_sold  374
# here
# not here
# timestep  32
# asset_id  j
# q_sold  516
# ri_sold  516
# timestep  33
# asset_id  j
# q_sold  516
# ri_sold  516
# here
# not here
# timestep  33
# asset_id  j
# q_sold  459
# ri_sold  459
# timestep  34
# asset_id  j
# q_sold  459
# ri_sold  459
# here
# not here
# timestep  34
# asset_id  j
# q_sold  -136
# ri_sold  -136
# timestep  35
# asset_id  j
# q_sold  -136
# ri_sold  -136
# here
# not here
# timestep  35
# asset_id  j
# q_sold  1332
# ri_sold  1332
# timestep  36
# asset_id  j
# q_sold  1332
# ri_sold  1332
# here
# not here
# timestep  36
# asset_id  i
# q_sold  950
# ri_sold  950
# timestep  37
# asset_id  i
# q_sold  950
# ri_sold  950
# here
# not here
# timestep  37
# asset_id  j
# q_sold  1118
# ri_sold  1118
# timestep  38
# asset_id  j
# q_sold  1118
# ri_sold  1118
# here
# not here
# timestep  38
# asset_id  j
# q_sold  1554
# ri_sold  1554
# timestep  39
# asset_id  j
# q_sold  1554
# ri_sold  1554
# here
# not here
# timestep  39
# asset_id  j
# q_sold  1305
# ri_sold  1305
# timestep  40
# asset_id  j
# q_sold  1305
# ri_sold  1305
# here
# not here
# timestep  40
# asset_id  j
# q_sold  657
# ri_sold  657
# timestep  41
# asset_id  j
# q_sold  657
# ri_sold  657
# here
# not here
# timestep  41
# asset_id  i
# q_sold  890
# ri_sold  890
# timestep  42
# asset_id  i
# q_sold  890
# ri_sold  890
# here
# not here
# timestep  42
# asset_id  j
# q_sold  1122
# ri_sold  1122
# timestep  43
# asset_id  j
# q_sold  1122
# ri_sold  1122
# here
# not here
# timestep  43
# asset_id  j
# q_sold  2367
# ri_sold  2367
# timestep  44
# asset_id  j
# q_sold  2367
# ri_sold  2367
# here
# not here
# timestep  44
# asset_id  j
# q_sold  399
# ri_sold  399
# timestep  45
# asset_id  j
# q_sold  399
# ri_sold  399
# here
# not here
# timestep  45
# asset_id  j
# q_sold  2371
# ri_sold  2371
# timestep  46
# asset_id  j
# q_sold  2371
# ri_sold  2371
# here
# not here
# timestep  46
# asset_id  j
# q_sold  1254
# ri_sold  1254
# timestep  47
# asset_id  j
# q_sold  1254
# ri_sold  1254
# here
# not here
# timestep  47
# asset_id  j
# q_sold  5
# ri_sold  5
# timestep  48
# asset_id  j
# q_sold  5
# ri_sold  5
# here
# not here
# timestep  48
# asset_id  i
# q_sold  1080
# ri_sold  1080
# timestep  49
# asset_id  i
# q_sold  1080
# ri_sold  1080
# here
# not here
# timestep  49
# asset_id  i
# q_sold  775
# ri_sold  775
# timestep  50
# asset_id  i
# q_sold  775
# ri_sold  775
# here
# not here
# timestep  50
# asset_id  i
# q_sold  1106
# ri_sold  1106
# timestep  51
# asset_id  i
# q_sold  1106
# ri_sold  1106
# here
# not here
# timestep  51
# asset_id  i
# q_sold  1801
# ri_sold  1801
# timestep  52
# asset_id  i
# q_sold  1801
# ri_sold  1801
# here
# not here
# timestep  52
# asset_id  j
# q_sold  -14
# ri_sold  -14
# timestep  53
# asset_id  j
# q_sold  -14
# ri_sold  -14
# here
# not here
# timestep  53
# asset_id  j
# q_sold  623
# ri_sold  623
# timestep  54
# asset_id  j
# q_sold  623
# ri_sold  623
# here
# not here
# timestep  54
# asset_id  j
# q_sold  740
# ri_sold  740
# timestep  55
# asset_id  j
# q_sold  740
# ri_sold  740
# here
# not here
# timestep  55
# asset_id  i
# q_sold  1243
# ri_sold  1243
# timestep  56
# asset_id  i
# q_sold  1243
# ri_sold  1243
# here
# not here
# timestep  56
# asset_id  i
# q_sold  367
# ri_sold  367
# timestep  57
# asset_id  i
# q_sold  367
# ri_sold  367
# here
# not here
# timestep  57
# asset_id  i
# q_sold  358
# ri_sold  358
# timestep  58
# asset_id  i
# q_sold  358
# ri_sold  358
# here
# not here
# timestep  58
# asset_id  i
# q_sold  789
# ri_sold  789
# timestep  59
# asset_id  i
# q_sold  789
# ri_sold  789
# here
# not here
# timestep  59
# asset_id  i
# q_sold  1415
# ri_sold  1415
# timestep  60
# asset_id  i
# q_sold  1415
# ri_sold  1415
# here
# not here
# timestep  60
# asset_id  j
# q_sold  1156
# ri_sold  1156
# timestep  61
# asset_id  j
# q_sold  1156
# ri_sold  1156
# here
# not here
# timestep  61
# asset_id  i
# q_sold  448
# ri_sold  448
# timestep  62
# asset_id  i
# q_sold  448
# ri_sold  448
# here
# not here
# timestep  62
# asset_id  i
# q_sold  1662
# ri_sold  1662
# timestep  63
# asset_id  i
# q_sold  1662
# ri_sold  1662
# here
# not here
# timestep  63
# asset_id  j
# q_sold  1092
# ri_sold  1092
# timestep  64
# asset_id  j
# q_sold  1092
# ri_sold  1092
# here
# not here
# timestep  64
# asset_id  j
# q_sold  1643
# ri_sold  1643
# timestep  65
# asset_id  j
# q_sold  1643
# ri_sold  1643
# here
# not here
# timestep  65
# asset_id  j
# q_sold  952
# ri_sold  952
# timestep  66
# asset_id  j
# q_sold  952
# ri_sold  952
# here
# not here
# timestep  66
# asset_id  j
# q_sold  -289
# ri_sold  -289
# timestep  67
# asset_id  j
# q_sold  -289
# ri_sold  -289
# here
# not here
# timestep  67
# asset_id  j
# q_sold  80
# ri_sold  80
# timestep  68
# asset_id  j
# q_sold  80
# ri_sold  80
# here
# not here
# timestep  68
# asset_id  i
# q_sold  261
# ri_sold  261
# timestep  69
# asset_id  i
# q_sold  261
# ri_sold  261
# here
# not here
# timestep  69
# asset_id  i
# q_sold  409
# ri_sold  409
# timestep  70
# asset_id  i
# q_sold  409
# ri_sold  409
# here
# not here
# timestep  70
# asset_id  i
# q_sold  1512
# ri_sold  1512
# timestep  71
# asset_id  i
# q_sold  1512
# ri_sold  1512
# here
# not here
# timestep  71
# asset_id  j
# q_sold  1178
# ri_sold  1178
# timestep  72
# asset_id  j
# q_sold  1178
# ri_sold  1178
# here
# not here
# timestep  72
# asset_id  j
# q_sold  2080
# ri_sold  2080
# timestep  73
# asset_id  j
# q_sold  2080
# ri_sold  2080
# here
# not here
# timestep  73
# asset_id  i
# q_sold  593
# ri_sold  593
# timestep  74
# asset_id  i
# q_sold  593
# ri_sold  593
# here
# not here
# timestep  74
# asset_id  j
# q_sold  1059
# ri_sold  1059
# timestep  75
# asset_id  j
# q_sold  1059
# ri_sold  1059
# here
# not here
# timestep  75
# asset_id  j
# q_sold  1485
# ri_sold  1485
# timestep  76
# asset_id  j
# q_sold  1485
# ri_sold  1485
# here
# not here
# timestep  76
# asset_id  i
# q_sold  1913
# ri_sold  1913
# timestep  77
# asset_id  i
# q_sold  1913
# ri_sold  1913
# here
# not here
# timestep  77
# asset_id  j
# q_sold  327
# ri_sold  327
# timestep  78
# asset_id  j
# q_sold  327
# ri_sold  327
# here
# not here
# timestep  78
# asset_id  j
# q_sold  135
# ri_sold  135
# timestep  79
# asset_id  j
# q_sold  135
# ri_sold  135
# here
# not here
# timestep  79
# asset_id  i
# q_sold  1284
# ri_sold  1284
# timestep  80
# asset_id  i
# q_sold  1284
# ri_sold  1284
# here
# not here
# timestep  80
# asset_id  i
# q_sold  1496
# ri_sold  1496
# timestep  81
# asset_id  i
# q_sold  1496
# ri_sold  1496
# here
# not here
# timestep  81
# asset_id  j
# q_sold  1621
# ri_sold  1621
# timestep  82
# asset_id  j
# q_sold  1621
# ri_sold  1621
# here
# not here
# timestep  82
# asset_id  i
# q_sold  -765
# ri_sold  -765
# timestep  83
# asset_id  i
# q_sold  -765
# ri_sold  -765
# here
# not here
# timestep  83
# asset_id  j
# q_sold  949
# ri_sold  949
# timestep  84
# asset_id  j
# q_sold  949
# ri_sold  949
# here
# not here
# timestep  84
# asset_id  j
# q_sold  1439
# ri_sold  1439
# timestep  85
# asset_id  j
# q_sold  1439
# ri_sold  1439
# here
# not here
# timestep  85
# asset_id  j
# q_sold  -133
# ri_sold  -133
# timestep  86
# asset_id  j
# q_sold  -133
# ri_sold  -133
# here
# not here
# timestep  86
# asset_id  j
# q_sold  992
# ri_sold  992
# timestep  87
# asset_id  j
# q_sold  992
# ri_sold  992
# here
# not here
# timestep  87
# asset_id  i
# q_sold  1369
# ri_sold  1369
# timestep  88
# asset_id  i
# q_sold  1369
# ri_sold  1369
# here
# not here
# timestep  88
# asset_id  i
# q_sold  183
# ri_sold  183
# timestep  89
# asset_id  i
# q_sold  183
# ri_sold  183
# here
# not here
# timestep  89
# asset_id  j
# q_sold  1255
# ri_sold  1255
# timestep  90
# asset_id  j
# q_sold  1255
# ri_sold  1255
# 150977
# Timestep-------------=  90
# delta_S remove 977
# delta_W remove 977.0
# here
# not here
# timestep  90
# asset_id  i
# q_sold  1639
# ri_sold  1639
# 150977
# timestep  91
# asset_id  i
# q_sold  1639
# ri_sold  1639
# here
# not here
# timestep  91
# asset_id  j
# q_sold  1557
# ri_sold  1557
# timestep  92
# asset_id  j
# q_sold  1557
# ri_sold  1557
# here
# not here
# timestep  92
# asset_id  j
# q_sold  1351
# ri_sold  1351
# timestep  93
# asset_id  j
# q_sold  1351
# ri_sold  1351
# here
# not here
# timestep  93
# asset_id  i
# q_sold  155
# ri_sold  155
# timestep  94
# asset_id  i
# q_sold  155
# ri_sold  155
# here
# not here
# timestep  94
# asset_id  i
# q_sold  1332
# ri_sold  1332
# timestep  95
# asset_id  i
# q_sold  1332
# ri_sold  1332
# here
# not here
# timestep  95
# asset_id  j
# q_sold  1421
# ri_sold  1421
# timestep  96
# asset_id  j
# q_sold  1421
# ri_sold  1421
# here
# not here
# timestep  96
# asset_id  i
# q_sold  438
# ri_sold  438
# timestep  97
# asset_id  i
# q_sold  438
# ri_sold  438
# here
# not here
# timestep  97
# asset_id  j
# q_sold  1872
# ri_sold  1872
# timestep  98
# asset_id  j
# q_sold  1872
# ri_sold  1872
# here
# not here
# timestep  98
# asset_id  i
# q_sold  960
# ri_sold  960
# timestep  99
# asset_id  i
# q_sold  960
# ri_sold  960
# here
# not here
# timestep  99
# asset_id  j
# q_sold  1592
# ri_sold  1592
# timestep  100
# asset_id  j
# q_sold  1592
# ri_sold  1592
# here
# not here
# Total execution time: 0.93s

# %% [markdown]
# ## Interpretation of Results

# %% [markdown]
# ### Creation of Results
#
# Before moving to the interpretation and analysis we first create and prepare the results: sometimes just to see whether the experiment is running corectly and sometimes to see into the results for analysis
#
# The following command lines creates views based on the simulation results.
#
# - the `model_history`, counting for the i-th base asset, the risk asset and the shares of the risk asset respectively.
# - the `uniswap_j`, counting for the j-th base asset, the risk asset and the shares of the risk asset respectively.,
# - the `uniswap_ij` counting for the i-j asset, the risk asset and the shares of the risk asset respectively, and
# - `hydra`, counting the base asset amount in the pool, the total base asset supply and the shares of the base asset respectively.

# %%
model_history = rdf[['UNI_Qi', 'UNI_Ri', 'UNI_Si']]
model_history.columns = ['model_UNI_Qi', 'model_UNI_Ri', 'model_UNI_Si']

uniswap_j = rdf[['UNI_Qj', 'UNI_Rj', 'UNI_Sj']]
uniswap_j.columns = ['UNI_Qj', 'UNI_Rj', 'UNI_Sj']

uniswap_ij = rdf[['UNI_ij', 'UNI_ji', 'UNI_Sij']]
uniswap_ij.columns = ['UNI_ij', 'UNI_ji', 'UNI_Sij']

hydra = rdf[['Q', 'H', 'Sq']]
hydra.columns = ['Hydra_Q', 'Hydra_H', 'Hydra_Sq']

# %% [markdown]
# ### Risk assets in the Omnipool - the `pool` variable
#
# The `pool` variable is the risk-asset side of the Omnipool in the Hydra world.
#
# For each asset in the Omnipool this variable tracks the following quantities:
#
# - $R$ (asset quantity),
# - $S$ (share quantity),
# - $W$ (weight quantity = share quantity),
# - $P$ (price) and
# - $dP$ (change in price).
#
# To locate specific values in the `pool` dataframe
# - `first_valid_index()`
# - `first_valid_index()*x`
# - `last_valid_index()`
#
# can be used for any integer value $x$.

# %%
rdf
# Out:
#       UNI_Qi  UNI_Ri  UNI_Si  UNI_Qj  UNI_Rj  UNI_Sj  UNI_ij  UNI_ji  \
# 4      20000  511598   10000   20000   67333   10000  511598   67333
# 8      20000  511598   10000   20000   67333   10000  511598   67333
# 12     20000  511598   10000   20000   67333   10000  511598   67333
# 16     20000  511598   10000   20000   67333   10000  511598   67333
# 20     20000  511598   10000   20000   67333   10000  511598   67333
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 1587   20001  511614   10000   20000   67333   10000  511598   67333
# 1591   20001  511614   10000   20000   67333   10000  511598   67333
# 1595   20001  511614   10000   20000   67333   10000  511598   67333
# 1599   20001  511614   10000   20000   67333   10000  511598   67333
# 1603   20001  511614   10000   20000   67333   10000  511598   67333
#
#           UNI_Sij                                         uni_agents  ...  \
# 4     34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 8     34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 12    34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 16    34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 20    34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# ...           ...                                                ...  ...
# 1587  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1591  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1595  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1599  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1603  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
#
#            Sq                                       hydra_agents  \
# 4    20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 8    20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 12   20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 16   20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 20   20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# ...       ...                                                ...
# 1587 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1591 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1595 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1599 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1603 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
#
#                     C asset_random_choice  trade_random_size  simulation  \
# 4    1000000000000.00                   i                452           0
# 8    1000000000000.00                   i                726           0
# 12   1000000000000.00                   i               -182           0
# 16   1000000000000.00                   i               1864           0
# 20   1000000000000.00                   j               -244           0
# ...               ...                 ...                ...         ...
# 1587 1000032985664.53                   i                438           0
# 1591 1000032985664.53                   j               1872           0
# 1595 1000032985664.53                   i                960           0
# 1599 1000032985664.53                   j               1592           0
# 1603 1000032985664.53                   i                786           0
#
#       subset  run substep  timestep
# 4          0    1       4         1
# 8          0    1       4         2
# 12         0    1       4         3
# 16         0    1       4         4
# 20         0    1       4         5
# ...      ...  ...     ...       ...
# 1587       3    3       4        96
# 1591       3    3       4        97
# 1595       3    3       4        98
# 1599       3    3       4        99
# 1603       3    3       4       100
#
# [400 rows x 27 columns]

# %%
len(rdf)
# Out:
# 400

# %%
rdf.pool.head()
# Out:
# 4     <class 'model.parts.asset_utils.Asset'>: {'poo...
# 8     <class 'model.parts.asset_utils.Asset'>: {'poo...
# 12    <class 'model.parts.asset_utils.Asset'>: {'poo...
# 16    <class 'model.parts.asset_utils.Asset'>: {'poo...
# 20    <class 'model.parts.asset_utils.Asset'>: {'poo...
# Name: pool, dtype: object

# %%
reserve_i = []
for i in rdf.pool.keys():
    reserve_i.append(rdf.pool[i].pool['i']['R'])
print(reserve_i)
len(set(reserve_i)) == 1
# Out:
# [511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 510276.5785833441, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 511598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 561598, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754, 511614.8754]
# False

# %%
print(rdf.pool[rdf.first_valid_index()])
# Out:
# <class 'model.parts.asset_utils.Asset'>: {'pool': {'i': {'R': 511598, 'S': 10000, 'W': 10000, 'P': 0.027643062763597497, 'dP': 0}, 'j': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656}, 'k': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656}}}

# %%
rdf.pool[rdf.first_valid_index()].pool
# Out:
# {'i': {'R': 511598,
#   'S': 10000,
#   'W': 10000,
#   'P': 0.027643062763597497,
#   'dP': 0},
#  'j': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656},
#  'k': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656}}

# %%
rdf.pool[rdf.first_valid_index()*10].pool
# Out:
# {'i': {'R': 561598,
#   'S': 10691.076569089937,
#   'W': 10691.076569089937,
#   'P': 0.026922221019975514,
#   'dP': 0},
#  'j': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656},
#  'k': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.21003275695024656}}

# %%
rdf.pool[rdf.last_valid_index()].pool
# Out:
# {'i': {'R': 511614.8754,
#   'S': 10000.329856645256,
#   'W': 10000.329856645256,
#   'P': 0.03909319426581026,
#   'dP': 0},
#  'j': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.2970311734216506},
#  'k': {'R': 67333, 'S': 10000, 'W': 10000, 'P': 0.2970311734216506}}

# %% [markdown]
# ### Representing results in table form
#
# The simulation results and variable quantities can be shown in table form where
#
# - `head(n)`
# - `tail(n)`
#
# can be used to target the $n$ specific entries.
#
# ##### The columns show:
# ##### for the uniswap universe
# - `UNI_Qi`...the quantity of the i-th assets base
# - `UNI_Ri`...the quantity of the i-th assets risk
# - `UNI_Si`...the quantity of the i-th assets shares
# - `UNI_Qj`...the quantity of the j-th assets base
# - `UNI_Rj`...the quantity of the j-th assets risk
# - `UNI_Sj`...the quantity of the j-th assets shares
# - `uni_agents`...the definition of the actions of the uniswap agents
# - `UNI_P_RQi`...the price of the i-th risk asset in terms of Q
# - `UNI_P_RQj`...the price of the j-th risk asset in terms of Q
#
# ##### for the hydra universe
# - `pool`...the definition of the pool variable
# - `Q`...the quantity of the base asset in the hydra pool
# - `H`...the total quantity of the base asset in the hydra system
# - `Wq`...total quantity of weigths of the base asset
# - `Sq`...total quantity of shares of the base asset
# - `hydra_agents`...the definition of the actions of the hydra agents
#
# ##### simulation parameters
# - `simulation`...simulation number
# - `subset`...subset number
# - `run`...run number
# - `substep`...substep number
# - `timestep`...timestep of simulation
#
# Notice, that due to postprocessing of the simulation results this table always shows the forth substep of each timestep only.

# %%
rdf.head(5)
# Out:
#     UNI_Qi  UNI_Ri  UNI_Si  UNI_Qj  UNI_Rj  UNI_Sj  UNI_ij  UNI_ji  \
# 4    20000  511598   10000   20000   67333   10000  511598   67333
# 8    20000  511598   10000   20000   67333   10000  511598   67333
# 12   20000  511598   10000   20000   67333   10000  511598   67333
# 16   20000  511598   10000   20000   67333   10000  511598   67333
# 20   20000  511598   10000   20000   67333   10000  511598   67333
#
#         UNI_Sij                                         uni_agents  ...  \
# 4   34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 8   34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 12  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 16  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 20  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
#
#          Sq                                       hydra_agents  \
# 4  20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 8  20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 12 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 16 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
# 20 20000.00     m  r_i_out  r_i_in       h     q_i     s_i ...
#
#                   C asset_random_choice  trade_random_size  simulation  \
# 4  1000000000000.00                   i                452           0
# 8  1000000000000.00                   i                726           0
# 12 1000000000000.00                   i               -182           0
# 16 1000000000000.00                   i               1864           0
# 20 1000000000000.00                   j               -244           0
#
#     subset  run substep  timestep
# 4        0    1       4         1
# 8        0    1       4         2
# 12       0    1       4         3
# 16       0    1       4         4
# 20       0    1       4         5
#
# [5 rows x 27 columns]

# %%
rdf.tail()
# Out:
#       UNI_Qi  UNI_Ri  UNI_Si  UNI_Qj  UNI_Rj  UNI_Sj  UNI_ij  UNI_ji  \
# 1587   20001  511614   10000   20000   67333   10000  511598   67333
# 1591   20001  511614   10000   20000   67333   10000  511598   67333
# 1595   20001  511614   10000   20000   67333   10000  511598   67333
# 1599   20001  511614   10000   20000   67333   10000  511598   67333
# 1603   20001  511614   10000   20000   67333   10000  511598   67333
#
#           UNI_Sij                                         uni_agents  ...  \
# 1587  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1591  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1595  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1599  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
# 1603  34447428134     m  r_i_out  r_i_in       h     q_i     s_i ...  ...
#
#            Sq                                       hydra_agents  \
# 1587 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1591 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1595 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1599 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
# 1603 20000.33     m  r_i_out  r_i_in       h     q_i     s_i ...
#
#                     C asset_random_choice  trade_random_size  simulation  \
# 1587 1000032985664.53                   i                438           0
# 1591 1000032985664.53                   j               1872           0
# 1595 1000032985664.53                   i                960           0
# 1599 1000032985664.53                   j               1592           0
# 1603 1000032985664.53                   i                786           0
#
#       subset  run substep  timestep
# 1587       3    3       4        96
# 1591       3    3       4        97
# 1595       3    3       4        98
# 1599       3    3       4        99
# 1603       3    3       4       100
#
# [5 rows x 27 columns]

# %% [markdown]
# # The pools and global states

# %% [markdown]
# ## Global State variables for the Uniswap world
# ## i - Q instance
# ### Quantities of i-th risk asset, the Q asset and the i-asset shares
#
# The following command lines **create three plots** that show: (for the i-th asset)
# - on the left: the quantity of base asset `model_UNI_Qi`
# - center: the quantity of risk asset `model_UNI_Ri`
# - on the right: the quantity of shares `model_UNI_Si`
# over all simulation steps
#
# To show other assets the suffix of these commands can be replaced by f.e. `Qj` instead of `Qi`

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Qi'])
plt.title('UNISWAP Asset i Q-Base Token')

ax = plt.subplot(132)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Ri'])
plt.title('UNISWAP Asset i Reserve Risk')

ax = plt.subplot(133)
model_history.astype(float).plot(ax=ax, y=['model_UNI_Si'])
plt.title('UNISWAP Asset i Shares')
plt.show()

# %% [markdown]
# ### Prices of the i-th asset
#
# The following command line creates a plot of the prices: (for the i-th asset)
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.
#
# For experiments where the price of the asset is affected - for example when it is traded - we expect this price either to rise or fall accordingly. For liquidity adds this price should remain unchanged.
#
# To show other assets the suffix of these commands can be replaced by f.e. `Qj` instead of `Qi`

# %%
price_plot(rdf,'UNISWAP Asset i Price', 'UNI_P_RQi', 'UNI_Ri', 'UNI_Qi')

# %% [markdown]
# ## j - Q instance
# ### Quantities of j-th risk asset, the Q asset and the j-asset shares
#
#
# The following command lines create three plots that show: (for the j-th asset)
# - on the left: the quantity of base asset `UNI_Qj`
# - center: the quantity of risk asset `UNI_Rj`
# - on the right: the quantity of shares `UNI_Sj`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Qj'])
plt.title('UNISWAP Asset j Q-Base Token')

ax = plt.subplot(132)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Rj'])
plt.title('UNISWAP Asset j Reserve Risk')

ax = plt.subplot(133)
uniswap_j.astype(float).plot(ax=ax, y=['UNI_Sj'])
plt.title('UNISWAP Asset j Shares')
plt.show()

# %% [markdown]
# ### Prices of the j-th asset
#
# The following command line creates a plot of the prices: (for the j-th asset)
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.
#
# For experiments where the price of the asset is affected - for example when it is traded - we expect this price either to rise or fall accordingly. For liquidity adds this price should remain unchanged.

# %%
price_plot(rdf,'UNISWAP Asset j Price', 'UNI_P_RQj', 'UNI_Rj', 'UNI_Qj')

# %% [markdown]
# ## i-j instance
# ### Quantities of i-th risk asset, the j-th risk asset and the i-j-asset shares
#
#
# The following command lines create three plots that show: (for the j-th asset)
# - on the left: the quantity of the i-th asset `UNI_ij`
# - center: the quantity of the j-th asset `UNI_ji`
# - on the right: the quantity of i-j-shares `UNI_Sij`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_ij'])
plt.title('UNISWAP IJ Instance Asset i Token')

ax = plt.subplot(132)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_ji'])
plt.title('UNISWAP IJ Instance Asset j Token')

ax = plt.subplot(133)
uniswap_ij.astype(float).plot(ax=ax, y=['UNI_Sij'])
plt.title('UNISWAP IJ Instance Shares')
plt.show()

# %% [markdown]
# ### Prices of the i-j asset swap
#
# The following command line creates a plot of the swap prices
# - the swap price of the risk asset
# - the pool ratio price of the risk asset
#
# Comparison of both plots shows the effects of fees.

# %%
price_plot(rdf,'UNISWAP Instance ij Price', 'UNI_P_ij', 'UNI_ji','UNI_ij' )

# %% [markdown]
# ## Global State Variables for Hydra instance
#
# The Hydra system state can be described with the following global variables:
#
# | Symbol | Name | Definition  | Domain |  | Unit | |
# | --------|------- | -------- | -------- | -------- | -------- |-------|
# | $H$     | HDX Total Supply     | Supply is the total quantity of the native protocol token (HDX).|  ${\mathbb{R}_{++}}$| | HDX; an amount in real positive numbers
# | $Q$     | Base Pool Liquidity     | Base Pool Liquidity is the total quantity of the base asset (HDX) inside Pool.|  ${\mathbb{R}_{+}}$| | HDX; a positive real number if a pool has at least one risk asset
# | $\mathbf{\vec{R}}$ | Reserve Risk Assets     | An $n$-dimensional vector whose components are quantities of risk assets provided to the Liquidity Pool by liquidity providers.      |  $\mathbb{R}_{++}^{n}$ | | BTC, ETH, DOT,...; a vector of real positive numbers denoting quantities of each asset in the pool.
# | $\mathbf{\vec{S}}$     | Asset Shares     | Asset Shares are non-normalized values of each risk asset in the pool which are minted and distributed to the liquidity providers at time of inception of their asset into the Liquidity Pool. |  $\mathbb{R}_{++}^{n}$ | | a vector of real positive numbers
# | $S^Q$     | Base Pool Share     | The Pool value share of the base asset (HDX), i.e. claims on $Q$.|  $\mathbb{R}_{+}$ | | HDX; a real positive number if there exists at least one risk asset in the pool
# | $\mathbf{\vec{W}}$     | Asset Weights     | Asset Weights are non-normalized values of each risk asset in the pool used in the Uniswap/Balancer mechanisms. |  $\mathbb{R}_{++}^{n}$ | | a vector of real positive numbers
# | $W^Q$     | Base Pool Weight     | The non-normalized Pool value weight of the base asset (HDX).|  $\mathbb{R}_{+}$ | | a real positive number
# | $\mathbf{{P}}$     | Price    | The Price is a (n+1)x(n+1) Matrix listing all spot prices for all risk assets present in the Liquidity pool. Its components $p_{i,j}$ are the prices of the i-th asset denoted in the j-th asset.| $\mathbb{R}_{++}^{n\times n}$ | | f.e: ETH/HDX; depending on the component $p_{ij}$ of the matrix the unit is currency$_i$ / currency$_j$ where for the above example $i$ is ETH and $j$ is HDX. |
# | $\vec{p}^Q$     | Asset Base Price    | The Asset Base Price is a vector listing the spot prices of all risk assets in the pool in terms of the base asset HDX. | $\mathbb{R}^n_{++}$ | | A real number representing the rate of exchange between a risk asset and HDX, e.g. ETH/HDX. |
#
#
# Notice that $H$, $Q$ and $S^Q$ represent the Base side of the Omnipool and are tracked separately in the Hydra World whereas the other variables representing the Risk side of the Omnipool are encoded in $\mathbf{\vec{R}}$ , $\mathbf{\vec{S}}$  are tracked by the `pool` variable

# %% [markdown]
# ## Hydra World
# ### Base Asset side of the Omnipool
# ### Quantities of the base asset in the pool and in the system, and the base-shares
#
# The following command lines create three plots that show: (for the base asset)
# - on the left: the quantity of base asset in the pool `Hydra_Q`
# - center: the total quantity of base asset in the system `Hydra_H`
# - on the right: the quantity of base asset shares `Hydra_Sq`
#
# over the simulation steps

# %%
plt.figure(figsize=(20,6))
ax = plt.subplot(131)
hydra.astype(float).plot(ax=ax, y=['Hydra_Q'])
plt.title('Hydra Q in OmniPool')

ax = plt.subplot(132) 
hydra.astype(float).plot(ax=ax, y=['Hydra_H'])
plt.title('Hydra H Total')

ax = plt.subplot(133)
hydra.astype(float).plot(ax=ax, y=['Hydra_Sq'])
plt.title('Hydra Sq Shares in OmniPool')
plt.show()

# %% [markdown]
# ## Hydra World
# ### Risk Asset side of the Omnipool
# ### Quantities of the i-th risk asset, i-Shares and the price for i
#
# The following command line creates three plots for the Hydra Omnipool (for the i-th asset on the risk side)
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset i Reserve and Shares', rdf.last_valid_index(),str('i'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 404
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d5699a4afcdd> in <module>
# ----> 1 hydra_pool_plot(rdf,'Asset i Reserve and Shares', rdf.last_valid_index(),str('i'))
#
# ~\Documents\GitHub\hydra\hydra_multi_class\model\plot_utils.py in hydra_pool_plot(experiments, test_title, T, asset_id)
#      22     for i in range (df.substep.max(),T+df.substep.max(),df.substep.max()):
#      23         asset_R_list = []
# ---> 24         asset_R_list.append(df.pool[i].pool[asset_id]['R'])
#      25         asset_R.append(asset_R_list)
#      26
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     849
#     850         elif key_is_scalar:
# --> 851             return self._get_value(key)
#     852
#     853         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     957
#     958         # Similar to Index.get_value, but we do not fall back to positional
# --> 959         loc = self.index.get_loc(label)
#     960         return self.index._get_values_for_loc(self, loc, label)
#     961
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 404

# %% [markdown]
# ### Quantities of the j-th risk asset, j-Shares and the price for j
#
# The following command line creates three plots for the Hydra Omnipool
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset j Reserve and Shares', rdf.last_valid_index(),str('j'))

# %% [markdown]
# ### Quantities of the k-th risk asset, k-Shares and the price for k
#
# The following command line creates three plots for the Hydra Omnipool
#
# - the asset index can be set individually to `i`, `j`, etc.

# %%
hydra_pool_plot(rdf,'Asset k Reserve and Shares', rdf.last_valid_index(),str('k'))

# %% [markdown]
# ### Price comparison for assets on the risk side of the Omnipool
#
# The following command lines create a plots for the Hydra Omnipool prices:
# - Asset Base Prices
# - Share to Reserve Ratio Base Prices
# - Relative Asset Prices `i` to `j`
# - Relative Asset Prices `i` to `k`
# - Relative Asset Prices `j` to `k`

# %%
hydra_pool_price_plot(rdf,'Asset Base Price', rdf.last_valid_index(),['i', 'j','k'])

# %%
trade_liq_plot(rdf,'Share to Reserve Ratio Base Price', rdf.last_valid_index(),['i', 'j','k'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['i', 'j'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['i', 'k'])

# %%
rel_price_plot(rdf,'Relative Asset Prices', rdf.last_valid_index(),['j', 'k'])

# %% [markdown]
# # Agents and their Local State Variables
#
# The following section tracks the development for the agent states.
# As every agent is defined to be responsible for a different action and all agent states are shown this section can be used to assess
# - the intentional changes in the local states directly affected by the actions, and
# - the unintentional changes in local states of other agents who are indirectly affected
#
# All agents carry the following local states:
#
# | Symbol | Name | Definition  | Domain |   | Unit
# | -------- | -------- | -------- | -------- | -------- | --------|
# | $\mathbf{r}^j$     | Reserve Assets     | Reserve Assets are quantities of privately held risk assets by liquidity provider agent $j$ which are not (yet) related to the Liquidity Pool. |  $\mathbb{R}_{+}^{n}$| | BTC, ETH, DOT,...; an amount in real non-negative numbers denoted in the respective currency unit
# | $h^j$     | Base Asset     | Total Base Asset (HDX) amount of $H$ held by agent $j$. |  $\mathbb{R}_{+}$| | a real non-negative amount of HDX |
# | $\mathbf{s}^j$     | Risk Asset Shares     | Risk Asset Share as value of liquidity provider agent $j$'s contribution of risk asset(s) to the Liquidity Pool, minted and distributed (as a claim) to agent $j$ at the time of introduction into the Pool.| $\mathbb{R}_{+}^{n}$  | |a vector of amounts in real non-negative numbers
# | $s^{qj}$     | Base Asset Share     | Base Asset (HDX) share as value of liquidity provider agent $j$'s contribution of HDX to the Liquidity Pool,  minted and distributed to agent $j$ (as a claim) at the time of introduction into the Pool.| $\mathbb{R}_{+}$  | |a real non-negative number
#
# To locate specific values in the dataframe the commands
# - `first_valid_index()`
# - `first_valid_index()*x`
# - `last_valid_index()`
#
# can be used.

# %% [markdown]
# ## Hydra World
#
# Results for the copy of the agents going through the Hydra world are saved in `hydra_agents`

# %%
rdf['hydra_agents'][rdf.first_valid_index()]

# %%
rdf['hydra_agents'][rdf.first_valid_index()*10]

# %% [markdown]
# ## Uniswap world
#
# Results for the copy of the agents going through the Hydra world are saved in `uni_agents`

# %%
rdf['uni_agents'][rdf.first_valid_index()]

# %%
rdf['uni_agents'][rdf.first_valid_index()*7]

# %%
rdf['uni_agents'][rdf.first_valid_index()*12]

# %%
rdf['uni_agents'][rdf.first_valid_index()*12].iloc[2]

# %% [markdown]
# ## Agent Token Holdings - Uniswap World
#
#
# The following command line creates eight plots, one for each agent individually, showing his token holdings

# %%
agent_plot(rdf,'Uniswap Token Holding for Agent ', len(rdf['timestep'])) #,4,'j')

# %% [markdown]
# ## Agent Values - Uniswap World
#
# The following command line creates eight plots, one for each agents showing his values. These are the token holdings multiplied by price.

# %%
agent_value_plot(rdf,'Uniswap Value of S, R, and H in H equivalent', len(rdf['timestep'])) #,2, 'i')

# %% [markdown]
# ## Agent Token Holdings - Hydra World
#
# The following command line creates eight plots, one for each agents indivudially, showing his token holdings

# %%
hydra_agent_plot(rdf,'Hydra Token Holdings for Agent ', len(rdf['timestep']))

# %% [markdown]
# ## Agent Values - Hydra World
#
# The following command line creates eight plots, one for each agents showing his values. These are the token holdings multiplied by price.

# %%
hydra_agent_value_plot(rdf,'Hydra Omnipool Value of Si, Ri, and H in H equivalent', len(rdf['timestep'])) #,2, 'i')

# %% [markdown]
# ### Impermanent Loss (IL) calculation
#
# Impermanent loss is defined as
#
# $$
# IL = \frac{\delta Pool Value}{\delta Hold Value} - 1
# $$

# %%
IL_plot(rdf,'Impermanent Loss in Uniswap Instances Over Fixed Windows of ', 30)

# %% [markdown]
# ## Metric calculations: slippage and impermanent loss
#
# ### Slippage
#
# Slippage is calculated in two different, but related ways: the first is as an elasticity, by measuring the percentage change in the price following a trade with respect to the trade size as a percentage of the pool reserve. The second is as the percentage difference between the effective (actual trade) price and the spot price, which measures trader expectations on the execution price.

# %%
# Assign ids for risk assets IN and OUT
asset_in_id = 'i'
asset_out_id = 'j'

# Extract time series - clunky, refactor into comprehensions for performance
reserve_asset_in_dict = {}
reserve_asset_out_dict = {}
asset_price_in_dict = {}  # Note: in terms of HDX as numeraire
asset_price_out_dict = {} # Note: in terms of HDX as numeraire
asset_weight_in_dict = {}
asset_weight_out_dict = {}
for t in rdf.pool.keys():
    reserve_asset_in_dict[t] = rdf.pool[t].pool[asset_in_id]['R']
    reserve_asset_out_dict[t] = rdf.pool[t].pool[asset_out_id]['R']
    asset_price_in_dict[t] = rdf.pool[t].pool[asset_in_id]['P']
    asset_price_out_dict[t] = rdf.pool[t].pool[asset_out_id]['P']
    asset_weight_in_dict[t] = rdf.pool[t].pool[asset_in_id]['W']
    asset_weight_out_dict[t] = rdf.pool[t].pool[asset_out_id]['W']
reserve_asset_in = pd.Series(reserve_asset_in_dict)
reserve_asset_out = pd.Series(reserve_asset_out_dict)
asset_price_in = pd.Series(asset_price_in_dict)
asset_price_out = pd.Series(asset_price_out_dict)
asset_weight_in = pd.Series(asset_weight_in_dict)
asset_weight_out = pd.Series(asset_weight_out_dict)

# Compute percent change in reserve
reserve_in_pct_change = reserve_asset_in.pct_change()
reserve_out_pct_change = reserve_asset_out.pct_change()

# Compute price of OUT asset in terms of IN asset
price_out_for_in = asset_price_in / asset_price_out

# Compute percent change in price (OUT per IN)
price_pct_change = price_out_for_in.pct_change()

# Slippage calculation #1: elasticity of price with respect to transactions size
elasticity = price_pct_change / reserve_in_pct_change

# Slippage calculation #2: percentage difference between effective and spot price
slippage = ( (reserve_in_pct_change / reserve_asset_in) / (reserve_out_pct_change / reserve_asset_out)
 * (asset_weight_in / asset_weight_out) - 1 )

# %% [markdown]
# #### Slippage Plots

# %%
# Plot elasticity as a function of transactions size
plt.plot(reserve_asset_in,elasticity,label='Elasticity', marker='o')
plt.xlabel('Transaction Size')
plt.ylabel('Elasticity')
plt.legend()
plt.title('Price Elasticity of Transactions')

# %%
# Plot analytical slippage as a function of transactions size
plt.plot(reserve_asset_in,slippage,label='Slippage', marker='o')
plt.xlabel('Transaction Size')
plt.ylabel('Slippage, %')
plt.legend()
plt.title('Slippage By Transaction Size')

# %% [markdown]
# ### Impermanent Loss
#
# Impermanent Loss (IL) is computed as a final value for a liqudity provider (LP) providing a single asset to the OMNIPool.
#
# This does not compute the 'running IL', which requires computing the amount of liquidity that would have been removed at each time period using the shares given to the LP when they added liquidity. This can still be post-processed but will require calls to the correct remove liquidity functions in the code, or re-writing the same code into the notebook.

# %%
# Set id of agent (LP) to be assessed for IL
agent_id = 2

# Set ids for asset that the LP has added
asset_id = 'i'
agent_asset_id = 'r_i_out'

# Set substep size
substep = 4

# Set amount added by LP during addLiquidity event 
# (usually set as an initial condition of the simulation)
liquidity_added = 50000

# Set timestamp of removeLiquidity event for LP
time_liquidity_out = 90

# Read amount removed by LP after removeLiquidity event
liquidity_removed = ( rdf['hydra_agents'][time_liquidity_out * substep].iloc[agent_id][agent_asset_id] - 
                     rdf['hydra_agents'][(time_liquidity_out - 1) * substep].iloc[agent_id][agent_asset_id] )

# Compute value of holding liquidity, with HDX as numeraire
hold_value = liquidity_added * rdf.pool[time_liquidity_out * substep].pool[asset_id]['P']
                     
# Compute value of liquidity after removing from pool, with HDX as numeraire
pool_value = liquidity_removed * rdf.pool[time_liquidity_out * substep].pool[asset_id]['P']
                     
# Compute impermanent loss
IL = (pool_value / hold_value) - 1

# %%
import math
mu_i_set = 100
sigma_i_set = 5
mu_j_set = 200
sigma_j_set = 10

############ CHOOSE STARTING LIQ TYPE #############################
    
if 'exo_starting_liquidity' == 'stochastic':
    sigma_i = sigma_i_set
    mu_i = mu_i_set
    sigma_j = sigma_j_set
    mu_j = mu_j_set
else:
    sigma_i = 0
    mu_i = mu_i_set
    sigma_j = 0
    mu_j = mu_j_set
            
############ CHOOSE STARTING LIQ TYPE #############################

R_i_start = np.random.normal(mu_i, sigma_i)
R_j_start = np.random.normal(mu_j, sigma_j)

asset_initial_values = {
    'i' : 
        {'R': 1000000,
        'Q': 2000000,
        # 'S': 100000000 * 200000000},
        'S': 10000},

    'j' : 
        {'R': 1000000,
        'Q': 2000000,
        # 'S': 100000000 * 200000000},
        'S': 10000},
}

asset_initial_values['i']['R'] = math.ceil(R_i_start)
asset_initial_values['j']['R'] = math.ceil(R_j_start)

initial_values = {
    'UNI_Qi': asset_initial_values['i']['Q'],
    'UNI_Ri': asset_initial_values['i']['R'],
    'UNI_Si': asset_initial_values['i']['S'],
    'UNI_Qj': asset_initial_values['j']['Q'],
    'UNI_Rj': asset_initial_values['j']['R'],
    'UNI_Sj': asset_initial_values['j']['S'],
    'UNI_ij': asset_initial_values['i']['R'],
    'UNI_ji': asset_initial_values['j']['R'],
    'UNI_Sij': asset_initial_values['j']['R']*asset_initial_values['i']['R'],
    'Ri': asset_initial_values['i']['R'],
    # 'Si': 5*asset_initial_values['i']['R'],
    'Si': asset_initial_values['i']['S'],
    'Rj': asset_initial_values['j']['R'],
    # 'Sj': 5*asset_initial_values['j']['R'],
    'Sj': asset_initial_values['j']['S'],
    'Sq': asset_initial_values['i']['S'] + asset_initial_values['j']['S'],
    # 'Sq': 5*Q,
    'Q':  asset_initial_values['i']['Q'] + asset_initial_values['j']['Q'],
    'H':  asset_initial_values['i']['Q'] + asset_initial_values['j']['Q'],
}

initial_values['UNI_Ri']

# %%
import math
import numpy as np

exo_starting_liquidity = 'stochastic'

mu_i_set = 100
sigma_i_set = 5
mu_j_set = 200
sigma_j_set = 10

############ CHOOSE STARTING LIQ TYPE #############################
    
if exo_starting_liquidity == 'stochastic':
    sigma_i = sigma_i_set
    mu_i = mu_i_set
    sigma_j = sigma_j_set
    mu_j = mu_j_set
else:
    sigma_i = 0
    mu_i = mu_i_set
    sigma_j = 0
    mu_j = mu_j_set
            
############ CHOOSE STARTING LIQ TYPE #############################

R_i_start = np.random.normal(mu_i, sigma_i)
R_j_start = np.random.normal(mu_j, sigma_j)

exo_starting_liquidity, R_i_start, R_j_start, mu_i, sigma_i, sigma_i_set

asset_initial_values = {
    'i' : 
        {'R': 1000000,
        'Q': 2000000,
        # 'S': 100000000 * 200000000},
        'S': 10000},

    'j' : 
        {'R': 1000000,
        'Q': 2000000,
        # 'S': 100000000 * 200000000},
        'S': 10000},
}

asset_initial_values['i']['R'] = math.ceil(R_i_start)
asset_initial_values['j']['R'] = math.ceil(R_j_start)

initial_values = {
    'UNI_Qi': asset_initial_values['i']['Q'],
    'UNI_Ri': asset_initial_values['i']['R'],
    'UNI_Si': asset_initial_values['i']['S'],
    'UNI_Qj': asset_initial_values['j']['Q'],
    'UNI_Rj': asset_initial_values['j']['R'],
    'UNI_Sj': asset_initial_values['j']['S'],
    'UNI_ij': asset_initial_values['i']['R'],
    'UNI_ji': asset_initial_values['j']['R'],
    'UNI_Sij': asset_initial_values['j']['R']*asset_initial_values['i']['R'],
    'Ri': asset_initial_values['i']['R'],
    # 'Si': 5*asset_initial_values['i']['R'],
    'Si': asset_initial_values['i']['S'],
    'Rj': asset_initial_values['j']['R'],
    # 'Sj': 5*asset_initial_values['j']['R'],
    'Sj': asset_initial_values['j']['S'],
    'Sq': asset_initial_values['i']['S'] + asset_initial_values['j']['S'],
    # 'Sq': 5*Q,
    'Q':  asset_initial_values['i']['Q'] + asset_initial_values['j']['Q'],
    'H':  asset_initial_values['i']['Q'] + asset_initial_values['j']['Q'],
}

exo_starting_liquidity, R_i_start, R_j_start, mu_i, sigma_i, sigma_i_set, asset_initial_values['i']['R'], asset_initial_values['j']['R'], initial_values['UNI_Ri']

# %%
exo_fee_size = [0.00] #in percent
fee_denominator = [1000]
fee_numerator = [0]
fee_numerator[0] = fee_denominator[0] - (exo_fee_size[0] / 100) * fee_denominator[0]
fee_numerator

# %%
exo_trade = ['test_r_for_r'] # agent 1
exo_liq = ['test_add']
ENABLE_SYMMETRIC_LIQ = [True] 
exo_asset = ['alternating']
exo_composite = ['alternating']
Ki = [10**7]
ACTION_LIST = [['test_add', 'test_r_for_q', 'test_q_for_r','test_r_for_r', 'test_remove']]
CHANGE_LOG = ['4-01-21']
a = [0.5]
ENABLE_BALANCER_PRICING = [True] 
exo_trade_size = ['fix_size']  # agent 5?
mu = [1000]
sigma = [0]
exo_random_sequence = ['on'] 

params = {
    'fee_numerator': fee_numerator,
    'fee_denominator': fee_denominator,
    'exo_trade': exo_trade, 
    'exo_liq' : exo_liq,
    'ENABLE_SYMMETRIC_LIQ' : ENABLE_SYMMETRIC_LIQ,
    'exo_asset' : exo_asset,
    'exo_composite' : exo_composite,
    'Ki' : Ki,
    'ACTION_LIST': ACTION_LIST,
    'CHANGE_LOG': CHANGE_LOG,
    'a': a, 
    'ENABLE_BALANCER_PRICING': ENABLE_BALANCER_PRICING,
    'exo_trade_size': exo_trade_size,
    'mu': mu,
    'sigma': sigma,
    'exo_random_sequence': exo_random_sequence,
}



if params['exo_random_sequence'] == 'on' :
    if timestep == 1 :
        params['exo_liq'] = 'test_add'
    elif timestep == 4000 :    
        params['exo_liq'] = 'test_remove'
    else :
        params['exo_liq'] = 'pass'

if params['exo_random_sequence'] == 'on':
    if timestep == 1:
        params['exo_trade'] = 'pass'
    elif timestep == 4000:    
        params['exo_trade'] = 'pass'
    else:
        params['exo_trade'] = random.choice(['test_r_for_r'])
            
if params['exo_random_sequence'] == 'on':
    action['asset_id'] = random.choice(['i', 'j'])
            
        
if params['exo_random_sequence'] == 'on':
    agent2_id = 2
    agent3_id = agent2_id 

time = 4000
#######
if params['exo_random_sequence'] == ['on']:
    if time == 1:
        params['exo_liq'] = 'test_add'
    elif time == 4000:    
        params['exo_liq'] = 'test_remove'
    else:    
        params['exo_liq'] = 'pass'    
else:
    params['exo_liq'] = 'pass1'
#######

    

params['exo_random_sequence'], params['exo_liq'], time

# %%
hydra_agents.values[5]['h'][2] = 100000000
