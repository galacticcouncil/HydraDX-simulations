# %%
import sys
import os
import glob
sys.path.append('../../..')

from model import processing
price_list = processing.import_binance_prices(assets=['DOT', 'ETH', 'BTC', 'DOGE'], start_date='Nov 1 2022', days=90)
print(price_list[0:10])
# Out:
# Downloading DOTUSDT-1s-2022-11-01
# Downloading DOTUSDT-1s-2022-11-02
# Downloading DOTUSDT-1s-2022-11-03
# Downloading DOTUSDT-1s-2022-11-04
# Downloading DOTUSDT-1s-2022-11-05
# Downloading DOTUSDT-1s-2022-11-06
# Downloading DOTUSDT-1s-2022-11-07
# Downloading DOTUSDT-1s-2022-11-08
# Downloading DOTUSDT-1s-2022-11-09
# Downloading DOTUSDT-1s-2022-11-10
# Downloading DOTUSDT-1s-2022-11-11
# Downloading DOTUSDT-1s-2022-11-12
# Downloading DOTUSDT-1s-2022-11-13
# Downloading DOTUSDT-1s-2022-11-14
# Downloading DOTUSDT-1s-2022-11-15
# Downloading DOTUSDT-1s-2022-11-16
# Downloading DOTUSDT-1s-2022-11-17
# Downloading DOTUSDT-1s-2022-11-18
# Downloading DOTUSDT-1s-2022-11-19
# Downloading DOTUSDT-1s-2022-11-20
# Downloading DOTUSDT-1s-2022-11-21
# Downloading DOTUSDT-1s-2022-11-22
# Downloading DOTUSDT-1s-2022-11-23
# Downloading DOTUSDT-1s-2022-11-24
# Downloading DOTUSDT-1s-2022-11-25
# Downloading DOTUSDT-1s-2022-11-26
# Downloading DOTUSDT-1s-2022-11-27
# Downloading DOTUSDT-1s-2022-11-28
# Downloading DOTUSDT-1s-2022-11-29
# Downloading DOTUSDT-1s-2022-11-30
# Downloading DOTUSDT-1s-2023-01-12
# Downloading DOTUSDT-1s-2023-01-13
# Downloading DOTUSDT-1s-2023-01-14
# Downloading DOTUSDT-1s-2023-01-15
# Downloading DOTUSDT-1s-2023-01-16
# Downloading DOTUSDT-1s-2023-01-17
# Downloading DOTUSDT-1s-2023-01-18
# Downloading DOTUSDT-1s-2023-01-19
# Downloading DOTUSDT-1s-2023-01-20
# Downloading DOTUSDT-1s-2023-01-21
# Downloading DOTUSDT-1s-2023-01-22
# Downloading DOTUSDT-1s-2023-01-23
# Downloading DOTUSDT-1s-2023-01-24
# Downloading DOTUSDT-1s-2023-01-25
# Downloading DOTUSDT-1s-2023-01-26
# Downloading DOTUSDT-1s-2023-01-27
# Downloading DOTUSDT-1s-2023-01-28
# Downloading DOTUSDT-1s-2023-01-29
# Downloading ETHUSDT-1s-2022-11-01
# Downloading ETHUSDT-1s-2022-11-02
# Downloading ETHUSDT-1s-2022-11-03
# Downloading ETHUSDT-1s-2022-11-04
# Downloading ETHUSDT-1s-2022-11-05
# Downloading ETHUSDT-1s-2022-11-06
# Downloading ETHUSDT-1s-2022-11-07
# Downloading ETHUSDT-1s-2022-11-08
# Downloading ETHUSDT-1s-2022-11-09
# Downloading ETHUSDT-1s-2022-11-10
# Downloading ETHUSDT-1s-2022-11-11
# Downloading ETHUSDT-1s-2022-11-12
# Downloading ETHUSDT-1s-2022-11-13
# Downloading ETHUSDT-1s-2022-11-14
# Downloading ETHUSDT-1s-2022-11-15
# Downloading ETHUSDT-1s-2022-11-16
# Downloading ETHUSDT-1s-2022-11-17
# Downloading ETHUSDT-1s-2022-11-18
# Downloading ETHUSDT-1s-2022-11-19
# Downloading ETHUSDT-1s-2022-11-20
# Downloading ETHUSDT-1s-2022-11-21
# Downloading ETHUSDT-1s-2022-11-22
# Downloading ETHUSDT-1s-2022-11-23
# Downloading ETHUSDT-1s-2022-11-24
# Downloading ETHUSDT-1s-2022-11-25
# Downloading ETHUSDT-1s-2022-11-26
# Downloading ETHUSDT-1s-2022-11-27
# Downloading ETHUSDT-1s-2022-11-28
# Downloading ETHUSDT-1s-2022-11-29
# Downloading ETHUSDT-1s-2022-11-30
# Downloading ETHUSDT-1s-2023-01-12
# Downloading ETHUSDT-1s-2023-01-13
# Downloading ETHUSDT-1s-2023-01-14
# Downloading ETHUSDT-1s-2023-01-15
# Downloading ETHUSDT-1s-2023-01-16
# Downloading ETHUSDT-1s-2023-01-17
# Downloading ETHUSDT-1s-2023-01-18
# Downloading ETHUSDT-1s-2023-01-19
# Downloading ETHUSDT-1s-2023-01-20
# Downloading ETHUSDT-1s-2023-01-21
# Downloading ETHUSDT-1s-2023-01-22
# Downloading ETHUSDT-1s-2023-01-23
# Downloading ETHUSDT-1s-2023-01-24
# Downloading ETHUSDT-1s-2023-01-25
# Downloading ETHUSDT-1s-2023-01-26
# Downloading ETHUSDT-1s-2023-01-27
# Downloading ETHUSDT-1s-2023-01-28
# Downloading ETHUSDT-1s-2023-01-29
# Downloading BTCUSDT-1s-2022-11-01
# Downloading BTCUSDT-1s-2022-11-02
# Downloading BTCUSDT-1s-2022-11-03
# Downloading BTCUSDT-1s-2022-11-04
# Downloading BTCUSDT-1s-2022-11-05
# Downloading BTCUSDT-1s-2022-11-06
# Downloading BTCUSDT-1s-2022-11-07
# Downloading BTCUSDT-1s-2022-11-08
# Downloading BTCUSDT-1s-2022-11-09
# Downloading BTCUSDT-1s-2022-11-10
# Downloading BTCUSDT-1s-2022-11-11
# Downloading BTCUSDT-1s-2022-11-12
# Downloading BTCUSDT-1s-2022-11-13
# Downloading BTCUSDT-1s-2022-11-14
# Downloading BTCUSDT-1s-2022-11-15
# Downloading BTCUSDT-1s-2022-11-16
# Downloading BTCUSDT-1s-2022-11-17
# Downloading BTCUSDT-1s-2022-11-18
# Downloading BTCUSDT-1s-2022-11-19
# Downloading BTCUSDT-1s-2022-11-20
# Downloading BTCUSDT-1s-2022-11-21
# Downloading BTCUSDT-1s-2022-11-22
# Downloading BTCUSDT-1s-2022-11-23
# Downloading BTCUSDT-1s-2022-11-24
# Downloading BTCUSDT-1s-2022-11-25
# Downloading BTCUSDT-1s-2022-11-26
# Downloading BTCUSDT-1s-2022-11-27
# Downloading BTCUSDT-1s-2022-11-28
# Downloading BTCUSDT-1s-2022-11-29
# Downloading BTCUSDT-1s-2022-11-30
# Downloading BTCUSDT-1s-2023-01-12
# Downloading BTCUSDT-1s-2023-01-13
# Downloading BTCUSDT-1s-2023-01-14
# Downloading BTCUSDT-1s-2023-01-15
# Downloading BTCUSDT-1s-2023-01-16
# Downloading BTCUSDT-1s-2023-01-17
# Downloading BTCUSDT-1s-2023-01-18
# Downloading BTCUSDT-1s-2023-01-19
# Downloading BTCUSDT-1s-2023-01-20
# Downloading BTCUSDT-1s-2023-01-21
# Downloading BTCUSDT-1s-2023-01-22
# Downloading BTCUSDT-1s-2023-01-23
# Downloading BTCUSDT-1s-2023-01-24
# Downloading BTCUSDT-1s-2023-01-25
# Downloading BTCUSDT-1s-2023-01-26
# Downloading BTCUSDT-1s-2023-01-27
# Downloading BTCUSDT-1s-2023-01-28
# Downloading BTCUSDT-1s-2023-01-29
# Downloading DOGEUSDT-1s-2022-11-01
# Downloading DOGEUSDT-1s-2022-11-02
# Downloading DOGEUSDT-1s-2022-11-03
# Downloading DOGEUSDT-1s-2022-11-04
# Downloading DOGEUSDT-1s-2022-11-05
# Downloading DOGEUSDT-1s-2022-11-06
# Downloading DOGEUSDT-1s-2022-11-07
# Downloading DOGEUSDT-1s-2022-11-08
# Downloading DOGEUSDT-1s-2022-11-09
# Downloading DOGEUSDT-1s-2022-11-10
# Downloading DOGEUSDT-1s-2022-11-11
# Downloading DOGEUSDT-1s-2022-11-12
# Downloading DOGEUSDT-1s-2022-11-13
# Downloading DOGEUSDT-1s-2022-11-14
# Downloading DOGEUSDT-1s-2022-11-15
# Downloading DOGEUSDT-1s-2022-11-16
# Downloading DOGEUSDT-1s-2022-11-17
# Downloading DOGEUSDT-1s-2022-11-18
# Downloading DOGEUSDT-1s-2022-11-19
# Downloading DOGEUSDT-1s-2022-11-20
# Downloading DOGEUSDT-1s-2022-11-21
# Downloading DOGEUSDT-1s-2022-11-22
# Downloading DOGEUSDT-1s-2022-11-23
# Downloading DOGEUSDT-1s-2022-11-24
# Downloading DOGEUSDT-1s-2022-11-25
# Downloading DOGEUSDT-1s-2022-11-26
# Downloading DOGEUSDT-1s-2022-11-27
# Downloading DOGEUSDT-1s-2022-11-28
# Downloading DOGEUSDT-1s-2022-11-29
# Downloading DOGEUSDT-1s-2022-11-30
# Downloading DOGEUSDT-1s-2023-01-12
# Downloading DOGEUSDT-1s-2023-01-13
# Downloading DOGEUSDT-1s-2023-01-14
# Downloading DOGEUSDT-1s-2023-01-15
# Downloading DOGEUSDT-1s-2023-01-16
# Downloading DOGEUSDT-1s-2023-01-17
# Downloading DOGEUSDT-1s-2023-01-18
# Downloading DOGEUSDT-1s-2023-01-19
# Downloading DOGEUSDT-1s-2023-01-20
# Downloading DOGEUSDT-1s-2023-01-21
# Downloading DOGEUSDT-1s-2023-01-22
# Downloading DOGEUSDT-1s-2023-01-23
# Downloading DOGEUSDT-1s-2023-01-24
# Downloading DOGEUSDT-1s-2023-01-25
# Downloading DOGEUSDT-1s-2023-01-26
# Downloading DOGEUSDT-1s-2023-01-27
# Downloading DOGEUSDT-1s-2023-01-28
# Downloading DOGEUSDT-1s-2023-01-29
# [{'DOT': 6.62, 'ETH': 1572.69, 'BTC': 20490.74, 'DOGE': 0.12685}, {'DOT': 6.63, 'ETH': 1572.69, 'BTC': 20491.49, 'DOGE': 0.12684}, {'DOT': 6.62, 'ETH': 1573.54, 'BTC': 20493.67, 'DOGE': 0.12714}, {'DOT': 6.62, 'ETH': 1573.09, 'BTC': 20490.01, 'DOGE': 0.12679}, {'DOT': 6.62, 'ETH': 1571.2, 'BTC': 20475.95, 'DOGE': 0.1262}, {'DOT': 6.62, 'ETH': 1571.44, 'BTC': 20474.28, 'DOGE': 0.12611}, {'DOT': 6.62, 'ETH': 1570.52, 'BTC': 20466.76, 'DOGE': 0.12578}, {'DOT': 6.61, 'ETH': 1570.53, 'BTC': 20466.56, 'DOGE': 0.12568}, {'DOT': 6.62, 'ETH': 1570.46, 'BTC': 20466.56, 'DOGE': 0.12579}, {'DOT': 6.62, 'ETH': 1570.24, 'BTC': 20464.07, 'DOGE': 0.12587}]

# %%
from pprint import pprint
import pandas as pd
import random
import sys
from matplotlib import pyplot as plt
sys.path.append('../..')

from model import run
from model import plot_utils as pu
from model import processing
from model.amm.omnipool_amm import OmnipoolState, price, usd_price, dynamicadd_asset_fee, dynamicadd_lrna_fee, cash_out_omnipool
from model.amm.agents import Agent
from model.amm.trade_strategies import omnipool_arbitrage, invest_all, back_and_forth, extra_trade_volume, price_sensitive_trading
from model.amm.global_state import GlobalState, fluctuate_prices, historical_prices

assets = {
    'HDX': {'usd price': 0.05, 'weight': 0.10},
    'USD': {'usd price': 1, 'weight': 0.20},
    'DOT': {'usd price': price_list[0]['DOT'], 'weight': 0.20},
    'DOGE': {'usd price': price_list[0]['DOGE'], 'weight': 0.10},
    'ETH': {'usd price': price_list[0]['ETH'], 'weight': 0.20},
    'BTC': {'usd price': price_list[0]['BTC'], 'weight': 0.20}
}

lrna_price_usd = 0.07
initial_omnipool_tvl = 10000000
liquidity = {}
lrna = {}

for tkn, info in assets.items():
    liquidity[tkn] = initial_omnipool_tvl * info['weight'] / info['usd price']
    lrna[tkn] = initial_omnipool_tvl * info['weight'] / lrna_price_usd

initial_state = GlobalState(
    pools={
        'omnipool': OmnipoolState(
            tokens={
                tkn: {'liquidity': liquidity[tkn], 'LRNA': lrna[tkn]} for tkn in assets
            },
            # oracles={'fee_raise': 50},  # , 'fee_lower': 7200},
            lrna_fee=0,
            asset_fee=0,
        )
    },
    agents = {
        'Trader': Agent(
            holdings={'HDX': 1000000000, 'USD': 1000000000, 'ETH': 1000000000, 'BTC': 3000000000, 'DOGE': 3000000000, 'DOT': 1000000000, 'LRNA': 1000000000},
            trade_strategy=omnipool_arbitrage(
                pool_id='omnipool',
                arb_precision=3
            ) + price_sensitive_trading(
                pool_id='omnipool', max_volume_usd=10, price_sensitivity=20
            )
        ),
        'LP': Agent(
            holdings={tkn: liquidity[tkn] / 10 for tkn in assets},
            trade_strategy=invest_all('omnipool')
        )
    },
    evolve_function=historical_prices(price_list),
    external_market={tkn: assets[tkn]['usd price'] for tkn in assets},
    archive_all = False
)
time_steps = len(price_list)-1
print(f'Running with {time_steps} time steps')

test_results = []

def pass_along(min_value, max_value, steps, current):
    return min_value + min(max_value - min_value, 1) * current ** 2 / (steps - 1 or 1) ** 2

trade_volume=10
for fee in [pass_along(0.0, 0.1, 25, i) for i in range(25)]:
    random.seed(42)
    test_state = initial_state.copy()
    test_state.pools['omnipool'].lrna_fee = fee
    test_state.pools['omnipool'].asset_fee = fee * 5
    # test_state.agents['Trader'].trade_strategy += extra_trade_volume('omnipool', percent_of_arb=50, percent_of_pool=1 / initial_omnipool_tvl * trade_volume )
    events = run.run(test_state, time_steps=time_steps)
    # print(events[-1])
    LP_returns = cash_out_omnipool(events[-1].pools['omnipool'], events[-1].agents['LP'], events[-1].external_market)
    total_volume=[sum(event.pools['omnipool'].volume_in.values()) + sum(event.pools['omnipool'].volume_out.values()) for event in events]
    test_results.append((trade_volume, fee, LP_returns, total_volume))
    print(f'lrna fee = {fee}, asset fee = {fee * 5}, trade volume = {sum(total_volume)}')
    print(f'returns = {LP_returns}')
    
# events = processing.postprocessing(events, optional_params=['withdraw_val'])
# Out:
# Running with 647587 time steps
# Starting simulation...
# Execution time: 196.305 seconds.
# lrna fee = 0.0, asset fee = 0.0, trade volume = 2283056958.9644914
# returns = 991190.8550572712
# Starting simulation...
# Execution time: 94.236 seconds.
# lrna fee = 0.00017361111111111112, asset fee = 0.0008680555555555556, trade volume = 748299118.1971849
# returns = 998998.2695161693
# Starting simulation...
# Execution time: 71.964 seconds.
# lrna fee = 0.0006944444444444445, asset fee = 0.0034722222222222225, trade volume = 267746099.20522085
# returns = 999908.7868665047
# Starting simulation...
# Execution time: 76.818 seconds.
# lrna fee = 0.0015625, asset fee = 0.0078125, trade volume = 152470098.5367955
# returns = 1002139.3749796404
# Starting simulation...
# Execution time: 77.679 seconds.
# lrna fee = 0.002777777777777778, asset fee = 0.01388888888888889, trade volume = 98193220.5472088
# returns = 1003897.9176852155
# Starting simulation...
# Execution time: 75.185 seconds.
# lrna fee = 0.004340277777777778, asset fee = 0.021701388888888888, trade volume = 61476686.94297636
# returns = 1004272.2747158712
# Starting simulation...
# Execution time: 80.332 seconds.
# lrna fee = 0.00625, asset fee = 0.03125, trade volume = 38801694.991671294
# returns = 1003594.0993632881
# Starting simulation...
# Execution time: 77.428 seconds.
# lrna fee = 0.008506944444444445, asset fee = 0.042534722222222224, trade volume = 23977081.96732603
# returns = 1002496.5722704714
# Starting simulation...
# Execution time: 77.916 seconds.
# lrna fee = 0.011111111111111112, asset fee = 0.05555555555555556, trade volume = 16468892.792338723
# returns = 1000812.8689495465
# Starting simulation...
# Execution time: 81.33 seconds.
# lrna fee = 0.014062499999999999, asset fee = 0.0703125, trade volume = 12390648.635477643
# returns = 1000432.6340689695
# Starting simulation...
# Execution time: 73.226 seconds.
# lrna fee = 0.017361111111111112, asset fee = 0.08680555555555555, trade volume = 9541838.368922343
# returns = 998891.010624583
# Starting simulation...
# Execution time: 67.965 seconds.
# lrna fee = 0.021006944444444446, asset fee = 0.10503472222222224, trade volume = 8153824.349075902
# returns = 999097.7897716279
# Starting simulation...
# Execution time: 73.233 seconds.
# lrna fee = 0.025, asset fee = 0.125, trade volume = 6871426.912881169
# returns = 998651.5823598423
# Starting simulation...
# Execution time: 72.419 seconds.
# lrna fee = 0.02934027777777778, asset fee = 0.1467013888888889, trade volume = 5516369.688056405
# returns = 996506.1015349542
# Starting simulation...
# Execution time: 73.698 seconds.
# lrna fee = 0.03402777777777778, asset fee = 0.1701388888888889, trade volume = 4202965.541965807
# returns = 994453.6099305769
# Starting simulation...
# Execution time: 66.283 seconds.
# lrna fee = 0.0390625, asset fee = 0.1953125, trade volume = 2995675.404268326
# returns = 994094.5582684104
# Starting simulation...
# Execution time: 76.639 seconds.
# lrna fee = 0.044444444444444446, asset fee = 0.22222222222222224, trade volume = 2218983.7860621344
# returns = 997820.3666269917
# Starting simulation...
# Execution time: 64.762 seconds.
# lrna fee = 0.05017361111111111, asset fee = 0.2508680555555556, trade volume = 1811358.6870685706
# returns = 1001022.962859409
# Starting simulation...
# Execution time: 60.184 seconds.
# lrna fee = 0.056249999999999994, asset fee = 0.28125, trade volume = 1453176.3074026592
# returns = 1004143.9263138798
# Starting simulation...
# Execution time: 61.916 seconds.
# lrna fee = 0.06267361111111111, asset fee = 0.3133680555555556, trade volume = 1034278.3257722858
# returns = 1006410.868857143
# Starting simulation...
# Execution time: 53.564 seconds.
# lrna fee = 0.06944444444444445, asset fee = 0.3472222222222222, trade volume = 807234.147254942
# returns = 1008443.8717293411
# Starting simulation...
# Execution time: 58.031 seconds.
# lrna fee = 0.0765625, asset fee = 0.3828125, trade volume = 445356.18265927164
# returns = 1010024.0883915904
# Starting simulation...
# Execution time: 55.644 seconds.
# lrna fee = 0.08402777777777778, asset fee = 0.42013888888888895, trade volume = 87573.53536101524
# returns = 1011438.7951705173
# Starting simulation...
# Execution time: 50.575 seconds.
# lrna fee = 0.09184027777777778, asset fee = 0.45920138888888895, trade volume = 0.0
# returns = 1011757.3359993685
# Starting simulation...
# Execution time: 49.394 seconds.
# lrna fee = 0.1, asset fee = 0.5, trade volume = 0.0
# returns = 1011757.3359993685

# %%
# lines = []
# with open('./output/test_results_static_fees_dec.txt', 'r') as file:
#     data = file.readlines()
#     lines = [float(line [10: 20]) for line in list(filter(lambda line: line[0] == 'r', data))]
    
# print(len(lines))
# print(lines)
# test_results = [lines[i * 10: i * 10 + 10] for i in range(10)]

# %%
# print(test_results[0])

# %%
# colors = pu.color_gradient(25)
plt.figure(figsize=(20, 5))
plt.plot([result[1] * 5 for result in test_results], [result[2] for result in test_results])

# %%
for tkn in initial_state.pools['omnipool'].asset_list:
    ax=pu.plot(events[::20], asset=tkn)
    pu.plot(events[::20], pool='omnipool', prop='usd_price', key=tkn, subplot=ax)

# %%
plt.figure(figsize=(20, 5))
from model.amm.omnipool_amm import cash_out_omnipool
plt.plot(range(len(events[::20])), [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events[::20]])

# %%
import copy
ordered_results = copy.copy(test_results)
ordered_results.sort(key=lambda x: x[2])
pprint([result[:3] for result in ordered_results])
# Out:
# [(10, 0.0, 991190.8550572712),
#  (10, 0.0390625, 994094.5582684104),
#  (10, 0.03402777777777778, 994453.6099305769),
#  (10, 0.02934027777777778, 996506.1015349542),
#  (10, 0.044444444444444446, 997820.3666269917),
#  (10, 0.025, 998651.5823598423),
#  (10, 0.017361111111111112, 998891.010624583),
#  (10, 0.00017361111111111112, 998998.2695161693),
#  (10, 0.021006944444444446, 999097.7897716279),
#  (10, 0.0006944444444444445, 999908.7868665047),
#  (10, 0.014062499999999999, 1000432.6340689695),
#  (10, 0.011111111111111112, 1000812.8689495465),
#  (10, 0.05017361111111111, 1001022.962859409),
#  (10, 0.0015625, 1002139.3749796404),
#  (10, 0.008506944444444445, 1002496.5722704714),
#  (10, 0.00625, 1003594.0993632881),
#  (10, 0.002777777777777778, 1003897.9176852155),
#  (10, 0.056249999999999994, 1004143.9263138798),
#  (10, 0.004340277777777778, 1004272.2747158712),
#  (10, 0.06267361111111111, 1006410.868857143),
#  (10, 0.06944444444444445, 1008443.8717293411),
#  (10, 0.0765625, 1010024.0883915904),
#  (10, 0.08402777777777778, 1011438.7951705173),
#  (10, 0.09184027777777778, 1011757.3359993685),
#  (10, 0.1, 1011757.3359993685)]

# %%
basic_state = initial_state.copy()
best_fee = 0.0005
basic_state.pools['omnipool'].asset_fee=best_fee * 5
basic_state.pools['omnipool'].lrna_fee=best_fee

print(best_fee)
print(basic_state.agents)
print(basic_state.pools['omnipool'])
# Out:
# 0.0005
# {'Trader': Agent: Trader
# ********************************
# trade strategy: omnipool arbitrage
#  + price sensitive trading (sensitivity =20)
# holdings: (
#
#     *HDX*: 1000000000
#
#     *USD*: 1000000000
#
#     *ETH*: 1000000000
#
#     *BTC*: 3000000000
#
#     *DOGE*: 3000000000
#
#     *DOT*: 1000000000
#
#     *LRNA*: 1000000000
# )
# , 'LP': Agent: LP
# ********************************
# trade strategy: invest all (omnipool)
# holdings: (
#
#     *HDX*: 2000000.0
#
#     *USD*: 200000.0
#
#     *DOT*: 30211.4803625378
#
#     *DOGE*: 788332.6763894365
#
#     *ETH*: 127.1706439286
#
#     *BTC*: 9.7605064532
#
#     *LRNA*: 0
# )
# }
# Omnipool: omnipool
# ********************************
# tvl cap: inf
# lrna fee:
#
#     HDX: 0.05%
#     USD: 0.05%
#     DOT: 0.05%
#     DOGE: 0.05%
#     ETH: 0.05%
#     BTC: 0.05%
#
# asset fee:
#
#     HDX: 0.25%
#     USD: 0.25%
#     DOT: 0.25%
#     DOGE: 0.25%
#     ETH: 0.25%
#     BTC: 0.25%
#
# asset pools: (
#
#     *HDX*
#     asset quantity: 20000000.0
#     lrna quantity: 14285714.285714284
#     USD price: 0.05
#     tvl: $1000000.0
#     weight: 14285714.285714284/142857142.85714284 (0.1)
#     weight cap: 1
#     total shares: 20000000.0
#     protocol shares: 20000000.0
#
#     *USD*
#     asset quantity: 2000000.0
#     lrna quantity: 28571428.571428567
#     USD price: 1.0
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 2000000.0
#     protocol shares: 2000000.0
#
#     *DOT*
#     asset quantity: 302114.80362537765
#     lrna quantity: 28571428.571428567
#     USD price: 6.62
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 302114.80362537765
#     protocol shares: 302114.80362537765
#
#     *DOGE*
#     asset quantity: 7883326.763894364
#     lrna quantity: 14285714.285714284
#     USD price: 0.12685
#     tvl: $1000000.0
#     weight: 14285714.285714284/142857142.85714284 (0.1)
#     weight cap: 1
#     total shares: 7883326.763894364
#     protocol shares: 7883326.763894364
#
#     *ETH*
#     asset quantity: 1271.706439285555
#     lrna quantity: 28571428.571428567
#     USD price: 1572.69
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 1271.7064392855552
#     protocol shares: 1271.7064392855552
#
#     *BTC*
#     asset quantity: 97.605064531588
#     lrna quantity: 28571428.571428567
#     USD price: 20490.74
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 97.60506453158841
#     protocol shares: 97.60506453158841
#
# )
# sub pools: (
#
#
# )
#
# error message: None

# %%
basic_events = run.run(basic_state, time_steps=time_steps)
# Out:
# Starting simulation...
# Execution time: 69.875 seconds.

# %%
ax=pu.plot(basic_events[::20], asset='ETH')
pu.plot(basic_events[::20], pool='omnipool', prop='usd_price', key='ETH', subplot=ax)
# Out:
# <AxesSubplot:title={'center':'asset price: ETH '}>

# %%
plt.figure(figsize=(20, 5))
LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in basic_events[::20]]


plt.plot(range(len(LP_holdings)), LP_holdings)
print(best_fee)
LP_returns = cash_out_omnipool(basic_events[-1].pools['omnipool'], basic_events[-1].agents['LP'], basic_events[-1].external_market)
print(LP_returns)
# Out:
# 0.0005
# 999251.0711298685

# %%
print([result[1] for result in test_results])
plt.figure(figsize=(20, 5))
plt.plot([result[1] for result in test_results], [sum(result[3]) * result[1] for result in test_results])
# plt.yscale('log')
# Out:
# [0.0, 0.00017361111111111112, 0.0006944444444444445, 0.0015625, 0.002777777777777778, 0.004340277777777778, 0.00625, 0.008506944444444445, 0.011111111111111112, 0.014062499999999999, 0.017361111111111112, 0.021006944444444446, 0.025, 0.02934027777777778, 0.03402777777777778, 0.0390625, 0.044444444444444446, 0.05017361111111111, 0.056249999999999994, 0.06267361111111111, 0.06944444444444445, 0.0765625, 0.08402777777777778, 0.09184027777777778, 0.1]

# %%
plt.figure(figsize=(20, 5))
LP_holdings1 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events[::20]]
LP_holdings2 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events2[::20]]
LP_holdings3 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events3[::20]]

plt.plot(range(len(LP_holdings1)), LP_holdings1)
plt.plot(range(len(LP_holdings2)), LP_holdings2)
plt.plot(range(len(LP_holdings2)), LP_holdings3)
plt.title('basic fees (blue) vs best tested parameters (orange) vs worst tested parameters (green)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 plt.figure(figsize=(20, 5))
#       2 LP_holdings1 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events[::20]]
# ----> 3 LP_holdings2 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events2[::20]]
#       4 LP_holdings3 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events3[::20]]
#       6 plt.plot(range(len(LP_holdings1)), LP_holdings1)
#
# NameError: name 'events2' is not defined

# %%
print(test_results[1])

# %%
random.seed(42)
basic_state2 = initial_state.copy()
basic_state2.pools['omnipool'].asset_fee=0.0025
basic_state2.pools['omnipool'].lrna_fee=0.0005

events4=run.run(basic_state2, time_steps=time_steps)
LP_holdings4 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events4[::20]]

# %%
random.seed(42)
basic_state3 = initial_state.copy()
basic_state3.pools['omnipool'].asset_fee=0.0025
basic_state3.pools['omnipool'].lrna_fee=0.0005

events5=run.run(basic_state3, time_steps=time_steps)
LP_holdings5 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events5[::20]]

# %%
print(LP_holdings1[-1])
print(LP_holdings2[-1])
print(LP_holdings3[-1])
print(LP_holdings4[-1])
print(LP_holdings5[-1])

# %%
# print(events[0], events[1000])

# %%
print(winning_state, losing_state)

# %%
pu.plot(events, asset='DOGE')

# %%
ax = pu.plot(events, pool='omnipool', oracle='fee_raise', prop='volume_in', key='DOT')
pu.plot(events2, pool='omnipool', oracle='fee_raise', prop='volume_in', key='DOT', subplot=ax)

# %%
print(test_results[0])
print(test_results[-1])

# %%
volume_out_usd = [event.pools['omnipool'].oracles['fee_raise'].price['USD'] for event in events3]
plt.plot(range(len(volume_out_usd)), volume_out_usd)

# %%
reverse_price_list = list(reversed(processing.import_binance_prices(assets=['DOT', 'ETH', 'BTC', 'DOGE'], start_date='Nov 1 2022', days=30)))
reverse_basic_state = initial_state.copy()
reverse_basic_state._evolve_function=historical_prices(reverse_price_list)
reverse_basic_events = run.run(reverse_basic_state, time_steps = time_steps)

reverse_state = reverse_basic_state.copy()
reverse_state.pools['omnipool'].lrna_fee = dynamicadd_lrna_fee(
    minimum=0.0005,
    amplification=test_results[-1].lrna_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[-1].lrna_decay,
    fee_max=test_results[-1].lrna_max,
)
reverse_state.pools['omnipool'].asset_fee = dynamicadd_asset_fee(
    minimum=0.0025,
    amplification=test_results[-1].asset_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[-1].asset_decay,
    fee_max=test_results[-1].asset_max,
)
reverse_state.pools['omnipool'].oracles['fee_raise'].decay_factor = 2 / (test_results[-1].oracle_length + 1)
reverse_events = run.run(reverse_state, time_steps = time_steps)

worst_reverse_state = reverse_state.copy()
worst_reverse_state.pools['omnipool'].lrna_fee = dynamicadd_lrna_fee(
    minimum=0.0005,
    amplification=test_results[0].lrna_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[0].lrna_decay,
    fee_max=test_results[0].lrna_max,
)
worst_reverse_state.pools['omnipool'].asset_fee = dynamicadd_asset_fee(
    minimum=0.0025,
    amplification=test_results[0].asset_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[0].asset_decay,
    fee_max=test_results[0].asset_max,
)
worst_reverse_state.pools['omnipool'].oracles['fee_raise'].decay_factor = 2 / (test_results[-1].oracle_length + 1)
worst_reverse_events = run.run(worst_reverse_state, time_steps = time_steps)

# %%
reverse_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in reverse_events[::20]]
worst_reverse_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in worst_reverse_events[::20]]
reverse_basic_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in reverse_basic_events[::20]]
plt.figure(figsize=(20, 5))
plt.plot(range(len(reverse_LP_holdings)), reverse_basic_LP_holdings)
plt.plot(range(len(reverse_LP_holdings)), reverse_LP_holdings)
plt.plot(range(len(reverse_LP_holdings)), worst_reverse_LP_holdings)
plt.title('basic fees (blue) vs best tested parameters (orange) vs worst tested parameters (green) with price movement reversed')

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(price_list)), [price_list[i]['ETH'] for i in range(len(price_list))])
plt.plot(range(len(price_list)), [reverse_price_list[i]['ETH'] for i in range(len(price_list))])
plt.title('two different, opposite price runs')

# %%
pu.plot(reverse_events, asset='ETH')

# %%
pu.plot(reverse_events[::100], agent='Trader', prop='holdings', key='ETH')

# %%
oracle = [event.pools['omnipool'].oracles['fee_raise'].volume_in['ETH'] for event in reverse_events][:100]
plt.plot(range(len(oracle)), oracle)

# %%
pu.plot(reverse_events[::20], pool='omnipool', prop='last_fee')
pu.plot(reverse_events[::20], pool='omnipool', prop='last_lrna_fee')

pu.plot(events2[::20], pool='omnipool', prop='last_fee')
pu.plot(events2[::20], pool='omnipool', prop='last_lrna_fee')

# %%
print('hi')

# %%
print(events2[0])

# %%
no_archive_state = basic_state.copy()
no_archive_state.archive_all = True
short_events_1 = run.run(no_archive_state, time_steps = 1)
short_events_2 = run.run(no_archive_state, time_steps = 1)
short_events_3 = run.run(no_archive_state, time_steps = 1)
short_events_4 = run.run(no_archive_state, time_steps = 1)

# %%
print(repr(short_events_1[0]) == repr(short_events_2[0]))
print(short_events_1[0])
print(short_events_2[0])
# state1 = repr(short_events_1[0])
# state2 = repr(short_events_2[0])
# for i, char in enumerate(state1):
#     if char != state2[i]:
#         print(char)
