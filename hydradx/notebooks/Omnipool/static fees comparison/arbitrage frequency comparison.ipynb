# %%
import sys
import os
import glob
sys.path.append('../../..')

from model import processing
price_list = processing.import_binance_prices(assets=['DOT', 'ETH', 'BTC', 'DOGE'], start_date='Dec 1 2022', days=40)
# price_list += [price_list[0]] * 10
print(price_list[0:10])
# Out:
# [{'DOT': 5.46, 'ETH': 1294.46, 'BTC': 17165.53, 'DOGE': 0.10676}, {'DOT': 5.46, 'ETH': 1293.98, 'BTC': 17160.01, 'DOGE': 0.10664}, {'DOT': 5.47, 'ETH': 1293.94, 'BTC': 17158.15, 'DOGE': 0.1067}, {'DOT': 5.47, 'ETH': 1294.58, 'BTC': 17161.9, 'DOGE': 0.10678}, {'DOT': 5.47, 'ETH': 1295.23, 'BTC': 17171.78, 'DOGE': 0.10679}, {'DOT': 5.48, 'ETH': 1295.32, 'BTC': 17175.44, 'DOGE': 0.10681}, {'DOT': 5.47, 'ETH': 1295.43, 'BTC': 17175.03, 'DOGE': 0.10711}, {'DOT': 5.47, 'ETH': 1295.66, 'BTC': 17176.04, 'DOGE': 0.10721}, {'DOT': 5.47, 'ETH': 1295.59, 'BTC': 17173.78, 'DOGE': 0.10722}, {'DOT': 5.48, 'ETH': 1295.59, 'BTC': 17175.09, 'DOGE': 0.10762}]

# %%
from pprint import pprint
import pandas as pd
import random
import sys
from matplotlib import pyplot as plt

from model import run
from model import plot_utils as pu
from model import processing
from model.amm.omnipool_amm import OmnipoolState, price, usd_price, dynamicadd_asset_fee, dynamicadd_lrna_fee, cash_out_omnipool
from model.amm.agents import Agent
from model.amm.trade_strategies import omnipool_arbitrage, invest_all, back_and_forth, extra_trade_volume, price_sensitive_trading
from model.amm.global_state import GlobalState, fluctuate_prices, historical_prices

assets = {
    'HDX': {'usd price': 0.05, 'weight': 0.10},
    'USD': {'usd price': 1, 'weight': 0.20},
    'DOT': {'usd price': price_list[0]['DOT'], 'weight': 0.20},
    'DOGE': {'usd price': price_list[0]['DOGE'], 'weight': 0.10},
    'ETH': {'usd price': price_list[0]['ETH'], 'weight': 0.20},
    'BTC': {'usd price': price_list[0]['BTC'], 'weight': 0.20}
}

lrna_price_usd = 0.07
initial_omnipool_tvl = 10000000
liquidity = {}
lrna = {}

for tkn, info in assets.items():
    liquidity[tkn] = initial_omnipool_tvl * info['weight'] / info['usd price']
    lrna[tkn] = initial_omnipool_tvl * info['weight'] / lrna_price_usd

initial_state = GlobalState(
    pools={
        'omnipool': OmnipoolState(
            tokens={
                tkn: {'liquidity': liquidity[tkn], 'LRNA': lrna[tkn]} for tkn in assets
            },
            # oracles={'fee_raise': 50},  # , 'fee_lower': 7200},
            lrna_fee=0,
            asset_fee=0,
        )
    },
    agents = {
        'Trader': Agent(
            holdings={'HDX': 1000000000, 'USD': 1000000000, 'ETH': 1000000000, 'BTC': 3000000000, 'DOGE': 3000000000, 'DOT': 1000000000, 'LRNA': 1000000000},
            trade_strategy=omnipool_arbitrage(
                pool_id='omnipool',
                arb_precision=3,
                frequency=3
            )
        ),
        'LP': Agent(
            holdings={tkn: liquidity[tkn] / 10 for tkn in assets},
            trade_strategy=invest_all('omnipool')
        )
    },
    evolve_function=historical_prices(price_list),
    external_market={tkn: assets[tkn]['usd price'] for tkn in assets},
    archive_all = False
)
time_steps = len(price_list)-1
print(f'Running with {time_steps} time steps')

test_results = {1: [], 2: [], 3: []}

def pass_along(min_value, max_value, steps, current):
    return min_value + min(max_value - min_value, 1) * current ** 2 / (steps - 1 or 1) ** 2

for frequency in test_results:
    for fee in [pass_along(0.0, 0.1, 25, i) for i in range(25)]:
        random.seed(42)
        test_state = initial_state.copy()
        test_state.pools['omnipool'].lrna_fee = fee
        test_state.pools['omnipool'].asset_fee = fee * 5
        test_state.agents['Trader'].trade_strategy=omnipool_arbitrage(
            pool_id='omnipool',
            arb_precision=3,
            frequency=frequency
        )
        events = run.run(test_state, time_steps=time_steps)
        # print(events[-1])
        LP_returns = cash_out_omnipool(events[-1].pools['omnipool'], events[-1].agents['LP'], events[-1].external_market)
        total_volume=[
            sum(events[i].pools['omnipool'].volume_in.values()) + sum(events[i].pools['omnipool'].volume_out.values()) 
            for i in range(len(events))
        ]
        test_results[frequency].append((trade_volume, fee, LP_returns, total_volume))
        print(f'lrna fee = {fee}, asset fee = {fee * 5}, trade volume = {sum(total_volume)}')
        print(f'returns = {LP_returns}')

# events = processing.postprocessing(events, optional_params=['withdraw_val'])
# Out:
# Running with 287809 time steps
# Starting simulation...
# Execution time: 75.051 seconds.
# lrna fee = 0.0, asset fee = 0.0, trade volume = 700862531.622927
# returns = 933926.9235660097
# Starting simulation...
# Execution time: 32.198 seconds.
# lrna fee = 0.00017361111111111112, asset fee = 0.0008680555555555556, trade volume = 137616550.60545465
# returns = 935510.2931699392
# Starting simulation...
# Execution time: 25.674 seconds.
# lrna fee = 0.0006944444444444445, asset fee = 0.0034722222222222225, trade volume = 37690404.999750584
# returns = 935280.4879688377
# Starting simulation...
# Execution time: 28.006 seconds.
# lrna fee = 0.0015625, asset fee = 0.0078125, trade volume = 18716079.6714216
# returns = 936184.0514760271
# Starting simulation...
# Execution time: 25.292 seconds.
# lrna fee = 0.002777777777777778, asset fee = 0.01388888888888889, trade volume = 11432589.098847486
# returns = 936271.6637088507
# Starting simulation...
# Execution time: 25.444 seconds.
# lrna fee = 0.004340277777777778, asset fee = 0.021701388888888888, trade volume = 6444893.441693656
# returns = 936521.1645173755
# Starting simulation...
# Execution time: 26.657 seconds.
# lrna fee = 0.00625, asset fee = 0.03125, trade volume = 4638992.957747229
# returns = 935571.7842312183
# Starting simulation...
# Execution time: 25.829 seconds.
# lrna fee = 0.008506944444444445, asset fee = 0.042534722222222224, trade volume = 3470331.4761217823
# returns = 935280.4974182972
# Starting simulation...
# Execution time: 23.4 seconds.
# lrna fee = 0.011111111111111112, asset fee = 0.05555555555555556, trade volume = 2422498.185122593
# returns = 935930.3276619471
# Starting simulation...
# Execution time: 35.094 seconds.
# lrna fee = 0.014062499999999999, asset fee = 0.0703125, trade volume = 2809149.387678387
# returns = 937134.7225209979
# Starting simulation...
# Execution time: 25.323 seconds.
# lrna fee = 0.017361111111111112, asset fee = 0.08680555555555555, trade volume = 3297604.8757661893
# returns = 937100.1607974153
# Starting simulation...
# Execution time: 26.313 seconds.
# lrna fee = 0.021006944444444446, asset fee = 0.10503472222222224, trade volume = 1251180.8493038253
# returns = 943470.8901732605
# Starting simulation...
# Execution time: 26.423 seconds.
# lrna fee = 0.025, asset fee = 0.125, trade volume = 1297860.9761607943
# returns = 943535.329861353
# Starting simulation...
# Execution time: 24.022 seconds.
# lrna fee = 0.02934027777777778, asset fee = 0.1467013888888889, trade volume = 1242111.6800731975
# returns = 945670.5201411878
# Starting simulation...
# Execution time: 25.842 seconds.
# lrna fee = 0.03402777777777778, asset fee = 0.1701388888888889, trade volume = 1104107.013889032
# returns = 946745.8461637723
# Starting simulation...
# Execution time: 24.144 seconds.
# lrna fee = 0.0390625, asset fee = 0.1953125, trade volume = 822015.8688509297
# returns = 948682.3873858568
# Starting simulation...
# Execution time: 26.283 seconds.
# lrna fee = 0.044444444444444446, asset fee = 0.22222222222222224, trade volume = 955020.7508295407
# returns = 948084.1353752557
# Starting simulation...
# Execution time: 22.448 seconds.
# lrna fee = 0.05017361111111111, asset fee = 0.2508680555555556, trade volume = 534002.5527697266
# returns = 950751.5184480081
# Starting simulation...
# Execution time: 22.759 seconds.
# lrna fee = 0.056249999999999994, asset fee = 0.28125, trade volume = 613348.0640661996
# returns = 950443.0030010926
# Starting simulation...
# Execution time: 21.035 seconds.
# lrna fee = 0.06267361111111111, asset fee = 0.3133680555555556, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 20.306 seconds.
# lrna fee = 0.06944444444444445, asset fee = 0.3472222222222222, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 20.716 seconds.
# lrna fee = 0.0765625, asset fee = 0.3828125, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 22.734 seconds.
# lrna fee = 0.08402777777777778, asset fee = 0.42013888888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 20.549 seconds.
# lrna fee = 0.09184027777777778, asset fee = 0.45920138888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 21.08 seconds.
# lrna fee = 0.1, asset fee = 0.5, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 43.866 seconds.
# lrna fee = 0.0, asset fee = 0.0, trade volume = 479249808.62942976
# returns = 933888.4028481557
# Starting simulation...
# Execution time: 17.437 seconds.
# lrna fee = 0.00017361111111111112, asset fee = 0.0008680555555555556, trade volume = 123807286.96288256
# returns = 935316.5717019502
# Starting simulation...
# Execution time: 19.496 seconds.
# lrna fee = 0.0006944444444444445, asset fee = 0.0034722222222222225, trade volume = 36110508.52156939
# returns = 935138.8133756989
# Starting simulation...
# Execution time: 19.457 seconds.
# lrna fee = 0.0015625, asset fee = 0.0078125, trade volume = 18299828.597631976
# returns = 935698.1125440627
# Starting simulation...
# Execution time: 18.823 seconds.
# lrna fee = 0.002777777777777778, asset fee = 0.01388888888888889, trade volume = 10911792.084888095
# returns = 936377.4185126071
# Starting simulation...
# Execution time: 17.009 seconds.
# lrna fee = 0.004340277777777778, asset fee = 0.021701388888888888, trade volume = 6991818.987085618
# returns = 936476.1892662926
# Starting simulation...
# Execution time: 19.081 seconds.
# lrna fee = 0.00625, asset fee = 0.03125, trade volume = 4354887.637100344
# returns = 935305.4230889841
# Starting simulation...
# Execution time: 15.819 seconds.
# lrna fee = 0.008506944444444445, asset fee = 0.042534722222222224, trade volume = 3156107.0381307467
# returns = 935279.071706564
# Starting simulation...
# Execution time: 17.458 seconds.
# lrna fee = 0.011111111111111112, asset fee = 0.05555555555555556, trade volume = 2743477.687429343
# returns = 934998.6837176118
# Starting simulation...
# Execution time: 17.313 seconds.
# lrna fee = 0.014062499999999999, asset fee = 0.0703125, trade volume = 2159201.86221911
# returns = 938004.1818490205
# Starting simulation...
# Execution time: 15.065 seconds.
# lrna fee = 0.017361111111111112, asset fee = 0.08680555555555555, trade volume = 3242183.1655128417
# returns = 936507.050847394
# Starting simulation...
# Execution time: 14.72 seconds.
# lrna fee = 0.021006944444444446, asset fee = 0.10503472222222224, trade volume = 1253782.6971615583
# returns = 943454.082406736
# Starting simulation...
# Execution time: 16.242 seconds.
# lrna fee = 0.025, asset fee = 0.125, trade volume = 1293217.0064644036
# returns = 943512.9943340141
# Starting simulation...
# Execution time: 16.439 seconds.
# lrna fee = 0.02934027777777778, asset fee = 0.1467013888888889, trade volume = 1241008.240595108
# returns = 945677.3467707239
# Starting simulation...
# Execution time: 14.532 seconds.
# lrna fee = 0.03402777777777778, asset fee = 0.1701388888888889, trade volume = 1102036.8606126849
# returns = 946758.5253493902
# Starting simulation...
# Execution time: 16.122 seconds.
# lrna fee = 0.0390625, asset fee = 0.1953125, trade volume = 844837.1336827469
# returns = 948542.1516547551
# Starting simulation...
# Execution time: 14.678 seconds.
# lrna fee = 0.044444444444444446, asset fee = 0.22222222222222224, trade volume = 952546.4652775717
# returns = 948098.6120290624
# Starting simulation...
# Execution time: 16.466 seconds.
# lrna fee = 0.05017361111111111, asset fee = 0.2508680555555556, trade volume = 534002.5527697266
# returns = 950751.5184480081
# Starting simulation...
# Execution time: 15.816 seconds.
# lrna fee = 0.056249999999999994, asset fee = 0.28125, trade volume = 613348.0640661996
# returns = 950443.0030010926
# Starting simulation...
# Execution time: 14.637 seconds.
# lrna fee = 0.06267361111111111, asset fee = 0.3133680555555556, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 15.191 seconds.
# lrna fee = 0.06944444444444445, asset fee = 0.3472222222222222, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 13.373 seconds.
# lrna fee = 0.0765625, asset fee = 0.3828125, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 14.939 seconds.
# lrna fee = 0.08402777777777778, asset fee = 0.42013888888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 13.266 seconds.
# lrna fee = 0.09184027777777778, asset fee = 0.45920138888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 14.719 seconds.
# lrna fee = 0.1, asset fee = 0.5, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 33.666 seconds.
# lrna fee = 0.0, asset fee = 0.0, trade volume = 380846732.71599317
# returns = 933886.5070998196
# Starting simulation...
# Execution time: 14.342 seconds.
# lrna fee = 0.00017361111111111112, asset fee = 0.0008680555555555556, trade volume = 113730126.68967927
# returns = 935207.3688257595
# Starting simulation...
# Execution time: 15.112 seconds.
# lrna fee = 0.0006944444444444445, asset fee = 0.0034722222222222225, trade volume = 34098391.51656852
# returns = 935135.3731511316
# Starting simulation...
# Execution time: 15.437 seconds.
# lrna fee = 0.0015625, asset fee = 0.0078125, trade volume = 18352433.743662458
# returns = 935970.1187717916
# Starting simulation...
# Execution time: 13.611 seconds.
# lrna fee = 0.002777777777777778, asset fee = 0.01388888888888889, trade volume = 10449651.124655992
# returns = 937052.0605158823
# Starting simulation...
# Execution time: 15.328 seconds.
# lrna fee = 0.004340277777777778, asset fee = 0.021701388888888888, trade volume = 7614908.739531913
# returns = 936573.1280760515
# Starting simulation...
# Execution time: 13.387 seconds.
# lrna fee = 0.00625, asset fee = 0.03125, trade volume = 4348993.023369541
# returns = 936661.4748171184
# Starting simulation...
# Execution time: 15.153 seconds.
# lrna fee = 0.008506944444444445, asset fee = 0.042534722222222224, trade volume = 3317275.173187234
# returns = 934780.4231259351
# Starting simulation...
# Execution time: 13.736 seconds.
# lrna fee = 0.011111111111111112, asset fee = 0.05555555555555556, trade volume = 2429253.5684163338
# returns = 935954.0434641253
# Starting simulation...
# Execution time: 14.734 seconds.
# lrna fee = 0.014062499999999999, asset fee = 0.0703125, trade volume = 2302306.4628036935
# returns = 937682.8118510129
# Starting simulation...
# Execution time: 12.515 seconds.
# lrna fee = 0.017361111111111112, asset fee = 0.08680555555555555, trade volume = 2244938.6343898578
# returns = 937673.0039566669
# Starting simulation...
# Execution time: 14.528 seconds.
# lrna fee = 0.021006944444444446, asset fee = 0.10503472222222224, trade volume = 1240201.8754413163
# returns = 943445.7369484667
# Starting simulation...
# Execution time: 12.607 seconds.
# lrna fee = 0.025, asset fee = 0.125, trade volume = 1094562.508615436
# returns = 946396.3532145862
# Starting simulation...
# Execution time: 14.357 seconds.
# lrna fee = 0.02934027777777778, asset fee = 0.1467013888888889, trade volume = 1244085.127853788
# returns = 945658.3126805044
# Starting simulation...
# Execution time: 12.501 seconds.
# lrna fee = 0.03402777777777778, asset fee = 0.1701388888888889, trade volume = 1104949.1654528826
# returns = 946740.6896444901
# Starting simulation...
# Execution time: 14.186 seconds.
# lrna fee = 0.0390625, asset fee = 0.1953125, trade volume = 849293.6663602758
# returns = 948514.8120088472
# Starting simulation...
# Execution time: 12.5 seconds.
# lrna fee = 0.044444444444444446, asset fee = 0.22222222222222224, trade volume = 951722.6891627084
# returns = 948103.4328310745
# Starting simulation...
# Execution time: 14.095 seconds.
# lrna fee = 0.05017361111111111, asset fee = 0.2508680555555556, trade volume = 534002.5527697266
# returns = 950751.5184480081
# Starting simulation...
# Execution time: 11.948 seconds.
# lrna fee = 0.056249999999999994, asset fee = 0.28125, trade volume = 607079.0724698287
# returns = 950478.2927464176
# Starting simulation...
# Execution time: 13.078 seconds.
# lrna fee = 0.06267361111111111, asset fee = 0.3133680555555556, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 13.403 seconds.
# lrna fee = 0.06944444444444445, asset fee = 0.3472222222222222, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 11.593 seconds.
# lrna fee = 0.0765625, asset fee = 0.3828125, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 13.216 seconds.
# lrna fee = 0.08402777777777778, asset fee = 0.42013888888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 11.354 seconds.
# lrna fee = 0.09184027777777778, asset fee = 0.45920138888888895, trade volume = 0.0
# returns = 954044.7562822247
# Starting simulation...
# Execution time: 12.897 seconds.
# lrna fee = 0.1, asset fee = 0.5, trade volume = 0.0
# returns = 954044.7562822247

# %%
# lines = []
# with open('./output/test_results_static_fees_dec.txt', 'r') as file:
#     data = file.readlines()
#     lines = [float(line [10: 20]) for line in list(filter(lambda line: line[0] == 'r', data))]
    
# print(len(lines))
# print(lines)
# test_results = [lines[i * 10: i * 10 + 10] for i in range(10)]

# %%
print(price_list[-10:-1])
# Out:
# [{'DOT': 4.893, 'ETH': 1321.59, 'BTC': 17189.0, 'DOGE': 0.07578}, {'DOT': 4.893, 'ETH': 1321.78, 'BTC': 17191.09, 'DOGE': 0.0758}, {'DOT': 4.894, 'ETH': 1321.43, 'BTC': 17187.67, 'DOGE': 0.07577}, {'DOT': 4.892, 'ETH': 1321.24, 'BTC': 17185.68, 'DOGE': 0.07576}, {'DOT': 4.892, 'ETH': 1321.28, 'BTC': 17187.4, 'DOGE': 0.07575}, {'DOT': 4.892, 'ETH': 1321.23, 'BTC': 17183.51, 'DOGE': 0.0757}, {'DOT': 4.891, 'ETH': 1320.56, 'BTC': 17178.44, 'DOGE': 0.07565}, {'DOT': 4.89, 'ETH': 1320.56, 'BTC': 17179.15, 'DOGE': 0.07565}, {'DOT': 4.887, 'ETH': 1320.56, 'BTC': 17179.9, 'DOGE': 0.07566}]

# %%
# colors = pu.color_gradient(25)
plt.figure(figsize=(20, 5))
for frequency in test_results:
    plt.plot([result[1] * 5 for result in test_results[frequency]], [result[2] for result in test_results[frequency]])

# %%
for frequency in test_results:
    plt.figure(figsize=(20, 5))
    plt.plot(range(time_steps), test_results[frequency][5][3])
    if frequency == 1:
        plt.title('Arbitrage every block.')
    else:
        plt.title(f'Arbitrage every {frequency} blocks.')

# %%
import copy
ordered_results = copy.copy(test_results)
ordered_results.sort(key=lambda x: x[2])
pprint([result[:3] for result in ordered_results])
# Out:
# [(10, 0.0, 933886.5070998196),
#  (10, 0.008506944444444445, 934780.4231259351),
#  (10, 0.0006944444444444445, 935135.3731511316),
#  (10, 0.00017361111111111112, 935207.3688257595),
#  (10, 0.011111111111111112, 935954.0434641253),
#  (10, 0.0015625, 935970.1187717916),
#  (10, 0.004340277777777778, 936573.1280760515),
#  (10, 0.00625, 936661.4748171184),
#  (10, 0.002777777777777778, 937052.0605158823),
#  (10, 0.017361111111111112, 937673.0039566669),
#  (10, 0.014062499999999999, 937682.8118510129),
#  (10, 0.021006944444444446, 943445.7369484667),
#  (10, 0.02934027777777778, 945658.3126805044),
#  (10, 0.025, 946396.3532145862),
#  (10, 0.03402777777777778, 946740.6896444901),
#  (10, 0.044444444444444446, 948103.4328310745),
#  (10, 0.0390625, 948514.8120088472),
#  (10, 0.056249999999999994, 950478.2927464176),
#  (10, 0.05017361111111111, 950751.5184480081),
#  (10, 0.06267361111111111, 954044.7562822247),
#  (10, 0.06944444444444445, 954044.7562822247),
#  (10, 0.0765625, 954044.7562822247),
#  (10, 0.08402777777777778, 954044.7562822247),
#  (10, 0.09184027777777778, 954044.7562822247),
#  (10, 0.1, 954044.7562822247)]

# %%
basic_state = initial_state.copy()
best_fee = 0.0005
basic_state.pools['omnipool'].asset_fee=best_fee * 5
basic_state.pools['omnipool'].lrna_fee=best_fee

print(best_fee)
print(basic_state.agents)
print(basic_state.pools['omnipool'])
# Out:
# 0.0005
# {'Trader': Agent: Trader
# ********************************
# trade strategy: omnipool arbitrage
# holdings: (
#
#     *HDX*: 1000000000
#
#     *USD*: 1000000000
#
#     *ETH*: 1000000000
#
#     *BTC*: 3000000000
#
#     *DOGE*: 3000000000
#
#     *DOT*: 1000000000
#
#     *LRNA*: 1000000000
# )
# , 'LP': Agent: LP
# ********************************
# trade strategy: invest all (omnipool)
# holdings: (
#
#     *HDX*: 2000000.0
#
#     *USD*: 200000.0
#
#     *DOT*: 36630.0366300366
#
#     *DOGE*: 936680.4046459349
#
#     *ETH*: 154.5045810608
#
#     *BTC*: 11.6512569085
#
#     *LRNA*: 0
# )
# }
# Omnipool: omnipool
# ********************************
# tvl cap: inf
# lrna fee:
#
#     HDX: 0.05%
#     USD: 0.05%
#     DOT: 0.05%
#     DOGE: 0.05%
#     ETH: 0.05%
#     BTC: 0.05%
#
# asset fee:
#
#     HDX: 0.25%
#     USD: 0.25%
#     DOT: 0.25%
#     DOGE: 0.25%
#     ETH: 0.25%
#     BTC: 0.25%
#
# asset pools: (
#
#     *HDX*
#     asset quantity: 20000000.0
#     lrna quantity: 14285714.285714284
#     USD price: 0.05
#     tvl: $1000000.0
#     weight: 14285714.285714284/142857142.85714284 (0.1)
#     weight cap: 1
#     total shares: 20000000.0
#     protocol shares: 20000000.0
#
#     *USD*
#     asset quantity: 2000000.0
#     lrna quantity: 28571428.571428567
#     USD price: 1.0
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 2000000.0
#     protocol shares: 2000000.0
#
#     *DOT*
#     asset quantity: 366300.3663003663
#     lrna quantity: 28571428.571428567
#     USD price: 5.46
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 366300.3663003663
#     protocol shares: 366300.3663003663
#
#     *DOGE*
#     asset quantity: 9366804.046459349
#     lrna quantity: 14285714.285714284
#     USD price: 0.10676
#     tvl: $1000000.0
#     weight: 14285714.285714284/142857142.85714284 (0.1)
#     weight cap: 1
#     total shares: 9366804.046459349
#     protocol shares: 9366804.046459349
#
#     *ETH*
#     asset quantity: 1545.045810608284
#     lrna quantity: 28571428.571428567
#     USD price: 1294.46
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 1545.0458106082845
#     protocol shares: 1545.0458106082845
#
#     *BTC*
#     asset quantity: 116.512569084671
#     lrna quantity: 28571428.571428567
#     USD price: 17165.53
#     tvl: $2000000.0
#     weight: 28571428.571428567/142857142.85714284 (0.2)
#     weight cap: 1
#     total shares: 116.51256908467144
#     protocol shares: 116.51256908467144
#
# )
# sub pools: (
#
#
# )
#
# error message: None

# %%
basic_events = run.run(basic_state, time_steps=time_steps)
# Out:
# Starting simulation...
# Execution time: 17.663 seconds.

# %%
ax=pu.plot(basic_events[::20], asset='ETH')
pu.plot(basic_events[::20], pool='omnipool', prop='usd_price', key='ETH', subplot=ax)
# Out:
# <AxesSubplot:title={'center':'asset price: ETH '}>

# %%
plt.figure(figsize=(20, 5))
LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in basic_events[::20]]


plt.plot(range(len(LP_holdings)), LP_holdings)
print(best_fee)
LP_returns = cash_out_omnipool(basic_events[-1].pools['omnipool'], basic_events[-1].agents['LP'], basic_events[-1].external_market)
print(LP_returns)
# Out:
# 0.0005
# 935093.6502664265

# %%
print([result[1] for result in test_results])
plt.figure(figsize=(20, 5))
plt.plot([result[1] for result in test_results], [sum(result[3]) * result[1] for result in test_results])
# plt.yscale('log')
# Out:
# [0.0, 0.00017361111111111112, 0.0006944444444444445, 0.0015625, 0.002777777777777778, 0.004340277777777778, 0.00625, 0.008506944444444445, 0.011111111111111112, 0.014062499999999999, 0.017361111111111112, 0.021006944444444446, 0.025, 0.02934027777777778, 0.03402777777777778, 0.0390625, 0.044444444444444446, 0.05017361111111111, 0.056249999999999994, 0.06267361111111111, 0.06944444444444445, 0.0765625, 0.08402777777777778, 0.09184027777777778, 0.1]

# %%
plt.figure(figsize=(20, 5))
LP_holdings1 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events[::20]]
LP_holdings2 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events2[::20]]
LP_holdings3 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events3[::20]]

plt.plot(range(len(LP_holdings1)), LP_holdings1)
plt.plot(range(len(LP_holdings2)), LP_holdings2)
plt.plot(range(len(LP_holdings2)), LP_holdings3)
plt.title('basic fees (blue) vs best tested parameters (orange) vs worst tested parameters (green)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 plt.figure(figsize=(20, 5))
#       2 LP_holdings1 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events[::20]]
# ----> 3 LP_holdings2 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events2[::20]]
#       4 LP_holdings3 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events3[::20]]
#       6 plt.plot(range(len(LP_holdings1)), LP_holdings1)
#
# NameError: name 'events2' is not defined

# %%
print(test_results[1])

# %%
random.seed(42)
basic_state2 = initial_state.copy()
basic_state2.pools['omnipool'].asset_fee=0.0025
basic_state2.pools['omnipool'].lrna_fee=0.0005

events4=run.run(basic_state2, time_steps=time_steps)
LP_holdings4 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events4[::20]]

# %%
random.seed(42)
basic_state3 = initial_state.copy()
basic_state3.pools['omnipool'].asset_fee=0.0025
basic_state3.pools['omnipool'].lrna_fee=0.0005

events5=run.run(basic_state3, time_steps=time_steps)
LP_holdings5 = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in events5[::20]]

# %%
print(LP_holdings1[-1])
print(LP_holdings2[-1])
print(LP_holdings3[-1])
print(LP_holdings4[-1])
print(LP_holdings5[-1])

# %%
# print(events[0], events[1000])

# %%
print(winning_state, losing_state)

# %%
pu.plot(events, asset='DOGE')

# %%
ax = pu.plot(events, pool='omnipool', oracle='fee_raise', prop='volume_in', key='DOT')
pu.plot(events2, pool='omnipool', oracle='fee_raise', prop='volume_in', key='DOT', subplot=ax)

# %%
print(test_results[0])
print(test_results[-1])

# %%
volume_out_usd = [event.pools['omnipool'].oracles['fee_raise'].price['USD'] for event in events3]
plt.plot(range(len(volume_out_usd)), volume_out_usd)

# %%
reverse_price_list = list(reversed(processing.import_binance_prices(assets=['DOT', 'ETH', 'BTC', 'DOGE'], start_date='Nov 1 2022', days=30)))
reverse_basic_state = initial_state.copy()
reverse_basic_state._evolve_function=historical_prices(reverse_price_list)
reverse_basic_events = run.run(reverse_basic_state, time_steps = time_steps)

reverse_state = reverse_basic_state.copy()
reverse_state.pools['omnipool'].lrna_fee = dynamicadd_lrna_fee(
    minimum=0.0005,
    amplification=test_results[-1].lrna_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[-1].lrna_decay,
    fee_max=test_results[-1].lrna_max,
)
reverse_state.pools['omnipool'].asset_fee = dynamicadd_asset_fee(
    minimum=0.0025,
    amplification=test_results[-1].asset_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[-1].asset_decay,
    fee_max=test_results[-1].asset_max,
)
reverse_state.pools['omnipool'].oracles['fee_raise'].decay_factor = 2 / (test_results[-1].oracle_length + 1)
reverse_events = run.run(reverse_state, time_steps = time_steps)

worst_reverse_state = reverse_state.copy()
worst_reverse_state.pools['omnipool'].lrna_fee = dynamicadd_lrna_fee(
    minimum=0.0005,
    amplification=test_results[0].lrna_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[0].lrna_decay,
    fee_max=test_results[0].lrna_max,
)
worst_reverse_state.pools['omnipool'].asset_fee = dynamicadd_asset_fee(
    minimum=0.0025,
    amplification=test_results[0].asset_amp,
    raise_oracle_name='fee_raise',
    decay=test_results[0].asset_decay,
    fee_max=test_results[0].asset_max,
)
worst_reverse_state.pools['omnipool'].oracles['fee_raise'].decay_factor = 2 / (test_results[-1].oracle_length + 1)
worst_reverse_events = run.run(worst_reverse_state, time_steps = time_steps)

# %%
reverse_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in reverse_events[::20]]
worst_reverse_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in worst_reverse_events[::20]]
reverse_basic_LP_holdings = [cash_out_omnipool(event.pools['omnipool'], event.agents['LP'], event.external_market) for event in reverse_basic_events[::20]]
plt.figure(figsize=(20, 5))
plt.plot(range(len(reverse_LP_holdings)), reverse_basic_LP_holdings)
plt.plot(range(len(reverse_LP_holdings)), reverse_LP_holdings)
plt.plot(range(len(reverse_LP_holdings)), worst_reverse_LP_holdings)
plt.title('basic fees (blue) vs best tested parameters (orange) vs worst tested parameters (green) with price movement reversed')

# %%
plt.figure(figsize=(20, 5))
plt.plot(range(len(price_list)), [price_list[i]['ETH'] for i in range(len(price_list))])
plt.plot(range(len(price_list)), [reverse_price_list[i]['ETH'] for i in range(len(price_list))])
plt.title('two different, opposite price runs')

# %%
pu.plot(reverse_events, asset='ETH')

# %%
pu.plot(reverse_events[::100], agent='Trader', prop='holdings', key='ETH')

# %%
oracle = [event.pools['omnipool'].oracles['fee_raise'].volume_in['ETH'] for event in reverse_events][:100]
plt.plot(range(len(oracle)), oracle)

# %%
pu.plot(reverse_events[::20], pool='omnipool', prop='last_fee')
pu.plot(reverse_events[::20], pool='omnipool', prop='last_lrna_fee')

pu.plot(events2[::20], pool='omnipool', prop='last_fee')
pu.plot(events2[::20], pool='omnipool', prop='last_lrna_fee')

# %%
print('hi')

# %%
print(events2[0])

# %%
no_archive_state = basic_state.copy()
no_archive_state.archive_all = True
short_events_1 = run.run(no_archive_state, time_steps = 1)
short_events_2 = run.run(no_archive_state, time_steps = 1)
short_events_3 = run.run(no_archive_state, time_steps = 1)
short_events_4 = run.run(no_archive_state, time_steps = 1)

# %%
print(repr(short_events_1[0]) == repr(short_events_2[0]))
print(short_events_1[0])
print(short_events_2[0])
# state1 = repr(short_events_1[0])
# state2 = repr(short_events_2[0])
# for i, char in enumerate(state1):
#     if char != state2[i]:
#         print(char)
