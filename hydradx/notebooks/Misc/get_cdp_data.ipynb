# %%
ADDRESS_PROVIDER_ABI = address_provider_abi = [
    {"inputs": [{"internalType": "string", "name": "marketId", "type": "string"},
             {"internalType": "address", "name": "owner", "type": "address"}], "stateMutability": "nonpayable",
  "type": "constructor"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}], "name": "ACLAdminUpdated",
                           "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}], "name": "ACLManagerUpdated",
                                              "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "bytes32", "name": "id", "type": "bytes32"},
    {"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}], "name": "AddressSet",
                                                                 "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "bytes32", "name": "id", "type": "bytes32"},
    {"indexed": True, "internalType": "address", "name": "proxyAddress", "type": "address"},
    {"indexed": False, "internalType": "address", "name": "oldImplementationAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newImplementationAddress", "type": "address"}],
                                                                                    "name": "AddressSetAsProxy",
                                                                                    "type": "event"},
 {"anonymous": False, "inputs": [{"indexed": True, "internalType": "string", "name": "oldMarketId", "type": "string"},
                                 {"indexed": True, "internalType": "string", "name": "newMarketId", "type": "string"}],
  "name": "MarketIdSet", "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "address", "name": "previousOwner", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newOwner", "type": "address"}],
                                            "name": "OwnershipTransferred", "type": "event"}, {"anonymous": False,
                                                                                               "inputs": [
                                                                                                   {"indexed": True,
                                                                                                    "internalType": "address",
                                                                                                    "name": "oldAddress",
                                                                                                    "type": "address"},
                                                                                                   {"indexed": True,
                                                                                                    "internalType": "address",
                                                                                                    "name": "newAddress",
                                                                                                    "type": "address"}],
                                                                                               "name": "PoolConfiguratorUpdated",
                                                                                               "type": "event"},
 {"anonymous": False, "inputs": [{"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
                                 {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}],
  "name": "PoolDataProviderUpdated", "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}], "name": "PoolUpdated",
                                                        "type": "event"}, {"anonymous": False, "inputs": [
    {"indexed": True, "internalType": "address", "name": "oldAddress", "type": "address"},
    {"indexed": True, "internalType": "address", "name": "newAddress", "type": "address"}],
                                                                           "name": "PriceOracleSentinelUpdated",
                                                                           "type": "event"}, {"anonymous": False,
                                                                                              "inputs": [
                                                                                                  {"indexed": True,
                                                                                                   "internalType": "address",
                                                                                                   "name": "oldAddress",
                                                                                                   "type": "address"},
                                                                                                  {"indexed": True,
                                                                                                   "internalType": "address",
                                                                                                   "name": "newAddress",
                                                                                                   "type": "address"}],
                                                                                              "name": "PriceOracleUpdated",
                                                                                              "type": "event"},
 {"anonymous": False, "inputs": [{"indexed": True, "internalType": "bytes32", "name": "id", "type": "bytes32"},
                                 {"indexed": True, "internalType": "address", "name": "proxyAddress",
                                  "type": "address"},
                                 {"indexed": True, "internalType": "address", "name": "implementationAddress",
                                  "type": "address"}], "name": "ProxyCreated", "type": "event"},
 {"inputs": [], "name": "getACLAdmin", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "getACLManager", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [{"internalType": "bytes32", "name": "id", "type": "bytes32"}], "name": "getAddress",
  "outputs": [{"internalType": "address", "name": "", "type": "address"}], "stateMutability": "view",
  "type": "function"},
 {"inputs": [], "name": "getMarketId", "outputs": [{"internalType": "string", "name": "", "type": "string"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "getPool", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "getPoolConfigurator", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "getPoolDataProvider", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "getPriceOracle", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"}, {"inputs": [], "name": "getPriceOracleSentinel", "outputs": [
    {"internalType": "address", "name": "", "type": "address"}], "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "owner", "outputs": [{"internalType": "address", "name": "", "type": "address"}],
  "stateMutability": "view", "type": "function"},
 {"inputs": [], "name": "renounceOwnership", "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newAclAdmin", "type": "address"}], "name": "setACLAdmin",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newAclManager", "type": "address"}], "name": "setACLManager",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"}, {
     "inputs": [{"internalType": "bytes32", "name": "id", "type": "bytes32"},
                {"internalType": "address", "name": "newAddress", "type": "address"}], "name": "setAddress",
     "outputs": [], "stateMutability": "nonpayable", "type": "function"}, {
     "inputs": [{"internalType": "bytes32", "name": "id", "type": "bytes32"},
                {"internalType": "address", "name": "newImplementationAddress", "type": "address"}],
     "name": "setAddressAsProxy", "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "string", "name": "newMarketId", "type": "string"}], "name": "setMarketId", "outputs": [],
  "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newPoolConfiguratorImpl", "type": "address"}],
  "name": "setPoolConfiguratorImpl", "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newDataProvider", "type": "address"}], "name": "setPoolDataProvider",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newPoolImpl", "type": "address"}], "name": "setPoolImpl",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newPriceOracle", "type": "address"}], "name": "setPriceOracle",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newPriceOracleSentinel", "type": "address"}],
  "name": "setPriceOracleSentinel", "outputs": [], "stateMutability": "nonpayable", "type": "function"},
 {"inputs": [{"internalType": "address", "name": "newOwner", "type": "address"}], "name": "transferOwnership",
  "outputs": [], "stateMutability": "nonpayable", "type": "function"}]

# %%
UI_POOL_DATA_PROVIDER_ADDRESS = "0x112b087b60C1a166130d59266363C45F8aa99db0"
UI_POOL_DATA_PROVIDER_ABI = [
    {
      "inputs": [
        {
          "internalType": "contract IEACAggregatorProxy",
          "name": "_networkBaseTokenPriceInUsdProxyAggregator",
          "type": "address"
        },
        {
          "internalType": "contract IEACAggregatorProxy",
          "name": "_marketReferenceCurrencyPriceInUsdProxyAggregator",
          "type": "address"
        }
      ],
      "stateMutability": "nonpayable",
      "type": "constructor"
    },
    {
      "inputs": [],
      "name": "ETH_CURRENCY_UNIT",
      "outputs": [
        {
          "internalType": "uint256",
          "name": "",
          "type": "uint256"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [],
      "name": "MKR_ADDRESS",
      "outputs": [
        {
          "internalType": "address",
          "name": "",
          "type": "address"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [
        {
          "internalType": "bytes32",
          "name": "_bytes32",
          "type": "bytes32"
        }
      ],
      "name": "bytes32ToString",
      "outputs": [
        {
          "internalType": "string",
          "name": "",
          "type": "string"
        }
      ],
      "stateMutability": "pure",
      "type": "function"
    },
    {
      "inputs": [
        {
          "internalType": "contract IPoolAddressesProvider",
          "name": "provider",
          "type": "address"
        }
      ],
      "name": "getReservesData",
      "outputs": [
        {
          "components": [
            {
              "internalType": "address",
              "name": "underlyingAsset",
              "type": "address"
            },
            {
              "internalType": "string",
              "name": "name",
              "type": "string"
            },
            {
              "internalType": "string",
              "name": "symbol",
              "type": "string"
            },
            {
              "internalType": "uint256",
              "name": "decimals",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "baseLTVasCollateral",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "reserveLiquidationThreshold",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "reserveLiquidationBonus",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "reserveFactor",
              "type": "uint256"
            },
            {
              "internalType": "bool",
              "name": "usageAsCollateralEnabled",
              "type": "bool"
            },
            {
              "internalType": "bool",
              "name": "borrowingEnabled",
              "type": "bool"
            },
            {
              "internalType": "bool",
              "name": "stableBorrowRateEnabled",
              "type": "bool"
            },
            {
              "internalType": "bool",
              "name": "isActive",
              "type": "bool"
            },
            {
              "internalType": "bool",
              "name": "isFrozen",
              "type": "bool"
            },
            {
              "internalType": "uint128",
              "name": "liquidityIndex",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "variableBorrowIndex",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "liquidityRate",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "variableBorrowRate",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "stableBorrowRate",
              "type": "uint128"
            },
            {
              "internalType": "uint40",
              "name": "lastUpdateTimestamp",
              "type": "uint40"
            },
            {
              "internalType": "address",
              "name": "aTokenAddress",
              "type": "address"
            },
            {
              "internalType": "address",
              "name": "stableDebtTokenAddress",
              "type": "address"
            },
            {
              "internalType": "address",
              "name": "variableDebtTokenAddress",
              "type": "address"
            },
            {
              "internalType": "address",
              "name": "interestRateStrategyAddress",
              "type": "address"
            },
            {
              "internalType": "uint256",
              "name": "availableLiquidity",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "totalPrincipalStableDebt",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "averageStableRate",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "stableDebtLastUpdateTimestamp",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "totalScaledVariableDebt",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "priceInMarketReferenceCurrency",
              "type": "uint256"
            },
            {
              "internalType": "address",
              "name": "priceOracle",
              "type": "address"
            },
            {
              "internalType": "uint256",
              "name": "variableRateSlope1",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "variableRateSlope2",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "stableRateSlope1",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "stableRateSlope2",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "baseStableBorrowRate",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "baseVariableBorrowRate",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "optimalUsageRatio",
              "type": "uint256"
            },
            {
              "internalType": "bool",
              "name": "isPaused",
              "type": "bool"
            },
            {
              "internalType": "bool",
              "name": "isSiloedBorrowing",
              "type": "bool"
            },
            {
              "internalType": "uint128",
              "name": "accruedToTreasury",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "unbacked",
              "type": "uint128"
            },
            {
              "internalType": "uint128",
              "name": "isolationModeTotalDebt",
              "type": "uint128"
            },
            {
              "internalType": "bool",
              "name": "flashLoanEnabled",
              "type": "bool"
            },
            {
              "internalType": "uint256",
              "name": "debtCeiling",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "debtCeilingDecimals",
              "type": "uint256"
            },
            {
              "internalType": "uint8",
              "name": "eModeCategoryId",
              "type": "uint8"
            },
            {
              "internalType": "uint256",
              "name": "borrowCap",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "supplyCap",
              "type": "uint256"
            },
            {
              "internalType": "uint16",
              "name": "eModeLtv",
              "type": "uint16"
            },
            {
              "internalType": "uint16",
              "name": "eModeLiquidationThreshold",
              "type": "uint16"
            },
            {
              "internalType": "uint16",
              "name": "eModeLiquidationBonus",
              "type": "uint16"
            },
            {
              "internalType": "address",
              "name": "eModePriceSource",
              "type": "address"
            },
            {
              "internalType": "string",
              "name": "eModeLabel",
              "type": "string"
            },
            {
              "internalType": "bool",
              "name": "borrowableInIsolation",
              "type": "bool"
            }
          ],
          "internalType": "struct IUiPoolDataProviderV3.AggregatedReserveData[]",
          "name": "",
          "type": "tuple[]"
        },
        {
          "components": [
            {
              "internalType": "uint256",
              "name": "marketReferenceCurrencyUnit",
              "type": "uint256"
            },
            {
              "internalType": "int256",
              "name": "marketReferenceCurrencyPriceInUsd",
              "type": "int256"
            },
            {
              "internalType": "int256",
              "name": "networkBaseTokenPriceInUsd",
              "type": "int256"
            },
            {
              "internalType": "uint8",
              "name": "networkBaseTokenPriceDecimals",
              "type": "uint8"
            }
          ],
          "internalType": "struct IUiPoolDataProviderV3.BaseCurrencyInfo",
          "name": "",
          "type": "tuple"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [
        {
          "internalType": "contract IPoolAddressesProvider",
          "name": "provider",
          "type": "address"
        }
      ],
      "name": "getReservesList",
      "outputs": [
        {
          "internalType": "address[]",
          "name": "",
          "type": "address[]"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [
        {
          "internalType": "contract IPoolAddressesProvider",
          "name": "provider",
          "type": "address"
        },
        {
          "internalType": "address",
          "name": "user",
          "type": "address"
        }
      ],
      "name": "getUserReservesData",
      "outputs": [
        {
          "components": [
            {
              "internalType": "address",
              "name": "underlyingAsset",
              "type": "address"
            },
            {
              "internalType": "uint256",
              "name": "scaledATokenBalance",
              "type": "uint256"
            },
            {
              "internalType": "bool",
              "name": "usageAsCollateralEnabledOnUser",
              "type": "bool"
            },
            {
              "internalType": "uint256",
              "name": "stableBorrowRate",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "scaledVariableDebt",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "principalStableDebt",
              "type": "uint256"
            },
            {
              "internalType": "uint256",
              "name": "stableBorrowLastUpdateTimestamp",
              "type": "uint256"
            }
          ],
          "internalType": "struct IUiPoolDataProviderV3.UserReserveData[]",
          "name": "",
          "type": "tuple[]"
        },
        {
          "internalType": "uint8",
          "name": "",
          "type": "uint8"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [],
      "name": "marketReferenceCurrencyPriceInUsdProxyAggregator",
      "outputs": [
        {
          "internalType": "contract IEACAggregatorProxy",
          "name": "",
          "type": "address"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    },
    {
      "inputs": [],
      "name": "networkBaseTokenPriceInUsdProxyAggregator",
      "outputs": [
        {
          "internalType": "contract IEACAggregatorProxy",
          "name": "",
          "type": "address"
        }
      ],
      "stateMutability": "view",
      "type": "function"
    }
]

# %%
from substrateinterface import SubstrateInterface
import requests
from web3 import Web3, WebSocketProvider
# from web3.middleware.validation import geth_poa_middleware
from pprint import pprint
from mpmath import mp, mpf
mp.dps = 50

# --- Configuration ---
RPC_URL = "wss://rpc.hydradx.cloud"
BORROWERS_API_ENDPOINT = "https://omniwatch.play.hydration.cloud/api/borrowers/by-health"
POOL_ADDRESS_PROVIDER_ADDRESS = "0xf3Ba4D1b50f78301BDD7EAEa9B67822A15FCA691"


class CustomPoaMiddleware:
    def __init__(self, w3):
        self.w3 = w3
    
    def wrap_make_request(self, make_request):
        def middleware(method, params):
            response = make_request(method, params)
            result = response.get('result')
            if result and isinstance(result, dict) and 'extraData' in result:
                # Just ignore extraData validation issues
                pass
            return response
        return middleware


def substrate_to_checksum(substrate_address):
    """Converts a Substrate address to an Ethereum checksum address, or returns input if already checksummed"""
    if substrate_address[:2] == '0x':
        try:
            return Web3.to_checksum_address(substrate_address) # handles hex and checksum
        except:
            return None # Handles invalid hex.
    try:
        # Use substrateinterface to directly convert to an Ethereum address
        substrate = SubstrateInterface(url="wss://rpc.hydradx.cloud")
        # Use decode_ss58 to get the public key in hex format
        public_key_hex = substrate.ss58_decode(substrate_address)

        # Create Ethereum address from the public key
        address = '0x' + public_key_hex[2:]  # Correctly skip the first byte (0x2a or similar)

        return Web3.to_checksum_address(address)

    except Exception as e:
        print(f"Error converting address {substrate_address}: {e}")
        return None

# %%
from web3 import Web3, LegacyWebSocketProvider

provider = LegacyWebSocketProvider(RPC_URL)
w3 = Web3(provider)
w3.middleware_onion.add(CustomPoaMiddleware)
if not w3.is_connected():
    raise Exception("Failed to connect to RPC endpoint.")

address_provider_contract = w3.eth.contract(address=Web3.to_checksum_address(POOL_ADDRESS_PROVIDER_ADDRESS), abi=ADDRESS_PROVIDER_ABI)
pool_address = address_provider_contract.functions.getPool().call()
pool_address = substrate_to_checksum(pool_address)  # Convert the pool address
print(f"Pool Address: {pool_address}")
data_provider_contract = w3.eth.contract(address=UI_POOL_DATA_PROVIDER_ADDRESS, abi=UI_POOL_DATA_PROVIDER_ABI)
results = []

fields = [entry['name'] for entry in UI_POOL_DATA_PROVIDER_ABI[4]['outputs'][0]['components']]

try:
    # reserves_list = pool_contract.functions.getReservesList().call()
    raw_data = data_provider_contract.functions.getReservesData(
        Web3.to_checksum_address(POOL_ADDRESS_PROVIDER_ADDRESS),
        # reserves_list
    ).call()
    reserves_data = {
        tkn[1]: {
            fields[i]: tkn[i]
            for i in range(len(fields))
        }
        for tkn in raw_data[0]
    }
    # correct decimals for python
    for tkn in reserves_data:
        reserves_data[tkn]['baseLTVasCollateral'] /= mpf(10000)
        reserves_data[tkn]['reserveLiquidationThreshold'] /= mpf(10000)
        reserves_data[tkn]['reserveLiquidationBonus'] /= mpf(10000)
        reserves_data[tkn]['reserveFactor'] /= mpf(10000)
        reserves_data[tkn]['eModeLtv'] /= mpf(10000)
        reserves_data[tkn]['eModeLiquidationThreshold'] /= mpf(10000)
        reserves_data[tkn]['eModeLiquidationBonus'] /= mpf(10000)
        reserves_data[tkn]['liquidityIndex'] /= mpf(1e27)
        reserves_data[tkn]['variableBorrowIndex'] /= mpf(1e27)
        reserves_data[tkn]['priceInMarketReferenceCurrency'] /= mpf(1e8)
    
    reserves_data.update({'etc': raw_data[1:]})
except Exception as e:
    print(f"Error getting reserve list: {e}")
    # checksummed_reserves_list = []
    reserves_data = {}

asset_map = {}
for key in reserves_data:
    print('---------------------------')
    print(f"{key}:")
    if (isinstance(reserves_data[key], dict)):
        for inner_key in reserves_data[key]:
            print(f"    {inner_key}: {reserves_data[key][inner_key]}")
        asset_map[reserves_data[key]['underlyingAsset']] = key
    else:
        print(reserves_data[key])
# Out:
# Pool Address: 0x1b02E051683b5cfaC5929C25E84adb26ECf87B38
# ---------------------------
# USDC:
#     underlyingAsset: 0x0000000000000000000000000000000100000016
#     name: USDC
#     symbol: USDC
#     decimals: 6
#     baseLTVasCollateral: 0.8
#     reserveLiquidationThreshold: 0.9
#     reserveLiquidationBonus: 1.03
#     reserveFactor: 0.2
#     usageAsCollateralEnabled: True
#     borrowingEnabled: True
#     stableBorrowRateEnabled: False
#     isActive: True
#     isFrozen: False
#     liquidityIndex: 1.0081178703753378462447864413203410574165317680771
#     variableBorrowIndex: 1.0121010170809071134261911201102340506329348843379
#     liquidityRate: 17672997965227630180825261
#     variableBorrowRate: 32242644364282922517785299
#     stableBorrowRate: 54030330545535365314723162
#     lastUpdateTimestamp: 1741295424
#     aTokenAddress: 0x2ec4884088D84E5C2970A034732E5209b0aCFA93
#     stableDebtTokenAddress: 0xDF9140c953215292DA5CDF4C05604e132606F208
#     variableDebtTokenAddress: 0xf006621eFdc155f5996C3Afa23F5a6379C578010
#     interestRateStrategyAddress: 0x905BB549dCD851d6EC6B3F108c2a157Ac2d48B8A
#     availableLiquidity: 441577301556
#     totalPrincipalStableDebt: 0
#     averageStableRate: 0
#     stableDebtLastUpdateTimestamp: 0
#     totalScaledVariableDebt: 949461396758
#     priceInMarketReferenceCurrency: 0.99998295
#     priceOracle: 0x17711BE5D63B2Fe8A2C379725DE720773158b954
#     variableRateSlope1: 40000000000000000000000000
#     variableRateSlope2: 600000000000000000000000000
#     stableRateSlope1: 5000000000000000000000000
#     stableRateSlope2: 600000000000000000000000000
#     baseStableBorrowRate: 50000000000000000000000000
#     baseVariableBorrowRate: 0
#     optimalUsageRatio: 850000000000000000000000000
#     isPaused: False
#     isSiloedBorrowing: False
#     accruedToTreasury: 925704270
#     unbacked: 0
#     isolationModeTotalDebt: 0
#     flashLoanEnabled: False
#     debtCeiling: 0
#     debtCeilingDecimals: 2
#     eModeCategoryId: 1
#     borrowCap: 1111111
#     supplyCap: 2222222
#     eModeLtv: 0.9
#     eModeLiquidationThreshold: 0.93
#     eModeLiquidationBonus: 1.015
#     eModePriceSource: 0x0000000000000000000000000000000000000000
#     eModeLabel: Stablecoins
#     borrowableInIsolation: True
# ---------------------------
# Tether USD:
#     underlyingAsset: 0x000000000000000000000000000000010000000A
#     name: Tether USD
#     symbol: USDT
#     decimals: 6
#     baseLTVasCollateral: 0.8
#     reserveLiquidationThreshold: 0.9
#     reserveLiquidationBonus: 1.03
#     reserveFactor: 0.2
#     usageAsCollateralEnabled: True
#     borrowingEnabled: True
#     stableBorrowRateEnabled: False
#     isActive: True
#     isFrozen: False
#     liquidityIndex: 1.0089933525699430906831377684449684506419168000243
#     variableBorrowIndex: 1.0130556548456842076865098192369474288448150654203
#     liquidityRate: 19569489979600692518924372
#     variableBorrowRate: 33928549473684783958031140
#     stableBorrowRate: 54241068684210597994753893
#     lastUpdateTimestamp: 1741295388
#     aTokenAddress: 0xc64980E4eAF9A1151bd21712b9946B81e41E2b92
#     stableDebtTokenAddress: 0x6863e05d3f794903E76056cc751c1b2006728380
#     variableDebtTokenAddress: 0x32a8090E20748e530670FF520C4AbC903dB7e127
#     interestRateStrategyAddress: 0x905BB549dCD851d6EC6B3F108c2a157Ac2d48B8A
#     availableLiquidity: 377842129381
#     totalPrincipalStableDebt: 0
#     averageStableRate: 0
#     stableDebtLastUpdateTimestamp: 0
#     totalScaledVariableDebt: 963759289375
#     priceInMarketReferenceCurrency: 1.00053907
#     priceOracle: 0x8b0DDfB8F56690eAde9ECa23a7d90E153C268d5B
#     variableRateSlope1: 40000000000000000000000000
#     variableRateSlope2: 600000000000000000000000000
#     stableRateSlope1: 5000000000000000000000000
#     stableRateSlope2: 600000000000000000000000000
#     baseStableBorrowRate: 50000000000000000000000000
#     baseVariableBorrowRate: 0
#     optimalUsageRatio: 850000000000000000000000000
#     isPaused: False
#     isSiloedBorrowing: False
#     accruedToTreasury: 996672534
#     unbacked: 0
#     isolationModeTotalDebt: 0
#     flashLoanEnabled: False
#     debtCeiling: 0
#     debtCeilingDecimals: 2
#     eModeCategoryId: 1
#     borrowCap: 1111111
#     supplyCap: 2222222
#     eModeLtv: 0.9
#     eModeLiquidationThreshold: 0.93
#     eModeLiquidationBonus: 1.015
#     eModePriceSource: 0x0000000000000000000000000000000000000000
#     eModeLabel: Stablecoins
#     borrowableInIsolation: True
# ---------------------------
# Bitcoin (Moonbeam Wormhole):
#     underlyingAsset: 0x0000000000000000000000000000000100000013
#     name: Bitcoin (Moonbeam Wormhole)
#     symbol: WBTC
#     decimals: 8
#     baseLTVasCollateral: 0.6
#     reserveLiquidationThreshold: 0.7
#     reserveLiquidationBonus: 1.05
#     reserveFactor: 0.2
#     usageAsCollateralEnabled: True
#     borrowingEnabled: True
#     stableBorrowRateEnabled: False
#     isActive: True
#     isFrozen: False
#     liquidityIndex: 1.0000372363806566082608168165413433622136664105032
#     variableBorrowIndex: 1.001195822199841545273805066663285277500733857719
#     liquidityRate: 622948958576115726806274
#     variableBorrowRate: 11005860446488409742315591
#     stableBorrowRate: 101005860446488409742315591
#     lastUpdateTimestamp: 1741291008
#     aTokenAddress: 0x02759D14d0D4F452B9c76f5A230750E8857D36f2
#     stableDebtTokenAddress: 0x017515FB70AEd4960c3Cc119cDD5241336758e69
#     variableDebtTokenAddress: 0x5C2209375bbF32Ac443ba9f10b9A7558Cd7F99e6
#     interestRateStrategyAddress: 0x28cc3980bdfa1cb78EBFF4A990A139E53bF3d3F2
#     availableLiquidity: 994071835
#     totalPrincipalStableDebt: 0
#     averageStableRate: 0
#     stableDebtLastUpdateTimestamp: 0
#     totalScaledVariableDebt: 75597174
#     priceInMarketReferenceCurrency: 89139.8350394
#     priceOracle: 0xeDD9A7C47A9F91a0F2db93978A88844167B4a04f
#     variableRateSlope1: 70000000000000000000000000
#     variableRateSlope2: 3000000000000000000000000000
#     stableRateSlope1: 70000000000000000000000000
#     stableRateSlope2: 3000000000000000000000000000
#     baseStableBorrowRate: 90000000000000000000000000
#     baseVariableBorrowRate: 0
#     optimalUsageRatio: 450000000000000000000000000
#     isPaused: False
#     isSiloedBorrowing: False
#     accruedToTreasury: 11406
#     unbacked: 0
#     isolationModeTotalDebt: 0
#     flashLoanEnabled: False
#     debtCeiling: 0
#     debtCeilingDecimals: 2
#     eModeCategoryId: 0
#     borrowCap: 10
#     supplyCap: 33
#     eModeLtv: 0.0
#     eModeLiquidationThreshold: 0.0
#     eModeLiquidationBonus: 0.0
#     eModePriceSource: 0x0000000000000000000000000000000000000000
#     eModeLabel:
#     borrowableInIsolation: False
# ---------------------------
# Polkadot:
#     underlyingAsset: 0x0000000000000000000000000000000100000005
#     name: Polkadot
#     symbol: DOT
#     decimals: 10
#     baseLTVasCollateral: 0.75
#     reserveLiquidationThreshold: 0.8
#     reserveLiquidationBonus: 1.07
#     reserveFactor: 0.2
#     usageAsCollateralEnabled: True
#     borrowingEnabled: True
#     stableBorrowRateEnabled: False
#     isActive: True
#     isFrozen: False
#     liquidityIndex: 1.0009730505552008586066166631599284152428959046696
#     variableBorrowIndex: 1.0046278549437086634887498785702436739697203360646
#     liquidityRate: 3308811499542582092232888
#     variableBorrowRate: 19647595483416486268904821
#     stableBorrowRate: 109647595483416486268904821
#     lastUpdateTimestamp: 1741295688
#     aTokenAddress: 0x02639ec01313c8775Fae74F2dad1118c8A8a86dA
#     stableDebtTokenAddress: 0xdc92F2FD6137B0bd5766Ddf59C39C828b24F5248
#     variableDebtTokenAddress: 0x34321CB7334807eb718B3E1DdFaEb0c6c0403F1A
#     interestRateStrategyAddress: 0x5383a606ECe147e94C1fA0b7375bc778f132b832
#     availableLiquidity: 6134547910464683
#     totalPrincipalStableDebt: 0
#     averageStableRate: 0
#     stableDebtLastUpdateTimestamp: 0
#     totalScaledVariableDebt: 1628183384472078
#     priceInMarketReferenceCurrency: 4.45207918
#     priceOracle: 0xFBCa0A6dC5B74C042DF23025D99ef0F1fcAC6702
#     variableRateSlope1: 70000000000000000000000000
#     variableRateSlope2: 3000000000000000000000000000
#     stableRateSlope1: 70000000000000000000000000
#     stableRateSlope2: 3000000000000000000000000000
#     baseStableBorrowRate: 90000000000000000000000000
#     baseVariableBorrowRate: 0
#     optimalUsageRatio: 750000000000000000000000000
#     isPaused: False
#     isSiloedBorrowing: False
#     accruedToTreasury: 1134998405111
#     unbacked: 0
#     isolationModeTotalDebt: 0
#     flashLoanEnabled: False
#     debtCeiling: 0
#     debtCeilingDecimals: 2
#     eModeCategoryId: 2
#     borrowCap: 500000
#     supplyCap: 1200000
#     eModeLtv: 0.8
#     eModeLiquidationThreshold: 0.9
#     eModeLiquidationBonus: 1.045
#     eModePriceSource: 0x0000000000000000000000000000000000000000
#     eModeLabel: DOT
#     borrowableInIsolation: False
# ---------------------------
# Bifrost Voucher DOT:
#     underlyingAsset: 0x000000000000000000000000000000010000000F
#     name: Bifrost Voucher DOT
#     symbol: vDOT
#     decimals: 10
#     baseLTVasCollateral: 0.6
#     reserveLiquidationThreshold: 0.7
#     reserveLiquidationBonus: 1.08
#     reserveFactor: 0.2
#     usageAsCollateralEnabled: True
#     borrowingEnabled: True
#     stableBorrowRateEnabled: False
#     isActive: True
#     isFrozen: False
#     liquidityIndex: 1.0000002715522376367528850237346874768149089922413
#     variableBorrowIndex: 1.0000610274409706133850832135171997455120864570875
#     liquidityRate: 6998241383530123778134
#     variableBorrowRate: 903582588779344014336451
#     stableBorrowRate: 90903582588779344014336451
#     lastUpdateTimestamp: 1741295202
#     aTokenAddress: 0x0e13b904F4168F93814216B6874cA8349457f263
#     stableDebtTokenAddress: 0x01F3bD47F97bb3f8484124CCf3b4F93Ee5Fee2c1
#     variableDebtTokenAddress: 0x89C28953e5AA32fa61cd2314868461B77B3D88E7
#     interestRateStrategyAddress: 0x5383a606ECe147e94C1fA0b7375bc778f132b832
#     availableLiquidity: 3301059347435435
#     totalPrincipalStableDebt: 0
#     averageStableRate: 0
#     stableDebtLastUpdateTimestamp: 0
#     totalScaledVariableDebt: 32268806380382
#     priceInMarketReferenceCurrency: 6.46639018
#     priceOracle: 0xF89728554C61B7AA08bf94823D1017697047c0fE
#     variableRateSlope1: 70000000000000000000000000
#     variableRateSlope2: 3000000000000000000000000000
#     stableRateSlope1: 70000000000000000000000000
#     stableRateSlope2: 3000000000000000000000000000
#     baseStableBorrowRate: 90000000000000000000000000
#     baseVariableBorrowRate: 0
#     optimalUsageRatio: 750000000000000000000000000
#     isPaused: False
#     isSiloedBorrowing: False
#     accruedToTreasury: 204064533
#     unbacked: 0
#     isolationModeTotalDebt: 0
#     flashLoanEnabled: False
#     debtCeiling: 0
#     debtCeilingDecimals: 2
#     eModeCategoryId: 2
#     borrowCap: 111111
#     supplyCap: 333333
#     eModeLtv: 0.8
#     eModeLiquidationThreshold: 0.9
#     eModeLiquidationBonus: 1.045
#     eModePriceSource: 0x0000000000000000000000000000000000000000
#     eModeLabel: DOT
#     borrowableInIsolation: False
# ---------------------------
# etc:
# [(100000000, 100000000, 220807186363, 8)]

# %%
def get_borrower_data():
    """Gets borrower data, including user configuration bitmasks."""

    try:
        response = requests.get(BORROWERS_API_ENDPOINT)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
        borrowers_data = response.json()["borrowers"]
    except requests.exceptions.RequestException as e:
        raise Exception(f"Error fetching borrowers from API: {e}")

    for borrower_entry in borrowers_data:
        borrower_info = borrower_entry[1]
        borrower_address = borrower_entry[0]  # borrower_info["account"]

        try:
            # Convert to checksummed address *before* passing to Web3.py
            checksummed_borrower_address = substrate_to_checksum(borrower_address)
            user_config = data_provider_contract.functions.getUserReservesData(
                Web3.to_checksum_address(POOL_ADDRESS_PROVIDER_ADDRESS),
                checksummed_borrower_address
            ).call()

            results.append({
                "borrower": checksummed_borrower_address,  # Store the checksummed address
                "config": {
                    'assets': {
                        asset_map[tkn[0]]: {
                            "underlyingAsset": tkn[0],
                            "scaledATokenBalance": tkn[1],
                            "usageAsCollateralEnabledOnUser": tkn[2],
                            "stableBorrowRate": tkn[3],
                            "scaledVariableDebt": tkn[4],
                            "principalStableDebt": tkn[5],
                            "stableBorrowLastUpdateTimestamp": tkn[6],
                        } 
                        for tkn in user_config[0]
                    },
                    'unknown number': user_config[1]
                },
                "totalCollateralBase": borrower_info["totalCollateralBase"],
                "totalDebtBase": borrower_info["totalDebtBase"],
                "healthFactor": borrower_info["healthFactor"],
                "availableBorrowsBase": borrower_info["availableBorrowsBase"],
                "currentLiquidationThreshold": borrower_info["currentLiquidationThreshold"],
                "ltv": borrower_info["ltv"],
                "updated": borrower_info["updated"],
                "account": borrower_info["account"],
                "pool": borrower_info["pool"]
            })

        except Exception as e:
            print(e)
            results.append({
                "borrower": checksummed_borrower_address,
                "bitmask": None,
                "error": str(e),
                "totalCollateralBase": borrower_info.get("totalCollateralBase", None),
                "totalDebtBase": borrower_info.get("totalDebtBase", None),
                "healthFactor": borrower_info.get("healthFactor", None)
            })

    return results

# %%
borrower_data = None
try:
    borrower_data = get_borrower_data()
    print("Borrower Data:")

except Exception as e:
    print(f"An error occurred: {e}")

print('--fetched borrower data.')
# Out:
# Borrower Data:
# --fetched borrower data.

# %%
def print_position(data):
    print('Hydration Account: ', data['account'])
    print('availableBorrowsBase: ', data['availableBorrowsBase'])
    print('borrower: ', data['borrower'])
    print('config:')
    for tkn, tkn_cfg in data['config']['assets'].items():
        print(f"    {tkn}:")
        print("        underlyingAsset: ", tkn_cfg["underlyingAsset"])
        print("        scaledATokenBalance: ", tkn_cfg["scaledATokenBalance"])
        print("        usageAsCollateralEnabledOnUser: ", tkn_cfg["usageAsCollateralEnabledOnUser"])
        print("        stableBorrowRate: ", tkn_cfg["stableBorrowRate"])
        print("        scaledVariableDebt: ", tkn_cfg["scaledVariableDebt"])
        print("        principalStableDebt: ", tkn_cfg["principalStableDebt"])
        print("        stableBorrowLastUpdateTimestamp: ", tkn_cfg["stableBorrowLastUpdateTimestamp"])

    print('currentLiquidationThreshold', data['currentLiquidationThreshold'])
    print('healthFactor', data['healthFactor'])
    print('calculated health factor', data['calculatedHealthFactor'])
    print('discrepancy:', data['discrepancy'])
    print('ltv', data['ltv'])
    print('pool', data['pool'])
    print('totalCollateralBase', data['totalCollateralBase'])
    print('totalDebtBase', data['totalDebtBase'])
    print('updated', data['updated'])
    print()
    print('---------------------------------------------------')

if borrower_data:
    # try to correctly calculate health factor
    for i, position in enumerate(borrower_data):
        if position['healthFactor'] == 0:
            print('skipping position with 0 health factor')
            continue
            
        tokens = position['config']['assets']
        collateral_tokens = [
            {
                'name': t,
                **reserves_data[t],
                **tokens[t]
            } for t in filter(lambda k: tokens[k]['usageAsCollateralEnabledOnUser'], tokens.keys())
        ]
        debt_tokens = [
            {
                'name': t,
                **reserves_data[t],
                **tokens[t]
            } for t in filter(lambda k: tokens[k]['scaledVariableDebt'] > 0, tokens.keys())
        ]

        liquidation_threshold = position['currentLiquidationThreshold'] / 100
        health_factor = (
            sum([
                mpf(c_tkn['scaledATokenBalance']) * c_tkn['priceInMarketReferenceCurrency'] * c_tkn['liquidityIndex'] / 10 ** c_tkn['decimals']
                for c_tkn in collateral_tokens
            ]) * liquidation_threshold
            / sum([
                mpf(d_tkn['scaledVariableDebt']) * d_tkn['priceInMarketReferenceCurrency'] * d_tkn['variableBorrowIndex'] / 10 ** d_tkn['decimals']
                for d_tkn in debt_tokens
            ])
        )
        position['calculatedHealthFactor'] = health_factor
        position['discrepancy'] = abs(1 - health_factor / position['healthFactor'])
        
        if position['discrepancy'] > 0.00001:
            print(f"position ({i}) didn't work out:")
            # print_position(position)
            print(f"calculated health factor: {health_factor} vs actual: {position['healthFactor']} discrepancy = {round(position['discrepancy'], 12)}")
            if len(collateral_tokens) > 1:
                print(f"{len(collateral_tokens)} collateral tokens.")
            if len(debt_tokens) > 1:
                print(f"{len(debt_tokens)} debt tokens.")
            # break;
        else:
            print(f"position{i} successfully calculated ({position['calculatedHealthFactor']} ~= {position['healthFactor']}) discrepancy ={round(position['discrepancy'], 12)}")

# collateral.scaledATokenBalance * collateral.priceInMarketReferenceCurrency * collateral.liquidityIndex * collateral.eModeLiquidationThreshold
# --------------------------------divided by------------------------------------------
# debt_token.scaledVariableDebt * debt_token.priceInMarketReferenceCurrency * debt_token.variableBorrowIndex
# Out:
# skipping position with 0 health factor
# skipping position with 0 health factor
# skipping position with 0 health factor
# position3 successfully calculated (0.95503743350604381193725172544703869786362073149112 ~= 0.9550374570456781) discrepancy =2.4648e-08
# position4 successfully calculated (0.95503743350604381193725172544703869786362073149112 ~= 0.9550374570456781) discrepancy =2.4648e-08
# position (5) didn't work out:
# calculated health factor: 0.98959688530625013669103971917995240984144845813907 vs actual: 0.9926119470222543 discrepancy = 0.003037502949
# position6 successfully calculated (1.0068493945827009720032917732501676478271289577265 ~= 1.0068549734579435) discrepancy =5.540893e-06
# position7 successfully calculated (1.0099644276346630246655595069040280710375662314076 ~= 1.009964402786196) discrepancy =2.4603e-08
# position272 successfully calculated (1.9352183994175991987231812166966578996619826632245 ~= 1.9352172165603023) discrepancy =6.11227e-07
# position273 successfully calculated (1.9486097340943877121580386570550973791260127476057 ~= 1.9486099237237096) discrepancy =9.7315e-08
# position274 successfully calculated (1.9486097340943877121580386570550973791260127476057 ~= 1.9486099237237096) discrepancy =9.7315e-08
# position275 successfully calculated (1.9504194872615923790710423227003630186374257470728 ~= 1.950418269907957) discrepancy =6.2415e-07
# position (276) didn't work out:
# calculated health factor: 1.953508335064606587556789818646870027566863444915 vs actual: 1.9558493661026726 discrepancy = 0.001196938312
# 2 collateral tokens.
# position277 successfully calculated (1.9678095102798917738701573762670653779946991813642 ~= 1.9678082101557481) discrepancy =6.60697e-07
# position278 successfully calculated (1.9678095102798917738701573762670653779946991813642 ~= 1.9678082101557481) discrepancy =6.60697e-07
# position279 successfully calculated (1.9787597778342338690749858250613174073651121585309 ~= 1.9787585683775426) discrepancy =6.1122e-07
# position280 successfully calculated (1.9787597778342338690749858250613174073651121585309 ~= 1.9787585683775426) discrepancy =6.1122e-07
# position281 successfully calculated (1.9883844671722182499349796931410455589662162051459 ~= 1.9883833829702624) discrepancy =5.45268e-07

# %%
for i, position in enumerate(borrower_data):
    # print(list(position['config'].keys()))
    if position['config']['assets']['Polkadot']['scaledVariableDebt'] > 0:
        collateral = [tkn for tkn in position['config']['assets'] if position['config']['assets'][tkn]['usageAsCollateralEnabledOnUser']][0]
        if collateral == 'USDC' or collateral == 'Tether USD':
            print(f"position {i}")
            print_position(position)
# Out:
# position 38
# Hydration Account:  7P7jA7dPQ8rMdhnU4oUkL3PFTkXrhvsFCT4oE8vzeZCK8KoH
# availableBorrowsBase:  205.4611937
# borrower:  0xf42fC37ca29f3BA9Ceb2E0f28Ea6B450a2F3caBd
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  2125317531
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  2859244891
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  230038770
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  667160
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  97240
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  4076587237271
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  31344177790
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 83.39
# healthFactor 1.176523811327065
# calculated health factor 1.1765242163180667715935057205550874551052251199284
# discrepancy: 0.00000034422677875309556887278637899121820115142530049687
# ltv 75.39
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 4553.95742949
# totalDebtBase 3227.76731239
# updated 1741296062166
#
# ---------------------------------------------------
# position 39
# Hydration Account:  7P7jA7dPQ8rMdhnU4oUkL3PFTkXrhvsFCT4oE8vzeZCK8KoH
# availableBorrowsBase:  205.4611937
# borrower:  0xf42fC37ca29f3BA9Ceb2E0f28Ea6B450a2F3caBd
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  2125317531
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  2859244891
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  230038770
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  667160
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  97240
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  4076587237271
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  31344177790
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 83.39
# healthFactor 1.176523811327065
# calculated health factor 1.1765242163180667715935057205550874551052251199284
# discrepancy: 0.00000034422677875309556887278637899121820115142530049687
# ltv 75.39
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 4553.95742949
# totalDebtBase 3227.76731239
# updated 1741296062181
#
# ---------------------------------------------------
# position 103
# Hydration Account:  7JCmEdYEruZ6eQAoLRpU6btAyEcdjFpgDiusjqhyd4cKtB7D
# availableBorrowsBase:  3510.04116903
# borrower:  0x1ad9d16cE64De2dF5b556e1C0Cf58b8428e6CE66
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  99115124
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  50970947075334
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  50700000000000
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 90
# healthFactor 1.2982103478204132
# calculated health factor 1.2982106468037584465750473491332911082924573730968
# discrepancy: 0.00000023030423823416472818493772987899935020419695728812
# ltv 80
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 32884.66757509
# totalDebtBase 22797.69289104
# updated 1741296062676
#
# ---------------------------------------------------
# position 104
# Hydration Account:  7JCmEdYEruZ6eQAoLRpU6btAyEcdjFpgDiusjqhyd4cKtB7D
# availableBorrowsBase:  3510.04116903
# borrower:  0x1ad9d16cE64De2dF5b556e1C0Cf58b8428e6CE66
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  99115124
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  50970947075334
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  50700000000000
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 90
# healthFactor 1.2982103478204132
# calculated health factor 1.2982106468037584465750473491332911082924573730968
# discrepancy: 0.00000023030423823416472818493772987899935020419695728812
# ltv 80
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 32884.66757509
# totalDebtBase 22797.69289104
# updated 1741296062684
#
# ---------------------------------------------------
# position 132
# Hydration Account:  7KvJsBKC6HoYAfAWPjLV5yuj5nggXnKNvWogYfWF7AvLpV2M
# availableBorrowsBase:  234.71799118
# borrower:  0x66c596f1c28F95b4Dd3E5a7Be13233Dfe59f9aa2
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  296663208
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  36
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  240371479
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  313132
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  3165791434355
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  72133001
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  9276741
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 80
# healthFactor 1.370734849091733
# calculated health factor 1.3707362302130424510040075665785199696673695002045
# discrepancy: 0.000001007577293539394713900752996986576648597978409586
# ltv 75
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 1410.80695629
# totalDebtBase 823.38722604
# updated 1741296062820
#
# ---------------------------------------------------
# position 133
# Hydration Account:  7KvJsBKC6HoYAfAWPjLV5yuj5nggXnKNvWogYfWF7AvLpV2M
# availableBorrowsBase:  234.71799118
# borrower:  0x66c596f1c28F95b4Dd3E5a7Be13233Dfe59f9aa2
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  296663208
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  36
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  240371479
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  313132
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  3165791434355
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  72133001
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  9276741
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 80
# healthFactor 1.370734849091733
# calculated health factor 1.3707362302130424510040075665785199696673695002045
# discrepancy: 0.000001007577293539394713900752996986576648597978409586
# ltv 75
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 1410.80695629
# totalDebtBase 823.38722604
# updated 1741296062799
#
# ---------------------------------------------------
# position 180
# Hydration Account:  7KATdGahXrJwhsBUj9QSGzYe8GYMmkoKRGdDu2A2ayq6jiZC
# availableBorrowsBase:  29.2931427
# borrower:  0x10efd89D53F43e9afb0445d600c0091d9113B0Fe
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  73512971
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  74210877
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  201061835617
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 90
# healthFactor 1.4914549990950732
# calculated health factor 1.4914547677780718760562932455474011589764890174732
# discrepancy: 0.0000001550948580006335103643487183964304794559288070118
# ltv 80
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 149.02718007
# totalDebtBase 89.92860136
# updated 1741296063238
#
# ---------------------------------------------------
# position 223
# Hydration Account:  7Ni7k6VzmMamc5XixohFCmMYe6WYeqqgkqSGhupA8FMEhHFP
# availableBorrowsBase:  93.55165576
# borrower:  0xe22de79CE2C3638003710ED8D7E09E5f715E9A8E
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  360709438
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  442168890419
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 90
# healthFactor 1.6571666093192159
# calculated health factor 1.6571663019365138905942929867789810526279492725966
# discrepancy: 0.000000185486902927823595881384928008098598736860365818
# ltv 80
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 364.14977345
# totalDebtBase 197.768163
# updated 1741296063518
#
# ---------------------------------------------------
# position 224
# Hydration Account:  7Ni7k6VzmMamc5XixohFCmMYe6WYeqqgkqSGhupA8FMEhHFP
# availableBorrowsBase:  93.55165576
# borrower:  0xe22de79CE2C3638003710ED8D7E09E5f715E9A8E
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  360709438
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  442168890419
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 90
# healthFactor 1.6571666093192159
# calculated health factor 1.6571663019365138905942929867789810526279492725966
# discrepancy: 0.000000185486902927823595881384928008098598736860365818
# ltv 80
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 364.14977345
# totalDebtBase 197.768163
# updated 1741296063529
#
# ---------------------------------------------------
# position 267
# Hydration Account:  7LC47rMsqUGmbdT5xBNMAwEu77kGmKBdezwEmAiGmuqkcuyK
# availableBorrowsBase:  14642.15746381
# borrower:  0x72c7dF8B90146D5eCbB62aC78c68a35FA47C85e2
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  27947695077
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  8939403421
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  36939040681489
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  24995298805477
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  0
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 86.31
# healthFactor 1.9033536295943976
# calculated health factor 1.9033540336667586885903540121072131906402510540055
# discrepancy: 0.00000021229494867786607436959489075734416451929179375183
# ltv 78.15
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# 44635.65690048lBase
# totalDebtBase 20240.60840392
# updated 1741296063799
#
# ---------------------------------------------------
# position 273
# Hydration Account:  7MoZWBS265u3RBU4bZycmkvDspJim3tCZmzeqPGZagwqLnzj
# availableBorrowsBase:  6153.01345116
# borrower:  0xBa189d4F166aD6e387Dd42C40f60FdD49eD7BEc1
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  281636
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  4775315024
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  282869
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  21075346
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  873
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  58958
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  5023140818899
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  10402399688927
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 74.08
# healthFactor 1.9486099237237096
# calculated health factor 1.9486097340943877121580386570550973791260127476057
# discrepancy: 0.00000009731517813670101347193519658982017260702591115119
# ltv 64.08
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 23608.09072125
# totalDebtBase 8975.05108302
# updated 1741296063381
#
# ---------------------------------------------------
# position 274
# Hydration Account:  7MoZWBS265u3RBU4bZycmkvDspJim3tCZmzeqPGZagwqLnzj
# availableBorrowsBase:  6153.01345116
# borrower:  0xBa189d4F166aD6e387Dd42C40f60FdD49eD7BEc1
# config:
#     USDC:
#         underlyingAsset:  0x0000000000000000000000000000000100000016
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  281636
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Tether USD:
#         underlyingAsset:  0x000000000000000000000000000000010000000A
#         scaledATokenBalance:  4775315024
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  282869
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bitcoin (Moonbeam Wormhole):
#         underlyingAsset:  0x0000000000000000000000000000000100000013
#         scaledATokenBalance:  21075346
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  873
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Polkadot:
#         underlyingAsset:  0x0000000000000000000000000000000100000005
#         scaledATokenBalance:  58958
#         usageAsCollateralEnabledOnUser:  True
#         stableBorrowRate:  0
#         scaledVariableDebt:  5023140818899
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
#     Bifrost Voucher DOT:
#         underlyingAsset:  0x000000000000000000000000000000010000000F
#         scaledATokenBalance:  0
#         usageAsCollateralEnabledOnUser:  False
#         stableBorrowRate:  0
#         scaledVariableDebt:  10402399688927
#         principalStableDebt:  0
#         stableBorrowLastUpdateTimestamp:  0
# currentLiquidationThreshold 74.08
# healthFactor 1.9486099237237096
# calculated health factor 1.9486097340943877121580386570550973791260127476057
# discrepancy: 0.00000009731517813670101347193519658982017260702591115119
# ltv 64.08
# pool 0x1b02e051683b5cfac5929c25e84adb26ecf87b38
# totalCollateralBase 23608.09072125
# totalDebtBase 8975.05108302
# updated 1741296063821
#
# ---------------------------------------------------

# %%
position = borrower_data[51]
tokens = position['config']['assets']
collateral_tokens = [
    {
        'name': t,
        **reserves_data[t],
        **tokens[t]
    } for t in filter(lambda k: tokens[k]['usageAsCollateralEnabledOnUser'], tokens.keys())
]
debt_tokens = [
    {
        'name': t,
        **reserves_data[t],
        **tokens[t]
    } for t in filter(lambda k: tokens[k]['scaledVariableDebt'] > 0, tokens.keys())
]
c_tkn = collateral_tokens[0]
d_tkn = debt_tokens[0]
tkns = [reserves_data[t] for t in reserves_data]

liquidation_threshold = position['currentLiquidationThreshold'] / 100
health_factor = (
    mpf(c_tkn['scaledATokenBalance']) * c_tkn['priceInMarketReferenceCurrency'] * c_tkn['liquidityIndex'] / 10 ** c_tkn['decimals']
    * liquidation_threshold
    / (mpf(d_tkn['scaledVariableDebt']) * d_tkn['priceInMarketReferenceCurrency'] * d_tkn['variableBorrowIndex'] / 10 ** d_tkn['decimals'])
)

if abs(1 - health_factor / position['healthFactor']) > 0.00001:
    print(f"position ({i}) didn't work out:")
    # print_position(position)
    print(f"calculated health factor: {health_factor} vs actual: {position['healthFactor']}")
    if len(collateral_tokens) > 1:
        print(f"{len(collateral_tokens)} collateral tokens.")
    if len(debt_tokens) > 1:
        print(f"{len(debt_tokens)} debt tokens.")
    # break;
else:
    print(f"position{i} successfully calculated ({health_factor} ~= {position['healthFactor']})")
# Out:
# position281 successfully calculated (1.1948934404429765816124804519965736248156263235027 ~= 1.1948926225308778)

# %%
liquidation_threshold
# Out:
# 0.8

# %%
health_factor / position['healthFactor']
# Out:
# mpf('1.0000006845067777284340387197448684011506911042220093')

# %%
import sys
sys.path.append('../..')
from model.processing import get_omnipool_router
router = get_omnipool_router()
omnipool = router.exchanges['omnipool']

# %%
print(omnipool)
# Out:
# Omnipool: omnipool
# ********************************
# tvl cap: inf
# lrna fee:
#
#     4-Pool: 0.0005
#     KSM: 0.0005
#     HDX: 0.0005
#     KILT: 0.0005
#     WETH: 0.0005
#     2-Pool101: 0.0005
#     GLMR: 0.0005
#     iBTC11: 0.0005
#     BNC: 0.0005
#     WBTC19: 0.0005
#     RING: 0.0005
#     vASTR: 0.0005
#     vDOT: 0.0005
#     CFG: 0.0005
#     CRU: 0.0005
#     2-Pool102: 0.0005
#     DOT: 0.0005
#     AAVE: 0.0005
#     PHA: 0.0005
#     tBTC: 0.0005
#     ZTG: 0.0005
#     INTR: 0.0005
#     ASTR: 0.0005
#     SOL: 0.0005
#
# asset fee:
#
#     4-Pool: 0.0015
#     KSM: 0.018138
#     HDX: 0.0015
#     KILT: 0.001542
#     WETH: 0.0015
#     2-Pool101: 0.0015
#     GLMR: 0.0015
#     iBTC11: 0.0015
#     BNC: 0.0015
#     WBTC19: 0.0015
#     RING: 0.0015
#     vASTR: 0.0015
#     vDOT: 0.0015
#     CFG: 0.0015
#     CRU: 0.0015
#     2-Pool102: 0.0015
#     DOT: 0.0015
#     AAVE: 0.0015
#     PHA: 0.0015
#     tBTC: 0.0015
#     ZTG: 0.0015
#     INTR: 0.0015
#     ASTR: 0.0015
#     SOL: 0.0015
#
# asset pools: (
#
#     *4-Pool*
#     asset quantity: 1228212.0015933402
#     lrna quantity: 52686.45766326416
#     USD price: N/A
#     weight: 52686.45766326416/2104645.2923673685 (0.025033414349836046)
#     weight cap: 1
#     total shares: 1228212.0015933402
#     protocol shares: 1228212.0015933402
#
#     *KSM*
#     asset quantity: 33280.122912268074
#     lrna quantity: 25087.885900478665
#     USD price: N/A
#     weight: 25087.885900478665/2104645.2923673685 (0.011920244229021154)
#     weight cap: 1
#     total shares: 33280.122912268074
#     protocol shares: 33280.122912268074
#
#     *HDX*
#     asset quantity: 87810167.46729402
#     lrna quantity: 38891.6688736501
#     USD price: N/A
#     weight: 38891.6688736501/2104645.2923673685 (0.018478966035128695)
#     weight cap: 1
#     total shares: 87810167.46729402
#     protocol shares: 87810167.46729402
#
#     *KILT*
#     asset quantity: 4251473.338988221
#     lrna quantity: 10144.610193098866
#     USD price: N/A
#     weight: 10144.610193098866/2104645.2923673685 (0.004820104475508983)
#     weight cap: 1
#     total shares: 4251473.338988221
#     protocol shares: 4251473.338988221
#
#     *WETH*
#     asset quantity: 894.395051478857
#     lrna quantity: 82339.65359304032
#     USD price: N/A
#     weight: 82339.65359304032/2104645.2923673685 (0.03912281746080937)
#     weight cap: 1
#     total shares: 894.3950514788573
#     protocol shares: 894.3950514788573
#
#     *2-Pool101*
#     asset quantity: 0.499509069805
#     lrna quantity: 1743.756342571039
#     USD price: N/A
#     weight: 1743.756342571039/2104645.2923673685 (0.0008285274240247911)
#     weight cap: 1
#     total shares: 0.4995090698049652
#     protocol shares: 0.4995090698049652
#
#     *GLMR*
#     asset quantity: 14783301.760995062
#     lrna quantity: 62791.26552131091
#     USD price: N/A
#     weight: 62791.26552131091/2104645.2923673685 (0.029834607165885613)
#     weight cap: 1
#     total shares: 14783301.760995062
#     protocol shares: 14783301.760995062
#
#     *iBTC11*
#     asset quantity: 9.8357352
#     lrna quantity: 36474.60517255334
#     USD price: N/A
#     weight: 36474.60517255334/2104645.2923673685 (0.017330523725223836)
#     weight cap: 1
#     total shares: 9.8357352
#     protocol shares: 9.8357352
#
#     *BNC*
#     asset quantity: 5545928.84830644
#     lrna quantity: 38669.678087767206
#     USD price: N/A
#     weight: 38669.678087767206/2104645.2923673685 (0.018373489455921755)
#     weight cap: 1
#     total shares: 5545928.84830644
#     protocol shares: 5545928.84830644
#
#     *WBTC19*
#     asset quantity: 9.69070459
#     lrna quantity: 36107.73660670248
#     USD price: N/A
#     weight: 36107.73660670248/2104645.2923673685 (0.01715620999778419)
#     weight cap: 1
#     total shares: 9.69070459
#     protocol shares: 9.69070459
#
#     *RING*
#     asset quantity: 33443366.423708465
#     lrna quantity: 1818.910478950926
#     USD price: N/A
#     weight: 1818.910478950926/2104645.2923673685 (0.0008642361188117171)
#     weight cap: 1
#     total shares: 33443366.423708465
#     protocol shares: 33443366.423708465
#
#     *vASTR*
#     asset quantity: 7407870.794786034
#     lrna quantity: 12346.693992672337
#     USD price: N/A
#     weight: 12346.693992672337/2104645.2923673685 (0.005866401353923351)
#     weight cap: 1
#     total shares: 7407870.794786034
#     protocol shares: 7407870.794786034
#
#     *vDOT*
#     asset quantity: 987598.5404234627
#     lrna quantity: 267321.97578111675
#     USD price: N/A
#     weight: 267321.97578111675/2104645.2923673685 (0.12701521569956567)
#     weight cap: 1
#     total shares: 987598.5404234627
#     protocol shares: 987598.5404234627
#
#     *CFG*
#     asset quantity: 5433625.310267792
#     lrna quantity: 33739.01944147824
#     USD price: N/A
#     weight: 33739.01944147824/2104645.2923673685 (0.01603073903419021)
#     weight cap: 1
#     total shares: 5433625.310267792
#     protocol shares: 5433625.310267792
#
#     *CRU*
#     asset quantity: 439685.02839650115
#     lrna quantity: 2834.772320263488
#     USD price: N/A
#     weight: 2834.772320263488/2104645.2923673685 (0.0013469121521540812)
#     weight cap: 1
#     total shares: 439685.02839650115
#     protocol shares: 439685.02839650115
#
#     *2-Pool102*
#     asset quantity: 15000771.440712238
#     lrna quantity: 630587.8687387143
#     USD price: N/A
#     weight: 630587.8687387143/2104645.2923673685 (0.29961717113357855)
#     weight cap: 1
#     total shares: 15000771.440712238
#     protocol shares: 15000771.440712238
#
#     *DOT*
#     asset quantity: 2819466.2056328724
#     lrna quantity: 521701.9379041839
#     USD price: N/A
#     weight: 521701.9379041839/2104645.2923673685 (0.24788117018871045)
#     weight cap: 1
#     total shares: 2819466.2056328724
#     protocol shares: 2819466.2056328724
#
#     *AAVE*
#     asset quantity: 2314.52540862911
#     lrna quantity: 20522.71896976584
#     USD price: N/A
#     weight: 20522.71896976584/2104645.2923673685 (0.00975115333885135)
#     weight cap: 1
#     total shares: 2314.52540862911
#     protocol shares: 2314.52540862911
#
#     *PHA*
#     asset quantity: 5317370.126217712
#     lrna quantity: 28792.066321452396
#     USD price: N/A
#     weight: 28792.066321452396/2104645.2923673685 (0.01368024646522085)
#     weight cap: 1
#     total shares: 5317370.126217712
#     protocol shares: 5317370.126217712
#
#     *tBTC*
#     asset quantity: 28.052285745318
#     lrna quantity: 104503.3209359538
#     USD price: N/A
#     weight: 104503.3209359538/2104645.2923673685 (0.04965365010196341)
#     weight cap: 1
#     total shares: 28.052285745317707
#     protocol shares: 28.052285745317707
#
#     *ZTG*
#     asset quantity: 8471819.329012513
#     lrna quantity: 3615.429649462205
#     USD price: N/A
#     weight: 3615.429649462205/2104645.2923673685 (0.001717833243717501)
#     weight cap: 1
#     total shares: 8471819.329012513
#     protocol shares: 8471819.329012513
#
#     *INTR*
#     asset quantity: 67424478.99982455
#     lrna quantity: 14158.298611689113
#     USD price: N/A
#     weight: 14158.298611689113/2104645.2923673685 (0.006727166170487299)
#     weight cap: 1
#     total shares: 67424478.99982455
#     protocol shares: 67424478.99982455
#
#     *ASTR*
#     asset quantity: 52430826.784420006
#     lrna quantity: 73470.66369567781
#     USD price: N/A
#     weight: 73470.66369567781/2104645.2923673685 (0.03490881050698847)
#     weight cap: 1
#     total shares: 52430826.784420006
#     protocol shares: 52430826.784420006
#
#     *SOL*
#     asset quantity: 712.137581411
#     lrna quantity: 4294.297571550102
#     USD price: N/A
#     weight: 4294.297571550102/2104645.2923673685 (0.00204039017269259)
#     weight cap: 1
#     total shares: 712.137581411
#     protocol shares: 712.137581411
#
# )
# sub pools: (
#
#
# )
# oracles: (
#     name: price
#     length: 9
#
# )
#
# error message: None

# %% [raw]
# from model.amm.money_market import MoneyMarket, CDP
# money_market = MoneyMarket(
#     liquidity: {asset['name']: asset['availableLiquidity'] / 10 ** asset['decimals'] for asset in reserves_data.values()},
#     oracles: omnipool.oracles,
#     liquidation_threshold: {asset['name']: asset['reserveLiquidiationThreshold']},
#     min_ltv: {asset['name']: asset['baseLTVasCollateral'] for asset in reserves_data.values()},
#     liquidation_penalty: float or dict[str: float] = 0.01,
#     cdps: list = None,
#     full_liquidation_threshold: float or dict[str: float] = None,
#     partial_liquidation_pct: float = 0.5
# ):
